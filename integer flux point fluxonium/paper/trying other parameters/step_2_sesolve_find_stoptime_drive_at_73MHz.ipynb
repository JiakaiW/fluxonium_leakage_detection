# %%
from utils import *

# %%
system = fluxonium_oscillator_system(
    EJ = 2.6,
    EC = 0.75,
    EL = 0.15,
    Er = 7.18642578,
    g_strength = 0.6,
    qubit_level = 30,
    osc_level = 50,
    # kappa = 0.001,
    products_to_keep=[[ql, ol] for ql in [1,2,3] for ol in range(40) ] \
                    + [[ql, ol] for ql in [0] for ol in range(60) ]
    )

system.w_d = system.w_d
# Out:
# max overlap^2 0.015132696727727837 below threshold for dressed state 1459 with eval 362.13070974545633
# max overlap^2 0.0020673131857199332 below threshold for dressed state 1464 with eval 363.46556748359524
# max overlap^2 0.002674460974560965 below threshold for dressed state 1471 with eval 365.9434786247224
# max overlap^2 0.008168823400765742 below threshold for dressed state 1472 with eval 366.54050221921057
# max overlap^2 0.004702741697277767 below threshold for dressed state 1473 with eval 367.2096129972191
# max overlap^2 0.01041580310931379 below threshold for dressed state 1474 with eval 367.53236253067325
# max overlap^2 0.009335882056643797 below threshold for dressed state 1475 with eval 368.3337234691371
# max overlap^2 0.0028262250815246567 below threshold for dressed state 1476 with eval 368.54214383165373
# max overlap^2 0.0016315609255132073 below threshold for dressed state 1478 with eval 369.8053215151943
# max overlap^2 0.01655080110015219 below threshold for dressed state 1479 with eval 370.0686007461274
# max overlap^2 0.0005236868199632656 below threshold for dressed state 1480 with eval 370.90287974080525
# max overlap^2 2.4899211181938033e-07 below threshold for dressed state 1481 with eval 371.09920996988626
# max overlap^2 9.717105985906001e-07 below threshold for dressed state 1483 with eval 372.10646565591827
# max overlap^2 3.794663490506651e-17 below threshold for dressed state 1484 with eval 372.5604449023476
# max overlap^2 3.989493151094689e-17 below threshold for dressed state 1485 with eval 373.6478819948113
# max overlap^2 7.316790250568129e-22 below threshold for dressed state 1486 with eval 374.7454707834926
# max overlap^2 1.684999663724613e-14 below threshold for dressed state 1487 with eval 374.9752178999474
# max overlap^2 0.0 below threshold for dressed state 1488 with eval 374.97947821492824
# max overlap^2 7.506895581751551e-21 below threshold for dressed state 1489 with eval 375.7162812661347
# max overlap^2 0.0 below threshold for dressed state 1490 with eval 376.6141963812474
# max overlap^2 0.0 below threshold for dressed state 1491 with eval 377.41620691046245
# max overlap^2 0.0 below threshold for dressed state 1492 with eval 378.6766047097419
# max overlap^2 0.0 below threshold for dressed state 1493 with eval 379.2904455832549
# max overlap^2 0.0 below threshold for dressed state 1494 with eval 381.21209258088766
# max overlap^2 0.0 below threshold for dressed state 1495 with eval 381.4216031222926
# max overlap^2 0.0 below threshold for dressed state 1496 with eval 384.24062762465843
# max overlap^2 0.0 below threshold for dressed state 1497 with eval 384.2931224347083
# max overlap^2 0.0 below threshold for dressed state 1498 with eval 388.1737043384515
# max overlap^2 0.0 below threshold for dressed state 1499 with eval 388.18741995747337

# %%
tot_time =500
tlist = np.linspace(0, tot_time, tot_time)

results = system.run_mesolve_on_driving_osc(
    intial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(i, 0)])) for i in range(4)],
    tlist = tlist,
    osc_decay = False,
    amp = 0.004,
)


# import pickle
# with open('pickles/sesolve_detection_results.pkl', 'wb') as file:
#     pickle.dump(results, file)

# with open('pickles/sesolve_detection_results.pkl', 'rb') as file:
#     results = pickle.load(file)
# Out:
#  Total run time: 421.07s*] Elapsed 421.07s / Remaining 00:00:00:00          0%           ] Elapsed 0.00s / Remaining 00:00:00:00
#  Total run time: 421.78s*] Elapsed 421.78s / Remaining 00:00:00:00
#  Total run time: 421.91s*] Elapsed 421.91s / Remaining 00:00:00:00
#  Total run time: 693.64s*] Elapsed 693.64s / Remaining 00:00:00:00
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/jiakaiwang/opt/miniconda3/envs/tensorflow/lib/python3.10/concurrent/futures/process.py", line 246, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "/Users/jiakaiwang/Downloads/erasure_hardware_sim/integer flux point fluxonium/paper/utils.py", line 215, in mesolve_and_pad
#     padded_states = [pad_back_custom(state, products_to_keep, product_to_dressed) for state in result.states]
#   File "/Users/jiakaiwang/Downloads/erasure_hardware_sim/integer flux point fluxonium/paper/utils.py", line 215, in <listcomp>
#     padded_states = [pad_back_custom(state, products_to_keep, product_to_dressed) for state in result.states]
#   File "/Users/jiakaiwang/Downloads/erasure_hardware_sim/integer flux point fluxonium/paper/utils.py", line 246, in pad_back_custom
#     full_dimension = max(product_to_dressed.values()) + 1
# TypeError: '>' not supported between instances of 'NoneType' and 'int'
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       1 tot_time =500
#       2 tlist = np.linspace(0, tot_time, tot_time)
# ----> 4 results = system.run_mesolve_on_driving_osc(
#       5     intial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(i, 0)])) for i in range(4)],
#       6     tlist = tlist,
#       7     osc_decay = False,
#       8     amp = 0.004,
#       9 )
#      12 # import pickle
#      13 # with open('pickles/sesolve_detection_results.pkl', 'wb') as file:
#      14 #     pickle.dump(results, file)
#      15
#      16 # with open('pickles/sesolve_detection_results.pkl', 'rb') as file:
#      17 #     results = pickle.load(file)
#
# File ~/Downloads/erasure_hardware_sim/integer flux point fluxonium/paper/utils.py:127, in fluxonium_oscillator_system.run_mesolve_on_driving_osc(self, intial_states, tlist, osc_decay, e_ops, amp, max_workers, t_stop)
#     125     for future in concurrent.futures.as_completed(futures):
#     126         original_index = futures[future]
# --> 127         results[original_index] = future.result()
#     129 return results
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# TypeError: '>' not supported between instances of 'NoneType' and 'int'

# %%
plot_population(results,
                system.qbt.truncated_dim,
                system.osc.truncated_dim,
                system.product_to_dressed,
                system.a,
                system.w_d,
                tlist,
                fourier=True,
                fix_ylim=True,
                plot_only_pn_alpha= True)
# Out:
# ComplexWarning: Casting complex values to real discards the imaginary part
#  /Users/jiakaiwang/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/array.py: 343

# %%
interactive_heatmap(results[0], system.product_to_dressed, system.qubit_level, system.osc_level)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Time Index:', max=999), Output(…

# %%
def get_pn_expect(result,a):
    pn_op = jnp.array((a.dag()*a).full())

    # Vectorize the function compute_expectation over the kets
    vectorized_compute_expectation = vmap(compute_expectation, in_axes=(0, None))
    vectorized_compute_expectation = jit(vectorized_compute_expectation)

    if hasattr(result, 'y'):
        states = jnp.array(result.y)  # assuming y contains JAX arrays or density matrices
    elif hasattr(result, 'states'):
        states = jnp.stack([jnp.array(q.full()) for q in result.states])  # assuming states contains QObj or density matrices

    pns_expect = vectorized_compute_expectation(states, pn_op)
    return pns_expect

pn_exp_one = get_pn_expect(results[1],system.a)
pn_exp_two = get_pn_expect(results[2],system.a)

plt.plot(pn_exp_one)
plt.plot(pn_exp_two)
# Out:
# ComplexWarning: Casting complex values to real discards the imaginary part
#  /Users/jiakaiwang/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/array.py: 343

# %%
def find_valley_index(values):
    # First, find the index of the peak
    peak_index = 0
    for i in range(1, len(values)):
        if values[i] < values[i - 1]:
            peak_index = i - 1
            break

    # Next, find the minimum value after the peak
    valley_index = peak_index + values[peak_index:].index(min(values[peak_index:]))

    return valley_index

index_of_valley_1 = find_valley_index(list(pn_exp_one))
index_of_valley_2 = find_valley_index(list(pn_exp_two))
index_of_valley_1, index_of_valley_2
# Out:
# (478, 470)

# %%
plt.plot(pn_exp_one)
plt.plot(pn_exp_two)
plt.xlim(min(index_of_valley_2,index_of_valley_1),max(index_of_valley_2,index_of_valley_1))
plt.ylim(0,0.01)
# Out:
# ComplexWarning: Casting complex values to real discards the imaginary part
#  /Users/jiakaiwang/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/array.py: 343
# (0.0, 0.01)

# %%
plt.figure(figsize=(6,6))

first_dominant_freq = find_dominant_frequency(results[0].expect[0],tlist)
 
def plot_husimi_probability_contours(dressed_state,product_to_dressed,qubit_level,osc_level):
    if dressed_state.dims[-1][0] == 1:
        dressed_state = qutip.ket2dm(dressed_state)
    dressed_dm_data = dressed_state.full()
    rho_product = np.zeros((qubit_level * osc_level, qubit_level * osc_level), dtype=complex)
    for (ql, ol), dressed_level in product_to_dressed.items():
        index1 = ql * osc_level + ol
        # Loop again to populate the density matrix
        for (ql2, ol2), dressed_level2 in product_to_dressed.items():
            index2 = ql2 * osc_level + ol2
            # TODO  the order of product_state and product_state2 doesn't make sense to me, but it produces the right result. :(
            element = dressed_dm_data[dressed_level, dressed_level2]
            rho_product[index1, index2] += element
    rho_product = qutip.Qobj(rho_product, dims=[[qubit_level, osc_level], [qubit_level, osc_level]])
    rho_coherent = rho_product.ptrace(1)

    # print(f"nonhermicity: abs(rho_coherent - rho_coherent.dag()).data.max() {abs(rho_coherent - rho_coherent.dag()).data.max()}")
    print(f"nonhermicity: Frobenius norm of the difference between rho and rho dag {np.linalg.norm((rho_coherent - rho_coherent.dag()).full(), 'fro')}")
    rho_coherent = 0.5 * (rho_coherent + rho_coherent.dag())

    print(f"trace: {rho_coherent.tr()}")
    rho_coherent = rho_coherent / rho_coherent.tr()


    xvec = np.linspace(-20,20,500)

    Q_coherent = qutip.qfunc(rho_coherent, xvec, xvec)

    q_values = Q_coherent
    sorted_q = np.sort(q_values.ravel())
    cumulative_sum = np.cumsum(sorted_q)
    total_sum = cumulative_sum[-1]
    X, Y = np.meshgrid(xvec, xvec)
    for prob in [0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1,0.05,0.02]:
        level_value = sorted_q[np.argmax(cumulative_sum >= total_sum * (1 - prob))]
        contour = plt.contour(X, Y, q_values, levels=[level_value], colors=[(prob, 0, 0, 1)])
        fmt = {level_value:f'{1 - prob:.2f}'}
        plt.clabel(contour, inline=False, fontsize=6, fmt=fmt)

    # Q_coherent[Q_coherent < sorted_q[np.argmax(cumulative_sum >= total_sum * (1 - 0.98))]] = None
    # plt.contourf(xvec, xvec, Q_coherent, 100)

alpha = results[0].expect[-2]*np.exp(-1j * 2 * np.pi * first_dominant_freq * tlist)
line, = plt.plot(-alpha.imag,alpha.real)

alpha = results[1].expect[-2]*np.exp(-1j * 2 * np.pi * first_dominant_freq * tlist)
line, = plt.plot(-alpha.imag,alpha.real)



t_idx = 250
plot_husimi_probability_contours(dressed_state=results[0].states[t_idx],
                                 product_to_dressed=system.product_to_dressed,
                                 qubit_level = system.qubit_level,
                                 osc_level = system.osc_level)
plot_husimi_probability_contours(dressed_state=results[1].states[t_idx],
                                 product_to_dressed=system.product_to_dressed,
                                 qubit_level = system.qubit_level,
                                 osc_level = system.osc_level)

plt.title("Probability Contours and values of the Husimi Q Function")
plt.xlabel("X")
plt.ylabel("Y")
plt.xlim(-8,8)
plt.ylim(-8,8)

plt.show()
# Out:
# nonhermicity: Frobenius norm of the difference between rho and rho dag 0.0
# trace: 0.9999999999847279
# nonhermicity: Frobenius norm of the difference between rho and rho dag 0.0
# trace: 0.9999999999936757

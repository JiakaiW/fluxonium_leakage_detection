# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
sys.path.append('../')
from utils_models import *

# %%
EJ = 2.65
EC = 0.6
EL = 0.13

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [1.8]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1.9299579100406916e-06
#              x: [ 1.782e+00]
#            nit: 11
#           nfev: 22
#  final_simplex: (array([[ 1.782e+00],
#                        [ 1.782e+00]]), array([ 1.930e-06,  7.675e-06]))
# Optimal solution: [1.7821582]
# Objective value: 1.9299579100406916e-06

# %%
max_ol = 30
max_ql = 25
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.15
system = FluxoniumOscillatorSystem(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# max overlap^2 0.08829154627805438 below threshold for dressed state 690 with eval 59.328458255048695
# max overlap^2 0.0363742172976471 below threshold for dressed state 701 with eval 60.716879237485074
# max overlap^2 0.0206841189970838 below threshold for dressed state 706 with eval 61.15298971323769
# max overlap^2 0.03755175257852629 below threshold for dressed state 707 with eval 61.62088316570066
# max overlap^2 0.04880097646599854 below threshold for dressed state 709 with eval 61.800021786037185
# max overlap^2 0.02055732826083605 below threshold for dressed state 712 with eval 61.94553444316934
# max overlap^2 0.05199759367619539 below threshold for dressed state 714 with eval 62.44744241550704
# max overlap^2 0.07064309631214183 below threshold for dressed state 715 with eval 62.71388618720129
# max overlap^2 0.019025980815652474 below threshold for dressed state 718 with eval 62.8097138431814
# max overlap^2 0.05217803094981489 below threshold for dressed state 719 with eval 63.2154307350669
# max overlap^2 0.025221043476623888 below threshold for dressed state 721 with eval 63.650191687954646
# max overlap^2 0.017804404373574067 below threshold for dressed state 723 with eval 63.726109416833665
# max overlap^2 0.005997345212696883 below threshold for dressed state 724 with eval 64.0476114527159
# max overlap^2 0.038652782097217606 below threshold for dressed state 727 with eval 64.58118213105125
# max overlap^2 0.01467199809165949 below threshold for dressed state 728 with eval 64.66168492909677
# max overlap^2 0.005795033363190874 below threshold for dressed state 729 with eval 64.95757111905658
# max overlap^2 0.043502537385408484 below threshold for dressed state 731 with eval 65.49625117712034
# max overlap^2 0.011787283886845884 below threshold for dressed state 732 with eval 65.6065101710678
# max overlap^2 0.021419264579707633 below threshold for dressed state 733 with eval 65.8949966825812
# max overlap^2 0.03761680229616051 below threshold for dressed state 734 with eval 65.94159726295334
# max overlap^2 0.03377052967771787 below threshold for dressed state 735 with eval 66.37032363773844
# max overlap^2 0.00988127231735799 below threshold for dressed state 736 with eval 66.55417679919299
# max overlap^2 0.006239871890396081 below threshold for dressed state 737 with eval 66.84604757657438
# max overlap^2 0.03362215077205216 below threshold for dressed state 738 with eval 67.13455336608855
# max overlap^2 0.009222287751382889 below threshold for dressed state 739 with eval 67.48535329413596
# max overlap^2 0.008073893284486674 below threshold for dressed state 740 with eval 67.73584672969703
# max overlap^2 0.00026398837581055064 below threshold for dressed state 741 with eval 67.8079471186589
# max overlap^2 6.689804554523234e-05 below threshold for dressed state 742 with eval 68.37176732251524
# max overlap^2 1.6554747253498216e-05 below threshold for dressed state 743 with eval 68.76567789904982
# max overlap^2 1.944201629699088e-07 below threshold for dressed state 744 with eval 69.1370314571523
# max overlap^2 7.67925741067835e-10 below threshold for dressed state 745 with eval 69.57130190681752
# max overlap^2 2.7296356341650254e-15 below threshold for dressed state 746 with eval 69.78927688988287
# max overlap^2 5.01981198915499e-13 below threshold for dressed state 747 with eval 70.62577502949955
# max overlap^2 4.201338586946726e-21 below threshold for dressed state 748 with eval 71.4694646839422
# max overlap^2 3.3563356002484723e-19 below threshold for dressed state 749 with eval 71.81110540679435
#
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.021105538589859973
# qbt freq at osc 1:	0.02117, 	diff to at osc ground 0.00007, 0.3140% diff
# qbt freq at osc 2:	0.02098, 	diff to at osc ground -0.00013, 0.5988% diff
# qbt freq at osc 3:	0.02075, 	diff to at osc ground -0.00035, 1.6655% diff
# qbt freq at osc 4:	0.02056, 	diff to at osc ground -0.00054, 2.5670% diff
# qbt freq at osc 5:	0.02043, 	diff to at osc ground -0.00067, 3.1842% diff
# qbt freq at osc 6:	0.02037, 	diff to at osc ground -0.00073, 3.4677% diff
# qbt freq at osc 7:	0.02039, 	diff to at osc ground -0.00072, 3.3970% diff
# qbt freq at osc 8:	0.02048, 	diff to at osc ground -0.00063, 2.9644% diff
# qbt freq at osc 9:	0.02065, 	diff to at osc ground -0.00046, 2.1679% diff
# qbt freq at osc 10:	0.02089, 	diff to at osc ground -0.00021, 1.0074% diff
# qbt freq at osc 11:	0.02121, 	diff to at osc ground 0.00011, 0.5175% diff
# qbt freq at osc 12:	0.02161, 	diff to at osc ground 0.00051, 2.4095% diff
# qbt freq at osc 13:	0.02209, 	diff to at osc ground 0.00099, 4.6744% diff
# qbt freq at osc 14:	0.02265, 	diff to at osc ground 0.00155, 7.3229% diff
# qbt freq at osc 15:	0.02329, 	diff to at osc ground 0.00219, 10.3722% diff
# qbt freq at osc 16:	0.02403, 	diff to at osc ground 0.00292, 13.8469% diff
# qbt freq at osc 17:	0.02486, 	diff to at osc ground 0.00375, 17.7808% diff
# qbt freq at osc 18:	0.02579, 	diff to at osc ground 0.00469, 22.2180% diff
# qbt freq at osc 19:	0.02685, 	diff to at osc ground 0.00574, 27.2130% diff
# qbt freq at osc 20:	0.02803, 	diff to at osc ground 0.00693, 32.8292% diff
# qbt freq at osc 21:	0.02937, 	diff to at osc ground 0.00826, 39.1341% diff
# qbt freq at osc 22:	0.03085, 	diff to at osc ground 0.00975, 46.1916% diff
# qbt freq at osc 23:	0.03251, 	diff to at osc ground 0.01141, 54.0508% diff
# qbt freq at osc 24:	0.03435, 	diff to at osc ground 0.01324, 62.7355% diff
# qbt freq at osc 25:	0.03635, 	diff to at osc ground 0.01525, 72.2375% diff
# qbt freq at osc 26:	0.03852, 	diff to at osc ground 0.01742, 82.5171% diff
# qbt freq at osc 27:	0.04084, 	diff to at osc ground 0.01973, 93.5023% diff
# qbt freq at osc 28:	0.04313, 	diff to at osc ground 0.02202, 104.3548% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	1.77838	1.77901	1.77907	1.81172
# oscillator transition 1-2: 	1.77838	1.77894	1.77875	1.80464  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 3.557893905270504e-06
# oscillator transition 2-3: 	1.77839	1.77888	1.77865	1.80108  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 8.314655123076165e-06
# oscillator transition 3-4: 	1.77839	1.77882	1.77863	1.79881  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 1.4445081176539531e-05
# oscillator transition 4-5: 	1.77840	1.77876	1.77863	1.79720  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 2.2163368400107686e-05
# oscillator transition 5-6: 	1.77841	1.77871	1.77865	1.79597  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 3.173820781388059e-05
# oscillator transition 6-7: 	1.77842	1.77867	1.77868	1.79499  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 4.3512902382580876e-05
# oscillator transition 7-8: 	1.77844	1.77862	1.77872	1.79418  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 5.79329037373455e-05
# oscillator transition 8-9: 	1.77845	1.77859	1.77875	1.79350  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 7.558438314791971e-05
# oscillator transition 9-10: 	1.77848	1.77855	1.77880	1.79291  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 9.724936505239867e-05
# oscillator transition 10-11: 	1.77850	1.77852	1.77884	1.79241  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00012398602848318063
# oscillator transition 11-12: 	1.77854	1.77849	1.77889	1.79196  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00015724775696579485
# oscillator transition 12-13: 	1.77858	1.77847	1.77895	1.79156  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00019906261191504626
# oscillator transition 13-14: 	1.77863	1.77845	1.77901	1.79120  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00025230798020725587
# oscillator transition 14-15: 	1.77870	1.77844	1.77908	1.79087  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00032113574418968227
# oscillator transition 15-16: 	1.77879	1.77842	1.77916	1.79058  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004116334065136229
# oscillator transition 16-17: 	1.77891	1.77841	1.77924	1.79031  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00053284173813406
# oscillator transition 17-18: 	1.77908	1.77841	1.77934	1.79006  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006982568859781324
# oscillator transition 18-19: 	1.77931	1.77840	1.77946	1.78983  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000927794340110033
# oscillator transition 19-20: 	1.77963	1.77840	1.77959	1.78962  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0012494846098034529
# oscillator transition 20-21: 	1.78008	1.77840	1.77973	1.78942  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0016980401788897481
# oscillator transition 21-22: 	1.78068	1.77840	1.77989	1.78924  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.002303476604434529
# oscillator transition 22-23: 	1.78144	1.77841	1.78007	1.78906  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0030629076280730416
# oscillator transition 23-24: 	1.78229	1.77842	1.78025	1.78891  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003909637286642287
# oscillator transition 24-25: 	1.74729	1.77842	1.78043	1.78875  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.031087933875743268
# oscillator transition 25-26: 	1.78042	1.77844	1.78061	1.78861  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0020434232221999693
# oscillator transition 26-27: 	1.77989	1.77845	1.78077	1.78848  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015086538502613323
# oscillator transition 27-28: 	1.77966	1.77876	1.78105	1.78860  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0012831644243744833
# oscillator transition 28-29: 	1.79421	1.79607	1.79537	1.16361  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.015834316858405195
#
# 10-11: 1.7790, diff to 00-01: 0.0006263620971975747
# 20-21: 1.7791, diff to 00-01: 0.000692643050814068
# max overlap^2 0.08829154627805438 below threshold for dressed state 690 with eval 59.328458255048695
# max overlap^2 0.0363742172976471 below threshold for dressed state 701 with eval 60.716879237485074
# max overlap^2 0.0206841189970838 below threshold for dressed state 706 with eval 61.15298971323769
# max overlap^2 0.03755175257852629 below threshold for dressed state 707 with eval 61.62088316570066
# max overlap^2 0.04880097646599854 below threshold for dressed state 709 with eval 61.800021786037185
# max overlap^2 0.02055732826083605 below threshold for dressed state 712 with eval 61.94553444316934
# max overlap^2 0.05199759367619539 below threshold for dressed state 714 with eval 62.44744241550704
# max overlap^2 0.07064309631214183 below threshold for dressed state 715 with eval 62.71388618720129
# max overlap^2 0.019025980815652474 below threshold for dressed state 718 with eval 62.8097138431814
# max overlap^2 0.05217803094981489 below threshold for dressed state 719 with eval 63.2154307350669
# max overlap^2 0.025221043476623888 below threshold for dressed state 721 with eval 63.650191687954646
# max overlap^2 0.017804404373574067 below threshold for dressed state 723 with eval 63.726109416833665
# max overlap^2 0.005997345212696883 below threshold for dressed state 724 with eval 64.0476114527159
# max overlap^2 0.038652782097217606 below threshold for dressed state 727 with eval 64.58118213105125
# max overlap^2 0.01467199809165949 below threshold for dressed state 728 with eval 64.66168492909677
# max overlap^2 0.005795033363190874 below threshold for dressed state 729 with eval 64.95757111905658
# max overlap^2 0.043502537385408484 below threshold for dressed state 731 with eval 65.49625117712034
# max overlap^2 0.011787283886845884 below threshold for dressed state 732 with eval 65.6065101710678
# max overlap^2 0.021419264579707633 below threshold for dressed state 733 with eval 65.8949966825812
# max overlap^2 0.03761680229616051 below threshold for dressed state 734 with eval 65.94159726295334
# max overlap^2 0.03377052967771787 below threshold for dressed state 735 with eval 66.37032363773844
# max overlap^2 0.00988127231735799 below threshold for dressed state 736 with eval 66.55417679919299
# max overlap^2 0.006239871890396081 below threshold for dressed state 737 with eval 66.84604757657438
# max overlap^2 0.03362215077205216 below threshold for dressed state 738 with eval 67.13455336608855
# max overlap^2 0.009222287751382889 below threshold for dressed state 739 with eval 67.48535329413596
# max overlap^2 0.008073893284486674 below threshold for dressed state 740 with eval 67.73584672969703
# max overlap^2 0.00026398837581055064 below threshold for dressed state 741 with eval 67.8079471186589
# max overlap^2 6.689804554523234e-05 below threshold for dressed state 742 with eval 68.37176732251524
# max overlap^2 1.6554747253498216e-05 below threshold for dressed state 743 with eval 68.76567789904982
# max overlap^2 1.944201629699088e-07 below threshold for dressed state 744 with eval 69.1370314571523
# max overlap^2 7.67925741067835e-10 below threshold for dressed state 745 with eval 69.57130190681752
# max overlap^2 2.7296356341650254e-15 below threshold for dressed state 746 with eval 69.78927688988287
# max overlap^2 5.01981198915499e-13 below threshold for dressed state 747 with eval 70.62577502949955
# max overlap^2 4.201338586946726e-21 below threshold for dressed state 748 with eval 71.4694646839422
# max overlap^2 3.3563356002484723e-19 below threshold for dressed state 749 with eval 71.81110540679435

# %%
plt.figure(figsize = (3,3))
n_osc_lvls = 20
dressed_osc_frequencies = [[] for _ in range(3)]
for j in [0,1,2]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [0,1,2]:
    plt.plot(list(range(max_ol-1))[:n_osc_lvls], dressed_osc_frequencies[j][:n_osc_lvls],label=rf'$\omega_{{{j},n+1}} - \omega_{{{j},n}}$')

plt.xticks(list(range(n_osc_lvls))[::2])
# plt.xticklabels([str(i) for i in range(n_osc_lvls)])
plt.legend(loc='lower right')

# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *

# %%
EJ = 2.33
EC = 0.69
EL = 0.12

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.15]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 6.98645748094251e-08
#              x: [ 7.165e+00]
#            nit: 13
#           nfev: 26
#  final_simplex: (array([[ 7.165e+00],
#                        [ 7.165e+00]]), array([ 6.986e-08,  2.176e-06]))
# Optimal solution: [7.16518677]
# Objective value: 6.98645748094251e-08

# %%
max_ol = 50
max_ql = 25
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.18
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.001,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  (non-linearity on qbt 0): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}  (non-linearity on qbt 3): {(dressed_ener(3,i+1)-dressed_ener(3,i))  -(dressed_ener(3,1)-dressed_ener(3,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
# plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.043449708308742174
# qbt freq at osc 1:	0.04345, 	diff to at osc ground -0.00000, 0.0094% diff
# qbt freq at osc 2:	0.04344, 	diff to at osc ground -0.00001, 0.0193% diff
# qbt freq at osc 3:	0.04344, 	diff to at osc ground -0.00001, 0.0297% diff
# qbt freq at osc 4:	0.04343, 	diff to at osc ground -0.00002, 0.0406% diff
# qbt freq at osc 5:	0.04343, 	diff to at osc ground -0.00002, 0.0521% diff
# qbt freq at osc 6:	0.04342, 	diff to at osc ground -0.00003, 0.0640% diff
# qbt freq at osc 7:	0.04342, 	diff to at osc ground -0.00003, 0.0766% diff
# qbt freq at osc 8:	0.04341, 	diff to at osc ground -0.00004, 0.0897% diff
# qbt freq at osc 9:	0.04340, 	diff to at osc ground -0.00004, 0.1034% diff
# qbt freq at osc 10:	0.04340, 	diff to at osc ground -0.00005, 0.1178% diff
# qbt freq at osc 11:	0.04339, 	diff to at osc ground -0.00006, 0.1328% diff
# qbt freq at osc 12:	0.04339, 	diff to at osc ground -0.00006, 0.1484% diff
# qbt freq at osc 13:	0.04338, 	diff to at osc ground -0.00007, 0.1647% diff
# qbt freq at osc 14:	0.04337, 	diff to at osc ground -0.00008, 0.1816% diff
# qbt freq at osc 15:	0.04336, 	diff to at osc ground -0.00009, 0.1993% diff
# qbt freq at osc 16:	0.04336, 	diff to at osc ground -0.00009, 0.2177% diff
# qbt freq at osc 17:	0.04335, 	diff to at osc ground -0.00010, 0.2368% diff
# qbt freq at osc 18:	0.04334, 	diff to at osc ground -0.00011, 0.2566% diff
# qbt freq at osc 19:	0.04333, 	diff to at osc ground -0.00012, 0.2772% diff
# qbt freq at osc 20:	0.04332, 	diff to at osc ground -0.00013, 0.2986% diff
# qbt freq at osc 21:	0.04331, 	diff to at osc ground -0.00014, 0.3208% diff
# qbt freq at osc 22:	0.04330, 	diff to at osc ground -0.00015, 0.3437% diff
# qbt freq at osc 23:	0.04329, 	diff to at osc ground -0.00016, 0.3675% diff
# qbt freq at osc 24:	0.04328, 	diff to at osc ground -0.00017, 0.3921% diff
# qbt freq at osc 25:	0.04327, 	diff to at osc ground -0.00018, 0.4176% diff
# qbt freq at osc 26:	0.04326, 	diff to at osc ground -0.00019, 0.4440% diff
# qbt freq at osc 27:	0.04324, 	diff to at osc ground -0.00020, 0.4712% diff
# qbt freq at osc 28:	0.04323, 	diff to at osc ground -0.00022, 0.4993% diff
# qbt freq at osc 29:	0.04322, 	diff to at osc ground -0.00023, 0.5283% diff
# qbt freq at osc 30:	0.04321, 	diff to at osc ground -0.00024, 0.5582% diff
# qbt freq at osc 31:	0.04319, 	diff to at osc ground -0.00026, 0.5891% diff
# qbt freq at osc 32:	0.04318, 	diff to at osc ground -0.00027, 0.6209% diff
# qbt freq at osc 33:	0.04317, 	diff to at osc ground -0.00028, 0.6537% diff
# qbt freq at osc 34:	0.04315, 	diff to at osc ground -0.00030, 0.6874% diff
# qbt freq at osc 35:	0.04314, 	diff to at osc ground -0.00031, 0.7222% diff
# qbt freq at osc 36:	0.04312, 	diff to at osc ground -0.00033, 0.7579% diff
# qbt freq at osc 37:	0.04310, 	diff to at osc ground -0.00035, 0.7946% diff
# qbt freq at osc 38:	0.04309, 	diff to at osc ground -0.00036, 0.8324% diff
# qbt freq at osc 39:	0.04307, 	diff to at osc ground -0.00038, 0.8712% diff
# qbt freq at osc 40:	0.04305, 	diff to at osc ground -0.00040, 0.9111% diff
# qbt freq at osc 41:	0.04304, 	diff to at osc ground -0.00041, 0.9520% diff
# qbt freq at osc 42:	0.04302, 	diff to at osc ground -0.00043, 0.9940% diff
# qbt freq at osc 43:	0.04300, 	diff to at osc ground -0.00045, 1.0371% diff
# qbt freq at osc 44:	0.04298, 	diff to at osc ground -0.00047, 1.0812% diff
# qbt freq at osc 45:	0.04296, 	diff to at osc ground -0.00049, 1.1265% diff
# qbt freq at osc 46:	0.04294, 	diff to at osc ground -0.00051, 1.1729% diff
# qbt freq at osc 47:	0.04292, 	diff to at osc ground -0.00053, 1.2203% diff
# qbt freq at osc 48:	0.04294, 	diff to at osc ground -0.00051, 1.1626% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.16474	7.16612	7.16611	7.16495
# oscillator transition 1-2: 	7.16474	7.16611	7.16611	7.16495  (non-linearity on qbt 0): -7.779310777777937e-07  (non-linearity on qbt 3): 2.509625016244854e-06
# oscillator transition 2-3: 	7.16474	7.16611	7.16611	7.16495  (non-linearity on qbt 0): -1.4553705067754663e-06  (non-linearity on qbt 3): 4.994660974588783e-06
# oscillator transition 3-4: 	7.16474	7.16611	7.16611	7.16495  (non-linearity on qbt 0): -2.0402892015880525e-06  (non-linearity on qbt 3): 7.455356373142763e-06
# oscillator transition 4-5: 	7.16474	7.16611	7.16611	7.16496  (non-linearity on qbt 0): -2.5399028960038095e-06  (non-linearity on qbt 3): 9.891958500318765e-06
# oscillator transition 5-6: 	7.16474	7.16611	7.16610	7.16496  (non-linearity on qbt 0): -2.960756573244794e-06  (non-linearity on qbt 3): 1.2304709835930794e-05
# oscillator transition 6-7: 	7.16474	7.16611	7.16610	7.16496  (non-linearity on qbt 0): -3.308793742107241e-06  (non-linearity on qbt 3): 1.4693852209646252e-05
# oscillator transition 7-8: 	7.16474	7.16611	7.16610	7.16496  (non-linearity on qbt 0): -3.589422446381718e-06  (non-linearity on qbt 3): 1.705962405118555e-05
# oscillator transition 8-9: 	7.16474	7.16611	7.16610	7.16497  (non-linearity on qbt 0): -3.8075702004647383e-06  (non-linearity on qbt 3): 1.9402261417056366e-05
# oscillator transition 9-10: 	7.16474	7.16610	7.16610	7.16497  (non-linearity on qbt 0): -3.967733603005286e-06  (non-linearity on qbt 3): 2.1721997748969102e-05
# oscillator transition 10-11: 	7.16474	7.16610	7.16610	7.16497  (non-linearity on qbt 0): -4.074021687117124e-06  (non-linearity on qbt 3): 2.4019064051472583e-05
# oscillator transition 11-12: 	7.16474	7.16610	7.16610	7.16497  (non-linearity on qbt 0): -4.130195646823154e-06  (non-linearity on qbt 3): 2.6293689709078194e-05
# oscillator transition 12-13: 	7.16474	7.16610	7.16609	7.16497  (non-linearity on qbt 0): -4.139702467043094e-06  (non-linearity on qbt 3): 2.854610029068283e-05
# oscillator transition 13-14: 	7.16474	7.16610	7.16609	7.16498  (non-linearity on qbt 0): -4.10570440401159e-06  (non-linearity on qbt 3): 3.077652073990578e-05
# oscillator transition 14-15: 	7.16474	7.16610	7.16609	7.16498  (non-linearity on qbt 0): -4.031108558066876e-06  (non-linearity on qbt 3): 3.298517226291153e-05
# oscillator transition 15-16: 	7.16474	7.16610	7.16609	7.16498  (non-linearity on qbt 0): -3.918589539964046e-06  (non-linearity on qbt 3): 3.5172274985839636e-05
# oscillator transition 16-17: 	7.16474	7.16610	7.16609	7.16498  (non-linearity on qbt 0): -3.77061053136174e-06  (non-linearity on qbt 3): 3.733804541106167e-05
# oscillator transition 17-18: 	7.16474	7.16609	7.16609	7.16499  (non-linearity on qbt 0): -3.589444700580202e-06  (non-linearity on qbt 3): 3.948269992726239e-05
# oscillator transition 18-19: 	7.16474	7.16609	7.16608	7.16499  (non-linearity on qbt 0): -3.37719012399873e-06  (non-linearity on qbt 3): 4.160645065987012e-05
# oscillator transition 19-20: 	7.16474	7.16609	7.16608	7.16499  (non-linearity on qbt 0): -3.1357878338411638e-06  (non-linearity on qbt 3): 4.370950976273491e-05
# oscillator transition 20-21: 	7.16474	7.16609	7.16608	7.16499  (non-linearity on qbt 0): -2.8670337410829916e-06  (non-linearity on qbt 3): 4.579208494170928e-05
# oscillator transition 21-22: 	7.16474	7.16609	7.16608	7.16499  (non-linearity on qbt 0): -2.5725914536423033e-06  (non-linearity on qbt 3): 4.785438373211548e-05
# oscillator transition 22-23: 	7.16474	7.16609	7.16608	7.16500  (non-linearity on qbt 0): -2.2540049524621963e-06  (non-linearity on qbt 3): 4.989660926391082e-05
# oscillator transition 23-24: 	7.16474	7.16609	7.16608	7.16500  (non-linearity on qbt 0): -1.9127079990965967e-06  (non-linearity on qbt 3): 5.1918967054476184e-05
# oscillator transition 24-25: 	7.16474	7.16609	7.16608	7.16500  (non-linearity on qbt 0): -1.5500330317053113e-06  (non-linearity on qbt 3): 5.392165742001964e-05
# oscillator transition 25-26: 	7.16474	7.16608	7.16607	7.16500  (non-linearity on qbt 0): -1.1672192936629244e-06  (non-linearity on qbt 3): 5.5904876811396775e-05
# oscillator transition 26-27: 	7.16474	7.16608	7.16607	7.16500  (non-linearity on qbt 0): -7.654218432406878e-07  (non-linearity on qbt 3): 5.786882494795975e-05
# oscillator transition 27-28: 	7.16474	7.16608	7.16607	7.16501  (non-linearity on qbt 0): -3.457173800569535e-07  (non-linearity on qbt 3): 5.981369606367082e-05
# oscillator transition 28-29: 	7.16474	7.16608	7.16607	7.16501  (non-linearity on qbt 0): 9.088970109871752e-08  (non-linearity on qbt 3): 6.173968260192453e-05
# oscillator transition 29-30: 	7.16474	7.16608	7.16607	7.16501  (non-linearity on qbt 0): 5.434615122368314e-07  (non-linearity on qbt 3): 6.364697683558518e-05
# oscillator transition 30-31: 	7.16474	7.16608	7.16607	7.16501  (non-linearity on qbt 0): 1.011121101512913e-06  (non-linearity on qbt 3): 6.553576927537108e-05
# oscillator transition 31-32: 	7.16474	7.16608	7.16606	7.16501  (non-linearity on qbt 0): 1.4930482752362195e-06  (non-linearity on qbt 3): 6.740624480450208e-05
# oscillator transition 32-33: 	7.16474	7.16608	7.16606	7.16501  (non-linearity on qbt 0): 1.9884737429975985e-06  (non-linearity on qbt 3): 6.925859273998469e-05
# oscillator transition 33-34: 	7.16474	7.16608	7.16606	7.16502  (non-linearity on qbt 0): 2.496678861874102e-06  (non-linearity on qbt 3): 7.109299483865072e-05
# oscillator transition 34-35: 	7.16474	7.16607	7.16606	7.16502  (non-linearity on qbt 0): 3.016987422554962e-06  (non-linearity on qbt 3): 7.290963476158652e-05
# oscillator transition 35-36: 	7.16474	7.16607	7.16606	7.16502  (non-linearity on qbt 0): 3.5487660756672312e-06  (non-linearity on qbt 3): 7.47086934129726e-05
# oscillator transition 36-37: 	7.16474	7.16607	7.16606	7.16502  (non-linearity on qbt 0): 4.091419841145694e-06  (non-linearity on qbt 3): 7.649034894008366e-05
# oscillator transition 37-38: 	7.16474	7.16607	7.16605	7.16502  (non-linearity on qbt 0): 4.644387788133031e-06  (non-linearity on qbt 3): 7.825478042811085e-05
# oscillator transition 38-39: 	7.16474	7.16607	7.16605	7.16503  (non-linearity on qbt 0): 5.2071444560652935e-06  (non-linearity on qbt 3): 8.000216048209552e-05
# oscillator transition 39-40: 	7.16475	7.16607	7.16605	7.16503  (non-linearity on qbt 0): 5.779194397703691e-06  (non-linearity on qbt 3): 8.17326682156505e-05
# oscillator transition 40-41: 	7.16475	7.16607	7.16605	7.16503  (non-linearity on qbt 0): 6.360069166433391e-06  (non-linearity on qbt 3): 8.344647091895752e-05
# oscillator transition 41-42: 	7.16475	7.16607	7.16605	7.16503  (non-linearity on qbt 0): 6.949330215277882e-06  (non-linearity on qbt 3): 8.514374321499929e-05
# oscillator transition 42-43: 	7.16475	7.16606	7.16605	7.16503  (non-linearity on qbt 0): 7.546561393567686e-06  (non-linearity on qbt 3): 8.682465205289702e-05
# oscillator transition 43-44: 	7.16475	7.16606	7.16604	7.16503  (non-linearity on qbt 0): 8.151370709086336e-06  (non-linearity on qbt 3): 8.848936711025601e-05
# oscillator transition 44-45: 	7.16475	7.16606	7.16604	7.16504  (non-linearity on qbt 0): 8.763399366173985e-06  (non-linearity on qbt 3): 9.01381657829603e-05
# oscillator transition 45-46: 	7.16475	7.16606	7.16604	7.16504  (non-linearity on qbt 0): 9.387077684053224e-06  (non-linearity on qbt 3): 9.18128192868295e-05
# oscillator transition 46-47: 	7.16475	7.16606	7.16604	7.16505  (non-linearity on qbt 0): 1.1463347847850969e-05  (non-linearity on qbt 3): 0.00010490160833320772
# oscillator transition 47-48: 	7.16503	7.16630	7.16632	7.16711  (non-linearity on qbt 0): 0.0002929432957348155  (non-linearity on qbt 3): 0.0021648825014697337
# oscillator transition 48-49: 	7.33684	7.20032	7.20524	7.31506  (non-linearity on qbt 0): 0.17210411927328728  (non-linearity on qbt 3): 0.15011513984411273
#
# 10-11: 7.1661, diff to 00-01: 0.0013753377235126152, diff to 30-31: 0.001169478965042714
# 20-21: 7.1661, diff to 00-01: 0.0013712428202765636, diff to 30-31: 0.0011653840618066624

# %%
import sys
sys.path.append('../')
from utils_models import *

w_d = 7.1648
def plot_frequencies_qbt_osc(dressed_ener: Callable, ols):
    colors = ['green', 'red', 'blue', 'orange']

    # Create a figure and a set of subplots
    fig, axs = plt.subplots(1, 2, figsize=(8, 4))  # Adjusted for better spacing

    # Second subplot for oscillator frequencies
    for ql in [0, 1, 2, 3]:
        osc_energies = []
        for ol in range(0, ols - 8):
            osc_energies.append(dressed_ener(ql, ol + 1) - dressed_ener(ql, ol))
        axs[0].plot(list(range(ols - 8)), osc_energies, label=f'{ql}', color=colors[ql])
    
    axs[0].plot([0,50],[w_d,w_d])

    axs[0].set_title('Oscillator Frequency vs Oscillator Level')
    axs[0].legend()



    qbt_energies = []
    for ol in range(ols-8):
        qbt_energies.append(dressed_ener(2, ol) - dressed_ener(1, ol))
    axs[1].plot(list(range(ols-8)), qbt_energies, label=f'qbt_freq', color=colors[ql])
    axs[1].set_title('Qbt Frequency vs Oscillator Level')
    axs[1].legend()

    # Show the plots
    plt.tight_layout()  # Adjust the layout to make room for the legend
    plt.show()
    
    
ql = 20
max_ol = 60

system = FluxoniumOscillatorSystem(
    computaional_states = '1,2',
    EJ = 2.33,
    EC = 0.69,
    EL = 0.12,
    Er = 7.16518677 ,
    qubit_level = ql,
    osc_level = max_ol,
    g_strength = 0.18,
    products_to_keep=[[ql,ol] for ql in [0,1,2,3] for ol in range(max_ol)] 
    )


energies=  system.hilbertspace.eigenvals(system.qbt.truncated_dim * system.osc.truncated_dim )


def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]


ols = system.osc.truncated_dim

plot_frequencies_qbt_osc(dressed_ener, ols)

# %%
dressed_ener(0,1)-dressed_ener(0,0)
# Out:
# 7.164739955739689

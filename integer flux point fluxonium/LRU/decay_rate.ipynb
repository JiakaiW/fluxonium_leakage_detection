# %%
from scqubits import *
import scqubits.core.units as units
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from qutip import *

# %%
qbt = Fluxonium(EJ = 6.86,
            EC = 1.46,
            EL = 0.23,
            flux = 0,
            cutoff=110,
            truncated_dim  = 8)
qbt.plot_matrixelements('n_operator',evals_count = 8,show3d= False)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: >)

# %%
1 / qbt.t1_effective(
                common_noise_options = dict(i = 1, 
                                            j = 0, 
                                            total = True,
                                            ),
                get_rate = True,
                )
# Out:
# 2684369.624398937

# %%
n_levels = 8
transition_rates = np.zeros((n_levels,n_levels))
for i in range(n_levels):
    for j in range(n_levels):
        if i == j:
            transition_rates[i,j] = 1e-20
        else:
            transition_rates[i,j] = qbt.t1_effective(
                                    common_noise_options = dict(i = i, 
                                                                j = j, 
                                                                total = False,
                                                                ),
                                    get_rate = True,
                                    )
            
        
transition_rates[transition_rates < 1e-19] = np.nan
transition_rates = np.ma.masked_invalid(transition_rates)
        
plt.imshow(transition_rates, norm=LogNorm(vmin=1e-10, vmax=transition_rates.max()), cmap='inferno')
plt.colorbar()
plt.xlabel('to j')
plt.ylabel('from i')
plt.title('transition rates in Log Scale')
plt.show()
# Out:
# UserWarning: By default all methods that involve calculations of the t1 coherence times/rates, return a sum of upward (i.e., excitation), and downward (i.e., relaxation) rates. To change this behavior, parameter total=False can be passed to any t1-related coherence methods. With total=False, only a one-directional transition between levels i and j is used to calculate the required t1 time or rate.
# See documentation for details.
# This warning can be disabled by executing:
# scqubits.settings.T1_DEFAULT_WARNING=False
#
#  /Users/jiakaiwang/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/scqubits/core/noise.py: 1194
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 8
#       6             transition_rates[i,j] = 1e-20
#       7         else:
# ----> 8             transition_rates[i,j] = qbt.t1_effective(
#       9                                     common_noise_options = dict(i = i,
#      10                                                                 j = j,
#      11                                                                 total = False,
#      12                                                                 ),
#      13                                     get_rate = True,
#      14                                     )
#      17 transition_rates[transition_rates < 1e-19] = np.nan
#      18 transition_rates = np.ma.masked_invalid(transition_rates)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/scqubits/core/noise.py:817, in NoisySystem.t1_effective(self, noise_channels, common_noise_options, esys, get_rate, **kwargs)
#     813             max_level = max(max_level, opts.get("i", 1), opts.get("j", 1))
#     815     esys = self.eigensys(evals_count=max_level + 1)  # type: ignore
# --> 817 rate = self._effective_rate(
#     818     noise_channels=noise_channels,
#     819     common_noise_options=common_noise_options,
#     820     esys=esys,
#     821     noise_type="t1",
#     822 )
#     823 if get_rate:
#     824     return rate
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/scqubits/core/noise.py:686, in NoisySystem._effective_rate(self, noise_channels, common_noise_options, esys, noise_type)
#     683     options["get_rate"] = True
#     685     # calculate the noise over the full param span in param_vals
# --> 686     rate += scale_factor * getattr(self, noise_channel_method)(
#     687         esys=esys, **options
#     688     )
#     690 # noise_channel is a tuple representing the noise method and default options
#     691 elif isinstance(noise_channel, tuple):
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/scqubits/core/noise.py:1466, in NoisySystem.t1_flux_bias_line(self, i, j, M, Z, T, total, esys, get_rate)
#    1463     s *= (units.to_standard_units(1)) ** 2.0
#    1464     return s
# -> 1466 noise_op = self.d_hamiltonian_d_flux()  # type: ignore
#    1468 return self.t1(
#    1469     i=i,
#    1470     j=j,
#    (...)
#    1475     get_rate=get_rate,
#    1476 )
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/scqubits/core/fluxonium.py:383, in Fluxonium.d_hamiltonian_d_flux(self, energy_esys)
#     361 def d_hamiltonian_d_flux(
#     362     self, energy_esys: Union[bool, Tuple[ndarray, ndarray]] = False
#     363 ) -> ndarray:
#     364     """
#     365     Returns operator representing a derivative of the Hamiltonian with respect to
#     366     flux in the harmonic-oscillator or eigenenergy basis. The flux is grouped as in the Hamiltonian.
#    (...)
#     381         for m given eigenvectors.
#     382     """
# --> 383     native = -2 * np.pi * self.EJ * self.sin_phi_operator(1, 2 * np.pi * self.flux)
#     384     return self.process_op(native_op=native, energy_esys=energy_esys)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/scqubits/core/fluxonium.py:292, in Fluxonium.sin_phi_operator(self, alpha, beta, energy_esys)
#     273 """
#     274 Returns the :math:`\\sin (\\alpha \\phi + \\beta)` operator with :math:`\\alpha` and :math:`\\beta` being
#     275 numbers, in the LC harmonic oscillator or eigenenergy basis.
#    (...)
#     289     x `truncated_dim`. Otherwise, if eigenenergy basis is chosen, :math:`\\sin (\\alpha \\phi + \\beta)` has dimensions of m x m, for m given eigenvectors.
#     290 """
#     291 argument = alpha * self.phi_operator() + beta * np.eye(self.hilbertdim())
# --> 292 native = sp.linalg.sinm(argument)
#     293 return self.process_op(native_op=native, energy_esys=energy_esys)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/scipy/linalg/_matfuncs.py:476, in sinm(A)
#     474     return -0.5j*(expm(1j*A) - expm(-1j*A))
#     475 else:
# --> 476     return expm(1j*A).imag
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.10/site-packages/scipy/linalg/_matfuncs.py:346, in expm(A)
#     343 # Generic/triangular case; copy the slice into scratch and send.
#     344 # Am will be mutated by pick_pade_structure
#     345 Am[0, :, :] = aw
# --> 346 m, s = pick_pade_structure(Am)
#     348 if s != 0:  # scaling needed
#     349     Am[:4] *= [[[2**(-s)]], [[4**(-s)]], [[16**(-s)]], [[64**(-s)]]]
#
# KeyboardInterrupt:

# %%
1/transition_rates[1,0]
# Out:
# 2684372.458656878

# %%
transition_rates[3,0]/transition_rates[1,0]
# Out:
# 136.0767564591035

# %% [markdown]
# # add a resonator with low Q.
#
# # sideband cooling like transmon?
#
# # adjust params so t1 is 255 micro sec

# %%
liovillian = Qobj(dims =  [[[n_levels], [n_levels]], [[n_levels], [n_levels]]])
for i in range(n_levels):
    for j in range(n_levels):
        if not transition_rates.mask[j,i]:        
            liovillian += lindblad_dissipator(
                                    np.sqrt(transition_rates[j,i]) * basis(n_levels,i) * basis(n_levels,j).dag()
                                              )

# %%
def plot_decay_of_state(j,tot_time = 1000000):
    tlist = np.linspace(0,tot_time,int(tot_time/100))
    result = mesolve(H = Qobj(qbt.hamiltonian(energy_esys = True)),
                    rho0 = qutip.basis(n_levels,j),
                    c_ops = [liovillian],
                    e_ops = [
                        basis(n_levels,i) * basis(n_levels,i).dag() for i in range(n_levels)
                    ],
                    tlist = tlist,
                    options = Options(store_states=True)
                    )

    for i in range(n_levels):
        if i != j:
            plt.plot(tlist, result.expect[i], label = f"{i}")
        else:
            plt.plot(tlist, 1- result.expect[i], label = f"1-{i}")
    plt.legend()
    plt.title('population with sponateous decay/excitation')

# %%
plot_decay_of_state(3)

# %%
plot_decay_of_state(7)

# %%
##################################################################
# Plotting the default spectural density
##################################################################

T = 0.015
EC = 0.6
def q_cap_fun(omega):
    return (
        1e6
        * (2 * np.pi * 6e9 / np.abs(units.to_standard_units(omega))) ** 0.7
    )

def calc_therm_ratio(
    omega: float, T: float, omega_in_standard_units: bool = False
) -> float:
    r"""Returns the ratio

    :math:`\beta \omega = \frac{\hbar \omega}{k_B T}`

    after converting `\omega` from system units, to standard units.

    Parameters
    ----------
    omega:
        angular frequency in system units
    T:
        temperature in Kelvin
    omega_in_standard_units:
        is omega given in standard units (i.e. Hz)

    Returns
    -------
    float
    """
    omega = units.to_standard_units(omega) if not omega_in_standard_units else omega
    return (sp.constants.hbar * omega) / (sp.constants.k * T)



def spectral_density(omega):
    therm_ratio = calc_therm_ratio(omega, T)
    s = (
        2
        * 8
        * EC
        / q_cap_fun(omega)
        * (1 / np.tanh(0.5 * np.abs(therm_ratio)))
        / (1 + np.exp(-therm_ratio))
    )
    s *= (
        2 * np.pi
    )  # We assume that system energies are given in units of frequency
    return s

o_list = np.linspace(-8,8,100)
density = spectral_density(2 * np.pi *o_list)
import matplotlib.pyplot as plt
plt.plot(o_list,density)
plt.title("spectrual density")
plt.ylabel("density")
plt.xlabel("frequency, or energy / 2pi")
# Out:
# Text(0.5, 0, 'frequency, or energy / 2pi')

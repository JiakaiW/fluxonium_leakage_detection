# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *

# %%
EJ = 2.5
EC = 0.65
EL = 0.12

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.05]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1.062791307016031e-06
#              x: [ 7.059e+00]
#            nit: 13
#           nfev: 26
#  final_simplex: (array([[ 7.059e+00],
#                        [ 7.059e+00]]), array([ 1.063e-06,  1.319e-06]))
# Optimal solution: [7.05877808]
# Objective value: 1.062791307016031e-06

# %%
max_ol = 50
max_ql = 25
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.23
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.001,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  (non-linearity on qbt 0): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}  (non-linearity on qbt 3): {(dressed_ener(3,i+1)-dressed_ener(3,i))  -(dressed_ener(3,1)-dressed_ener(3,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.025838585378685774
# qbt freq at osc 1:	0.02583, 	diff to at osc ground -0.00001, 0.0520% diff
# qbt freq at osc 2:	0.02581, 	diff to at osc ground -0.00003, 0.1102% diff
# qbt freq at osc 3:	0.02579, 	diff to at osc ground -0.00005, 0.1751% diff
# qbt freq at osc 4:	0.02577, 	diff to at osc ground -0.00006, 0.2467% diff
# qbt freq at osc 5:	0.02575, 	diff to at osc ground -0.00008, 0.3254% diff
# qbt freq at osc 6:	0.02573, 	diff to at osc ground -0.00011, 0.4114% diff
# qbt freq at osc 7:	0.02571, 	diff to at osc ground -0.00013, 0.5050% diff
# qbt freq at osc 8:	0.02568, 	diff to at osc ground -0.00016, 0.6062% diff
# qbt freq at osc 9:	0.02565, 	diff to at osc ground -0.00018, 0.7155% diff
# qbt freq at osc 10:	0.02562, 	diff to at osc ground -0.00022, 0.8331% diff
# qbt freq at osc 11:	0.02559, 	diff to at osc ground -0.00025, 0.9591% diff
# qbt freq at osc 12:	0.02556, 	diff to at osc ground -0.00028, 1.0938% diff
# qbt freq at osc 13:	0.02552, 	diff to at osc ground -0.00032, 1.2375% diff
# qbt freq at osc 14:	0.02548, 	diff to at osc ground -0.00036, 1.3904% diff
# qbt freq at osc 15:	0.02544, 	diff to at osc ground -0.00040, 1.5528% diff
# qbt freq at osc 16:	0.02539, 	diff to at osc ground -0.00045, 1.7248% diff
# qbt freq at osc 17:	0.02535, 	diff to at osc ground -0.00049, 1.9067% diff
# qbt freq at osc 18:	0.02530, 	diff to at osc ground -0.00054, 2.0988% diff
# qbt freq at osc 19:	0.02524, 	diff to at osc ground -0.00059, 2.3013% diff
# qbt freq at osc 20:	0.02519, 	diff to at osc ground -0.00065, 2.5144% diff
# qbt freq at osc 21:	0.02513, 	diff to at osc ground -0.00071, 2.7383% diff
# qbt freq at osc 22:	0.02507, 	diff to at osc ground -0.00077, 2.9734% diff
# qbt freq at osc 23:	0.02501, 	diff to at osc ground -0.00083, 3.2198% diff
# qbt freq at osc 24:	0.02494, 	diff to at osc ground -0.00090, 3.4777% diff
# qbt freq at osc 25:	0.02487, 	diff to at osc ground -0.00097, 3.7474% diff
# qbt freq at osc 26:	0.02480, 	diff to at osc ground -0.00104, 4.0292% diff
# qbt freq at osc 27:	0.02472, 	diff to at osc ground -0.00112, 4.3231% diff
# qbt freq at osc 28:	0.02464, 	diff to at osc ground -0.00120, 4.6296% diff
# qbt freq at osc 29:	0.02456, 	diff to at osc ground -0.00128, 4.9488% diff
# qbt freq at osc 30:	0.02447, 	diff to at osc ground -0.00136, 5.2809% diff
# qbt freq at osc 31:	0.02438, 	diff to at osc ground -0.00145, 5.6262% diff
# qbt freq at osc 32:	0.02429, 	diff to at osc ground -0.00155, 5.9849% diff
# qbt freq at osc 33:	0.02420, 	diff to at osc ground -0.00164, 6.3572% diff
# qbt freq at osc 34:	0.02410, 	diff to at osc ground -0.00174, 6.7433% diff
# qbt freq at osc 35:	0.02399, 	diff to at osc ground -0.00185, 7.1434% diff
# qbt freq at osc 36:	0.02389, 	diff to at osc ground -0.00195, 7.5578% diff
# qbt freq at osc 37:	0.02377, 	diff to at osc ground -0.00206, 7.9866% diff
# qbt freq at osc 38:	0.02366, 	diff to at osc ground -0.00218, 8.4302% diff
# qbt freq at osc 39:	0.02354, 	diff to at osc ground -0.00230, 8.8886% diff
# qbt freq at osc 40:	0.02342, 	diff to at osc ground -0.00242, 9.3621% diff
# qbt freq at osc 41:	0.02329, 	diff to at osc ground -0.00255, 9.8509% diff
# qbt freq at osc 42:	0.02316, 	diff to at osc ground -0.00268, 10.3552% diff
# qbt freq at osc 43:	0.02303, 	diff to at osc ground -0.00281, 10.8752% diff
# qbt freq at osc 44:	0.02289, 	diff to at osc ground -0.00295, 11.4111% diff
# qbt freq at osc 45:	0.02275, 	diff to at osc ground -0.00309, 11.9630% diff
# qbt freq at osc 46:	0.02260, 	diff to at osc ground -0.00324, 12.5311% diff
# qbt freq at osc 47:	0.02245, 	diff to at osc ground -0.00339, 13.1093% diff
# qbt freq at osc 48:	0.02250, 	diff to at osc ground -0.00334, 12.9303% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.05913	7.06064	7.06062	7.05824
# oscillator transition 1-2: 	7.05909	7.06063	7.06062	7.05825  (non-linearity on qbt 0): -4.202641698736187e-05  (non-linearity on qbt 3): 8.096376599375787e-06
# oscillator transition 2-3: 	7.05905	7.06063	7.06061	7.05826  (non-linearity on qbt 0): -8.322073559163812e-05  (non-linearity on qbt 3): 1.6057401924562953e-05
# oscillator transition 3-4: 	7.05901	7.06063	7.06061	7.05827  (non-linearity on qbt 0): -0.00012351638273599974  (non-linearity on qbt 3): 2.3885877193485783e-05
# oscillator transition 4-5: 	7.05897	7.06062	7.06060	7.05827  (non-linearity on qbt 0): -0.00016285447786046348  (non-linearity on qbt 3): 3.158452409746104e-05
# oscillator transition 5-6: 	7.05893	7.06062	7.06060	7.05828  (non-linearity on qbt 0): -0.00020118401757329707  (non-linearity on qbt 3): 3.915598541137655e-05
# oscillator transition 6-7: 	7.05889	7.06062	7.06059	7.05829  (non-linearity on qbt 0): -0.00023846191799847816  (non-linearity on qbt 3): 4.6602830713560195e-05
# oscillator transition 7-8: 	7.05886	7.06061	7.06059	7.05830  (non-linearity on qbt 0): -0.00027465292450656875  (non-linearity on qbt 3): 5.3927557316590935e-05
# oscillator transition 8-9: 	7.05882	7.06061	7.06058	7.05830  (non-linearity on qbt 0): -0.00030972940770013224  (non-linearity on qbt 3): 6.113259478635058e-05
# oscillator transition 9-10: 	7.05879	7.06060	7.06057	7.05831  (non-linearity on qbt 0): -0.000343671058661954  (non-linearity on qbt 3): 6.822030719089156e-05
# oscillator transition 10-11: 	7.05875	7.06060	7.06057	7.05832  (non-linearity on qbt 0): -0.00037646450011763477  (non-linearity on qbt 3): 7.519299480573949e-05
# oscillator transition 11-12: 	7.05872	7.06060	7.06056	7.05832  (non-linearity on qbt 0): -0.00040810283531911296  (non-linearity on qbt 3): 8.20528976310797e-05
# oscillator transition 12-13: 	7.05869	7.06059	7.06056	7.05833  (non-linearity on qbt 0): -0.0004385851486965464  (non-linearity on qbt 3): 8.880219821261193e-05
# oscillator transition 13-14: 	7.05866	7.06059	7.06055	7.05834  (non-linearity on qbt 0): -0.00046791597373996296  (non-linearity on qbt 3): 9.544302193997822e-05
# oscillator transition 14-15: 	7.05863	7.06059	7.06054	7.05834  (non-linearity on qbt 0): -0.000496104747977455  (non-linearity on qbt 3): 0.0001019774411537
# oscillator transition 15-16: 	7.05861	7.06058	7.06054	7.05835  (non-linearity on qbt 0): -0.000523165259860292  (non-linearity on qbt 3): 0.0001084074767794263
# oscillator transition 16-17: 	7.05858	7.06058	7.06053	7.05836  (non-linearity on qbt 0): -0.0005491151089067614  (non-linearity on qbt 3): 0.00011473509770265622
# oscillator transition 17-18: 	7.05856	7.06058	7.06053	7.05836  (non-linearity on qbt 0): -0.0005739751763904621  (non-linearity on qbt 3): 0.00012096222767521425
# oscillator transition 18-19: 	7.05853	7.06057	7.06052	7.05837  (non-linearity on qbt 0): -0.0005977691269372087  (non-linearity on qbt 3): 0.00012709074248729024
# oscillator transition 19-20: 	7.05851	7.06057	7.06051	7.05838  (non-linearity on qbt 0): -0.000620522931594536  (non-linearity on qbt 3): 0.00013312247224117613
# oscillator transition 20-21: 	7.05849	7.06056	7.06051	7.05838  (non-linearity on qbt 0): -0.000642264434215889  (non-linearity on qbt 3): 0.00013905920535872696
# oscillator transition 21-22: 	7.05847	7.06056	7.06050	7.05839  (non-linearity on qbt 0): -0.0006630229416053623  (non-linearity on qbt 3): 0.00014490268923506022
# oscillator transition 22-23: 	7.05845	7.06056	7.06049	7.05839  (non-linearity on qbt 0): -0.0006828288635709612  (non-linearity on qbt 3): 0.0001506546286895727
# oscillator transition 23-24: 	7.05843	7.06055	7.06049	7.05840  (non-linearity on qbt 0): -0.00070171337722158  (non-linearity on qbt 3): 0.00015631669255977698
# oscillator transition 24-25: 	7.05841	7.06055	7.06048	7.05840  (non-linearity on qbt 0): -0.0007197081389413995  (non-linearity on qbt 3): 0.0001618905091822498
# oscillator transition 25-26: 	7.05839	7.06055	7.06047	7.05841  (non-linearity on qbt 0): -0.0007368450216596045  (non-linearity on qbt 3): 0.00016737767355490263
# oscillator transition 26-27: 	7.05838	7.06054	7.06047	7.05841  (non-linearity on qbt 0): -0.0007531558947810879  (non-linearity on qbt 3): 0.00017277974281793007
# oscillator transition 27-28: 	7.05836	7.06054	7.06046	7.05842  (non-linearity on qbt 0): -0.0007686724252060628  (non-linearity on qbt 3): 0.00017809824188130818
# oscillator transition 28-29: 	7.05835	7.06053	7.06045	7.05843  (non-linearity on qbt 0): -0.0007834259176568992  (non-linearity on qbt 3): 0.00018333466234476958
# oscillator transition 29-30: 	7.05833	7.06053	7.06045	7.05843  (non-linearity on qbt 0): -0.0007974471720295639  (non-linearity on qbt 3): 0.00018849046457258822
# oscillator transition 30-31: 	7.05832	7.06053	7.06044	7.05844  (non-linearity on qbt 0): -0.000810766367802529  (non-linearity on qbt 3): 0.00019356707632933734
# oscillator transition 31-32: 	7.05831	7.06052	7.06043	7.05844  (non-linearity on qbt 0): -0.000823412978743221  (non-linearity on qbt 3): 0.00019856589678735048
# oscillator transition 32-33: 	7.05830	7.06052	7.06042	7.05845  (non-linearity on qbt 0): -0.0008354156870460372  (non-linearity on qbt 3): 0.000203488296185661
# oscillator transition 33-34: 	7.05828	7.06052	7.06042	7.05845  (non-linearity on qbt 0): -0.000846802337431285  (non-linearity on qbt 3): 0.0002083356162847494
# oscillator transition 34-35: 	7.05827	7.06051	7.06041	7.05846  (non-linearity on qbt 0): -0.000857599886526117  (non-linearity on qbt 3): 0.0002131091718160505
# oscillator transition 35-36: 	7.05826	7.06051	7.06040	7.05846  (non-linearity on qbt 0): -0.000867834378052379  (non-linearity on qbt 3): 0.00021781025065248372
# oscillator transition 36-37: 	7.05825	7.06051	7.06039	7.05846  (non-linearity on qbt 0): -0.0008775309229882566  (non-linearity on qbt 3): 0.00022244011440530898
# oscillator transition 37-38: 	7.05824	7.06050	7.06039	7.05847  (non-linearity on qbt 0): -0.0008867136901038464  (non-linearity on qbt 3): 0.00022700000143682786
# oscillator transition 38-39: 	7.05824	7.06050	7.06038	7.05847  (non-linearity on qbt 0): -0.0008954059072969756  (non-linearity on qbt 3): 0.00023149112441611663
# oscillator transition 39-40: 	7.05823	7.06049	7.06037	7.05848  (non-linearity on qbt 0): -0.0009036298638100959  (non-linearity on qbt 3): 0.00023591467216643736
# oscillator transition 40-41: 	7.05822	7.06049	7.06036	7.05848  (non-linearity on qbt 0): -0.0009114069266864533  (non-linearity on qbt 3): 0.00024027181344532522
# oscillator transition 41-42: 	7.05821	7.06049	7.06036	7.05849  (non-linearity on qbt 0): -0.000918757554327243  (non-linearity on qbt 3): 0.0002445636886454494
# oscillator transition 42-43: 	7.05821	7.06048	7.06035	7.05849  (non-linearity on qbt 0): -0.0009257013141130699  (non-linearity on qbt 3): 0.0002487914236075639
# oscillator transition 43-44: 	7.05820	7.06048	7.06034	7.05850  (non-linearity on qbt 0): -0.0009322569087224508  (non-linearity on qbt 3): 0.0002529561268351799
# oscillator transition 44-45: 	7.25523	7.06048	7.06033	7.05850  (non-linearity on qbt 0): 0.19610214005362891  (non-linearity on qbt 3): 0.0002570610769430104
# oscillator transition 45-46: 	7.06057	7.06047	7.06032	7.05850  (non-linearity on qbt 0): 0.0014411821584623397  (non-linearity on qbt 3): 0.0002615507514951432
# oscillator transition 46-47: 	7.06058	7.06047	7.06032	7.05857  (non-linearity on qbt 0): 0.0014489058250752862  (non-linearity on qbt 3): 0.00033137299506957874
# oscillator transition 47-48: 	7.06092	7.06119	7.06123	7.06481  (non-linearity on qbt 0): 0.0017852733866199344  (non-linearity on qbt 3): 0.006569778369075685
# oscillator transition 48-49: 	7.09686	7.11783	7.12554	7.30377  (non-linearity on qbt 0): 0.03773102891060276  (non-linearity on qbt 3): 0.24552395991522413
#
# 10-11: 7.0606, diff to 00-01: 0.001507287404769464, diff to 30-31: 0.0023959758168476952
# 20-21: 7.0606, diff to 00-01: 0.0014938627428033868, diff to 30-31: 0.002382551154881618

# %%
system.qbt.plot_matrixelements(operator = 'n_operator',evals_count = 15)
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

# %%
elements = system.qbt.matrixelement_table(operator="n_operator",evals_count=15)

for i in [1,3,5,7,9,11,13]:
    print(f"{i}-0: {elements[0,i]}")
# Out:
# 1-0: 0.0865397614576715j
# 3-0: 0.5596610034395441j
# 5-0: -0.08845727677113235j
# 7-0: -0.06743576672587895j
# 9-0: -0.022174241970136063j
# 11-0: 0.02347037669455564j
# 13-0: -0.013243825690125745j

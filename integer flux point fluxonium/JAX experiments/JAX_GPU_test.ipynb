# %%
import os 
os.environ['JAX_JIT_PJIT_API_MERGE'] = '0'
import jax
jax.config.update("jax_enable_x64", True)
jax.config.update('jax_platform_name', 'gpu')

# %%
import sys
sys.path.append('../')
from utils import *


system = fluxonium_oscillator_system(
    computaional_states = '1,2',
    products_to_keep = [[ql, ol] for ql in [1,2] for ol in range(20) ] 
)


result = system.run_jax_gpu_solve(
    initial_state = system.truncate_function(qutip.basis(system.hilbertspace.dimension, 0)), 
    tlist  =  jnp.linspace(0,100, 100), 
    )
# Out:
# /home/kai/miniconda3/envs/tensorflow/lib/python3.10/site-packages/qiskit_dynamics/dispatch/backends/jax.py:34: UserWarning: The functionality in the perturbation module of Qiskit Dynamics requires a JAX version <= 0.4.6, due to a bug in JAX versions > 0.4.6. For versions 0.4.4, 0.4.5, and 0.4.6, using the perturbation module functionality requires setting os.environ['JAX_JIT_PJIT_API_MERGE'] = '0' before importing JAX or Dynamics.
#   warnings.warn(
# 2024-02-18 02:40:52.663394: W external/xla/xla/service/gpu/nvptx_compiler.cc:744] The NVIDIA driver's CUDA version is 12.0 which is older than the ptxas CUDA version (12.3.107). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# solving through chunks:  12%|█▏        | 12/100 [01:29<10:55,  7.45s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#       4 from utils import *
#       7 system = fluxonium_oscillator_system(
#       8     computaional_states = '1,2',
#       9     products_to_keep = [[ql, ol] for ql in [1,2] for ol in range(20) ]
#      10 )
# ---> 13 result = system.run_jax_gpu_solve(
#      14     initial_state = system.truncate_function(qutip.basis(system.hilbertspace.dimension, 0)),
#      15     tlist  =  jnp.linspace(0,100, 100),
#      16     )
#
# File ~/Github/erasure_hardware_sim/integer flux point fluxonium/JAX experiments/../utils.py:284, in fluxonium_oscillator_system.run_jax_gpu_solve(self, initial_state, tlist, osc_decay, amp, t_stop, t_rise, driven_operator, chunk_size)
#     281     else:
#     282         chunk_results.extend(result.y[1:])
# --> 284     current_state = result.y[-1]
#     285 ode_result = qutip.solver.Result()
#     286 ode_result.times=tlist
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/qiskit_dynamics/array/array.py:153, in Array.__getitem__(self, key)
#     151 def __getitem__(self, key: str) -> Any:
#     152     """Return value from wrapped array."""
# --> 153     return self._data[key]
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/array.py:350, in ArrayImpl.__getitem__(self, idx)
#     347     else:
#     348       return out
# --> 350 return lax_numpy._rewriting_take(self, idx)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:4559, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#    4550 def _rewriting_take(arr, idx, indices_are_sorted=False, unique_indices=False,
#    4551                     mode=None, fill_value=None):
#    4552   # Computes arr[idx].
#    (...)
#    4556   # For simplicity of generated primitives, we call lax.dynamic_slice in the
#    4557   # simplest cases: i.e. non-dynamic arrays indexed with integers and slices.
# -> 4559   if (result := _attempt_rewriting_take_via_slice(arr, idx, mode)) is not None:
#    4560     return result
#    4562   # TODO(mattjj,dougalm): expand dynamic shape indexing support
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:4543, in _attempt_rewriting_take_via_slice(arr, idx, mode)
#    4541   if len(start_indices) > 1:
#    4542     start_indices = util.promote_dtypes(*start_indices)
# -> 4543   arr = lax.dynamic_slice(
#    4544       arr, start_indices=start_indices, slice_sizes=slice_sizes)
#    4545 if int_indices:
#    4546   arr = lax.squeeze(arr, tuple(int_indices))
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/lax/slicing.py:161, in dynamic_slice(operand, start_indices, slice_sizes)
#     113 def dynamic_slice(
#     114     operand: Array | np.ndarray,
#     115     start_indices: Array | np.ndarray | Sequence[ArrayLike],
#     116     slice_sizes: Shape,
#     117 ) -> Array:
#     118   """Wraps XLA's `DynamicSlice
#     119   <https://www.tensorflow.org/xla/operation_semantics#dynamicslice>`_
#     120   operator.
#    (...)
#     159     - :func:`jax.lax.dynamic_index_in_dim`
#     160   """
# --> 161   start_indices = _dynamic_slice_indices(operand, start_indices)
#     162   if config.dynamic_shapes.value:
#     163     dynamic_sizes, static_sizes = lax._extract_tracers_dyn_shape(slice_sizes)
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/lax/slicing.py:2600, in _dynamic_slice_indices(operand, start_indices)
#    2598     continue
#    2599   d_arr = lax.convert_element_type(d, _dtype(i))
# -> 2600   result.append(lax.select(i < 0, i + d_arr, i))
#    2601 return result
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:264, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     262 args = (other, self) if swap else (self, other)
#     263 if isinstance(other, _accepted_binop_types):
# --> 264   return binary_op(*args)
#     265 # Note: don't use isinstance here, because we don't want to raise for
#     266 # subclasses, e.g. NamedTuple objects that may override operators.
#     267 if type(other) in _rejected_binop_types:
#
# KeyboardInterrupt:

# %%
import sys
sys.path.append('../')
from utils import *


system = fluxonium_oscillator_system(
    computaional_states = '1,2',
    products_to_keep = [[ql, ol] for ql in [1,2] for ol in range(20) ] 
)
# Out:
# /home/kai/miniconda3/envs/tensorflow/lib/python3.10/site-packages/qiskit_dynamics/dispatch/backends/jax.py:34: UserWarning: The functionality in the perturbation module of Qiskit Dynamics requires a JAX version <= 0.4.6, due to a bug in JAX versions > 0.4.6. For versions 0.4.4, 0.4.5, and 0.4.6, using the perturbation module functionality requires setting os.environ['JAX_JIT_PJIT_API_MERGE'] = '0' before importing JAX or Dynamics.
#   warnings.warn(

# %%
result = system.run_mesolve_on_driving_osc(
    initial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, 0))], 
    tlist  =  jnp.linspace(0,100, 100), 
    osc_decay = True,
    post_processing = []
    )
# Out:
# RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#  /home/kai/miniconda3/envs/tensorflow/lib/python3.10/multiprocessing/popen_fork.py: 662024-02-18 02:55:05.639043: F external/xla/xla/stream_executor/cuda/cuda_driver.cc:164] Failed setting context: CUDA_ERROR_NOT_INITIALIZED: initialization error
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 result = system.run_mesolve_on_driving_osc(
#       2     initial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, 0))],
#       3     tlist  =  jnp.linspace(0,100, 100),
#       4     osc_decay = True,
#       5     post_processing = []
#       6     )
#
# File ~/Github/erasure_hardware_sim/integer flux point fluxonium/JAX experiments/../utils.py:160, in fluxonium_oscillator_system.run_mesolve_on_driving_osc(self, initial_states, tlist, osc_decay, e_ops, amp, max_workers, t_stop, t_rise, post_processing, driven_operator)
#     158     for future in concurrent.futures.as_completed(futures):
#     159         original_index = futures[future]
# --> 160         results[original_index] = future.result()
#     162 return results
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

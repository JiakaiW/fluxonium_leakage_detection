# %%
from param_search_var_osc import *

# %%
! python3 param_search_var_osc.py 0
# Out:
# done one
# Total time: 0.5527303218841553
# done one
# Total time: 0.46074628829956055
# done one
# Total time: 0.3211054801940918
# done one
# Total time: 0.49868297576904297
# done one
# Total time: 0.539473295211792
# done one
# Total time: 0.4890260696411133
# done one
# Total time: 0.47047996520996094
# done one
# Total time: 0.41492247581481934
# done one
# Total time: 0.5723140239715576
# done one
# Total time: 0.5200884342193604
# done one
# Total time: 0.5089724063873291
# done one
# Total time: 0.5798914432525635
# done one
# Total time: 0.4468681812286377
# done one
# Total time: 0.5168743133544922
# done one
# Total time: 0.4884767532348633
# done one
# Total time: 0.4017646312713623
# done one
# Total time: 0.5175409317016602
# done one
# Total time: 0.5064644813537598
# done one
# Total time: 0.3805079460144043
# done one
# Total time: 0.35361480712890625
# done one
# Total time: 0.37036895751953125
# done one
# Total time: 0.5474379062652588
# done one
# ...

# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *
sys.path = original_sys_path

# %%
EJ = 3
EC = 0.6
EL = 0.13

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.26]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 3.861367100232993e-07
#              x: [ 7.276e+00]
#            nit: 14
#           nfev: 30
#  final_simplex: (array([[ 7.276e+00],
#                        [ 7.276e+00]]), array([ 3.861e-07,  4.415e-06]))
# Optimal solution: [7.27604077]
# Objective value: 3.861367100232993e-07

# %%
max_ol = 50
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.13
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.009189105149339571
# qbt freq at osc 1:	0.00919, 	diff to at osc ground 0.00000, 0.0137% diff
# qbt freq at osc 2:	0.00919, 	diff to at osc ground 0.00000, 0.0291% diff
# qbt freq at osc 3:	0.00919, 	diff to at osc ground 0.00000, 0.0463% diff
# qbt freq at osc 4:	0.00920, 	diff to at osc ground 0.00001, 0.0653% diff
# qbt freq at osc 5:	0.00920, 	diff to at osc ground 0.00001, 0.0864% diff
# qbt freq at osc 6:	0.00920, 	diff to at osc ground 0.00001, 0.1096% diff
# qbt freq at osc 7:	0.00920, 	diff to at osc ground 0.00001, 0.1350% diff
# qbt freq at osc 8:	0.00920, 	diff to at osc ground 0.00001, 0.1628% diff
# qbt freq at osc 9:	0.00921, 	diff to at osc ground 0.00002, 0.1929% diff
# qbt freq at osc 10:	0.00921, 	diff to at osc ground 0.00002, 0.2255% diff
# qbt freq at osc 11:	0.00921, 	diff to at osc ground 0.00002, 0.2607% diff
# qbt freq at osc 12:	0.00922, 	diff to at osc ground 0.00003, 0.2986% diff
# qbt freq at osc 13:	0.00922, 	diff to at osc ground 0.00003, 0.3391% diff
# qbt freq at osc 14:	0.00922, 	diff to at osc ground 0.00004, 0.3823% diff
# qbt freq at osc 15:	0.00923, 	diff to at osc ground 0.00004, 0.4284% diff
# qbt freq at osc 16:	0.00923, 	diff to at osc ground 0.00004, 0.4774% diff
# qbt freq at osc 17:	0.00924, 	diff to at osc ground 0.00005, 0.5292% diff
# qbt freq at osc 18:	0.00924, 	diff to at osc ground 0.00005, 0.5841% diff
# qbt freq at osc 19:	0.00925, 	diff to at osc ground 0.00006, 0.6419% diff
# qbt freq at osc 20:	0.00925, 	diff to at osc ground 0.00006, 0.7028% diff
# qbt freq at osc 21:	0.00926, 	diff to at osc ground 0.00007, 0.7668% diff
# qbt freq at osc 22:	0.00927, 	diff to at osc ground 0.00008, 0.8339% diff
# qbt freq at osc 23:	0.00927, 	diff to at osc ground 0.00008, 0.9042% diff
# qbt freq at osc 24:	0.00928, 	diff to at osc ground 0.00009, 0.9777% diff
# qbt freq at osc 25:	0.00929, 	diff to at osc ground 0.00010, 1.0545% diff
# qbt freq at osc 26:	0.00929, 	diff to at osc ground 0.00010, 1.1345% diff
# qbt freq at osc 27:	0.00930, 	diff to at osc ground 0.00011, 1.2178% diff
# qbt freq at osc 28:	0.00931, 	diff to at osc ground 0.00012, 1.3044% diff
# qbt freq at osc 29:	0.00932, 	diff to at osc ground 0.00013, 1.3944% diff
# qbt freq at osc 30:	0.00933, 	diff to at osc ground 0.00014, 1.4878% diff
# qbt freq at osc 31:	0.00933, 	diff to at osc ground 0.00015, 1.5845% diff
# qbt freq at osc 32:	0.00934, 	diff to at osc ground 0.00015, 1.6847% diff
# qbt freq at osc 33:	0.00935, 	diff to at osc ground 0.00016, 1.7883% diff
# qbt freq at osc 34:	0.00936, 	diff to at osc ground 0.00017, 1.8953% diff
# qbt freq at osc 35:	0.00937, 	diff to at osc ground 0.00018, 2.0058% diff
# qbt freq at osc 36:	0.00938, 	diff to at osc ground 0.00019, 2.1198% diff
# qbt freq at osc 37:	0.00939, 	diff to at osc ground 0.00021, 2.2373% diff
# qbt freq at osc 38:	0.00941, 	diff to at osc ground 0.00022, 2.3583% diff
# qbt freq at osc 39:	0.00942, 	diff to at osc ground 0.00023, 2.4827% diff
# qbt freq at osc 40:	0.00943, 	diff to at osc ground 0.00024, 2.6108% diff
# qbt freq at osc 41:	0.00944, 	diff to at osc ground 0.00025, 2.7423% diff
# qbt freq at osc 42:	0.00945, 	diff to at osc ground 0.00026, 2.8774% diff
# qbt freq at osc 43:	0.00947, 	diff to at osc ground 0.00028, 3.0161% diff
# qbt freq at osc 44:	0.00948, 	diff to at osc ground 0.00029, 3.1583% diff
# qbt freq at osc 45:	0.00949, 	diff to at osc ground 0.00030, 3.3040% diff
# qbt freq at osc 46:	0.00951, 	diff to at osc ground 0.00032, 3.4533% diff
# qbt freq at osc 47:	0.00952, 	diff to at osc ground 0.00033, 3.6060% diff
# qbt freq at osc 48:	0.00954, 	diff to at osc ground 0.00035, 3.7726% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.27652	7.27691	7.27691	7.27582
# oscillator transition 1-2: 	7.27652	7.27691	7.27691	7.27582  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.481887754119839e-06
# oscillator transition 2-3: 	7.27651	7.27691	7.27691	7.27582  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.9825419997116e-06
# oscillator transition 3-4: 	7.27651	7.27691	7.27691	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.0501792696793188e-05
# oscillator transition 4-5: 	7.27651	7.27691	7.27691	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.4039461119885743e-05
# oscillator transition 5-6: 	7.27650	7.27691	7.27691	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.759535845646809e-05
# oscillator transition 6-7: 	7.27650	7.27690	7.27691	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.1169288067390823e-05
# oscillator transition 7-8: 	7.27650	7.27690	7.27691	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.4761042516807663e-05
# oscillator transition 8-9: 	7.27649	7.27690	7.27691	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.837040571446181e-05
# oscillator transition 9-10: 	7.27649	7.27690	7.27691	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.199715140222992e-05
# oscillator transition 10-11: 	7.27648	7.27690	7.27691	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.564104483810837e-05
# oscillator transition 11-12: 	7.27648	7.27690	7.27690	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.9301840778271924e-05
# oscillator transition 12-13: 	7.27648	7.27690	7.27690	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.297928580054844e-05
# oscillator transition 13-14: 	7.27647	7.27690	7.27690	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.6673114986184316e-05
# oscillator transition 14-15: 	7.27647	7.27690	7.27690	7.27583  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.0383053681990475e-05
# oscillator transition 15-16: 	7.27647	7.27690	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.4108820939369195e-05
# oscillator transition 16-17: 	7.27646	7.27690	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.785012216730223e-05
# oscillator transition 17-18: 	7.27646	7.27690	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.16066548166927e-05
# oscillator transition 18-19: 	7.27646	7.27690	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.537810668927335e-05
# oscillator transition 19-20: 	7.27645	7.27690	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.916415708868584e-05
# oscillator transition 20-21: 	7.27645	7.27689	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.296447277038709e-05
# oscillator transition 21-22: 	7.27644	7.27689	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.677871480549214e-05
# oscillator transition 22-23: 	7.27644	7.27689	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.060653096375603e-05
# oscillator transition 23-24: 	7.27644	7.27689	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.444756327374847e-05
# oscillator transition 24-25: 	7.27643	7.27689	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.830144285010277e-05
# oscillator transition 25-26: 	7.27643	7.27689	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -9.216779006404607e-05
# oscillator transition 26-27: 	7.27642	7.27689	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -9.60462189203426e-05
# oscillator transition 27-28: 	7.27642	7.27689	7.27690	7.27584  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -9.993633287930237e-05
# oscillator transition 28-29: 	7.27642	7.27689	7.27690	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00010383772795474755
# oscillator transition 29-30: 	7.27641	7.27689	7.27690	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00010774998864970797
# oscillator transition 30-31: 	7.27641	7.27689	7.27690	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00011167269435130578
# oscillator transition 31-32: 	7.27640	7.27689	7.27690	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00011560541378852207
# oscillator transition 32-33: 	7.27640	7.27689	7.27690	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00011954770810174153
# oscillator transition 33-34: 	7.27640	7.27689	7.27689	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00012349913064380047
# oscillator transition 34-35: 	7.27639	7.27688	7.27689	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0001274592272926256
# oscillator transition 35-36: 	7.27639	7.27688	7.27689	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00013142753491646175
# oscillator transition 36-37: 	7.27639	7.27688	7.27689	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0001354035829370659
# oscillator transition 37-38: 	7.27638	7.27688	7.27689	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0001393868960297695
# oscillator transition 38-39: 	7.27638	7.27688	7.27689	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00014337699065603005
# oscillator transition 39-40: 	7.27637	7.27688	7.27689	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00014737337386971916
# oscillator transition 40-41: 	7.27637	7.27688	7.27689	7.27585  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0001513755503372849
# oscillator transition 41-42: 	7.27637	7.27688	7.27689	7.27586  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00015538301716500058
# oscillator transition 42-43: 	7.27636	7.27688	7.27689	7.27586  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00015939526213681887
# oscillator transition 43-44: 	7.27636	7.27688	7.27689	7.27586  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00016341177428724762
# oscillator transition 44-45: 	7.27635	7.27688	7.27689	7.27586  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00016743203048630306
# oscillator transition 45-46: 	7.27635	7.27688	7.27689	7.27586  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00017145488562331224
# oscillator transition 46-47: 	7.27635	7.27688	7.27689	7.27586  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.00017514725903478023
# oscillator transition 47-48: 	7.27646	7.27697	7.27699	7.27680  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.8237975458119706e-05
# oscillator transition 48-49: 	7.30156	7.29937	7.30075	7.37599  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.02504138153880664
#
# 10-11: 7.2769, diff to 00-01: 0.00038807532924689525
# 20-21: 7.2769, diff to 00-01: 0.00038933852062417174

# %%
dressed_osc_frequencies = [[] for _ in range(3)]
for j in [0,1,2]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [0,1,2]:
    plt.plot(list(range(max_ol-1))[:30], dressed_osc_frequencies[j][:30],label=f'{j}')
plt.legend()

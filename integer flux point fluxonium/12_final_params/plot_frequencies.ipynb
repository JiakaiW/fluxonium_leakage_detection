# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils_models import *
sys.path = original_sys_path

# %%
EJ = 2.65
EC = 0.6
EL = 0.13

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.17391479]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2.178418441731167e-06
#              x: [ 7.174e+00]
#            nit: 13
#           nfev: 27
#  final_simplex: (array([[ 7.174e+00],
#                        [ 7.174e+00]]), array([ 2.178e-06,  6.199e-06]))
# Optimal solution: [7.17391479]
# Objective value: 2.178418441731167e-06

# %%
max_ol = 60
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.14
system = FluxoniumOscillatorSystem(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.02161788430113387
# qbt freq at osc 1:	0.02162, 	diff to at osc ground 0.00000, 0.0035% diff
# qbt freq at osc 2:	0.02162, 	diff to at osc ground 0.00000, 0.0087% diff
# qbt freq at osc 3:	0.02162, 	diff to at osc ground 0.00000, 0.0156% diff
# qbt freq at osc 4:	0.02162, 	diff to at osc ground 0.00001, 0.0243% diff
# qbt freq at osc 5:	0.02163, 	diff to at osc ground 0.00001, 0.0346% diff
# qbt freq at osc 6:	0.02163, 	diff to at osc ground 0.00001, 0.0466% diff
# qbt freq at osc 7:	0.02163, 	diff to at osc ground 0.00001, 0.0603% diff
# qbt freq at osc 8:	0.02163, 	diff to at osc ground 0.00002, 0.0757% diff
# qbt freq at osc 9:	0.02164, 	diff to at osc ground 0.00002, 0.0927% diff
# qbt freq at osc 10:	0.02164, 	diff to at osc ground 0.00002, 0.1112% diff
# qbt freq at osc 11:	0.02165, 	diff to at osc ground 0.00003, 0.1315% diff
# qbt freq at osc 12:	0.02165, 	diff to at osc ground 0.00003, 0.1532% diff
# qbt freq at osc 13:	0.02166, 	diff to at osc ground 0.00004, 0.1766% diff
# qbt freq at osc 14:	0.02166, 	diff to at osc ground 0.00004, 0.2016% diff
# qbt freq at osc 15:	0.02167, 	diff to at osc ground 0.00005, 0.2280% diff
# qbt freq at osc 16:	0.02167, 	diff to at osc ground 0.00006, 0.2560% diff
# qbt freq at osc 17:	0.02168, 	diff to at osc ground 0.00006, 0.2856% diff
# qbt freq at osc 18:	0.02169, 	diff to at osc ground 0.00007, 0.3166% diff
# qbt freq at osc 19:	0.02169, 	diff to at osc ground 0.00008, 0.3491% diff
# qbt freq at osc 20:	0.02170, 	diff to at osc ground 0.00008, 0.3831% diff
# qbt freq at osc 21:	0.02171, 	diff to at osc ground 0.00009, 0.4186% diff
# qbt freq at osc 22:	0.02172, 	diff to at osc ground 0.00010, 0.4555% diff
# qbt freq at osc 23:	0.02172, 	diff to at osc ground 0.00011, 0.4938% diff
# qbt freq at osc 24:	0.02173, 	diff to at osc ground 0.00012, 0.5336% diff
# qbt freq at osc 25:	0.02174, 	diff to at osc ground 0.00012, 0.5747% diff
# qbt freq at osc 26:	0.02175, 	diff to at osc ground 0.00013, 0.6172% diff
# qbt freq at osc 27:	0.02176, 	diff to at osc ground 0.00014, 0.6611% diff
# qbt freq at osc 28:	0.02177, 	diff to at osc ground 0.00015, 0.7063% diff
# qbt freq at osc 29:	0.02178, 	diff to at osc ground 0.00016, 0.7529% diff
# qbt freq at osc 30:	0.02179, 	diff to at osc ground 0.00017, 0.8008% diff
# qbt freq at osc 31:	0.02180, 	diff to at osc ground 0.00018, 0.8499% diff
# qbt freq at osc 32:	0.02181, 	diff to at osc ground 0.00019, 0.9003% diff
# qbt freq at osc 33:	0.02182, 	diff to at osc ground 0.00021, 0.9520% diff
# qbt freq at osc 34:	0.02184, 	diff to at osc ground 0.00022, 1.0049% diff
# qbt freq at osc 35:	0.02185, 	diff to at osc ground 0.00023, 1.0590% diff
# qbt freq at osc 36:	0.02186, 	diff to at osc ground 0.00024, 1.1143% diff
# qbt freq at osc 37:	0.02187, 	diff to at osc ground 0.00025, 1.1707% diff
# qbt freq at osc 38:	0.02188, 	diff to at osc ground 0.00027, 1.2283% diff
# qbt freq at osc 39:	0.02190, 	diff to at osc ground 0.00028, 1.2870% diff
# qbt freq at osc 40:	0.02191, 	diff to at osc ground 0.00029, 1.3467% diff
# qbt freq at osc 41:	0.02192, 	diff to at osc ground 0.00030, 1.4074% diff
# qbt freq at osc 42:	0.02194, 	diff to at osc ground 0.00032, 1.4692% diff
# qbt freq at osc 43:	0.02195, 	diff to at osc ground 0.00033, 1.5318% diff
# qbt freq at osc 44:	0.02196, 	diff to at osc ground 0.00034, 1.5954% diff
# qbt freq at osc 45:	0.02198, 	diff to at osc ground 0.00036, 1.6598% diff
# qbt freq at osc 46:	0.02199, 	diff to at osc ground 0.00037, 1.7249% diff
# qbt freq at osc 47:	0.02201, 	diff to at osc ground 0.00039, 1.7908% diff
# qbt freq at osc 48:	0.02202, 	diff to at osc ground 0.00040, 1.8573% diff
# qbt freq at osc 49:	0.02203, 	diff to at osc ground 0.00042, 1.9243% diff
# qbt freq at osc 50:	0.02205, 	diff to at osc ground 0.00043, 1.9917% diff
# qbt freq at osc 51:	0.02206, 	diff to at osc ground 0.00045, 2.0593% diff
# qbt freq at osc 52:	0.02208, 	diff to at osc ground 0.00046, 2.1271% diff
# qbt freq at osc 53:	0.02209, 	diff to at osc ground 0.00047, 2.1947% diff
# qbt freq at osc 54:	0.02211, 	diff to at osc ground 0.00049, 2.2620% diff
# qbt freq at osc 55:	0.02212, 	diff to at osc ground 0.00050, 2.3287% diff
# qbt freq at osc 56:	0.02214, 	diff to at osc ground 0.00052, 2.3943% diff
# qbt freq at osc 57:	0.02215, 	diff to at osc ground 0.00053, 2.4583% diff
# qbt freq at osc 58:	0.02216, 	diff to at osc ground 0.00054, 2.5089% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.17294	7.17435	7.17435	7.17386
# oscillator transition 1-2: 	7.17301	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 7.007027122085674e-05
# oscillator transition 2-3: 	7.17307	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00012746249769701734
# oscillator transition 3-4: 	7.17311	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00017555774623101428
# oscillator transition 4-5: 	7.17315	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00021659770992865646
# oscillator transition 5-6: 	7.17319	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002521351331727928
# oscillator transition 6-7: 	7.17322	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00028328407456879034
# oscillator transition 7-8: 	7.17325	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003108673228160441
# oscillator transition 8-9: 	7.17327	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00033550745951682615
# oscillator transition 9-10: 	7.17330	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00035768538692959595
# oscillator transition 10-11: 	7.17332	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003777792166905769
# oscillator transition 11-12: 	7.17333	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00039609086586178677
# oscillator transition 12-13: 	7.17335	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004128647012739961
# oscillator transition 13-14: 	7.17337	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004283008962024937
# oscillator transition 14-15: 	7.17338	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004425651867299152
# oscillator transition 15-16: 	7.17339	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004557961190405635
# oscillator transition 16-17: 	7.17341	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004681105176151945
# oscillator transition 17-18: 	7.17342	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00047960766876453675
# oscillator transition 18-19: 	7.17343	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004903725562703798
# oscillator transition 19-20: 	7.17344	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005004784025848252
# oscillator transition 20-21: 	7.17345	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005099886751898097
# oscillator transition 21-22: 	7.17346	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005189586923668443
# oscillator transition 22-23: 	7.17347	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005274369168253301
# oscillator transition 23-24: 	7.17347	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005354660078173978
# oscillator transition 24-25: 	7.17348	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00054308368208833
# oscillator transition 25-26: 	7.17349	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005503234225718856
# oscillator transition 26-27: 	7.17349	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005572150726598224
# oscillator transition 27-28: 	7.17350	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000563785322639454
# oscillator transition 28-29: 	7.17351	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005700581254179937
# oscillator transition 29-30: 	7.17351	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005760550490370164
# oscillator transition 30-31: 	7.17352	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005817955662612562
# oscillator transition 31-32: 	7.17353	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005872973140403914
# oscillator transition 32-33: 	7.17353	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005925763047391897
# oscillator transition 33-34: 	7.17354	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000597647114260802
# oscillator transition 34-35: 	7.17354	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000602523044334724
# oscillator transition 35-36: 	7.17354	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006072162585146756
# oscillator transition 36-37: 	7.17355	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006117379066088446
# oscillator transition 37-38: 	7.17355	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006160982271969928
# oscillator transition 38-39: 	7.17356	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006203066451169192
# oscillator transition 39-40: 	7.17356	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006243718443377233
# oscillator transition 40-41: 	7.17357	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006283018538217888
# oscillator transition 41-42: 	7.17357	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006321040920900245
# oscillator transition 42-43: 	7.17357	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006357854429372978
# oscillator transition 43-44: 	7.17358	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006393522881742442
# oscillator transition 44-45: 	7.17358	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006428105654938676
# oscillator transition 45-46: 	7.17358	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006461657989964564
# oscillator transition 46-47: 	7.17359	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006494231409126527
# oscillator transition 47-48: 	7.17359	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006525873978082686
# oscillator transition 48-49: 	7.17359	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006556630628713478
# oscillator transition 49-50: 	7.17360	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006586543425148861
# oscillator transition 50-51: 	7.26413	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.09119422877918648
# oscillator transition 51-52: 	7.17449	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015548854450733174
# oscillator transition 52-53: 	7.17449	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015523568931419263
# oscillator transition 53-54: 	7.17449	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015498991121765116
# oscillator transition 54-55: 	7.17449	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015475090324619245
# oscillator transition 55-56: 	7.17448	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00154518379500157
# oscillator transition 56-57: 	7.17448	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015429492024443547
# oscillator transition 57-58: 	7.17450	7.17437	7.17438	7.17428  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015604509227662433
# oscillator transition 58-59: 	7.18314	7.18944	7.19074	7.24101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.01020638007153618
#
# 10-11: 7.1743, diff to 00-01: 0.0014112696518964185
# 20-21: 7.1743, diff to 00-01: 0.0014120205036922684

# %%
plt.figure(figsize = (3,3))
n_osc_lvls = 20
dressed_osc_frequencies = [[] for _ in range(3)]
for j in [0,1,2]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [0,1,2]:
    plt.plot(list(range(max_ol-1))[:n_osc_lvls], dressed_osc_frequencies[j][:n_osc_lvls],label=rf'$\omega_{{{j},n+1}} - \omega_{{{j},n}}$')

plt.xticks(list(range(n_osc_lvls))[::2])
# plt.xticklabels([str(i) for i in range(n_osc_lvls)])
plt.legend(loc='lower right')

# %%
plt.figure(figsize = (3,3))
n_osc_lvls = 20
dressed_osc_frequencies = [[] for _ in range(3)]
for j in [1,2]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [1,2]:
    plt.plot(list(range(max_ol-1))[:n_osc_lvls], dressed_osc_frequencies[j][:n_osc_lvls],label=rf'$\omega_{{{j},n+1}} - \omega_{{{j},n}}$')

plt.xticks(list(range(n_osc_lvls))[::2])
# plt.xticklabels([str(i) for i in range(n_osc_lvls)])
plt.ylim(7.1742,7.1744)
plt.legend(loc='lower right')

# %% [markdown]
# # Old interaction term

# %%
EJ = 2.65
EC = 0.6
EL = 0.13

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.17391479]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2.178418441731167e-06
#              x: [ 7.174e+00]
#            nit: 13
#           nfev: 27
#  final_simplex: (array([[ 7.174e+00],
#                        [ 7.174e+00]]), array([ 2.178e-06,  6.199e-06]))
# Optimal solution: [7.17391479]
# Objective value: 2.178418441731167e-06

# %%
max_ol = 60
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.14
system = FluxoniumOscillatorSystem(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.02161788430113387
# qbt freq at osc 1:	0.02162, 	diff to at osc ground 0.00000, 0.0035% diff
# qbt freq at osc 2:	0.02162, 	diff to at osc ground 0.00000, 0.0087% diff
# qbt freq at osc 3:	0.02162, 	diff to at osc ground 0.00000, 0.0156% diff
# qbt freq at osc 4:	0.02162, 	diff to at osc ground 0.00001, 0.0243% diff
# qbt freq at osc 5:	0.02163, 	diff to at osc ground 0.00001, 0.0346% diff
# qbt freq at osc 6:	0.02163, 	diff to at osc ground 0.00001, 0.0466% diff
# qbt freq at osc 7:	0.02163, 	diff to at osc ground 0.00001, 0.0603% diff
# qbt freq at osc 8:	0.02163, 	diff to at osc ground 0.00002, 0.0757% diff
# qbt freq at osc 9:	0.02164, 	diff to at osc ground 0.00002, 0.0927% diff
# qbt freq at osc 10:	0.02164, 	diff to at osc ground 0.00002, 0.1112% diff
# qbt freq at osc 11:	0.02165, 	diff to at osc ground 0.00003, 0.1315% diff
# qbt freq at osc 12:	0.02165, 	diff to at osc ground 0.00003, 0.1532% diff
# qbt freq at osc 13:	0.02166, 	diff to at osc ground 0.00004, 0.1766% diff
# qbt freq at osc 14:	0.02166, 	diff to at osc ground 0.00004, 0.2016% diff
# qbt freq at osc 15:	0.02167, 	diff to at osc ground 0.00005, 0.2280% diff
# qbt freq at osc 16:	0.02167, 	diff to at osc ground 0.00006, 0.2560% diff
# qbt freq at osc 17:	0.02168, 	diff to at osc ground 0.00006, 0.2856% diff
# qbt freq at osc 18:	0.02169, 	diff to at osc ground 0.00007, 0.3166% diff
# qbt freq at osc 19:	0.02169, 	diff to at osc ground 0.00008, 0.3491% diff
# qbt freq at osc 20:	0.02170, 	diff to at osc ground 0.00008, 0.3831% diff
# qbt freq at osc 21:	0.02171, 	diff to at osc ground 0.00009, 0.4186% diff
# qbt freq at osc 22:	0.02172, 	diff to at osc ground 0.00010, 0.4555% diff
# qbt freq at osc 23:	0.02172, 	diff to at osc ground 0.00011, 0.4938% diff
# qbt freq at osc 24:	0.02173, 	diff to at osc ground 0.00012, 0.5336% diff
# qbt freq at osc 25:	0.02174, 	diff to at osc ground 0.00012, 0.5747% diff
# qbt freq at osc 26:	0.02175, 	diff to at osc ground 0.00013, 0.6172% diff
# qbt freq at osc 27:	0.02176, 	diff to at osc ground 0.00014, 0.6611% diff
# qbt freq at osc 28:	0.02177, 	diff to at osc ground 0.00015, 0.7063% diff
# qbt freq at osc 29:	0.02178, 	diff to at osc ground 0.00016, 0.7529% diff
# qbt freq at osc 30:	0.02179, 	diff to at osc ground 0.00017, 0.8008% diff
# qbt freq at osc 31:	0.02180, 	diff to at osc ground 0.00018, 0.8499% diff
# qbt freq at osc 32:	0.02181, 	diff to at osc ground 0.00019, 0.9003% diff
# qbt freq at osc 33:	0.02182, 	diff to at osc ground 0.00021, 0.9520% diff
# qbt freq at osc 34:	0.02184, 	diff to at osc ground 0.00022, 1.0049% diff
# qbt freq at osc 35:	0.02185, 	diff to at osc ground 0.00023, 1.0590% diff
# qbt freq at osc 36:	0.02186, 	diff to at osc ground 0.00024, 1.1143% diff
# qbt freq at osc 37:	0.02187, 	diff to at osc ground 0.00025, 1.1707% diff
# qbt freq at osc 38:	0.02188, 	diff to at osc ground 0.00027, 1.2283% diff
# qbt freq at osc 39:	0.02190, 	diff to at osc ground 0.00028, 1.2870% diff
# qbt freq at osc 40:	0.02191, 	diff to at osc ground 0.00029, 1.3467% diff
# qbt freq at osc 41:	0.02192, 	diff to at osc ground 0.00030, 1.4074% diff
# qbt freq at osc 42:	0.02194, 	diff to at osc ground 0.00032, 1.4692% diff
# qbt freq at osc 43:	0.02195, 	diff to at osc ground 0.00033, 1.5318% diff
# qbt freq at osc 44:	0.02196, 	diff to at osc ground 0.00034, 1.5954% diff
# qbt freq at osc 45:	0.02198, 	diff to at osc ground 0.00036, 1.6598% diff
# qbt freq at osc 46:	0.02199, 	diff to at osc ground 0.00037, 1.7249% diff
# qbt freq at osc 47:	0.02201, 	diff to at osc ground 0.00039, 1.7908% diff
# qbt freq at osc 48:	0.02202, 	diff to at osc ground 0.00040, 1.8573% diff
# qbt freq at osc 49:	0.02203, 	diff to at osc ground 0.00042, 1.9243% diff
# qbt freq at osc 50:	0.02205, 	diff to at osc ground 0.00043, 1.9917% diff
# qbt freq at osc 51:	0.02206, 	diff to at osc ground 0.00045, 2.0593% diff
# qbt freq at osc 52:	0.02208, 	diff to at osc ground 0.00046, 2.1271% diff
# qbt freq at osc 53:	0.02209, 	diff to at osc ground 0.00047, 2.1947% diff
# qbt freq at osc 54:	0.02211, 	diff to at osc ground 0.00049, 2.2620% diff
# qbt freq at osc 55:	0.02212, 	diff to at osc ground 0.00050, 2.3287% diff
# qbt freq at osc 56:	0.02214, 	diff to at osc ground 0.00052, 2.3943% diff
# qbt freq at osc 57:	0.02215, 	diff to at osc ground 0.00053, 2.4583% diff
# qbt freq at osc 58:	0.02216, 	diff to at osc ground 0.00054, 2.5089% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.17294	7.17435	7.17435	7.17386
# oscillator transition 1-2: 	7.17301	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 7.007027122085674e-05
# oscillator transition 2-3: 	7.17307	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00012746249769701734
# oscillator transition 3-4: 	7.17311	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00017555774623101428
# oscillator transition 4-5: 	7.17315	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00021659770992865646
# oscillator transition 5-6: 	7.17319	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002521351331727928
# oscillator transition 6-7: 	7.17322	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00028328407456879034
# oscillator transition 7-8: 	7.17325	7.17435	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003108673228160441
# oscillator transition 8-9: 	7.17327	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00033550745951682615
# oscillator transition 9-10: 	7.17330	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00035768538692959595
# oscillator transition 10-11: 	7.17332	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003777792166905769
# oscillator transition 11-12: 	7.17333	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00039609086586178677
# oscillator transition 12-13: 	7.17335	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004128647012739961
# oscillator transition 13-14: 	7.17337	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004283008962024937
# oscillator transition 14-15: 	7.17338	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004425651867299152
# oscillator transition 15-16: 	7.17339	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004557961190405635
# oscillator transition 16-17: 	7.17341	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004681105176151945
# oscillator transition 17-18: 	7.17342	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00047960766876453675
# oscillator transition 18-19: 	7.17343	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004903725562703798
# oscillator transition 19-20: 	7.17344	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005004784025848252
# oscillator transition 20-21: 	7.17345	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005099886751898097
# oscillator transition 21-22: 	7.17346	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005189586923668443
# oscillator transition 22-23: 	7.17347	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005274369168253301
# oscillator transition 23-24: 	7.17347	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005354660078173978
# oscillator transition 24-25: 	7.17348	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00054308368208833
# oscillator transition 25-26: 	7.17349	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005503234225718856
# oscillator transition 26-27: 	7.17349	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005572150726598224
# oscillator transition 27-28: 	7.17350	7.17434	7.17435	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000563785322639454
# oscillator transition 28-29: 	7.17351	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005700581254179937
# oscillator transition 29-30: 	7.17351	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005760550490370164
# oscillator transition 30-31: 	7.17352	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005817955662612562
# oscillator transition 31-32: 	7.17353	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005872973140403914
# oscillator transition 32-33: 	7.17353	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005925763047391897
# oscillator transition 33-34: 	7.17354	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000597647114260802
# oscillator transition 34-35: 	7.17354	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000602523044334724
# oscillator transition 35-36: 	7.17354	7.17433	7.17434	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006072162585146756
# oscillator transition 36-37: 	7.17355	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006117379066088446
# oscillator transition 37-38: 	7.17355	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006160982271969928
# oscillator transition 38-39: 	7.17356	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006203066451169192
# oscillator transition 39-40: 	7.17356	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006243718443377233
# oscillator transition 40-41: 	7.17357	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006283018538217888
# oscillator transition 41-42: 	7.17357	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006321040920900245
# oscillator transition 42-43: 	7.17357	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006357854429372978
# oscillator transition 43-44: 	7.17358	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006393522881742442
# oscillator transition 44-45: 	7.17358	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006428105654938676
# oscillator transition 45-46: 	7.17358	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006461657989964564
# oscillator transition 46-47: 	7.17359	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006494231409126527
# oscillator transition 47-48: 	7.17359	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006525873978082686
# oscillator transition 48-49: 	7.17359	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006556630628713478
# oscillator transition 49-50: 	7.17360	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006586543425148861
# oscillator transition 50-51: 	7.26413	7.17433	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.09119422877918648
# oscillator transition 51-52: 	7.17449	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015548854450733174
# oscillator transition 52-53: 	7.17449	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015523568931419263
# oscillator transition 53-54: 	7.17449	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015498991121765116
# oscillator transition 54-55: 	7.17449	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015475090324619245
# oscillator transition 55-56: 	7.17448	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00154518379500157
# oscillator transition 56-57: 	7.17448	7.17432	7.17434	7.17387  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015429492024443547
# oscillator transition 57-58: 	7.17450	7.17437	7.17438	7.17428  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015604509227662433
# oscillator transition 58-59: 	7.18314	7.18944	7.19074	7.24101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.01020638007153618
#
# 10-11: 7.1743, diff to 00-01: 0.0014112696518964185
# 20-21: 7.1743, diff to 00-01: 0.0014120205036922684

# %%
dressed_osc_frequencies = [[] for _ in range(3)]
for j in [0,1,2]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [0,1,2]:
    plt.plot(list(range(max_ol-1))[:20], dressed_osc_frequencies[j][:20],label=f'{j}')
plt.legend()

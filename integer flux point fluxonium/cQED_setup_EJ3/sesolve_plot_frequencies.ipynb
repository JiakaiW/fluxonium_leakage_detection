# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
sys.path.append('../')
from utils_models import *

# %%
EJ = 3
EC = EJ/4
EL = EJ/20.5  

qubit_level = 40


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [8.32993958]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 4.929763194501391e-07
#              x: [ 8.461e+00]
#            nit: 14
#           nfev: 28
#  final_simplex: (array([[ 8.461e+00],
#                        [ 8.461e+00]]), array([ 4.930e-07,  1.087e-06]))
# Optimal solution: [8.46111172]
# Objective value: 4.929763194501391e-07

# %%
Er = result.x[0]

g = 0.17



max_ol = 80
max_ql = 30
system = FluxoniumOscillatorSystem(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = Er,
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
# plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.030190796434001355
# qbt freq at osc 1:	0.03019, 	diff to at osc ground -0.00000, 0.0029% diff
# qbt freq at osc 2:	0.03019, 	diff to at osc ground -0.00000, 0.0067% diff
# qbt freq at osc 3:	0.03019, 	diff to at osc ground -0.00000, 0.0112% diff
# qbt freq at osc 4:	0.03019, 	diff to at osc ground -0.00000, 0.0165% diff
# qbt freq at osc 5:	0.03018, 	diff to at osc ground -0.00001, 0.0225% diff
# qbt freq at osc 6:	0.03018, 	diff to at osc ground -0.00001, 0.0291% diff
# qbt freq at osc 7:	0.03018, 	diff to at osc ground -0.00001, 0.0364% diff
# qbt freq at osc 8:	0.03018, 	diff to at osc ground -0.00001, 0.0443% diff
# qbt freq at osc 9:	0.03017, 	diff to at osc ground -0.00002, 0.0528% diff
# qbt freq at osc 10:	0.03017, 	diff to at osc ground -0.00002, 0.0619% diff
# qbt freq at osc 11:	0.03017, 	diff to at osc ground -0.00002, 0.0716% diff
# qbt freq at osc 12:	0.03017, 	diff to at osc ground -0.00002, 0.0819% diff
# qbt freq at osc 13:	0.03016, 	diff to at osc ground -0.00003, 0.0927% diff
# qbt freq at osc 14:	0.03016, 	diff to at osc ground -0.00003, 0.1041% diff
# qbt freq at osc 15:	0.03016, 	diff to at osc ground -0.00004, 0.1160% diff
# qbt freq at osc 16:	0.03015, 	diff to at osc ground -0.00004, 0.1285% diff
# qbt freq at osc 17:	0.03015, 	diff to at osc ground -0.00004, 0.1416% diff
# qbt freq at osc 18:	0.03014, 	diff to at osc ground -0.00005, 0.1552% diff
# qbt freq at osc 19:	0.03014, 	diff to at osc ground -0.00005, 0.1693% diff
# qbt freq at osc 20:	0.03014, 	diff to at osc ground -0.00006, 0.1840% diff
# qbt freq at osc 21:	0.03013, 	diff to at osc ground -0.00006, 0.1992% diff
# qbt freq at osc 22:	0.03013, 	diff to at osc ground -0.00006, 0.2149% diff
# qbt freq at osc 23:	0.03012, 	diff to at osc ground -0.00007, 0.2312% diff
# qbt freq at osc 24:	0.03012, 	diff to at osc ground -0.00007, 0.2480% diff
# qbt freq at osc 25:	0.03011, 	diff to at osc ground -0.00008, 0.2654% diff
# qbt freq at osc 26:	0.03011, 	diff to at osc ground -0.00009, 0.2833% diff
# qbt freq at osc 27:	0.03010, 	diff to at osc ground -0.00009, 0.3017% diff
# qbt freq at osc 28:	0.03009, 	diff to at osc ground -0.00010, 0.3207% diff
# qbt freq at osc 29:	0.03009, 	diff to at osc ground -0.00010, 0.3403% diff
# qbt freq at osc 30:	0.03008, 	diff to at osc ground -0.00011, 0.3604% diff
# qbt freq at osc 31:	0.03008, 	diff to at osc ground -0.00012, 0.3810% diff
# qbt freq at osc 32:	0.03007, 	diff to at osc ground -0.00012, 0.4022% diff
# qbt freq at osc 33:	0.03006, 	diff to at osc ground -0.00013, 0.4240% diff
# qbt freq at osc 34:	0.03006, 	diff to at osc ground -0.00013, 0.4463% diff
# qbt freq at osc 35:	0.03005, 	diff to at osc ground -0.00014, 0.4692% diff
# qbt freq at osc 36:	0.03004, 	diff to at osc ground -0.00015, 0.4926% diff
# qbt freq at osc 37:	0.03003, 	diff to at osc ground -0.00016, 0.5167% diff
# qbt freq at osc 38:	0.03003, 	diff to at osc ground -0.00016, 0.5413% diff
# qbt freq at osc 39:	0.03002, 	diff to at osc ground -0.00017, 0.5665% diff
# qbt freq at osc 40:	0.03001, 	diff to at osc ground -0.00018, 0.5923% diff
# qbt freq at osc 41:	0.03000, 	diff to at osc ground -0.00019, 0.6187% diff
# qbt freq at osc 42:	0.03000, 	diff to at osc ground -0.00019, 0.6457% diff
# qbt freq at osc 43:	0.02999, 	diff to at osc ground -0.00020, 0.6732% diff
# qbt freq at osc 44:	0.02998, 	diff to at osc ground -0.00021, 0.7014% diff
# qbt freq at osc 45:	0.02997, 	diff to at osc ground -0.00022, 0.7302% diff
# qbt freq at osc 46:	0.02996, 	diff to at osc ground -0.00023, 0.7597% diff
# qbt freq at osc 47:	0.02995, 	diff to at osc ground -0.00024, 0.7897% diff
# qbt freq at osc 48:	0.02994, 	diff to at osc ground -0.00025, 0.8204% diff
# qbt freq at osc 49:	0.02993, 	diff to at osc ground -0.00026, 0.8517% diff
# qbt freq at osc 50:	0.02992, 	diff to at osc ground -0.00027, 0.8836% diff
# qbt freq at osc 51:	0.02991, 	diff to at osc ground -0.00028, 0.9162% diff
# qbt freq at osc 52:	0.02990, 	diff to at osc ground -0.00029, 0.9495% diff
# qbt freq at osc 53:	0.02989, 	diff to at osc ground -0.00030, 0.9834% diff
# qbt freq at osc 54:	0.02988, 	diff to at osc ground -0.00031, 1.0180% diff
# qbt freq at osc 55:	0.02987, 	diff to at osc ground -0.00032, 1.0532% diff
# qbt freq at osc 56:	0.02986, 	diff to at osc ground -0.00033, 1.0891% diff
# qbt freq at osc 57:	0.02985, 	diff to at osc ground -0.00034, 1.1258% diff
# qbt freq at osc 58:	0.02984, 	diff to at osc ground -0.00035, 1.1631% diff
# qbt freq at osc 59:	0.02983, 	diff to at osc ground -0.00036, 1.2011% diff
# qbt freq at osc 60:	0.02982, 	diff to at osc ground -0.00037, 1.2398% diff
# qbt freq at osc 61:	0.02980, 	diff to at osc ground -0.00039, 1.2793% diff
# qbt freq at osc 62:	0.02979, 	diff to at osc ground -0.00040, 1.3194% diff
# qbt freq at osc 63:	0.02978, 	diff to at osc ground -0.00041, 1.3603% diff
# qbt freq at osc 64:	0.02977, 	diff to at osc ground -0.00042, 1.4020% diff
# qbt freq at osc 65:	0.02975, 	diff to at osc ground -0.00044, 1.4444% diff
# qbt freq at osc 66:	0.02974, 	diff to at osc ground -0.00045, 1.4875% diff
# qbt freq at osc 67:	0.02973, 	diff to at osc ground -0.00046, 1.5314% diff
# qbt freq at osc 68:	0.02971, 	diff to at osc ground -0.00048, 1.5761% diff
# qbt freq at osc 69:	0.02970, 	diff to at osc ground -0.00049, 1.6216% diff
# qbt freq at osc 70:	0.02969, 	diff to at osc ground -0.00050, 1.6679% diff
# qbt freq at osc 71:	0.02967, 	diff to at osc ground -0.00052, 1.7150% diff
# qbt freq at osc 72:	0.02966, 	diff to at osc ground -0.00053, 1.7629% diff
# qbt freq at osc 73:	0.02964, 	diff to at osc ground -0.00055, 1.8116% diff
# qbt freq at osc 74:	0.02963, 	diff to at osc ground -0.00056, 1.8612% diff
# qbt freq at osc 75:	0.02961, 	diff to at osc ground -0.00058, 1.9116% diff
# qbt freq at osc 76:	0.02960, 	diff to at osc ground -0.00059, 1.9629% diff
# qbt freq at osc 77:	0.02958, 	diff to at osc ground -0.00061, 2.0151% diff
# qbt freq at osc 78:	0.02957, 	diff to at osc ground -0.00062, 2.0549% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	8.46044	8.46154	8.46154	8.46098
# oscillator transition 1-2: 	8.46046	8.46154	8.46154	8.46098  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 1.9867805781004222e-05
# oscillator transition 2-3: 	8.46048	8.46154	8.46154	8.46098  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 3.802032458111171e-05
# oscillator transition 3-4: 	8.46049	8.46154	8.46154	8.46098  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 5.468369411865126e-05
# oscillator transition 4-5: 	8.46051	8.46154	8.46154	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 7.004470765714643e-05
# oscillator transition 5-6: 	8.46052	8.46154	8.46154	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 8.425918783849795e-05
# oscillator transition 6-7: 	8.46053	8.46154	8.46154	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 9.745826776885735e-05
# oscillator transition 7-8: 	8.46055	8.46154	8.46154	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00010975319755068824
# oscillator transition 8-9: 	8.46056	8.46154	8.46154	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00012123904101635219
# oscillator transition 9-10: 	8.46057	8.46154	8.46154	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00013199757985127292
# oscillator transition 10-11: 	8.46058	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00014209960043309877
# oscillator transition 11-12: 	8.46059	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0001516067143345623
# oscillator transition 12-13: 	8.46060	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0001605728290545727
# oscillator transition 13-14: 	8.46061	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00016904534256845238
# oscillator transition 14-15: 	8.46061	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00017706610925394273
# oscillator transition 15-16: 	8.46062	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00018467224921359104
# oscillator transition 16-17: 	8.46063	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0001918968097047724
# oscillator transition 17-18: 	8.46064	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00019876932058515706
# oscillator transition 18-19: 	8.46064	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00020531625777131524
# oscillator transition 19-20: 	8.46065	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002115614352735662
# oscillator transition 20-21: 	8.46065	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00021752634237692803
# oscillator transition 21-22: 	8.46066	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00022323041833693935
# oscillator transition 22-23: 	8.46067	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00022869130337177523
# oscillator transition 23-24: 	8.46067	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00023392504039954076
# oscillator transition 24-25: 	8.46068	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000238946257562489
# oscillator transition 25-26: 	8.46068	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00024376832454642283
# oscillator transition 26-27: 	8.46069	8.46154	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002484034842584748
# oscillator transition 27-28: 	8.46069	8.46153	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002528629752394096
# oscillator transition 28-29: 	8.46069	8.46153	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002571571319922583
# oscillator transition 29-30: 	8.46070	8.46153	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002612954753917762
# oscillator transition 30-31: 	8.46070	8.46153	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002652867938000014
# oscillator transition 31-32: 	8.46071	8.46153	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002691392127278647
# oscillator transition 32-33: 	8.46071	8.46153	8.46153	8.46099  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002728602587556139
# oscillator transition 33-34: 	8.46071	8.46153	8.46153	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00027645691273825435
# oscillator transition 34-35: 	8.46072	8.46153	8.46153	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00027993565834982803
# oscillator transition 35-36: 	8.46072	8.46153	8.46153	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00028330252974662073
# oscillator transition 36-37: 	8.46072	8.46153	8.46153	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002865631490269749
# oscillator transition 37-38: 	8.46073	8.46153	8.46153	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002897227594278462
# oscillator transition 38-39: 	8.46073	8.46153	8.46153	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002927862588624208
# oscillator transition 39-40: 	8.46073	8.46153	8.46153	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002957582291376326
# oscillator transition 40-41: 	8.46074	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002986429596578688
# oscillator transition 41-42: 	8.46074	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00030144447323188217
# oscillator transition 42-43: 	8.46074	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003041665427847562
# oscillator transition 43-44: 	8.46074	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00030681271443633307
# oscillator transition 44-45: 	8.46075	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00030938632495214335
# oscillator transition 45-46: 	8.46075	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003118905112931003
# oscillator transition 46-47: 	8.46075	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003143282345465792
# oscillator transition 47-48: 	8.46075	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00031670228242752785
# oscillator transition 48-49: 	8.46076	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003190152928684853
# oscillator transition 49-50: 	8.46076	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003212697527690267
# oscillator transition 50-51: 	8.46076	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003234680172088389
# oscillator transition 51-52: 	8.46076	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003256123147341583
# oscillator transition 52-53: 	8.46076	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00032770475469057203
# oscillator transition 53-54: 	8.46077	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00032974734006963047
# oscillator transition 54-55: 	8.46077	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003317419673951605
# oscillator transition 55-56: 	8.46077	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000333690437523515
# oscillator transition 56-57: 	8.46077	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003355944670122568
# oscillator transition 57-58: 	8.46077	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003374556797641759
# oscillator transition 58-59: 	8.46078	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003392756258424612
# oscillator transition 59-60: 	8.46078	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00034105577652532304
# oscillator transition 60-61: 	8.46078	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00034279754067689794
# oscillator transition 61-62: 	8.46078	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00034450225542492774
# oscillator transition 62-63: 	8.46078	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003461711934367173
# oscillator transition 63-64: 	8.46078	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003478055790626655
# oscillator transition 64-65: 	8.46079	8.46153	8.46152	8.46100  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00034940656906634615
# oscillator transition 65-66: 	8.46079	8.46153	8.46152	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00035097528042093984
# oscillator transition 66-67: 	8.46079	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00035251277086878474
# oscillator transition 67-68: 	8.46079	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00035402005881657317
# oscillator transition 68-69: 	8.46079	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003554981145814651
# oscillator transition 69-70: 	8.46079	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00035694787187345867
# oscillator transition 70-71: 	8.46080	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003583702202920591
# oscillator transition 71-72: 	8.46080	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00035976601282960985
# oscillator transition 72-73: 	8.46080	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003611360712145739
# oscillator transition 73-74: 	8.46080	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003624811784082027
# oscillator transition 74-75: 	8.59362	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.1331801319202075
# oscillator transition 75-76: 	8.46170	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0012619616271738465
# oscillator transition 76-77: 	8.46170	8.46153	8.46151	8.46101  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0012608280779975445
# oscillator transition 77-78: 	8.46174	8.46163	8.46161	8.46184  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0012988186681557323
# oscillator transition 78-79: 	8.47492	8.48557	8.48707	8.56416  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.014483222552380326
#
# 10-11: 8.4615, diff to 00-01: 0.0011016472552416445
# 20-21: 8.4615, diff to 00-01: 0.0011007589815772434

# %%
dressed_ener(0,1)-dressed_ener(0,0)
# Out:
# 8.46043705000408

# %%
plt.figure(figsize = (8,3))
n_osc_lvls = max_ol-1
dressed_osc_frequencies = [[] for _ in range(3)]
for j in [0,1,2]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [0,1,2]:
    plt.plot(list(range(max_ol-1))[:n_osc_lvls], dressed_osc_frequencies[j][:n_osc_lvls],label=rf'$\omega_{{{j},n+1}} - \omega_{{{j},n}}$')

plt.xticks(list(range(n_osc_lvls))[::5])
plt.ylim(Er-0.005, Er+0.005)
# plt.ylim(7.9,7.92)

# plt.xticklabels([str(i) for i in range(n_osc_lvls)])
plt.legend(loc='lower right')

# %%
evals, evecs = system.hilbertspace.hamiltonian().eigenstates()
overlap_matrix = scqubits.utils.spectrum_utils.convert_evecs_to_ndarray(evecs)
def print_top_two_dressed_state(product_index):
    overlaps_with_product_state = np.abs(overlap_matrix[:, product_index])
    sorted_indices = np.argsort(overlaps_with_product_state)[::-1]
    sorted_overlaps = overlaps_with_product_state[sorted_indices]
    print(list(sorted_indices)[:2])
    print(list(sorted_overlaps)[:2])

print(f"\t\tqubit 0\t\t\tqubit 1 \t\t qubit 2")

print(f"osc lvl\t\tdressed-overlap^2\tdressed-overlap^2\tdressed-overlap^2")
for i in range(max_ol-1):
    product_index_q0 = 0 * system.osc.truncated_dim + i
    product_index_q1 = 1 * system.osc.truncated_dim + i
    product_index_q2 = 2 * system.osc.truncated_dim + i

    overlaps_with_product_state_q0 = np.abs(overlap_matrix[:, product_index_q0])
    sorted_indices_q0 = np.argsort(overlaps_with_product_state_q0)[::-1]
    sorted_overlaps_q0 = overlaps_with_product_state_q0[sorted_indices_q0]

    overlaps_with_product_state_q1 = np.abs(overlap_matrix[:, product_index_q1])
    sorted_indices_q1 = np.argsort(overlaps_with_product_state_q1)[::-1]
    sorted_overlaps_q1 = overlaps_with_product_state_q1[sorted_indices_q1]
    
    overlaps_with_product_state_q2 = np.abs(overlap_matrix[:, product_index_q2])
    sorted_indices_q2 = np.argsort(overlaps_with_product_state_q2)[::-1]
    sorted_overlaps_q2 = overlaps_with_product_state_q2[sorted_indices_q2]

    print(f"ol-{i}:\t\t{list(sorted_indices_q0)[0]}-{list(sorted_overlaps_q0)[0]**2:.3f} \t\t{list(sorted_indices_q1)[0]}-{list(sorted_overlaps_q1)[0]**2:.3f} \t\t{list(sorted_indices_q2)[0]}-{list(sorted_overlaps_q2)[0]**2:.3f}")
# Out:
# 		qubit 0			qubit 1 		 qubit 2
# osc lvl		dressed-overlap^2	dressed-overlap^2	dressed-overlap^2
# ol-0:		0-1.000 		1-1.000 		2-1.000
# ol-1:		7-0.968 		12-1.000 		13-0.999
# ol-2:		24-0.939 		32-0.999 		33-0.998
# ol-3:		50-0.913 		61-0.999 		62-0.997
# ol-4:		80-0.889 		91-0.998 		92-0.996
# ol-5:		110-0.867 		121-0.998 		122-0.995
# ol-6:		140-0.847 		151-0.998 		152-0.994
# ol-7:		170-0.828 		181-0.997 		182-0.993
# ol-8:		200-0.811 		211-0.997 		212-0.992
# ol-9:		230-0.795 		241-0.996 		242-0.991
# ol-10:		260-0.780 		271-0.996 		272-0.990
# ol-11:		290-0.765 		301-0.996 		302-0.989
# ol-12:		320-0.752 		331-0.995 		332-0.988
# ol-13:		350-0.739 		361-0.995 		362-0.987
# ol-14:		380-0.727 		391-0.994 		392-0.985
# ol-15:		410-0.715 		421-0.994 		422-0.984
# ol-16:		440-0.705 		451-0.994 		452-0.983
# ol-17:		470-0.694 		481-0.993 		482-0.982
# ol-18:		500-0.684 		511-0.993 		512-0.981
# ol-19:		530-0.675 		541-0.992 		542-0.980
# ol-20:		560-0.665 		571-0.992 		572-0.979
# ol-21:		590-0.657 		601-0.992 		602-0.978
# ol-22:		620-0.648 		631-0.991 		632-0.977
# ol-23:		650-0.640 		661-0.991 		662-0.976
# ol-24:		680-0.632 		691-0.990 		692-0.975
# ol-25:		710-0.624 		721-0.990 		722-0.973
# ol-26:		740-0.617 		751-0.990 		752-0.972
# ol-27:		770-0.610 		781-0.989 		782-0.971
# ol-28:		800-0.603 		811-0.989 		812-0.970
# ol-29:		830-0.596 		841-0.988 		842-0.969
# ol-30:		860-0.590 		871-0.988 		872-0.968
# ol-31:		890-0.584 		901-0.988 		902-0.967
# ol-32:		920-0.578 		931-0.987 		932-0.966
# ol-33:		950-0.572 		961-0.987 		962-0.964
# ol-34:		980-0.566 		991-0.987 		992-0.963
# ol-35:		1010-0.560 		1021-0.986 		1022-0.962
# ol-36:		1040-0.555 		1051-0.986 		1052-0.961
# ol-37:		1070-0.550 		1081-0.985 		1082-0.960
# ol-38:		1100-0.544 		1111-0.985 		1112-0.958
# ol-39:		1130-0.539 		1141-0.985 		1142-0.957
# ol-40:		1160-0.534 		1171-0.984 		1172-0.956
# ol-41:		1190-0.530 		1201-0.984 		1202-0.955
# ol-42:		1220-0.525 		1231-0.984 		1232-0.954
# ol-43:		1250-0.520 		1261-0.983 		1262-0.952
# ol-44:		1280-0.516 		1291-0.983 		1292-0.951
# ol-45:		1310-0.512 		1321-0.983 		1322-0.950
# ol-46:		1340-0.507 		1351-0.982 		1352-0.949
# ol-47:		1370-0.503 		1381-0.982 		1382-0.948
# ol-48:		1400-0.499 		1411-0.981 		1412-0.946
# ol-49:		1430-0.495 		1441-0.981 		1442-0.945
# ol-50:		1461-0.494 		1471-0.981 		1472-0.944
# ol-51:		1491-0.498 		1501-0.980 		1502-0.943
# ol-52:		1521-0.501 		1531-0.980 		1532-0.941
# ol-53:		1551-0.505 		1561-0.980 		1562-0.940
# ol-54:		1581-0.508 		1591-0.979 		1592-0.939
# ol-55:		1611-0.511 		1621-0.979 		1622-0.937
# ol-56:		1641-0.515 		1651-0.979 		1652-0.936
# ol-57:		1671-0.518 		1681-0.978 		1682-0.935
# ol-58:		1701-0.521 		1711-0.978 		1712-0.934
# ol-59:		1731-0.524 		1741-0.978 		1742-0.932
# ol-60:		1761-0.527 		1771-0.977 		1772-0.931
# ol-61:		1791-0.530 		1801-0.977 		1802-0.929
# ol-62:		1821-0.533 		1831-0.976 		1832-0.928
# ol-63:		1851-0.535 		1861-0.976 		1862-0.927
# ol-64:		1881-0.538 		1891-0.976 		1892-0.925
# ol-65:		1911-0.541 		1921-0.975 		1922-0.924
# ol-66:		1941-0.544 		1951-0.975 		1952-0.923
# ol-67:		1971-0.546 		1981-0.975 		1982-0.921
# ol-68:		2001-0.549 		2011-0.974 		2012-0.920
# ol-69:		2031-0.551 		2041-0.974 		2042-0.918
# ol-70:		2061-0.554 		2071-0.974 		2072-0.917
# ol-71:		2091-0.556 		2101-0.973 		2102-0.916
# ol-72:		2121-0.558 		2131-0.973 		2132-0.914
# ol-73:		2151-0.561 		2161-0.973 		2162-0.913
# ol-74:		2181-0.563 		2191-0.972 		2192-0.911
# ol-75:		2211-0.565 		2221-0.972 		2222-0.910
# ol-76:		2241-0.568 		2251-0.972 		2252-0.908
# ol-77:		2271-0.570 		2281-0.971 		2282-0.907
# ol-78:		2301-0.573 		2311-0.971 		2312-0.905

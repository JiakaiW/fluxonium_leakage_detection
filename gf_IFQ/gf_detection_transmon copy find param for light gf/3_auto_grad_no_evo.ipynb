# %%
import sys
sys.path.append('../utils')
from utils_models import *
from scipy.optimize import minimize

from utils_jax import *
dq.set_device('cpu')
import optax
# Out:
# WARNING:jax._src.xla_bridge:An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %% [markdown]
# # Get some initial params

# %%
EJ = 3
EC = 3/3
EL = 3/30

n_lvls_transmon  = 4
n_lvls_fluxonium = 20

qsf = qs.Fluxonium.create(
    n_lvls_fluxonium,
    {"Ej": EJ, "Ec": EC, "El": EL, "phi_ext": 0.0},
    N_pre_diag=100,
    use_linear = False
    )

# %%
def detuned_rabi_period(amp_with_2pi, element, detunning):
    # element: obtained from scqubit operator
    # detunning: obtained from scqubit
    return 2*jnp.pi / jnp.sqrt(
        (amp_with_2pi*element)**2
        + (2*jnp.pi*detunning)**2
    )

# %%
def objective(params):    
    one_period_mult = 0.5
    zero_period_mult = 1
    two_period_mult = 1

    Ej_t, g_tf, amp_with_2pi = params
    

    qst = MyTransmon.create(
        N = n_lvls_transmon,
        params = {"Ej": Ej_t, "Ec": 0.2,"ng":0.0},
        N_max_charge=10
        )

    devices = [qsf, qst]
    f_indx = 0
    t_indx = 1
    Ns = [device.N for device in devices]
    fn = qs.promote(qsf.ops["n"], f_indx, Ns)
    tn = qs.promote(qst.ops['n'], t_indx, Ns)

    system = qs.System.create(devices, couplings=[
        g_tf *  fn @ tn
        ])
    system.params["g_tf"] = g_tf
    system_evals_in_product_indices, system_evecs_in_product_indices = system.calculate_eig_linear()
    system_evals_sorted, system_evecs_sorted, product_indices_sorted_by_eval = calculate_eig(Ns, system.get_H())
    driven_op = transform_op_into_dressed_basis_jax(tn, system_evecs_sorted.T)

    def get_dressed_idx(ql,tl):
        return find_closest_dressed_index(ql*qst.N+tl, product_indices_sorted_by_eval)
    zero = system_evals_in_product_indices[0,1] - system_evals_in_product_indices[0,0]
    one = system_evals_in_product_indices[1,1] - system_evals_in_product_indices[1,0]
    two = system_evals_in_product_indices[2,1] - system_evals_in_product_indices[2,0]
    zero_period = detuned_rabi_period(amp_with_2pi, jnp.abs(driven_op[get_dressed_idx(0,0),get_dressed_idx(0,1)]),one -zero)
    one_period = detuned_rabi_period(amp_with_2pi, jnp.abs(driven_op[get_dressed_idx(1,0),get_dressed_idx(1,1)]),one -one)
    two_period = detuned_rabi_period(amp_with_2pi, jnp.abs(driven_op[get_dressed_idx(2,0),get_dressed_idx(2,1)]),one -two)

    return jnp.abs(one_period*one_period_mult - zero_period*zero_period_mult)/one_period + \
        jnp.abs(one_period*one_period_mult - two_period*two_period_mult)/one_period

func = jax.value_and_grad(objective)

# %% [markdown]
# # Analyze the parameters I found from param sweep with g=0.2

# %%
params = jnp.array( [43.95586,  0.1,  0.03917588 ]) #     Ej_t, g_tf, amp_with_2pi = params

optimizer = optax.nadam(learning_rate=jnp.array([1e-2,1e-2,1e-2])) 
opt_state = optimizer.init(params)

num_steps = 1000
for step in range(num_steps):
    val, grads = func(params)
    # clear_output()
    print(f"iter: {step}, val={val:.4f} grads: {grads}, params: {params}")
    if val < 1e-4:
        break
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)

print(f'Optimized params: {params}')
# Out:
# iter: 0, val=0.0081 grads: [ -4.74609975   0.39150813 -12.85961308], params: [4.395586e+01 1.000000e-01 3.917588e-02]
# iter: 1, val=0.2035 grads: [5.22099076 0.34452475 6.25777498], params: [43.97059684  0.08526316  0.05391272]
# iter: 2, val=0.3200 grads: [-5.59046864 -8.66624012  5.04463061], params: [43.96445728  0.07406963  0.05240136]
# iter: 3, val=0.1795 grads: [5.33945013 0.09642121 7.22731532], params: [43.97081077  0.08464136  0.0501968 ]
# iter: 4, val=0.1251 grads: [ 5.26161511 -0.18131269  9.06695044], params: [43.96739175  0.08818988  0.04574107]
# iter: 5, val=0.0614 grads: [-5.234615   -9.84852802 11.81086262], params: [4.39626549e+01 9.15710881e-02 3.95954520e-02]
# iter: 6, val=0.0745 grads: [ -4.65215195   1.2903362  -17.08759415], params: [4.39646646e+01 1.00569610e-01 3.19479437e-02]
# iter: 7, val=0.0300 grads: [ -4.50842596   1.33835453 -15.98654653], params: [4.39677155e+01 1.04167902e-01 3.40812789e-02]
# iter: 8, val=0.0405 grads: [ 4.39121922 -1.30644084 13.98465641], params: [4.39716999e+01 1.06891882e-01 3.78467393e-02]
# iter: 9, val=0.0042 grads: [ 0.01958112  0.06675573 -0.0394792 ], params: [4.39711413e+01 1.10660784e-01 3.53545527e-02]
# iter: 10, val=0.0127 grads: [ -4.09196006   1.49502768 -16.07144698], params: [4.39719153e+01 1.13577790e-01 3.48657535e-02]
# iter: 11, val=0.0475 grads: [ 4.03185625 -1.43793583 14.28865614], params: [4.39749584e+01 1.15213556e-01 3.81832378e-02]
# iter: 12, val=0.0107 grads: [ 3.91605418 -1.50994336 15.54612619], params: [4.39742526e+01 1.18131005e-01 3.61890067e-02]
# iter: 13, val=0.0582 grads: [ -3.75685829   1.5852526  -17.73496707], params: [4.39725572e+01 1.21301181e-01 3.27316541e-02]
# iter: 14, val=0.0218 grads: [ -3.7356368    1.55565417 -16.65402268], params: [4.39740820e+01 1.22616520e-01 3.46379541e-02]
# iter: 15, val=0.0351 grads: [ 3.72846524 -1.49557193 14.9423617 ], params: [4.39764502e+01 1.23274837e-01 3.77448028e-02]
# iter: 16, val=0.0089 grads: [ 3.65194769 -1.5197887  15.75776547], params: [4.39756863e+01 1.25368583e-01 3.64296520e-02]
# iter: 17, val=0.0438 grads: [ -3.54270108   1.55380196 -17.33913878], params: [4.39740483e+01 1.27800079e-01 3.38271858e-02]
# iter: 18, val=0.0101 grads: [ -3.54176289   1.52178692 -16.33384543], params: [4.39752782e+01 1.28463960e-01 3.56302050e-02]
# iter: 19, val=0.0414 grads: [ 3.55122901 -1.46671382 14.79436781], params: [4.39773116e+01 1.28538185e-01 3.84856449e-02]
# iter: 20, val=0.0213 grads: [ 3.50008391 -1.47576468 15.38459341], params: [4.39765000e+01 1.30097494e-01 3.74915140e-02]
# iter: 21, val=0.0217 grads: [ -3.42373548   1.49660732 -16.62925205], params: [4.39748708e+01 1.32041698e-01 3.53404285e-02]
# iter: 22, val=0.0089 grads: [ 3.42987655 -1.46462002 15.71854396], params: [4.39759432e+01 1.32288479e-01 3.70287747e-02]
# iter: 23, val=0.0312 grads: [ -3.35903318   1.47873456 -16.85948614], params: [4.39743944e+01 1.34022475e-01 3.50448798e-02]
# iter: 24, val=0.0059 grads: [ 0.02308009  0.0741426  -0.03879489], params: [4.39754755e+01 1.34075169e-01 3.68097432e-02]
# iter: 25, val=0.0081 grads: [ 3.36271161 -1.43364195 15.68606799], params: [4.39756476e+01 1.34568370e-01 3.72501755e-02]
# iter: 26, val=0.0296 grads: [ -3.30193385   1.44555605 -16.74245977], params: [4.39741228e+01 1.36062423e-01 3.53715649e-02]
# iter: 27, val=0.0060 grads: [ 0.02314004  0.07469863 -0.03921268], params: [4.39752055e+01 1.35890697e-01 3.71524339e-02]
# iter: 28, val=0.0109 grads: [ 3.31841705 -1.40209152 15.54285671], params: [4.39753848e+01 1.36179256e-01 3.76337670e-02]
# iter: 29, val=0.0247 grads: [ -3.26600499   1.41301544 -16.53041735], params: [4.39738683e+01 1.37494477e-01 3.58394093e-02]
# iter: 30, val=0.0079 grads: [ 3.29109076 -1.38469815 15.58285863], params: [4.39749600e+01 1.37152532e-01 3.76199910e-02]
# iter: 31, val=0.0257 grads: [ -3.24229821   1.39334246 -16.50712495], params: [4.39734845e+01 1.38372383e-01 3.59271066e-02]
# iter: 32, val=0.0074 grads: [ 3.27021816 -1.36566511 15.54930827], params: [4.39745973e+01 1.37940670e-01 3.77347360e-02]
# iter: 33, val=0.0245 grads: [ -3.22501135   1.37281853 -16.41841225], params: [4.39731529e+01 1.39081770e-01 3.61278830e-02]
# iter: 34, val=0.0089 grads: [ 3.25450742 -1.34563183 15.46075343], params: [4.39742850e+01 1.38576794e-01 3.79471515e-02]
# iter: 35, val=0.0215 grads: [ -3.21273498   1.35183327 -16.28181809], params: [4.39728640e+01 1.39652724e-01 3.64134364e-02]
# iter: 36, val=0.0117 grads: [ 3.24286067 -1.32498715 15.3315982 ], params: [4.39740140e+01 1.39087952e-01 3.82333675e-02]
# iter: 37, val=0.0173 grads: [ -3.20431375   1.3306041  -16.11072668], params: [4.39726106e+01 1.40109786e-01 3.67620770e-02]
# iter: 38, val=0.0156 grads: [ 3.23437306 -1.30397523 15.17297333], params: [4.39737772e+01 1.39496272e-01 3.85748840e-02]
# iter: 39, val=0.0122 grads: [ -3.19882138   1.30925793 -15.91533446], params: [4.39723867e+01 1.40473015e-01 3.71571320e-02]
# iter: 40, val=0.0203 grads: [ 3.22831394 -1.28275679 14.99345287], params: [4.39735687e+01 1.39819876e-01 3.89573382e-02]
# iter: 41, val=0.0064 grads: [ -3.1955265    1.28787515 -15.70340031], params: [4.39721878e+01 1.40758846e-01 3.75857537e-02]
# iter: 42, val=0.0255 grads: [ 3.22410182 -1.26144396 14.79962386], params: [4.39733842e+01 1.40073628e-01 3.93695651e-02]
# iter: 43, val=0.0063 grads: [ 0.02350226  0.07576192 -0.03786049], params: [4.39720101e+01 1.40980766e-01 3.80380250e-02]
# iter: 44, val=0.0063 grads: [ 0.02382525  0.07558549 -0.03590481], params: [4.39715472e+01 1.41250051e-01 3.77671015e-02]
# iter: 45, val=0.0117 grads: [ -3.17796353   1.25686335 -15.74825969], params: [4.39711195e+01 1.41461895e-01 3.75230905e-02]
# iter: 46, val=0.0224 grads: [ 3.21203273 -1.2308599  14.79164334], params: [4.39724230e+01 1.40628294e-01 3.94171744e-02]
# iter: 47, val=0.0063 grads: [ 0.02354929  0.07574653 -0.03727903], params: [4.39710953e+01 1.41417672e-01 3.81348211e-02]
# iter: 48, val=0.0069 grads: [ -3.17980202   1.23122364 -15.54642657], params: [4.39706911e+01 1.41572266e-01 3.79234885e-02]
# iter: 49, val=0.0272 grads: [ 3.2138238  -1.20500044 14.59268079], params: [4.39720394e+01 1.40684113e-01 3.98314533e-02]
# iter: 50, val=0.0062 grads: [ 0.02316818  0.07591405 -0.03914361], params: [4.39707176e+01 1.41428128e-01 3.85839525e-02]
# iter: 51, val=0.0062 grads: [ 0.0233789   0.07577238 -0.03783106], params: [4.39703302e+01 1.41538628e-01 3.83975041e-02]
# iter: 52, val=0.0062 grads: [ 0.02356094  0.07563244 -0.0366476 ], params: [4.39699714e+01 1.41603892e-01 3.82307439e-02]
# iter: 53, val=0.0079 grads: [ -3.18228083   1.19664961 -15.45975671], params: [4.39696384e+01 1.41627780e-01 3.80818417e-02]
# iter: 54, val=0.0280 grads: [ 3.2200599  -1.17025837 14.46484514], params: [4.39711063e+01 1.40608590e-01 4.00858202e-02]
# iter: 55, val=0.0062 grads: [ 0.02292797  0.07584265 -0.03979614], params: [4.39698092e+01 1.41252924e-01 3.88748343e-02]
# iter: 56, val=0.0062 grads: [ 0.02307329  0.07571514 -0.03883816], params: [4.39694712e+01 1.41264290e-01 3.87365808e-02]
# iter: 57, val=0.0062 grads: [ 0.02319579  0.07558902 -0.03798638], params: [4.39691575e+01 1.41238071e-01 3.86138584e-02]
# iter: 58, val=0.0062 grads: [ 0.02329762  0.07546449 -0.0372338 ], params: [4.39688656e+01 1.41177470e-01 3.85052207e-02]
# iter: 59, val=0.0062 grads: [ 0.02338073  0.07534167 -0.03657342], params: [4.39685937e+01 1.41085404e-01 3.84093571e-02]
# iter: 60, val=0.0075 grads: [ -3.20596319   1.15483089 -15.30573582], params: [4.39683397e+01 1.40964530e-01 3.83250796e-02]
# iter: 61, val=0.0305 grads: [ 3.24775031 -1.12765316 14.25894473], params: [4.39699732e+01 1.39794638e-01 4.04503252e-02]
# iter: 62, val=0.0085 grads: [ 3.23018585 -1.1335264  14.82959161], params: [4.39686842e+01 1.40331684e-01 3.92684048e-02]
# iter: 63, val=0.0337 grads: [ -3.18401947   1.1452344  -15.93342265], params: [4.39665446e+01 1.41391882e-01 3.70489414e-02]
# iter: 64, val=0.0102 grads: [ -3.21489906   1.12743845 -15.281767  ], params: [4.39673485e+01 1.40730875e-01 3.83393387e-02]
# iter: 65, val=0.0299 grads: [ 3.25761093 -1.09718402 14.17735163], params: [4.39690609e+01 1.39566464e-01 4.05998619e-02]
# iter: 66, val=0.0107 grads: [ 3.24102325 -1.09911422 14.66586747], params: [4.39678326e+01 1.40100801e-01 3.95832585e-02]
# iter: 67, val=0.0282 grads: [ -3.19813248   1.10791804 -15.67146977], params: [4.39657433e+01 1.41151129e-01 3.75399812e-02]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 8
#       6 num_steps = 1000
#       7 for step in range(num_steps):
# ----> 8     val, grads = func(params)
#       9     # clear_output()
#      10     print(f"iter: {step}, val={val:.4f} grads: {grads}, params: {params}")
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/api.py:691, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     689   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     690 if not has_aux:
# --> 691   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     692 else:
#     693   ans, vjp_py, aux = _vjp(
#     694       f_partial, *dyn_args, has_aux=True)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/api.py:2178, in _vjp(fun, has_aux, *primals)
#    2176 if not has_aux:
#    2177   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2178   out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    2179   out_tree = out_tree()
#    2180 else:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:143, in vjp(traceable, primals, has_aux)
#     141 def vjp(traceable, primals, has_aux=False):
#     142   if not has_aux:
# --> 143     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144   else:
#     145     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:132, in linearize(traceable, *primals, **kwargs)
#     130 _, in_tree = tree_flatten(((primals, primals), {}))
#     131 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# Cell In[4], line 19, in objective(params)
#      17 t_indx = 1
#      18 Ns = [device.N for device in devices]
# ---> 19 fn = qs.promote(qsf.ops["n"], f_indx, Ns)
#      20 tn = qs.promote(qst.ops['n'], t_indx, Ns)
#      22 system = qs.System.create(devices, couplings=[
#      23     g_tf *  fn @ tn
#      24     ])
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:42, in Device.ops(self)
#      40 @property
#      41 def ops(self):
# ---> 42     return self.full_ops()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:111, in Device.full_ops(self)
#     109 ops = {}
#     110 for name, op in linear_ops.items():
# --> 111     ops[name] = self.get_op_in_H_eigenbasis(op)
#     113 return ops
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:85, in Device.get_op_in_H_eigenbasis(self, op)
#      84 def get_op_in_H_eigenbasis(self, op: jqt.Qarray):
# ---> 85     evecs = self.eig_systems["vecs"][:, : self.N]
#      86     dims = [[self.N], [self.N]]
#      87     return get_op_in_new_basis(op, evecs, dims)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:78, in Device.eig_systems(self)
#      75 @property
#      76 def eig_systems(self):
#      77     eig_systems = {}
# ---> 78     eig_systems["vals"], eig_systems["vecs"] = self._calculate_eig_systems()
#      80     eig_systems["vecs"] = eig_systems["vecs"]
#      81     eig_systems["vals"] = eig_systems["vals"]
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:70, in Device._calculate_eig_systems(self)
#      69 def _calculate_eig_systems(self):
# ---> 70     data = self._get_H_in_linear_basis().data
#      71     evs, evecs = jnp.linalg.eigh(data)  # Hermitian
#      72     idxs_sorted = jnp.argsort(evs)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:67, in Device._get_H_in_linear_basis(self)
#      66 def _get_H_in_linear_basis(self):
# ---> 67     return self.get_H_linear() if self._use_linear else self.get_H_full()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/fluxonium.py:65, in Fluxonium.get_H_full(self)
#      60 phi_ext = self.params["phi_ext"]
#      61 Hcos = op_cos_phi * jnp.cos(2.0 * jnp.pi * phi_ext) + op_sin_phi * jnp.sin(
#      62     2.0 * jnp.pi * phi_ext
#      63 )
# ---> 65 H = self.get_H_linear() - self.params["Ej"] * Hcos
#      66 return H
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/fluxonium.py:51, in Fluxonium.get_H_linear(self)
#      48 """Return linear terms in H."""
#      49 w = self.get_linear_ω()
#      50 return w * (
# ---> 51     self.linear_ops["a_dag"] @ self.linear_ops["a"]
#      52     + 0.5 * self.linear_ops["id"]
#      53 )
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:38, in Device.linear_ops(self)
#      36 @property
#      37 def linear_ops(self):
# ---> 38     return self.common_ops()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/fluxonium.py:31, in Fluxonium.common_ops(self)
#      28 ops["n"] = 1j * self.n_zpf() * (ops["a_dag"] - ops["a"])
#      30 ops["cos(φ/2)"] = jqt.cosm(ops["phi"] / 2)
# ---> 31 ops["sin(φ/2)"] = jqt.sinm(ops["phi"] / 2)
#      33 return ops
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jaxquantum/core/qarray.py:363, in sinm(qarr)
#     362 def sinm(qarr: Qarray) -> Qarray:
# --> 363     return (expm(1j*qarr) - expm(-1j*qarr))/(2j)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jaxquantum/core/qarray.py:354, in expm(qarr, **kwargs)
#     348 def expm(qarr: Qarray, **kwargs) -> Qarray:
#     349     """Matrix exponential wrapper.
#     350
#     351     Returns:
#     352         matrix exponential
#     353     """
# --> 354     data = jsp.linalg.expm(qarr.data, **kwargs)
#     355     dims = deepcopy(qarr.dims)
#     356     return Qarray.create(data, dims=dims)
#
# KeyboardInterrupt:

# %% [markdown]
# # Let's check the short period one
#
# # iter: 58, val=0.0062 grads: [ 0.02329762  0.07546449 -0.0372338 ], params: [4.39688656e+01 1.41177470e-01 3.85052207e-02]

# %%
transmon_EJ,g,amp = [4.39688656e+01 ,1.41177470e-01 ,3.85052207e-02]

fluxonium = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=n_lvls_fluxonium)
transmon = scqubits.Transmon(
    EJ=transmon_EJ,
    EC=0.2,
    ng=0.0,
    ncut=10,
    truncated_dim = 4
    )

system = FluxoniumTransmonSystem(
    fluxonium  = fluxonium,
    transmon = transmon,
    computaional_states = '0,2',
    g_strength = g,
    )

e_ops = []
for ql in range(n_lvls_fluxonium):
    for tl in range(4):
        e_ops.append(system.truncate_function(qutip.ket2dm(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,tl)]))))


amp_with_2pi = amp
t_tot = 90
tlist = np.linspace(0,t_tot,int(t_tot)*10)


results = system.run_qutip_mesolve_parrallel(
        initial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, i)) for i in range(3)],
        tlist = tlist,
        drive_terms = [DriveTerm( 
                driven_op=system.truncate_function(system.hilbertspace.op_in_dressed_eigenbasis(system.transmon.n_operator)),
                pulse_shape_func=square_pulse_with_rise_fall,
                pulse_shape_args={
                    'w_d':system.evals[system.product_to_dressed[(1,1)]] - system.evals[system.product_to_dressed[(1,0)]],
                    'amp': amp_with_2pi/(2*np.pi),
                    't_rise': 10,
                    't_square': 57
                  },
                )],
        c_ops = None,
        e_ops = e_ops
    )
# Out:
# RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#  /home/kai/miniconda3/envs/test/lib/python3.10/site-packages/loky/backend/fork_exec.py: 38An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
#  Total run time:  39.57s*] Elapsed 39.57s / Remaining 00:00:00:00 [*********94%********** ] Elapsed 37.56s / Remaining 00:00:00:02
#  Total run time:  39.65s*] Elapsed 39.65s / Remaining 00:00:00:00
#  [*********99%***********] Elapsed 39.69s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 900/900 [00:00<00:00, 7255.41it/s]
# Processing states with pad_back_custom: 100%|██████████| 900/900 [00:00<00:00, 7157.75it/s]
#  Total run time:  40.09s*] Elapsed 40.09s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 900/900 [00:00<00:00, 7357.88it/s]

# %%
colors = ['green','red','darkorange']
fig,axes = plt.subplots(2,3,figsize = (12,6))
for col, levels_list in zip([0,1,2],
                    [
                        [(0,0),(0,1)],
                        [(1,0),(1,1),(10,0),(10,1)],
                        [(2,0),(2,1)]
                    ]):
    for row in [0,1]:
        for (ql,tl) in levels_list:
            i = ql*4+tl
            # if (ql,tl) not in [(0,0), (1,1),(2,0)]:
            axes[row, col].plot(tlist,results[col].expect[i],label = rf"$\langle{ql},{tl}\rangle$",alpha=0.5)
            # else:
            #     axes[row, col].plot(tlist,1 - results[col].expect[i],label = rf"1 - $\langle{ql}{tl}\rangle$",alpha=0.5)
    axes[0,col].legend()
    # axes[1,col].axvline(x=270, color='b', linestyle='--')
    # axes[1,col].set_xlim(260,280)
axes[0,0].set_ylim(-1e-3,1)
axes[0,1].set_ylim(-1e-5,1)
axes[0,2].set_ylim(-1e-5,1)
axes[1,0].set_ylim(-1e-5,1e-2)
axes[1,1].set_ylim(-1e-5,1e-1)
axes[1,2].set_ylim(-1e-5,1e-2)

# axes[1,0].set_xlim(65,70)
# axes[1,1].set_xlim(65,70)
# axes[1,2].set_xlim(65,70)
# Out:
# (-1e-05, 0.01)

# %%
import pickle
import numpy as np
import scqubits
from scqubits.core.discretization import Grid1d
import matplotlib.pyplot as plt
from tqdm import tqdm
import qutip
from copy import deepcopy
from CoupledQuantumSystems.systems import TransmonOscillatorSystem
from CoupledQuantumSystems.drive import DriveTerm,square_pulse_with_rise_fall
from CoupledQuantumSystems.evo_parrallel import run_parallel_ODEsolve_and_post_process_jobs_with_different_systems

# %%
max_ql = 40
max_ol = 120
EJ = 13
EC = 0.3
ng = 0.0
ncut = 50
qbt = scqubits.Transmon(EJ=EJ, EC=EC, ng=ng,ncut=ncut,truncated_dim=max_ql)
qbt.plot_wavefunction(which = list(range(12)),
                      phi_grid=Grid1d(min_val=-2*np.pi,max_val=2*np.pi,pt_count=100),
                      scaling=0.5)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='$\\varphi$', ylabel='Re $\\psi_j(\\varphi)$,  energy [GHz]'>)

# %%
qbt.eigenvals(10)-qbt.eigenvals(10)[0]
# Out:
# array([ 0.        ,  5.26674561, 10.18371638, 14.71003604, 18.63892983,
#        22.6007086 , 23.98831075, 30.62961774, 30.68015993, 41.00731365])

# %%
qbt.plot_matrixelements(operator='n_operator',
                        evals_count=10,
                        show3d=False,
                        show_numbers=True)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: >)

# %%
def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)

# %%
fig, ax = plt.subplots(1,1,figsize=(4,3))

matrix = qbt.n_operator(energy_esys=True)
evals = qbt.eigenvals()
Er_list = np.linspace(0,60,100)
qls = [0,1]
ylim=(-2,2)
num_evals =len(evals)

for ql  in qls:
    shift_from_qubit_transition = []
    for Er in tqdm(Er_list, desc = "Er loop"):
        shifts = [get_shift_accurate(matrix[ql,ql2], evals[ql2], evals[ql], Er) for ql2 in range(num_evals)] 
        shift_from_qubit_transition.append(sum(shifts))
    shift_from_qubit_transition = np.abs(shift_from_qubit_transition)
    ax.plot(Er_list, shift_from_qubit_transition, label=rf'$\chi_{ql}$')

ax.grid(which='major', linestyle=':', linewidth='0.5', color='black')
ax.minorticks_on()
ax.grid(which='minor', linestyle=':', linewidth='0.5', color='gray')
ax.set_xlim(Er_list[0],Er_list[-1])
# ax.set_ylim(ylim[0],ylim[1])
ax.set_xlabel(rf'$\omega_r$')
ax.set_yscale('log')
ax.legend()
# Out:
# Er loop:   0%|          | 0/100 [00:00<?, ?it/s]RuntimeWarning: divide by zero encountered in scalar divide
#  /tmp/ipykernel_69841/1747159573.py: 2RuntimeWarning: invalid value encountered in scalar subtract
# Er loop: 100%|██████████| 100/100 [00:00<00:00, 119495.84it/s]
# Er loop: 100%|██████████| 100/100 [00:00<00:00, 133279.44it/s]

# %%
g = 10
Er = 30
kappa = 0.01
system  =  TransmonOscillatorSystem(
                qbt = qbt,
                Er = Er,
                g_strength = g,
                kappa=kappa,
                max_ql = max_ql,
                osc_level = max_ol,
                products_to_keep=[[ql, ol] for ql in range(15) for ol in range(max_ol) ],
                )
# Out:
# max overlap^2 0.036481303293674425 below threshold for dressed state 0 with eval -172.5553687988368
# max overlap^2 0.03645747927125869 below threshold for dressed state 1 with eval -172.51837198423976
# max overlap^2 0.0432192317072626 below threshold for dressed state 2 with eval -152.03890201424863
# max overlap^2 0.04317654112855611 below threshold for dressed state 3 with eval -152.03056280005563
# max overlap^2 0.03204822651250759 below threshold for dressed state 4 with eval -142.16807139934716
# max overlap^2 0.032033263859300345 below threshold for dressed state 5 with eval -142.1313622001271
# max overlap^2 0.02930147330812418 below threshold for dressed state 6 with eval -135.25346915723952
# max overlap^2 0.029296777305656052 below threshold for dressed state 7 with eval -135.25272079694082
# max overlap^2 0.04240468959604938 below threshold for dressed state 8 with eval -122.01793852336624
# max overlap^2 0.04237235373001415 below threshold for dressed state 9 with eval -122.00942701730516
# max overlap^2 0.031336755593132676 below threshold for dressed state 10 with eval -119.83479362953321
# max overlap^2 0.031336492562726435 below threshold for dressed state 11 with eval -119.8347591237663
# max overlap^2 0.03096611001918259 below threshold for dressed state 12 with eval -111.82248524221336
# max overlap^2 0.030957460056918053 below threshold for dressed state 13 with eval -111.7859454742556
# max overlap^2 0.0396530661312915 below threshold for dressed state 14 with eval -105.42219927720609
# max overlap^2 0.039696229410563603 below threshold for dressed state 15 with eval -105.42207208752608
# max overlap^2 0.02751835943417079 below threshold for dressed state 16 with eval -105.19125851005201
# max overlap^2 0.02753424988353836 below threshold for dressed state 17 with eval -105.19065271598967
# max overlap^2 0.042403480606898615 below threshold for dressed state 18 with eval -91.99198927467981
# max overlap^2 0.04236809595310701 below threshold for dressed state 19 with eval -91.98340637450312
# max overlap^2 0.03681574682971481 below threshold for dressed state 20 with eval -91.8772616732284
# max overlap^2 0.03680608105009444 below threshold for dressed state 21 with eval -91.87724661218887
# max overlap^2 0.03336522976406377 below threshold for dressed state 22 with eval -89.80297124222406
# max overlap^2 0.03336497325876772 below threshold for dressed state 23 with eval -89.8029373062452
# max overlap^2 0.030591705335943294 below threshold for dressed state 24 with eval -81.51432484642187
# max overlap^2 0.030587694167516753 below threshold for dressed state 25 with eval -81.47786136702588
# max overlap^2 0.03990896255723912 below threshold for dressed state 26 with eval -79.30487316450541
# max overlap^2 0.039908962843924 below threshold for dressed state 27 with eval -79.30487316185305
# max overlap^2 0.039425239297667995 below threshold for dressed state 28 with eval -75.41317666233809
# max overlap^2 0.039476388413885254 below threshold for dressed state 29 with eval -75.41300743511765
# max overlap^2 0.02718224051984071 below threshold for dressed state 30 with eval -75.1456358970805
# max overlap^2 0.027205456687634945 below threshold for dressed state 31 with eval -75.14509415154328
# max overlap^2 0.04801470851052888 below threshold for dressed state 32 with eval -67.67665394920428
# max overlap^2 0.04801470851105178 below threshold for dressed state 33 with eval -67.67665394917472
# max overlap^2 0.043874488467753645 below threshold for dressed state 34 with eval -61.96259064770658
# max overlap^2 0.04382971028109986 below threshold for dressed state 35 with eval -61.954007640872824
# max overlap^2 0.0281313671654314 below threshold for dressed state 36 with eval -61.846795463374875
# max overlap^2 0.028116974702065794 below threshold for dressed state 37 with eval -61.84676316550253
# max overlap^2 0.03566990022221164 below threshold for dressed state 38 with eval -59.77452418205596
# max overlap^2 0.03566951488814968 below threshold for dressed state 39 with eval -59.774491025292384
# max overlap^2 0.05652245937498008 below threshold for dressed state 40 with eval -56.995514306179295
# max overlap^2 0.05652245937498346 below threshold for dressed state 41 with eval -56.99551430617486
# max overlap^2 0.03010857571272168 below threshold for dressed state 42 with eval -51.2399940972012
# max overlap^2 0.030104129466710816 below threshold for dressed state 43 with eval -51.20353202714913
# max overlap^2 0.04809058968498832 below threshold for dressed state 44 with eval -49.2699699053754
# max overlap^2 0.0480905901073487 below threshold for dressed state 45 with eval -49.26996990093779
# max overlap^2 0.05112328137416835 below threshold for dressed state 46 with eval -47.266711718578165
# max overlap^2 0.05112328137413729 below threshold for dressed state 47 with eval -47.266711718577284
# max overlap^2 0.04184325872590894 below threshold for dressed state 48 with eval -45.398531658672226
# max overlap^2 0.041896421896539755 below threshold for dressed state 49 with eval -45.398345876457405
# max overlap^2 0.026240591996822164 below threshold for dressed state 50 with eval -45.1094404195036
# max overlap^2 0.026265925191335842 below threshold for dressed state 51 with eval -45.10894138798947
# max overlap^2 0.0657635191594693 below threshold for dressed state 52 with eval -38.49940516404032
# max overlap^2 0.06576351919230673 below threshold for dressed state 53 with eval -38.49940516335965
# max overlap^2 0.036660059840542686 below threshold for dressed state 54 with eval -37.636459855092184
# max overlap^2 0.03666005984497406 below threshold for dressed state 55 with eval -37.63645985504674
# max overlap^2 0.04469739099938652 below threshold for dressed state 56 with eval -31.93092802888141
# max overlap^2 0.04464496847580742 below threshold for dressed state 57 with eval -31.922401024993988
# max overlap^2 0.030834969663165887 below threshold for dressed state 58 with eval -31.81798648231897
# max overlap^2 0.03080887081036892 below threshold for dressed state 59 with eval -31.81793734616623
# max overlap^2 0.06008349481917536 below threshold for dressed state 60 with eval -30.708425859008976
# max overlap^2 0.060083512314994904 below threshold for dressed state 61 with eval -30.708425535400874
# max overlap^2 0.03766089184602388 below threshold for dressed state 62 with eval -29.749001863095483
# max overlap^2 0.03766043353905265 below threshold for dressed state 63 with eval -29.74896980552917
# max overlap^2 0.04161569352852401 below threshold for dressed state 64 with eval -26.949151978098513
# max overlap^2 0.041615693242321866 below threshold for dressed state 65 with eval -26.94915197805072
# max overlap^2 0.06875630719634444 below threshold for dressed state 66 with eval -23.923793165606856
# max overlap^2 0.0687485315123753 below threshold for dressed state 67 with eval -23.923709873334108
# max overlap^2 0.029769033513142803 below threshold for dressed state 68 with eval -20.9964044265661
# max overlap^2 0.02977437292372428 below threshold for dressed state 69 with eval -20.959882710304893
# max overlap^2 0.05385267017477569 below threshold for dressed state 70 with eval -19.237311305544438
# max overlap^2 0.053852670549017975 below threshold for dressed state 71 with eval -19.237311299945627
# max overlap^2 0.06277465047733961 below threshold for dressed state 72 with eval -18.216527977535023
# max overlap^2 0.06627422081954111 below threshold for dressed state 73 with eval -18.206434615503625
# max overlap^2 0.029742883432973398 below threshold for dressed state 74 with eval -17.212089684712534
# max overlap^2 0.02974155446371681 below threshold for dressed state 75 with eval -17.21208949969426
# max overlap^2 0.045234800215063764 below threshold for dressed state 76 with eval -15.380841990187259
# max overlap^2 0.04529065660865971 below threshold for dressed state 77 with eval -15.380651760182696
# max overlap^2 0.027006312584414743 below threshold for dressed state 78 with eval -15.079829286930309
# max overlap^2 0.02703339063894035 below threshold for dressed state 79 with eval -15.079363801913
# max overlap^2 0.054074762565865214 below threshold for dressed state 82 with eval -11.172731838669876
# max overlap^2 0.05581509947142766 below threshold for dressed state 83 with eval -9.350098472958564
# max overlap^2 0.05958455906377125 below threshold for dressed state 84 with eval -8.43368274174331
# max overlap^2 0.05953243133235596 below threshold for dressed state 85 with eval -8.433680614469017
# max overlap^2 0.043509942588222904 below threshold for dressed state 86 with eval -7.59911707087196
# max overlap^2 0.04350994330407203 below threshold for dressed state 87 with eval -7.599117070314444
# max overlap^2 0.07303454625186741 below threshold for dressed state 89 with eval -4.458431591350092
# max overlap^2 0.04577569672796168 below threshold for dressed state 90 with eval -1.897900833666498
# max overlap^2 0.04571061658264869 below threshold for dressed state 91 with eval -1.8894761022302409
# max overlap^2 0.03499666941778637 below threshold for dressed state 92 with eval -1.790833053113698
# max overlap^2 0.03495452495649911 below threshold for dressed state 93 with eval -1.790767604112483
# max overlap^2 0.08746256603118302 below threshold for dressed state 94 with eval -1.7118843854278911
# max overlap^2 0.06236376317764941 below threshold for dressed state 95 with eval -0.626542025463972
# max overlap^2 0.062336878836970075 below threshold for dressed state 96 with eval -0.6265414895170872
# max overlap^2 0.040042737822158156 below threshold for dressed state 97 with eval 0.2739738274232297
# max overlap^2 0.04004216296426023 below threshold for dressed state 98 with eval 0.27400445858056716
# max overlap^2 0.03511198961561861 below threshold for dressed state 100 with eval 3.093836604547631
# max overlap^2 0.03511198963685985 below threshold for dressed state 101 with eval 3.0938366045744576
# max overlap^2 0.054481567479807015 below threshold for dressed state 103 with eval 6.182747274002801
# max overlap^2 0.05447719998353716 below threshold for dressed state 104 with eval 6.182787044666148
# max overlap^2 0.029865746403252645 below threshold for dressed state 106 with eval 9.219146373042447
# max overlap^2 0.02987416688058555 below threshold for dressed state 107 with eval 9.25577799810193
# max overlap^2 0.06044703857183444 below threshold for dressed state 108 with eval 10.793192395804978
# max overlap^2 0.060447038987313344 below threshold for dressed state 109 with eval 10.793192401978365
# max overlap^2 0.0393574827559984 below threshold for dressed state 111 with eval 11.934923949410704
# max overlap^2 0.040843861919616545 below threshold for dressed state 112 with eval 11.940434628596005
# max overlap^2 0.03988530516749211 below threshold for dressed state 113 with eval 12.838422708457644
# max overlap^2 0.03988554773457363 below threshold for dressed state 114 with eval 12.838422868667795
# max overlap^2 0.04845734675011276 below threshold for dressed state 115 with eval 14.638564067712139
# max overlap^2 0.04851410633080487 below threshold for dressed state 116 with eval 14.638751880601951
# max overlap^2 0.027247269444518288 below threshold for dressed state 117 with eval 14.944770164922375
# max overlap^2 0.02727506383532637 below threshold for dressed state 118 with eval 14.945207018874028
# max overlap^2 0.03321999966109307 below threshold for dressed state 121 with eval 19.095733819219788
# max overlap^2 0.05403822454373321 below threshold for dressed state 122 with eval 20.715609794183933
# max overlap^2 0.053684879466766706 below threshold for dressed state 123 with eval 21.627025196122016
# max overlap^2 0.05364137696638894 below threshold for dressed state 124 with eval 21.62702790117512
# max overlap^2 0.052180807510480175 below threshold for dressed state 125 with eval 22.43553733041831
# max overlap^2 0.052180808160198155 below threshold for dressed state 126 with eval 22.435537331337652
# max overlap^2 0.09406464601615416 below threshold for dressed state 128 with eval 25.39998091905295
# max overlap^2 0.07533630102403287 below threshold for dressed state 129 with eval 28.042467465073326
# max overlap^2 0.04604070221005971 below threshold for dressed state 130 with eval 28.13580909116627
# max overlap^2 0.0459594681604058 below threshold for dressed state 131 with eval 28.144092248262606
# max overlap^2 0.037223800426254505 below threshold for dressed state 132 with eval 28.234692560704396
# max overlap^2 0.037161843753238145 below threshold for dressed state 133 with eval 28.234774589993386
# max overlap^2 0.07464780665605421 below threshold for dressed state 134 with eval 29.44886269628742
# max overlap^2 0.07462592212621941 below threshold for dressed state 135 with eval 29.44886318680622
# max overlap^2 0.041556802292338324 below threshold for dressed state 136 with eval 30.294723507747623
# max overlap^2 0.04155616670106227 below threshold for dressed state 137 with eval 30.294752427438837
# max overlap^2 0.07010413454816053 below threshold for dressed state 138 with eval 30.861455465767705
# max overlap^2 0.04416444534567799 below threshold for dressed state 139 with eval 33.133643716131395
# max overlap^2 0.04416444535313346 below threshold for dressed state 140 with eval 33.13364371614314
# max overlap^2 0.03652507613464428 below threshold for dressed state 142 with eval 36.28049291411245
# max overlap^2 0.03652700762271959 below threshold for dressed state 143 with eval 36.28051146901892
# max overlap^2 0.029197655323224582 below threshold for dressed state 145 with eval 39.40905767651068
# max overlap^2 0.029209894562300543 below threshold for dressed state 146 with eval 39.44584082592112
# max overlap^2 0.059653824995291774 below threshold for dressed state 148 with eval 40.821632879993885
# max overlap^2 0.059653825306866796 below threshold for dressed state 149 with eval 40.82163288627423
# max overlap^2 0.03601832233647589 below threshold for dressed state 150 with eval 42.07200198876538
# max overlap^2 0.03514087049785643 below threshold for dressed state 151 with eval 42.07493461153108
# max overlap^2 0.0412718864576997 below threshold for dressed state 152 with eval 42.88507260972764
# max overlap^2 0.04127198155674176 below threshold for dressed state 153 with eval 42.88507271086627
# max overlap^2 0.04944888359396724 below threshold for dressed state 154 with eval 44.65889141750878
# max overlap^2 0.04950402454233234 below threshold for dressed state 155 with eval 44.65907259917652
# max overlap^2 0.027017044755946528 below threshold for dressed state 156 with eval 44.96537877019538
# max overlap^2 0.02704466707346628 below threshold for dressed state 157 with eval 44.965790056626126
# max overlap^2 0.09161353105340234 below threshold for dressed state 158 with eval 46.60208277327976
# max overlap^2 0.0836340843479725 below threshold for dressed state 159 with eval 46.77159380053703
# max overlap^2 0.01840911034646717 below threshold for dressed state 160 with eval 49.39239243720223
# max overlap^2 0.06938167589801904 below threshold for dressed state 161 with eval 50.79705775250363
# max overlap^2 0.03275473813737885 below threshold for dressed state 162 with eval 51.68301018832431
# max overlap^2 0.03277009167631049 below threshold for dressed state 163 with eval 51.68301273097279
# max overlap^2 0.062307071012092 below threshold for dressed state 164 with eval 52.467657563155946
# max overlap^2 0.062307071398805904 below threshold for dressed state 165 with eval 52.46765756411341
# max overlap^2 0.07733360636905959 below threshold for dressed state 166 with eval 52.956558334195364
# max overlap^2 0.06026099944944709 below threshold for dressed state 167 with eval 55.27802982757942
# max overlap^2 0.04936219758641836 below threshold for dressed state 168 with eval 57.81647743709635
# max overlap^2 0.04454301046851167 below threshold for dressed state 169 with eval 58.169683218983316
# max overlap^2 0.04444114295515323 below threshold for dressed state 170 with eval 58.17779036854749
# max overlap^2 0.03442055262571699 below threshold for dressed state 171 with eval 58.25863352026834
# max overlap^2 0.03434148660904221 below threshold for dressed state 172 with eval 58.2587339150455
# max overlap^2 0.033366131057523694 below threshold for dressed state 173 with eval 59.518195644505404
# max overlap^2 0.03337196287968831 below threshold for dressed state 174 with eval 59.518196074685484
# max overlap^2 0.040613617098968643 below threshold for dressed state 175 with eval 60.313520878736256
# max overlap^2 0.04061299246907015 below threshold for dressed state 176 with eval 60.3135478655005
# max overlap^2 0.04614161350987962 below threshold for dressed state 178 with eval 63.17045220160078
# max overlap^2 0.04614161350971772 below threshold for dressed state 179 with eval 63.17045220160123
# max overlap^2 0.03649567103045751 below threshold for dressed state 181 with eval 66.37005360989951
# max overlap^2 0.03155289166291021 below threshold for dressed state 182 with eval 66.37006242639204
# max overlap^2 0.09627417283606193 below threshold for dressed state 183 with eval 66.43450546704838
# max overlap^2 0.026952010801952163 below threshold for dressed state 184 with eval 69.57548525193702
# max overlap^2 0.026967755835930037 below threshold for dressed state 186 with eval 69.61245446586945
# max overlap^2 0.038944842250258675 below threshold for dressed state 187 with eval 70.84810265309366
# max overlap^2 0.03894484238878435 below threshold for dressed state 188 with eval 70.84810265914194
# max overlap^2 0.03104299105365616 below threshold for dressed state 189 with eval 72.1962750865823
# max overlap^2 0.04753308786917759 below threshold for dressed state 190 with eval 72.19779540030957
# max overlap^2 0.02709649518883041 below threshold for dressed state 191 with eval 72.92809299643736
# max overlap^2 0.027096293759681114 below threshold for dressed state 192 with eval 72.92809305143946
# max overlap^2 0.04312071102235729 below threshold for dressed state 193 with eval 74.67962071977719
# max overlap^2 0.043166515049328606 below threshold for dressed state 194 with eval 74.6797926075407
# max overlap^2 0.02484914267163621 below threshold for dressed state 195 with eval 74.98272464239994
# max overlap^2 0.024874294203860583 below threshold for dressed state 196 with eval 74.98311250778794
# max overlap^2 0.06768848903206767 below threshold for dressed state 197 with eval 76.82984303425931
# max overlap^2 0.057047882330057156 below threshold for dressed state 198 with eval 76.9358585604165
# max overlap^2 0.015720933370230394 below threshold for dressed state 199 with eval 79.70867906331696
# max overlap^2 0.07594109469881115 below threshold for dressed state 200 with eval 80.89243660897705
# max overlap^2 0.03222530295520852 below threshold for dressed state 201 with eval 81.73455058416513
# max overlap^2 0.03220914072065457 below threshold for dressed state 202 with eval 81.73455266466364
# max overlap^2 0.05425675724108471 below threshold for dressed state 203 with eval 82.49738966946319
# max overlap^2 0.054256757376833185 below threshold for dressed state 204 with eval 82.49738967023204
# max overlap^2 0.0568988517193258 below threshold for dressed state 205 with eval 82.97134249739617
# max overlap^2 0.04342287545787675 below threshold for dressed state 206 with eval 85.17568693105389
# max overlap^2 0.048920452137893304 below threshold for dressed state 207 with eval 87.61008491123354
# max overlap^2 0.0387375694122361 below threshold for dressed state 208 with eval 88.20332524292002
# max overlap^2 0.03861509998026433 below threshold for dressed state 209 with eval 88.21122466190631
# max overlap^2 0.02048168673875276 below threshold for dressed state 210 with eval 88.28104364831512
# max overlap^2 0.020414713836771126 below threshold for dressed state 211 with eval 88.28116687252958
# max overlap^2 0.03210640282546788 below threshold for dressed state 212 with eval 89.58184081870806
# max overlap^2 0.03209941471857259 below threshold for dressed state 213 with eval 89.5818412312522
# max overlap^2 0.0900937831235621 below threshold for dressed state 214 with eval 90.22237760137327
# max overlap^2 0.032929659002365476 below threshold for dressed state 215 with eval 90.33060057519808
# max overlap^2 0.03292916917126988 below threshold for dressed state 216 with eval 90.33062547762076
# max overlap^2 0.035994875475893404 below threshold for dressed state 218 with eval 93.20443599501851
# max overlap^2 0.03599487547631803 below threshold for dressed state 219 with eval 93.2044359950208
# max overlap^2 0.048597614517766466 below threshold for dressed state 221 with eval 96.45199427392198
# max overlap^2 0.03086625326935742 below threshold for dressed state 222 with eval 96.45199794643165
# max overlap^2 0.02190053725028825 below threshold for dressed state 224 with eval 99.72038429663448
# max overlap^2 0.021917330385086798 below threshold for dressed state 225 with eval 99.75756822921775
# max overlap^2 0.03196327839010667 below threshold for dressed state 226 with eval 100.8726941714308
# max overlap^2 0.03196327846858584 below threshold for dressed state 227 with eval 100.8726941770161
# max overlap^2 0.02983450236493027 below threshold for dressed state 228 with eval 102.30901036285128
# max overlap^2 0.030653614604751148 below threshold for dressed state 229 with eval 102.30977746018223
# max overlap^2 0.030168998501190127 below threshold for dressed state 230 with eval 102.96770382755166
# max overlap^2 0.030169007897550514 below threshold for dressed state 231 with eval 102.9677038546406
# max overlap^2 0.03247621291747463 below threshold for dressed state 232 with eval 104.70039309562863
# max overlap^2 0.03250882412302068 below threshold for dressed state 233 with eval 104.70055401970419
# max overlap^2 0.018549224537264236 below threshold for dressed state 234 with eval 104.99735989683813
# max overlap^2 0.018567617565203247 below threshold for dressed state 235 with eval 104.99772599025228
# max overlap^2 0.054465180869283564 below threshold for dressed state 236 with eval 107.0262612505668
# max overlap^2 0.046031756662510456 below threshold for dressed state 237 with eval 107.09010543146726
# max overlap^2 0.07472627892667394 below threshold for dressed state 239 with eval 110.99951728313923
# max overlap^2 0.02935823877467033 below threshold for dressed state 240 with eval 111.78191210733846
# max overlap^2 0.02937029438866911 below threshold for dressed state 241 with eval 111.7819136624025
# max overlap^2 0.030588617366883862 below threshold for dressed state 242 with eval 112.52487203727927
# max overlap^2 0.030588617401317665 below threshold for dressed state 243 with eval 112.5248720377787
# max overlap^2 0.025884133969314337 below threshold for dressed state 244 with eval 113.01181839506538
# max overlap^2 0.038968914398067094 below threshold for dressed state 245 with eval 115.09292281969007
# max overlap^2 0.07239787572969893 below threshold for dressed state 246 with eval 117.42328857959606
# max overlap^2 0.026486935936924194 below threshold for dressed state 247 with eval 118.23642936074128
# max overlap^2 0.02636027552499627 below threshold for dressed state 248 with eval 118.24408872107168
# max overlap^2 0.02597177828483641 below threshold for dressed state 249 with eval 118.30198614278586
# max overlap^2 0.025842582778907427 below threshold for dressed state 250 with eval 118.30214190746129
# max overlap^2 0.030295919400198816 below threshold for dressed state 251 with eval 119.6401604292436
# max overlap^2 0.03030218550477895 below threshold for dressed state 252 with eval 119.64016096720817
# max overlap^2 0.05350859354040387 below threshold for dressed state 253 with eval 119.93215011065264
# max overlap^2 0.01618525375471215 below threshold for dressed state 254 with eval 120.34616424068582
# max overlap^2 0.016185028157710484 below threshold for dressed state 255 with eval 120.34618697564187
# max overlap^2 0.07428548046064434 below threshold for dressed state 256 with eval 122.60237691564797
# max overlap^2 0.022946310389985364 below threshold for dressed state 257 with eval 123.23576060518829
# max overlap^2 0.022946310390687043 below threshold for dressed state 258 with eval 123.23576060519162
# max overlap^2 0.03153012497505752 below threshold for dressed state 260 with eval 126.52683674540721
# max overlap^2 0.03153036236082754 below threshold for dressed state 261 with eval 126.52683832500152
# max overlap^2 0.01787626925269437 below threshold for dressed state 263 with eval 129.84554139350627
# max overlap^2 0.017881965571273566 below threshold for dressed state 264 with eval 129.88296374371808
# max overlap^2 0.04598377963448452 below threshold for dressed state 265 with eval 130.89549914354313
# max overlap^2 0.04598377966061627 below threshold for dressed state 266 with eval 130.89549914851926
# max overlap^2 0.03197525264852591 below threshold for dressed state 267 with eval 132.41126007167793
# max overlap^2 0.03752843246625192 below threshold for dressed state 268 with eval 132.41163634089733
# max overlap^2 0.02833113603838558 below threshold for dressed state 269 with eval 133.00411305891967
# max overlap^2 0.028331139041961346 below threshold for dressed state 270 with eval 133.00411307125046
# max overlap^2 0.03782260487656733 below threshold for dressed state 271 with eval 134.72095071751616
# max overlap^2 0.03785887233904827 below threshold for dressed state 272 with eval 134.7210996805429
# max overlap^2 0.013214336554233104 below threshold for dressed state 273 with eval 135.00972128008328
# max overlap^2 0.01322682077281218 below threshold for dressed state 274 with eval 135.01006695865024
# max overlap^2 0.043191055356927195 below threshold for dressed state 275 with eval 137.19626781681123
# max overlap^2 0.03592773907055214 below threshold for dressed state 276 with eval 137.23336450765265
# max overlap^2 0.06909341378652722 below threshold for dressed state 278 with eval 141.11569262241633
# max overlap^2 0.028673392640259008 below threshold for dressed state 279 with eval 141.82534833892
# max overlap^2 0.02868137295922918 below threshold for dressed state 280 with eval 141.8253494226621
# max overlap^2 0.03126638074865467 below threshold for dressed state 281 with eval 142.55023589138133
# max overlap^2 0.03126638075481363 below threshold for dressed state 282 with eval 142.5502358916565
# max overlap^2 0.03792600603983524 below threshold for dressed state 283 with eval 143.0804661531201
# max overlap^2 0.09227506091805147 below threshold for dressed state 284 with eval 145.02967790871523
# max overlap^2 0.04282675867966916 below threshold for dressed state 285 with eval 147.25616201182893
# max overlap^2 0.019145154881077407 below threshold for dressed state 286 with eval 148.268753249627
# max overlap^2 0.018983251162781833 below threshold for dressed state 287 with eval 148.2761321827189
# max overlap^2 0.01707157349960423 below threshold for dressed state 288 with eval 148.32153649825474
# max overlap^2 0.016926760804962106 below threshold for dressed state 289 with eval 148.32174662070076
# max overlap^2 0.08107988090400235 below threshold for dressed state 290 with eval 149.66130083114473
# max overlap^2 0.029199669241591522 below threshold for dressed state 291 with eval 149.69349730060517
# max overlap^2 0.02924279629579097 below threshold for dressed state 292 with eval 149.693500163021
# max overlap^2 0.020706514614639925 below threshold for dressed state 293 with eval 150.36038538932314
# max overlap^2 0.020706226643287362 below threshold for dressed state 294 with eval 150.36040593574842
# max overlap^2 0.0867952587679882 below threshold for dressed state 295 with eval 152.2284257245619
# max overlap^2 0.021889445253703076 below threshold for dressed state 296 with eval 153.2645835638913
# max overlap^2 0.021889445253682485 below threshold for dressed state 297 with eval 153.26458356389338
# max overlap^2 0.03265665830747279 below threshold for dressed state 299 with eval 156.59506858240536
# max overlap^2 0.027443369309179594 below threshold for dressed state 300 with eval 156.59506923934063
# max overlap^2 0.0989993075518951 below threshold for dressed state 301 with eval 157.78963404042779
# max overlap^2 0.02038947157294301 below threshold for dressed state 302 with eval 159.9525987080262
# max overlap^2 0.02040797914166515 below threshold for dressed state 303 with eval 159.99027897620238
# max overlap^2 0.030252003322676115 below threshold for dressed state 304 with eval 160.91660797425394
# max overlap^2 0.030252003293638367 below threshold for dressed state 305 with eval 160.9166079785392
# max overlap^2 0.02669023538820385 below threshold for dressed state 306 with eval 162.50392189744773
# max overlap^2 0.02764491462521738 below threshold for dressed state 307 with eval 162.50410105872427
# max overlap^2 0.031933377322522924 below threshold for dressed state 308 with eval 163.03751752632525
# max overlap^2 0.03193337833385667 below threshold for dressed state 309 with eval 163.03751753155774
# max overlap^2 0.025280329124911655 below threshold for dressed state 310 with eval 164.7411030398486
# max overlap^2 0.025303105726693014 below threshold for dressed state 311 with eval 164.74123951722578
# max overlap^2 0.01329849058645681 below threshold for dressed state 312 with eval 165.02016500616276
# max overlap^2 0.013310783401069613 below threshold for dressed state 313 with eval 165.0204914412271
# max overlap^2 0.03854598216612578 below threshold for dressed state 314 with eval 167.34434253735262
# max overlap^2 0.03328565451302254 below threshold for dressed state 315 with eval 167.36516372205386
# max overlap^2 0.02802397228757285 below threshold for dressed state 316 with eval 170.66680954616706
# max overlap^2 0.07435414268152375 below threshold for dressed state 317 with eval 171.23807021383848
# max overlap^2 0.0351037159603119 below threshold for dressed state 318 with eval 171.8651011418266
# max overlap^2 0.035104149664899005 below threshold for dressed state 319 with eval 171.8651018544201
# max overlap^2 0.025732654419019684 below threshold for dressed state 320 with eval 172.57360575372465
# max overlap^2 0.02573265443010805 below threshold for dressed state 321 with eval 172.57360575385243
# max overlap^2 0.04138880195633428 below threshold for dressed state 322 with eval 173.1801036255042
# max overlap^2 0.03489471368081597 below threshold for dressed state 324 with eval 177.10887718996693
# max overlap^2 0.01681358291906827 below threshold for dressed state 325 with eval 178.3000866343746
# max overlap^2 0.01652112619891378 below threshold for dressed state 326 with eval 178.3071134873758
# max overlap^2 0.016705899592771644 below threshold for dressed state 327 with eval 178.3397961037219
# max overlap^2 0.01641214372223158 below threshold for dressed state 328 with eval 178.340117293705
# max overlap^2 0.06409305150043083 below threshold for dressed state 329 with eval 179.40977407004848
# max overlap^2 0.02947583289301928 below threshold for dressed state 330 with eval 179.74217323378048
# max overlap^2 0.029478196494533582 below threshold for dressed state 331 with eval 179.74217339470945
# max overlap^2 0.01795381977987825 below threshold for dressed state 332 with eval 180.3734134031233
# max overlap^2 0.017953602814861372 below threshold for dressed state 333 with eval 180.37343179347909
# max overlap^2 0.07550701678277431 below threshold for dressed state 334 with eval 181.87374357591605
# max overlap^2 0.024799707025687283 below threshold for dressed state 335 with eval 183.29105483636457
# max overlap^2 0.024799707025679397 below threshold for dressed state 336 with eval 183.29105483636712
# max overlap^2 0.09770837195711027 below threshold for dressed state 337 with eval 184.4831107241317
# max overlap^2 0.028384552631897333 below threshold for dressed state 338 with eval 186.65714435215583
# max overlap^2 0.02838447779455701 below threshold for dressed state 339 with eval 186.6571446156261
# max overlap^2 0.09407612769213927 below threshold for dressed state 340 with eval 187.22575478132163
# max overlap^2 0.01255552643371464 below threshold for dressed state 341 with eval 190.04307264020593
# max overlap^2 0.012554943397398075 below threshold for dressed state 342 with eval 190.08102677165755
# max overlap^2 0.02851770493855961 below threshold for dressed state 343 with eval 190.93610932414163
# max overlap^2 0.028517704903836944 below threshold for dressed state 344 with eval 190.9361093277066
# max overlap^2 0.03166430472469907 below threshold for dressed state 345 with eval 192.58777975857782
# max overlap^2 0.030683260937395814 below threshold for dressed state 346 with eval 192.58786242368097
# max overlap^2 0.034008130389040235 below threshold for dressed state 347 with eval 193.06810371157414
# max overlap^2 0.03400813063412075 below threshold for dressed state 348 with eval 193.06810371364946
# max overlap^2 0.024377527571699205 below threshold for dressed state 349 with eval 194.7607061585399
# max overlap^2 0.024398344045868072 below threshold for dressed state 350 with eval 194.76082996714578
# max overlap^2 0.012602446485069274 below threshold for dressed state 351 with eval 195.02898835283193
# max overlap^2 0.012613494760766621 below threshold for dressed state 352 with eval 195.02929658656157
# max overlap^2 0.029681312315021264 below threshold for dressed state 353 with eval 197.47415773488513
# max overlap^2 0.03352541925325417 below threshold for dressed state 354 with eval 197.48544859091896
# max overlap^2 0.06863344489034756 below threshold for dressed state 355 with eval 200.95351235063194
# max overlap^2 0.07270591027711433 below threshold for dressed state 356 with eval 201.3636088314365
# max overlap^2 0.026507176627970617 below threshold for dressed state 357 with eval 201.90140104471752
# max overlap^2 0.02651002576779654 below threshold for dressed state 358 with eval 201.9014014912042
# max overlap^2 0.02954305427064585 below threshold for dressed state 359 with eval 202.59509987049955
# max overlap^2 0.029543054269352057 below threshold for dressed state 360 with eval 202.59509987055594
# max overlap^2 0.03642239516886372 below threshold for dressed state 361 with eval 203.31320209966535
# max overlap^2 0.04013337899211461 below threshold for dressed state 362 with eval 204.9610734989321
# max overlap^2 0.03438415226715069 below threshold for dressed state 363 with eval 206.98174048306427
# max overlap^2 0.01826475750665402 below threshold for dressed state 364 with eval 208.3301802655316
# max overlap^2 0.017309525745246003 below threshold for dressed state 365 with eval 208.33664767899933
# max overlap^2 0.017493220757662346 below threshold for dressed state 366 with eval 208.35694991516777
# max overlap^2 0.016582525316465358 below threshold for dressed state 367 with eval 208.35757782445614
# max overlap^2 0.05319513391244084 below threshold for dressed state 368 with eval 209.17754510130746
# max overlap^2 0.039343483346432166 below threshold for dressed state 369 with eval 209.7864938997832
# max overlap^2 0.03934350936665074 below threshold for dressed state 370 with eval 209.78649395031968
# max overlap^2 0.020876404376987942 below threshold for dressed state 371 with eval 210.385376888037
# max overlap^2 0.020876191638542464 below threshold for dressed state 372 with eval 210.3853931987909
# max overlap^2 0.058886466597937615 below threshold for dressed state 373 with eval 211.53818821711045
# max overlap^2 0.025208150222488016 below threshold for dressed state 374 with eval 213.31531719598397
# max overlap^2 0.025208150222485477 below threshold for dressed state 375 with eval 213.3153171959866
# max overlap^2 0.0877235416651309 below threshold for dressed state 376 with eval 214.04366950931657
# max overlap^2 0.08246500528168532 below threshold for dressed state 377 with eval 216.68097618817018
# max overlap^2 0.028600734779969134 below threshold for dressed state 378 with eval 216.7134891154224
# max overlap^2 0.028601171910982808 below threshold for dressed state 379 with eval 216.71348923403113
# max overlap^2 0.012691789824499798 below threshold for dressed state 380 with eval 220.11836844029887
# max overlap^2 0.012705569371643197 below threshold for dressed state 381 with eval 220.15660940709697
# max overlap^2 0.027118777728171152 below threshold for dressed state 382 with eval 220.95408976354372
# max overlap^2 0.02711877768780216 below threshold for dressed state 383 with eval 220.95408976640368
# max overlap^2 0.026861300983877012 below threshold for dressed state 384 with eval 222.6635311414542
# max overlap^2 0.028221050455869565 below threshold for dressed state 385 with eval 222.6635680244704
# max overlap^2 0.037060930796450633 below threshold for dressed state 386 with eval 223.0960484091199
# max overlap^2 0.03706093079969996 below threshold for dressed state 387 with eval 223.09604840988942
# max overlap^2 0.022391466556127518 below threshold for dressed state 388 with eval 224.77964947987354
# max overlap^2 0.022409473002892154 below threshold for dressed state 389 with eval 224.77976068886937
# max overlap^2 0.010527169178464907 below threshold for dressed state 390 with eval 225.03644387086757
# max overlap^2 0.010535793062814951 below threshold for dressed state 391 with eval 225.03673484683173
# max overlap^2 0.02663722534009203 below threshold for dressed state 392 with eval 227.58857196430068
# max overlap^2 0.029617015000948325 below threshold for dressed state 393 with eval 227.59448401030056
# max overlap^2 0.04788149640008351 below threshold for dressed state 394 with eval 231.2097975024682
# max overlap^2 0.06509220789300746 below threshold for dressed state 395 with eval 231.48928391200386
# max overlap^2 0.026108392844407087 below threshold for dressed state 396 with eval 231.9344676005337
# max overlap^2 0.02610842168130436 below threshold for dressed state 397 with eval 231.93446787025752
# max overlap^2 0.030482264256813333 below threshold for dressed state 398 with eval 232.61483060452653
# max overlap^2 0.030482264255880576 below threshold for dressed state 399 with eval 232.61483060454827
# max overlap^2 0.031040802110733692 below threshold for dressed state 400 with eval 233.48065339497154
# max overlap^2 0.042113556269980625 below threshold for dressed state 402 with eval 236.8752477489932
# max overlap^2 0.018273577484370876 below threshold for dressed state 403 with eval 238.35839356874126
# max overlap^2 0.01364466895737237 below threshold for dressed state 404 with eval 238.36329614932154
# max overlap^2 0.01654506239021973 below threshold for dressed state 405 with eval 238.37360870420625
# max overlap^2 0.01237268548362541 below threshold for dressed state 406 with eval 238.37553994418764
# max overlap^2 0.03853042698561598 below threshold for dressed state 407 with eval 238.96465521260498
# max overlap^2 0.029453886092433386 below threshold for dressed state 408 with eval 239.82674760345927
# max overlap^2 0.02945389190401639 below threshold for dressed state 409 with eval 239.82674762388595
# max overlap^2 0.014752850932791018 below threshold for dressed state 410 with eval 240.3963865364438
# max overlap^2 0.014752709131606543 below threshold for dressed state 411 with eval 240.3964008784027
# max overlap^2 0.04487306428074077 below threshold for dressed state 412 with eval 241.2216630728595
# max overlap^2 0.03253902356464955 below threshold for dressed state 413 with eval 243.33750656619358
# max overlap^2 0.03253902356464901 below threshold for dressed state 414 with eval 243.33750656619512
# max overlap^2 0.08975712722739536 below threshold for dressed state 415 with eval 243.62307553349655
# max overlap^2 0.07311983674918066 below threshold for dressed state 416 with eval 246.15492218808996
# max overlap^2 0.030145912691253367 below threshold for dressed state 417 with eval 246.76450091394568
# max overlap^2 0.030145913382675693 below threshold for dressed state 418 with eval 246.76450095293612
# max overlap^2 0.012499101158421087 below threshold for dressed state 419 with eval 250.17979183181944
# max overlap^2 0.012500604620241442 below threshold for dressed state 420 with eval 250.21833020505548
# max overlap^2 0.026355048271726775 below threshold for dressed state 421 with eval 250.97063350438842
# max overlap^2 0.02635504823751743 below threshold for dressed state 422 with eval 250.9706335065966
# max overlap^2 0.043376060819974444 below threshold for dressed state 423 with eval 252.73180545502993
# max overlap^2 0.026295591341522807 below threshold for dressed state 424 with eval 252.73182132927187
# max overlap^2 0.03273871324448369 below threshold for dressed state 425 with eval 253.12151930967966
# max overlap^2 0.03273871321651222 below threshold for dressed state 426 with eval 253.12151930994457
# max overlap^2 0.022699455941783155 below threshold for dressed state 427 with eval 254.79784674272022
# max overlap^2 0.02271656629470669 below threshold for dressed state 428 with eval 254.79794561190747
# max overlap^2 0.010665391538878228 below threshold for dressed state 429 with eval 255.04274918687835
# max overlap^2 0.010673642450246172 below threshold for dressed state 430 with eval 255.04302376644017
# max overlap^2 0.026665671442864827 below threshold for dressed state 431 with eval 257.6897702960949
# max overlap^2 0.02469628352800672 below threshold for dressed state 432 with eval 257.69275543894776
# max overlap^2 0.04025047014886148 below threshold for dressed state 433 with eval 261.4318378617045
# max overlap^2 0.055561076565442305 below threshold for dressed state 434 with eval 261.61226247668435
# max overlap^2 0.024389119520485825 below threshold for dressed state 435 with eval 261.964509732074
# max overlap^2 0.02439039454869148 below threshold for dressed state 436 with eval 261.9645098919372
# max overlap^2 0.030953886410657556 below threshold for dressed state 437 with eval 262.63290479245813
# max overlap^2 0.030953886410402837 below threshold for dressed state 438 with eval 262.6329047924676
# max overlap^2 0.01708178477136541 below threshold for dressed state 439 with eval 263.68036596891136
# max overlap^2 0.09703454787425594 below threshold for dressed state 440 with eval 264.9666687765065
# max overlap^2 0.04801006051020454 below threshold for dressed state 441 with eval 266.79016763123263
# max overlap^2 0.010425800550238664 below threshold for dressed state 442 with eval 268.3815241644
# max overlap^2 0.01295918080820582 below threshold for dressed state 443 with eval 268.38291678776284
# max overlap^2 0.010610129272500496 below threshold for dressed state 444 with eval 268.39297181148487
# max overlap^2 0.013175228285369213 below threshold for dressed state 445 with eval 268.39814539073774
# max overlap^2 0.0408528589879394 below threshold for dressed state 446 with eval 268.7712032797988
# max overlap^2 0.04473601925691427 below threshold for dressed state 447 with eval 269.8632067742815
# max overlap^2 0.04473601562360321 below threshold for dressed state 448 with eval 269.86320678352905
# max overlap^2 0.01401649338174319 below threshold for dressed state 449 with eval 270.4065375967804
# max overlap^2 0.014016380949034455 below threshold for dressed state 450 with eval 270.4065501058271
# max overlap^2 0.09519543813776664 below threshold for dressed state 451 with eval 270.92412505711286
# max overlap^2 0.0892822334362288 below threshold for dressed state 452 with eval 273.22113025423323
# max overlap^2 0.018539960271002583 below threshold for dressed state 453 with eval 273.3577523333543
# max overlap^2 0.018539960271002257 below threshold for dressed state 454 with eval 273.3577523333549
# max overlap^2 0.05132454399212579 below threshold for dressed state 455 with eval 275.6472369058738
# max overlap^2 0.03721870633167305 below threshold for dressed state 456 with eval 276.81055291512934
# max overlap^2 0.037218706861490564 below threshold for dressed state 457 with eval 276.81055292909053
# max overlap^2 0.012418292347650583 below threshold for dressed state 458 with eval 280.2285583630142
# max overlap^2 0.012420598688296456 below threshold for dressed state 459 with eval 280.2674029465631
# max overlap^2 0.02835518372850127 below threshold for dressed state 460 with eval 280.9858221964184
# max overlap^2 0.02835518369537121 below threshold for dressed state 461 with eval 280.98582219805695
# max overlap^2 0.026735154008187406 below threshold for dressed state 462 with eval 282.7931765368362
# max overlap^2 0.026740089857439343 below threshold for dressed state 463 with eval 282.79318310858866
# max overlap^2 0.032499141637086816 below threshold for dressed state 464 with eval 283.14467551515816
# max overlap^2 0.03249914162930651 below threshold for dressed state 465 with eval 283.14467551524217
# max overlap^2 0.02006072742002204 below threshold for dressed state 466 with eval 284.8152297890871
# max overlap^2 0.020074721490558604 below threshold for dressed state 467 with eval 284.81531672612203
# max overlap^2 0.010197608066611278 below threshold for dressed state 468 with eval 285.0480940205883
# max overlap^2 0.010204963512444975 below threshold for dressed state 469 with eval 285.0483529913814
# max overlap^2 0.0294816638446174 below threshold for dressed state 470 with eval 287.7794315160886
# max overlap^2 0.025745584395660093 below threshold for dressed state 471 with eval 287.7808821257254
# max overlap^2 0.04072563941688123 below threshold for dressed state 472 with eval 291.61974743266086
# max overlap^2 0.052399999714379995 below threshold for dressed state 473 with eval 291.73006534384257
# max overlap^2 0.02436966644572454 below threshold for dressed state 474 with eval 291.9917260734324
# max overlap^2 0.02436965013413118 below threshold for dressed state 475 with eval 291.9917261692951
# max overlap^2 0.03052596557861395 below threshold for dressed state 476 with eval 292.64942406743563
# max overlap^2 0.03052596557854404 below threshold for dressed state 477 with eval 292.6494240674416
# max overlap^2 0.07661942346497949 below threshold for dressed state 478 with eval 293.9065404689736
# max overlap^2 0.08727354056758893 below threshold for dressed state 479 with eval 294.9950094479817
# max overlap^2 0.058383355686725154 below threshold for dressed state 480 with eval 296.7276626811472
# max overlap^2 0.015121362430970604 below threshold for dressed state 481 with eval 298.39717009707744
# max overlap^2 0.01547779151400265 below threshold for dressed state 482 with eval 298.39743478780196
# max overlap^2 0.01401000057348644 below threshold for dressed state 483 with eval 298.4174589408521
# max overlap^2 0.014350415450238786 below threshold for dressed state 484 with eval 298.4234891711799
# max overlap^2 0.039890349664967385 below threshold for dressed state 485 with eval 298.59735175047695
# max overlap^2 0.03754283858503954 below threshold for dressed state 486 with eval 299.8961288438153
# max overlap^2 0.03754283781173671 below threshold for dressed state 487 with eval 299.8961288483703
# max overlap^2 0.013425430587970324 below threshold for dressed state 488 with eval 300.4159120210557
# max overlap^2 0.013425342281146705 below threshold for dressed state 489 with eval 300.41592284965094
# max overlap^2 0.08603051467811976 below threshold for dressed state 491 with eval 302.8376768142799
# max overlap^2 0.030286463735360116 below threshold for dressed state 492 with eval 303.37617763428995
# max overlap^2 0.03028646373535953 below threshold for dressed state 493 with eval 303.37617763429165
# max overlap^2 0.05262944252534235 below threshold for dressed state 494 with eval 305.15758643564266
# max overlap^2 0.027911599344597034 below threshold for dressed state 495 with eval 306.8519952842205
# max overlap^2 0.027911599471635563 below threshold for dressed state 496 with eval 306.8519952890125
# max overlap^2 0.01233512177292639 below threshold for dressed state 497 with eval 310.2658009559673
# max overlap^2 0.01233806461849885 below threshold for dressed state 498 with eval 310.30495961034273
# max overlap^2 0.028983174851386642 below threshold for dressed state 499 with eval 310.9997347768832
# max overlap^2 0.02898317482520473 below threshold for dressed state 500 with eval 310.999734778051
# max overlap^2 0.026909441249031715 below threshold for dressed state 501 with eval 312.848171398925
# max overlap^2 0.026914315266284995 below threshold for dressed state 502 with eval 312.8481740071723
# ...
# max overlap^2 0.011072518104580037 below threshold for dressed state 4639 with eval 4786.6643414395185
# max overlap^2 0.011072518104578693 below threshold for dressed state 4640 with eval 4786.664341439526
# max overlap^2 0.030739724617896806 below threshold for dressed state 4641 with eval 4805.400336561246
# max overlap^2 0.030739930064903147 below threshold for dressed state 4642 with eval 4805.401186723019
# max overlap^2 0.0009444602326627616 below threshold for dressed state 4643 with eval 4818.613673916321
# max overlap^2 0.0009444602326617962 below threshold for dressed state 4644 with eval 4818.613673916323
# max overlap^2 0.04310658005152774 below threshold for dressed state 4645 with eval 4826.152674400528
# max overlap^2 0.043106580063339874 below threshold for dressed state 4646 with eval 4826.1526744062285
# max overlap^2 0.02212116784598614 below threshold for dressed state 4647 with eval 4846.649809528435
# max overlap^2 0.016829999284534262 below threshold for dressed state 4648 with eval 4846.724138227406
# max overlap^2 0.04031866120670745 below threshold for dressed state 4649 with eval 4855.062480251651
# max overlap^2 0.04031866120670745 below threshold for dressed state 4650 with eval 4855.062480251654
# max overlap^2 6.63219383262158e-11 below threshold for dressed state 4651 with eval 4864.894267635589
# max overlap^2 6.632193831866093e-11 below threshold for dressed state 4652 with eval 4864.894267635599
# max overlap^2 0.042297352067401116 below threshold for dressed state 4653 with eval 4865.9109161113765
# max overlap^2 0.042297358010712854 below threshold for dressed state 4654 with eval 4865.910919244968
# max overlap^2 6.897753235956792e-13 below threshold for dressed state 4655 with eval 4870.801769577181
# max overlap^2 6.897753246885955e-13 below threshold for dressed state 4656 with eval 4870.8017695772
# max overlap^2 2.7519351546868068e-08 below threshold for dressed state 4657 with eval 4880.438734771133
# max overlap^2 2.7519351547350966e-08 below threshold for dressed state 4658 with eval 4880.438734771138
# max overlap^2 0.001195155316266017 below threshold for dressed state 4659 with eval 4892.717933252845
# max overlap^2 0.0011951553162416547 below threshold for dressed state 4660 with eval 4892.717933252853
# max overlap^2 0.06320901135125555 below threshold for dressed state 4661 with eval 4894.994608046066
# max overlap^2 2.6506798017659977e-09 below threshold for dressed state 4662 with eval 4905.349143482515
# max overlap^2 2.650679801694527e-09 below threshold for dressed state 4663 with eval 4905.349143482516
# max overlap^2 0.03416674901003954 below threshold for dressed state 4664 with eval 4905.834745848079
# max overlap^2 0.03416709218497395 below threshold for dressed state 4665 with eval 4905.835633166446
# max overlap^2 0.025276013653807546 below threshold for dressed state 4666 with eval 4931.201711075374
# max overlap^2 0.025276013652164142 below threshold for dressed state 4667 with eval 4931.2017110813495
# max overlap^2 1.3952500245417305e-08 below threshold for dressed state 4668 with eval 4935.442404725118
# max overlap^2 1.3952500246458674e-08 below threshold for dressed state 4669 with eval 4935.442404725121
# max overlap^2 0.0230580477559276 below threshold for dressed state 4670 with eval 4947.101665956188
# max overlap^2 0.02305518372831251 below threshold for dressed state 4671 with eval 4947.178297001532
# max overlap^2 3.1554812707048446e-06 below threshold for dressed state 4672 with eval 4968.735592219792
# max overlap^2 3.1554812707103025e-06 below threshold for dressed state 4673 with eval 4968.735592219804
# max overlap^2 0.04249008941155971 below threshold for dressed state 4674 with eval 4970.257106393446
# max overlap^2 0.04249009423720036 below threshold for dressed state 4675 with eval 4970.257109679707
# max overlap^2 0.0003485388640268598 below threshold for dressed state 4676 with eval 5004.136759613602
# max overlap^2 0.00034853886402567524 below threshold for dressed state 4677 with eval 5004.136759613612
# max overlap^2 0.03493497195560408 below threshold for dressed state 4678 with eval 5009.709888272361
# max overlap^2 0.03493545226554481 below threshold for dressed state 4679 with eval 5009.710814904755
# max overlap^2 6.795759914376876e-14 below threshold for dressed state 4680 with eval 5027.00966257843
# max overlap^2 6.795759792519121e-14 below threshold for dressed state 4681 with eval 5027.009662578431
# max overlap^2 9.53299395277724e-16 below threshold for dressed state 4682 with eval 5037.996394279519
# max overlap^2 9.532990841978384e-16 below threshold for dressed state 4683 with eval 5037.996394279527
# max overlap^2 9.753397585637406e-12 below threshold for dressed state 4684 with eval 5039.230331067371
# max overlap^2 9.753397407314148e-12 below threshold for dressed state 4685 with eval 5039.230331067375
# max overlap^2 0.016267858813994656 below threshold for dressed state 4686 with eval 5040.983214890145
# max overlap^2 0.016267858809787192 below threshold for dressed state 4687 with eval 5040.983214896449
# max overlap^2 0.022513008283003594 below threshold for dressed state 4688 with eval 5050.740345292839
# max overlap^2 0.015940595176511904 below threshold for dressed state 4689 with eval 5050.8193379367185
# max overlap^2 4.197753817175951e-09 below threshold for dressed state 4690 with eval 5061.751625289182
# max overlap^2 4.197753817149116e-09 below threshold for dressed state 4691 with eval 5061.751625289192
# max overlap^2 0.045090392347403585 below threshold for dressed state 4692 with eval 5078.844565119541
# max overlap^2 0.045090398342595796 below threshold for dressed state 4693 with eval 5078.844568575826
# max overlap^2 3.7598096058697996e-07 below threshold for dressed state 4694 with eval 5090.050641295086
# max overlap^2 3.759809605875234e-07 below threshold for dressed state 4695 with eval 5090.050641295086
# max overlap^2 0.035499435212692755 below threshold for dressed state 4696 with eval 5117.434321459004
# max overlap^2 0.03549975245968159 below threshold for dressed state 4697 with eval 5117.435289694179
# max overlap^2 5.411106847293496e-06 below threshold for dressed state 4698 with eval 5121.964590726043
# max overlap^2 5.411106839235357e-06 below threshold for dressed state 4699 with eval 5121.96459072605
# max overlap^2 0.0007943939458109622 below threshold for dressed state 4700 with eval 5156.292608243042
# max overlap^2 0.00079439392966218 below threshold for dressed state 4701 with eval 5156.292608249733
# max overlap^2 0.01930627389793169 below threshold for dressed state 4702 with eval 5157.9102956710085
# max overlap^2 0.018233354065506864 below threshold for dressed state 4703 with eval 5157.991716077653
# max overlap^2 2.941446491310204e-14 below threshold for dressed state 4704 with eval 5192.041176425753
# max overlap^2 2.941446181016554e-14 below threshold for dressed state 4705 with eval 5192.041176425756
# max overlap^2 0.04423221872224568 below threshold for dressed state 4706 with eval 5192.30038404971
# max overlap^2 0.04423222567942976 below threshold for dressed state 4707 with eval 5192.300387694988
# max overlap^2 2.645107356887601e-11 below threshold for dressed state 4708 with eval 5201.013864941349
# max overlap^2 2.6451073512090142e-11 below threshold for dressed state 4709 with eval 5201.013864941356
# max overlap^2 5.816038633452332e-17 below threshold for dressed state 4710 with eval 5207.951468139472
# max overlap^2 5.816039237969924e-17 below threshold for dressed state 4711 with eval 5207.9514681394885
# max overlap^2 1.8485809115009147e-08 below threshold for dressed state 4712 with eval 5221.173461864163
# max overlap^2 1.848580911487504e-08 below threshold for dressed state 4713 with eval 5221.173461864167
# max overlap^2 0.03639807068552534 below threshold for dressed state 4714 with eval 5229.515759291142
# max overlap^2 0.03639858210012364 below threshold for dressed state 4715 with eval 5229.516771602413
# max overlap^2 5.87043532349485e-06 below threshold for dressed state 4716 with eval 5247.682149896113
# max overlap^2 5.870435322548971e-06 below threshold for dressed state 4717 with eval 5247.682149896124
# max overlap^2 0.021125794952242233 below threshold for dressed state 4718 with eval 5269.031661248768
# max overlap^2 0.021120137781822278 below threshold for dressed state 4719 with eval 5269.115583992279
# max overlap^2 0.0006449298038334278 below threshold for dressed state 4720 with eval 5278.207073055167
# max overlap^2 0.0006449297993249925 below threshold for dressed state 4721 with eval 5278.20707306232
# max overlap^2 0.015297810791465605 below threshold for dressed state 4722 with eval 5311.444233145519
# max overlap^2 0.015297810396638576 below threshold for dressed state 4723 with eval 5311.444237001491
# max overlap^2 0.029198340513730933 below threshold for dressed state 4724 with eval 5346.599559806122
# max overlap^2 0.02919852645622707 below threshold for dressed state 4725 with eval 5346.600618936437
# max overlap^2 1.584413579377066e-11 below threshold for dressed state 4726 with eval 5359.90849277264
# max overlap^2 1.5844135787273797e-11 below threshold for dressed state 4727 with eval 5359.908492772652
# max overlap^2 2.242622526440128e-09 below threshold for dressed state 4728 with eval 5365.703130305707
# max overlap^2 2.2426225263695723e-09 below threshold for dressed state 4729 with eval 5365.703130305714
# max overlap^2 6.37049914612832e-18 below threshold for dressed state 4730 with eval 5380.604547306793
# max overlap^2 6.370499762603188e-18 below threshold for dressed state 4731 with eval 5380.604547306795
# max overlap^2 6.8373817511240784e-09 below threshold for dressed state 4732 with eval 5383.528542374785
# max overlap^2 6.837379246724773e-09 below threshold for dressed state 4733 with eval 5383.5285423748
# max overlap^2 0.0257797134435723 below threshold for dressed state 4734 with eval 5384.6265686495435
# max overlap^2 0.020752109082622906 below threshold for dressed state 4735 with eval 5384.713078798734
# max overlap^2 4.2092593285045686e-06 below threshold for dressed state 4736 with eval 5408.254812419941
# max overlap^2 4.209255262484901e-06 below threshold for dressed state 4737 with eval 5408.25481242766
# max overlap^2 0.0010014939765297913 below threshold for dressed state 4738 with eval 5437.38617492402
# max overlap^2 0.001001486217899572 below threshold for dressed state 4739 with eval 5437.386179017443
# max overlap^2 0.026876060422180995 below threshold for dressed state 4740 with eval 5469.529295568368
# max overlap^2 0.026876113728105958 below threshold for dressed state 4741 with eval 5469.53040466371
# max overlap^2 0.043046201477244424 below threshold for dressed state 4742 with eval 5505.358718169039
# max overlap^2 0.04304069021324264 below threshold for dressed state 4743 with eval 5505.447914139803
# max overlap^2 1.0164379658544016e-10 below threshold for dressed state 4744 with eval 5530.542717710198
# max overlap^2 1.016438048051084e-10 below threshold for dressed state 4745 with eval 5530.542717710214
# max overlap^2 6.036222052563793e-10 below threshold for dressed state 4746 with eval 5533.233431757593
# max overlap^2 6.03622083146155e-10 below threshold for dressed state 4747 with eval 5533.233431757606
# max overlap^2 1.2738613858590951e-06 below threshold for dressed state 4748 with eval 5548.746963607624
# max overlap^2 1.2738603973436296e-06 below threshold for dressed state 4749 with eval 5548.746963616115
# max overlap^2 7.121347144967872e-18 below threshold for dressed state 4750 with eval 5555.908766171623
# max overlap^2 7.122609892396104e-18 below threshold for dressed state 4751 with eval 5555.908766171631
# max overlap^2 1.67883246108516e-06 below threshold for dressed state 4752 with eval 5571.701147555141
# max overlap^2 1.6772772118756549e-06 below threshold for dressed state 4753 with eval 5571.70115192406
# max overlap^2 0.00023176420124943557 below threshold for dressed state 4754 with eval 5599.447448944475
# max overlap^2 0.00023157019333778492 below threshold for dressed state 4755 with eval 5599.4486117976285
# max overlap^2 0.01978439001678533 below threshold for dressed state 4756 with eval 5632.0956931443125
# max overlap^2 0.019783453508076233 below threshold for dressed state 4757 with eval 5632.187690749747
# max overlap^2 4.048834453222218e-09 below threshold for dressed state 4758 with eval 5703.42056069264
# max overlap^2 4.046196432985394e-09 below threshold for dressed state 4759 with eval 5703.420560701274
# max overlap^2 2.9495143561417207e-10 below threshold for dressed state 4760 with eval 5704.020033014908
# max overlap^2 2.9476318433136e-10 below threshold for dressed state 4761 with eval 5704.020033016501
# max overlap^2 5.954075527325996e-07 below threshold for dressed state 4762 with eval 5716.771261910077
# max overlap^2 5.94960503175806e-07 below threshold for dressed state 4763 with eval 5716.771266629273
# max overlap^2 8.410033633311475e-15 below threshold for dressed state 4764 with eval 5733.827392485877
# max overlap^2 8.411037206357227e-15 below threshold for dressed state 4765 with eval 5733.82739248588
# max overlap^2 0.00024983233430286834 below threshold for dressed state 4766 with eval 5737.9750546132445
# max overlap^2 0.00024963313934100377 below threshold for dressed state 4767 with eval 5737.976276222416
# max overlap^2 0.012073574209112913 below threshold for dressed state 4768 with eval 5766.0125513202975
# max overlap^2 0.01207165241516454 below threshold for dressed state 4769 with eval 5766.107489682221
# max overlap^2 0.0 below threshold for dressed state 4770 with eval 5876.529841245054
# max overlap^2 0.0 below threshold for dressed state 4771 with eval 5876.529846696416
# max overlap^2 0.0 below threshold for dressed state 4772 with eval 5879.986633850467
# max overlap^2 0.0 below threshold for dressed state 4773 with eval 5879.986633880547
# max overlap^2 0.0 below threshold for dressed state 4774 with eval 5887.564377406232
# max overlap^2 0.0 below threshold for dressed state 4775 with eval 5887.565665822626
# max overlap^2 0.0 below threshold for dressed state 4776 with eval 5908.776645920204
# max overlap^2 0.0 below threshold for dressed state 4777 with eval 5908.874695771111
# max overlap^2 0.0 below threshold for dressed state 4778 with eval 5914.331036373493
# max overlap^2 0.0 below threshold for dressed state 4779 with eval 5914.331036373506
# max overlap^2 0.0 below threshold for dressed state 4780 with eval 6052.269833765879
# max overlap^2 0.0 below threshold for dressed state 4781 with eval 6052.27122328348
# max overlap^2 0.0 below threshold for dressed state 4782 with eval 6058.672779610597
# max overlap^2 0.0 below threshold for dressed state 4783 with eval 6058.672786150197
# max overlap^2 0.0 below threshold for dressed state 4784 with eval 6062.910526518656
# max overlap^2 0.0 below threshold for dressed state 4785 with eval 6063.011885635144
# max overlap^2 0.0 below threshold for dressed state 4786 with eval 6097.395800357794
# max overlap^2 0.0 below threshold for dressed state 4787 with eval 6097.395800367905
# max overlap^2 0.0 below threshold for dressed state 4788 with eval 6232.5884362177085
# max overlap^2 0.0 below threshold for dressed state 4789 with eval 6232.693444962402
# max overlap^2 0.0 below threshold for dressed state 4790 with eval 6239.992930779841
# max overlap^2 0.0 below threshold for dressed state 4791 with eval 6239.994404457087
# max overlap^2 0.0 below threshold for dressed state 4792 with eval 6283.002018818307
# max overlap^2 0.0 below threshold for dressed state 4793 with eval 6283.002024438646
# max overlap^2 0.0 below threshold for dressed state 4794 with eval 6425.920567835366
# max overlap^2 0.0 below threshold for dressed state 4795 with eval 6426.029762802668
# max overlap^2 0.0 below threshold for dressed state 4796 with eval 6471.14610213938
# max overlap^2 0.0 below threshold for dressed state 4797 with eval 6471.147617962651
# max overlap^2 0.0 below threshold for dressed state 4798 with eval 6663.938436295606
# max overlap^2 0.0 below threshold for dressed state 4799 with eval 6664.052672707405

# %%
id_wrapped_resonator_destory = qutip.tensor(qutip.identity(max_ql), qutip.destroy(max_ol))
id_wrapped_qbt_destory = qutip.tensor(qutip.destroy(max_ql), qutip.identity(max_ol))
resonator_creation_arr = id_wrapped_resonator_destory.dag().full()
resonator_destory_arr= id_wrapped_resonator_destory.full()
qbt_creation_arr = id_wrapped_qbt_destory.dag().full()
qbt_destory_arr= id_wrapped_qbt_destory.full()

ladder_overlap = system.get_ladder_overlap_arr(resonator_creation_arr)
with open('ladder_overlap_large_g.pkl', 'wb') as f:
    pickle.dump(ladder_overlap,f)
def find_next_in_branch(dressed_idx_of_qubit_i_resonator_n:int):
    return np.argmax(ladder_overlap[:,dressed_idx_of_qubit_i_resonator_n])

diagonalization_idx_arr = np.zeros((max_ql,max_ol),dtype=int)
overlap_idx_arr = np.zeros((max_ql,max_ol),dtype=int)
for ql in tqdm(range(max_ql), desc = "ql loop"):
    for ol in range(max_ol):
        diagonalization_idx_arr[ql,ol] = system.product_to_dressed[(ql,ol)] if system.product_to_dressed[(ql,ol)] is not None else -1
        
        if ol < 1:
            overlap_idx_arr[ql,ol] = system.product_to_dressed[(ql,ol)]
        else:
            overlap_idx_arr[ql,ol] = np.argmax(ladder_overlap[:,overlap_idx_arr[ql,ol-1]])

for ql in range(max_ql):
    for ol in range(max_ol):
        system.product_to_dressed[(ql,ol)] =  overlap_idx_arr[ql,ol]
# Out:
# ql loop: 100%|██████████| 40/40 [00:00<00:00, 284.53it/s]

# %%
system.set_sign_multiplier()
system.set_new_product_to_keep([[ql, ol] for ql in range(15) for ol in range(max_ol) ])
system.set_new_operators_after_setting_new_product_to_keep()
with open('syste_large_g.pkl', 'wb') as f:
    pickle.dump(system,f)

# %%
plt.plot(overlap_idx_arr.flatten())
# plt.ylim(0,100)

# %%
for ql in range(max_ql):
    print(overlap_idx_arr[ql][0])
# Out:
# 4799
# 81
# 88
# 73
# 82
# 83
# 110
# 105
# 102
# 99
# 94
# 103
# 104
# 135
# 134
# 123
# 124
# 192
# 191
# 153
# 152
# 178
# 179
# 203
# 204
# 188
# 187
# 210
# 211
# 272
# 271
# 254
# 255
# 312
# 313
# 325
# 326
# 380
# 381
# 668

# %%
def get_photon_number(state):
    state_after_a = resonator_destory_arr @ state
    return np.abs(np.sum(state_after_a**2).real)
def get_qbt_number(state):
    state_after_a = qbt_destory_arr @ state
    return np.abs(np.sum(state_after_a**2).real)

# %%
fig,ax = plt.subplots(1,1,figsize=(4,3))
qls = list(range(max_ql))


for ql in list(range(10)):

    photon_num_arr = np.zeros((max_ol))
    qbt_num_arr = np.zeros((max_ol))
    for ol in range(max_ol):
        photon_num_arr[ol] = get_photon_number(system.evecs[overlap_idx_arr[ql][ol]].full())
        qbt_num_arr[ol] = get_qbt_number(system.evecs[overlap_idx_arr[ql][ol]].full())

    ax.plot(photon_num_arr,qbt_num_arr,label=f'{ql}')

# ax.set_ylim(0,4)
# ax.set_xlim(0,max_ol-5)
ax.set_xlabel(r'$N_r$')
ax.set_ylabel(r'$N_f$')

plt.tight_layout()
fig.savefig('hybridization.pdf')

# %%
with open('syste.pkl', 'rb') as f:
    system = pickle.load(f)

# %%
system.evals[ system.product_to_dressed[(0,1)] ] - system.evals[ system.product_to_dressed[(0,0)] ], \
system.evals[ system.product_to_dressed[(1,1)] ] - system.evals[ system.product_to_dressed[(1,0)] ]
# Out:
# (30.000000665900046, 30.000000502781365)

# %%
state_leak_dressed = qutip.basis(max_ql * max_ol, system.product_to_dressed[(0,0)])
state_0_dressed = qutip.basis(max_ql * max_ol, system.product_to_dressed[(1,0)])
state_1_dressed = qutip.basis(max_ql * max_ol, system.product_to_dressed[(2,0)])
state_plus_X_dressed = (state_0_dressed +  state_1_dressed).unit()
state_minus_X_dressed = (state_0_dressed - state_1_dressed).unit()
state_plus_Y_dressed = (state_0_dressed + 1j * state_1_dressed).unit()
state_minus_Y_dressed = (state_0_dressed - 1j * state_1_dressed).unit()

initial_states  = [
                    state_leak_dressed,
                   state_0_dressed,
                   state_1_dressed,
                   state_plus_X_dressed,
                   state_minus_X_dressed,
                   state_plus_Y_dressed,
                   state_minus_Y_dressed
                   ]

leakage_products_to_keep = [[ql, ol] for ql in [0] for ol in range(max_ol) ]
computational_products_to_keep = [[ql, ol] for ql in [1,2] for ol in range(150) ]
list_of_products_to_keep = [
    leakage_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep
]


list_of_systems = []
list_of_kwargs = []
for products_to_keep, y0 in zip(list_of_products_to_keep, initial_states):
    system.set_new_product_to_keep(products_to_keep)
    system.set_new_operators_after_setting_new_product_to_keep()
    list_of_systems.append(deepcopy(system))
    list_of_kwargs.append( {
        'y0':system.truncate_function(y0) ,
        'tlist':tlist,
        'drive_terms':[DriveTerm( 
                            driven_op= system.driven_operator,
                            pulse_shape_func=square_pulse_with_rise_fall,
                            pulse_shape_args={
                                'w_d': w_d ,
                                'amp': amp,
                                't_rise': 20,
                                't_square': tot_time
                            })],
        'e_ops':[system.a_trunc , system.a_trunc.dag()*system.a_trunc],
        # 'c_ops':[kappa *qutip.lindblad_dissipator(system.a_trunc) ]
        })
    

results = run_parallel_ODEsolve_and_post_process_jobs_with_different_systems(
    list_of_systems,
    list_of_kwargs,
    post_processing = ['pad_back']
)

import pickle
with open('sesolve_small_dim_a015_tomo.pkl', 'wb') as file:
    pickle.dump(results, file)
# Out:
#  Total run time: 290.89s*] Elapsed 290.89s / Remaining 00:00:00:00 [*********43%           ] Elapsed 126.09s / Remaining 00:00:02:47
#  [*********98%***********] Elapsed 290.96s / Remaining 00:00:00:05
# Processing states with pad_back_custom:   7%|▋         | 29/400 [00:00<00:04, 79.35it/s]
#  [*********99%***********] Elapsed 291.27s / Remaining 00:00:00:02
# Processing states with pad_back_custom:  16%|█▌        | 63/400 [00:00<00:04, 78.21it/s]
#  [********100%***********] Elapsed 291.76s / Remaining 00:00:00:00
# Processing states with pad_back_custom:  20%|█▉        | 79/400 [00:01<00:04, 71.68it/s]
#  [*********99%***********] Elapsed 292.04s / Remaining 00:00:00:02
# Processing states with pad_back_custom:  24%|██▍       | 96/400 [00:01<00:04, 73.18it/s]
#  [*********99%***********] Elapsed 292.41s / Remaining 00:00:00:02
# Processing states with pad_back_custom:  28%|██▊       | 112/400 [00:01<00:04, 71.57it/s]
#  Total run time: 292.50s*] Elapsed 292.50s / Remaining 00:00:00:00
#  [*********98%***********] Elapsed 292.55s / Remaining 00:00:00:05
# Processing states with pad_back_custom:   6%|▌         | 23/400 [00:00<00:05, 66.79it/s]]
#  [*********99%***********] Elapsed 292.96s / Remaining 00:00:00:02
# Processing states with pad_back_custom:  14%|█▍        | 55/400 [00:00<00:04, 73.72it/s]]
#  [*********98%***********] Elapsed 293.32s / Remaining 00:00:00:05
# Processing states with pad_back_custom:   0%|          | 0/400 [00:00<?, ?it/s]0.21it/s]]
#  Total run time: 293.70s*] Elapsed 293.70s / Remaining 00:00:00:00
#  [*********99%***********] Elapsed 293.80s / Remaining 00:00:00:02
# Processing states with pad_back_custom:  57%|█████▋    | 229/400 [00:03<00:02, 73.66it/s]
#  [*********99%***********] Elapsed 294.13s / Remaining 00:00:00:02
# Processing states with pad_back_custom:  40%|███▉      | 158/400 [00:02<00:03, 72.28it/s]
#  [********100%***********] Elapsed 294.76s / Remaining 00:00:00:00
# Processing states with pad_back_custom:  47%|████▋     | 188/400 [00:02<00:03, 62.98it/s]
#  [*********60%**         ] Elapsed 295.02s / Remaining 00:00:03:16
# Processing states with pad_back_custom:  34%|███▍      | 136/400 [00:01<00:03, 69.52it/s]
#  Total run time: 295.41s*] Elapsed 295.41s / Remaining 00:00:00:00
# Processing states with pad_back_custom:   0%|          | 0/400 [00:00<?, ?it/s]73.40it/s]
#  Total run time: 295.77s*] Elapsed 295.77s / Remaining 00:00:00:00
#  [*********99%***********] Elapsed 295.89s / Remaining 00:00:00:02
# Processing states with pad_back_custom:  67%|██████▋   | 269/400 [00:03<00:01, 73.55it/s]
#  [*********60%**         ] Elapsed 296.18s / Remaining 00:00:03:17
# Processing states with pad_back_custom: 100%|██████████| 400/400 [00:05<00:00, 74.12it/s]
# Processing states with pad_back_custom:  80%|████████  | 321/400 [00:04<00:01, 78.14it/s]
#  [********100%***********] Elapsed 296.70s / Remaining 00:00:00:00
# Processing states with pad_back_custom:  66%|██████▋   | 266/400 [00:03<00:01, 74.67it/s]
#  Total run time: 297.37s*] Elapsed 297.37s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 400/400 [00:05<00:00, 73.86it/s]
# Processing states with pad_back_custom:  55%|█████▌    | 221/400 [00:02<00:02, 78.46it/s]
#  [*********61%**         ] Elapsed 298.31s / Remaining 00:00:03:10
# Processing states with pad_back_custom: 100%|██████████| 400/400 [00:05<00:00, 76.14it/s]
# Processing states with pad_back_custom:  37%|███▋      | 149/400 [00:01<00:03, 80.27it/s]
#  [*********61%**         ] Elapsed 299.25s / Remaining 00:00:03:11
# Processing states with pad_back_custom:  56%|█████▌    | 222/400 [00:02<00:02, 82.13it/s]
#  [*********61%**         ] Elapsed 300.12s / Remaining 00:00:03:11
# Processing states with pad_back_custom: 100%|██████████| 400/400 [00:05<00:00, 77.44it/s]
# Processing states with pad_back_custom: 100%|██████████| 400/400 [00:05<00:00, 78.44it/s]
# Processing states with pad_back_custom:  74%|███████▎  | 294/400 [00:03<00:01, 81.72it/s]
#  [*********62%**         ] Elapsed 301.03s / Remaining 00:00:03:04
# Processing states with pad_back_custom:  92%|█████████▏| 366/400 [00:04<00:00, 87.38it/s]
#  [*********62%**         ] Elapsed 301.88s / Remaining 00:00:03:05
# Processing states with pad_back_custom: 100%|██████████| 400/400 [00:04<00:00, 82.21it/s]
#  Total run time: 478.48s*] Elapsed 478.48s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 400/400 [00:04<00:00, 81.63it/s]

# %%
with open('sesolve_small_dim_a015_tomo.pkl', 'rb') as file:
    results = pickle.load(file)

# %%
for i in [0,1,2]:
    plt.plot(results[i].expect[1])

# %%
for i in [0,1,2]:
    plt.plot(results[i].expect[1])
plt.xlim(345,350)
# plt.ylim(0,0.01)
# Out:
# (345.0, 350.0)

# %%
from CoupledQuantumSystems.visualization import *
plot_heatmap(results[0],347,system.product_to_dressed,max_ql,max_ol,LogNorm())

# %%
plot_heatmap(results[1],int(347/2),system.product_to_dressed,max_ql,max_ol,LogNorm())

# %%
from functools import partial
import multiprocessing
from tqdm import tqdm
from CoupledQuantumSystems.qobj_manip import find_dominant_frequency,get_product_vectorized,dressed_to_product_vectorized

def convert_dressed_to_product_vectorized(system, states, products_to_keep, num_processes=None, update_products_to_keep=True):
    if update_products_to_keep:
        system.set_new_product_to_keep(products_to_keep)
        system.set_new_operators_after_setting_new_product_to_keep()

    if num_processes is None:
        num_processes = multiprocessing.cpu_count()

    # Multiprocessing, vectorized
    partial_function = partial(get_product_vectorized,
                               pad_back_custom=system.pad_back_function,
                               product_to_dressed=system.product_to_dressed,
                               sign_multiplier_vector=system.sign_multiplier_vector)

    with multiprocessing.Pool(processes=num_processes) as pool:
        # Wrap tqdm around the iterator to show the progress
        product_states = list(tqdm(pool.imap(partial_function, states), total=len(states), desc="Processing States"))

    return product_states


for i, (result, products_to_keep) in enumerate(zip(results, list_of_products_to_keep)):
    result.states_in_product_basis = convert_dressed_to_product_vectorized(system=system, 
                                                                           states= result.states,
                                                                            products_to_keep = products_to_keep,
                                                                            num_processes = 14
                                                                                    )
with open('sesolve_small_dim_a015_tomo_product.pkl', 'wb') as f:
    pickle.dump(results,f)
# Out:
# Processing States: 100%|██████████| 400/400 [03:04<00:00,  2.16it/s]
# Processing States: 100%|██████████| 400/400 [03:32<00:00,  1.88it/s]
# Processing States: 100%|██████████| 400/400 [03:30<00:00,  1.90it/s]
# Processing States: 100%|██████████| 400/400 [03:38<00:00,  1.83it/s]
# Processing States: 100%|██████████| 400/400 [03:38<00:00,  1.83it/s]
# Processing States: 100%|██████████| 400/400 [03:36<00:00,  1.84it/s]
# Processing States: 100%|██████████| 400/400 [03:19<00:00,  2.01it/s]

# %%
with open('sesolve_small_dim_a015_tomo_product.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
leakage_arr = np.zeros(shape=(3,len(tlist)))
for ql,result in zip([0,1,2],[results[0],results[1],results[2]]):
    initial_qbt_state = qutip.basis(max_ql,  ql)
    op = initial_qbt_state * initial_qbt_state.dag()
    for t_idx in tqdm(range(len(tlist)), desc = "t loop"):
        rho_product = result.states_in_product_basis[t_idx]
        rho_qbt = qutip.Qobj(np.array(rho_product.ptrace(0)))
        leakage_arr[ql,t_idx] = 1-qutip.expect(op, rho_qbt)

for ql in [0,1,2]:
    plt.plot(leakage_arr[ql],label=f'{ql}')
plt.legend()
plt.yscale('log')
# Out:
# t loop: 100%|██████████| 400/400 [00:00<00:00, 447.19it/s]
# t loop: 100%|██████████| 400/400 [00:00<00:00, 417.86it/s]
# t loop: 100%|██████████| 400/400 [00:00<00:00, 458.62it/s]

# %%
def truncate_to_computational(state,i,j):
    arr = state.full()
    arr= arr[[i, j], :][:, [i, j]]
    dm = qutip.Qobj(arr)
    dm = dm/dm.tr()
    return dm
zero = qutip.basis(2, 0)
one = qutip.basis(2, 1)
states_ideal  = [zero,
                one,
                (zero +  one).unit(),
                (zero - one).unit(),
                (zero + 1j * one).unit(),
                (zero - 1j *one).unit()]

def calc_average_fidelity_with_phase(phase,dms,states_ideal):
    gate = qutip.qip.operations.phasegate(phase)
    fid=[]
    for dm,ket_ideal in zip(dms,states_ideal):
        fid.append(qutip.fidelity(gate*dm*gate.dag(), ket_ideal))
    return 1-sum(fid)/len(fid)

# %%
from scipy.optimize import minimize
infidelity = []
phase = []
original_phase = 2*np.pi*tlist*(system.evals[system.product_to_dressed[(2,0)]]-system.evals[system.product_to_dressed[(1,0)]]) + np.pi
original_phase = original_phase % (2*np.pi) 

for idx in tqdm(range(len(tlist)), desc='Processing'):
    dms = [truncate_to_computational(result.states_in_product_basis[idx].ptrace(0), 1,2) for result in results[1:]]
    def objective_function(phase):
        return calc_average_fidelity_with_phase(phase[0], dms, states_ideal)
    opt_result = minimize(objective_function,x0=  [original_phase[idx]],bounds = [(0, 2*np.pi)], method="Powell")
    infidelity.append(opt_result.fun)
    phase.append(opt_result.x[0])
    

fig, axes = plt.subplots(1,2,figsize = (6,3))
axes[0].plot(tlist,phase)
axes[0].set_title('phase correction')
axes[1].plot(tlist,infidelity)
axes[1].set_yscale('log')
axes[1].set_title('infidelity')
# Out:
# Processing:  23%|██▎       | 92/400 [00:04<00:16, 18.59it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 11
#       9 def objective_function(phase):
#      10     return calc_average_fidelity_with_phase(phase[0], dms, states_ideal)
# ---> 11 opt_result = minimize(objective_function,x0=  [original_phase[idx]],bounds = [(0, 2*np.pi)], method="Powell")
#      12 infidelity.append(opt_result.fun)
#      13 phase.append(opt_result.x[0])
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_minimize.py:704, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
# --> 704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     705 elif meth == 'cg':
#     706     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3595, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3593 direc1 = direc[i]
#    3594 fx2 = fval
# -> 3595 fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3596                                      tol=xtol * 100,
#    3597                                      lower_bound=lower_bound,
#    3598                                      upper_bound=upper_bound,
#    3599                                      fval=fval)
#    3600 if (fx2 - fval) > delta:
#    3601     delta = fx2 - fval
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3283, in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    3280     return _linesearch_powell(func, p, xi, fval=fval, tol=tol)
#    3281 elif not np.isneginf(bound[0]) and not np.isposinf(bound[1]):
#    3282     # we can use a bounded scalar minimization
# -> 3283     res = _minimize_scalar_bounded(myfunc, bound, xatol=tol / 100)
#    3284     xi = res.x * xi
#    3285     return squeeze(res.fun), p + xi, xi
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:2426, in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    2424 si = np.sign(rat) + (rat == 0)
#    2425 x = xf + si * np.maximum(np.abs(rat), tol1)
# -> 2426 fu = func(x, *args)
#    2427 num += 1
#    2428 fmin_data = (num, x, fu)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:3264, in _linesearch_powell.<locals>.myfunc(alpha)
#    3263 def myfunc(alpha):
# -> 3264     return func(p + alpha*xi)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:640, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     638 ncalls[0] += 1
#     639 # A copy of x is sent to the user function (gh13740)
# --> 640 fx = function(np.copy(x), *(wrapper_args + args))
#     641 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     642 # backwards-compatibility, also allow np.array([1.3]),
#     643 # np.array([[1.3]]) etc.
#     644 if not np.isscalar(fx):
#
# Cell In[7], line 10, in objective_function(phase)
#       9 def objective_function(phase):
# ---> 10     return calc_average_fidelity_with_phase(phase[0], dms, states_ideal)
#
# Cell In[6], line 20, in calc_average_fidelity_with_phase(phase, dms, states_ideal)
#      18 fid=[]
#      19 for dm,ket_ideal in zip(dms,states_ideal):
# ---> 20     fid.append(qutip.fidelity(gate*dm*gate.dag(), ket_ideal))
#      21 return 1-sum(fid)/len(fid)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/metrics.py:67, in fidelity(A, B)
#      63 else:
#      64     if B.isket or B.isbra:
#      65         # Swap the order so that we can take a more numerically
#      66         # stable square root of B.
# ---> 67         return fidelity(B, A)
#      68     # If we made it here, both A and B are operators, so
#      69     # we have to take the sqrtm of one of them.
#      70     sqrtmA = A.sqrtm()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/metrics.py:80, in fidelity(A, B)
#      73     raise TypeError('Density matrices do not have same dimensions.')
#      75 # We don't actually need the whole matrix here, just the trace
#      76 # of its square root, so let's just get its eigenenergies instead.
#      77 # We also truncate negative eigenvalues to avoid nan propagation;
#      78 # even for positive semidefinite matrices, small negative eigenvalues
#      79 # can be reported.
# ---> 80 eig_vals = (sqrtmA * B * sqrtmA).eigenenergies()
#      81 return float(np.real(np.sqrt(eig_vals[eig_vals > 0]).sum()))
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/qobj.py:1762, in Qobj.eigenenergies(self, sparse, sort, eigvals, tol, maxiter)
#    1730 def eigenenergies(self, sparse=False, sort='low',
#    1731                   eigvals=0, tol=0, maxiter=100000):
#    1732     """Eigenenergies of a quantum object.
#    1733
#    1734     Eigenenergies (eigenvalues) are defined for operators or superoperators
#    (...)
#    1760
#    1761     """
# -> 1762     return sp_eigs(self.data, self.isherm, vecs=False, sparse=sparse,
#    1763                    sort=sort, eigvals=eigvals, tol=tol, maxiter=maxiter)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/sparse.py:379, in sp_eigs(data, isherm, vecs, sparse, sort, eigvals, tol, maxiter)
#     376     evals, evecs = _sp_eigs(data, isherm, vecs, N, eigvals, num_large,
#     377                             num_small, tol, maxiter)
#     378 else:
# --> 379     evals, evecs = _dense_eigs(data.toarray(), isherm, vecs, N, eigvals,
#     380                                num_large, num_small)
#     382 if sort == 'high':  # flip arrays to largest values first
#     383     if vecs:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/sparse.py:200, in _dense_eigs(data, isherm, vecs, N, eigvals, num_large, num_small)
#     197     else:
#     198         evals = la.eigvals(data)
# --> 200 _zipped = list(zip(evals, range(len(evals))))
#     201 _zipped.sort()
#     202 evals, perm = list(zip(*_zipped))
#
# KeyboardInterrupt:

# %%
# state_leak_dressed = qutip.basis(max_ql * max_ol, system.product_to_dressed[(0,0)])
state_0_dressed = qutip.basis(max_ql * max_ol, system.product_to_dressed[(1,0)])
state_1_dressed = qutip.basis(max_ql * max_ol, system.product_to_dressed[(2,0)])
state_plus_X_dressed = (state_0_dressed +  state_1_dressed).unit()
state_minus_X_dressed = (state_0_dressed - state_1_dressed).unit()
state_plus_Y_dressed = (state_0_dressed + 1j * state_1_dressed).unit()
state_minus_Y_dressed = (state_0_dressed - 1j * state_1_dressed).unit()

initial_states  = [
                    # state_leak_dressed,
                   state_0_dressed,
                   state_1_dressed,
                   state_plus_X_dressed,
                   state_minus_X_dressed,
                   state_plus_Y_dressed,
                   state_minus_Y_dressed
                   ]

# leakage_products_to_keep = [[ql, ol] for ql in range(10) for ol in range(max_ol) ]
computational_products_to_keep = [[ql, ol] for ql in range(10) for ol in range(150) ]
list_of_products_to_keep = [
    # leakage_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep,
    computational_products_to_keep
]


# list_of_systems = []
# list_of_kwargs = []
# for products_to_keep, y0 in zip(list_of_products_to_keep, initial_states):
#     system.set_new_product_to_keep(products_to_keep)
#     system.set_new_operators_after_setting_new_product_to_keep()
#     list_of_systems.append(deepcopy(system))
#     list_of_kwargs.append( {
#         'y0':system.truncate_function(y0) ,
#         'tlist':tlist,
#         'drive_terms':[DriveTerm( 
#                             driven_op= system.driven_operator,
#                             pulse_shape_func=square_pulse_with_rise_fall,
#                             pulse_shape_args={
#                                 'w_d': w_d ,
#                                 'amp': amp,
#                                 't_rise': 20,
#                                 't_square': tot_time
#                             })],
#         'e_ops':[system.a_trunc , system.a_trunc.dag()*system.a_trunc],
#         # 'c_ops':[kappa *qutip.lindblad_dissipator(system.a_trunc) ]
#         })
    

# results = run_parallel_ODEsolve_and_post_process_jobs_with_different_systems(
#     list_of_systems,
#     list_of_kwargs,
#     post_processing = ['pad_back']
# )

# import pickle
# with open('sesolve_large_dim_a015_tomo.pkl', 'wb') as file:
#     pickle.dump(results, file)

# %%
import pickle
with open('sesolve_large_dim_a015_tomo.pkl', 'rb') as file:
    results = pickle.load(file)

# %%
from functools import partial
import multiprocessing
from tqdm import tqdm
from CoupledQuantumSystems.qobj_manip import find_dominant_frequency,get_product_vectorized,dressed_to_product_vectorized

def convert_dressed_to_product_vectorized(system, states, products_to_keep, num_processes=None, update_products_to_keep=True):
    if update_products_to_keep:
        system.set_new_product_to_keep(products_to_keep)
        system.set_new_operators_after_setting_new_product_to_keep()

    if num_processes is None:
        num_processes = multiprocessing.cpu_count()

    # Multiprocessing, vectorized
    partial_function = partial(get_product_vectorized,
                               pad_back_custom=system.pad_back_function,
                               product_to_dressed=system.product_to_dressed,
                               sign_multiplier_vector=system.sign_multiplier_vector)

    with multiprocessing.Pool(processes=num_processes) as pool:
        # Wrap tqdm around the iterator to show the progress
        product_states = list(tqdm(pool.imap(partial_function, states), total=len(states), desc="Processing States"))

    return product_states


# for i, (result, products_to_keep) in enumerate(zip(results, list_of_products_to_keep)):
#     result.states_in_product_basis = convert_dressed_to_product_vectorized(system=system, 
#                                                                            states= result.states,
#                                                                             products_to_keep = products_to_keep,
#                                                                             num_processes = 18
#                                                                                     )
# with open('sesolve_large_dim_a015_tomo_product.pkl', 'wb') as f:
#     pickle.dump(results,f)


for i, result, products_to_keep in zip([0,1,2,3,4,5][5:],results[5:], list_of_products_to_keep[5:]):
    states_in_product_basis = convert_dressed_to_product_vectorized(system=system, 
                                                                           states= result.states,
                                                                            products_to_keep = products_to_keep,
                                                                            num_processes = 14
                                                                                    )
    with open(f'sesolve_large_dim_a015_tomo_product_part{i}.pkl', 'wb') as f:
        pickle.dump(states_in_product_basis,f)
# Out:
# Processing States: 100%|██████████| 400/400 [03:40<00:00,  1.81it/s]

# %%
leakage_arr = np.zeros(shape=(2,len(tlist)))
for ql in [1,2]:
    initial_qbt_state = qutip.basis(max_ql,  ql)
    op = initial_qbt_state * initial_qbt_state.dag()
    with open(f'sesolve_large_dim_a015_tomo_product_part{ql-1}.pkl', 'rb') as f:
        states_in_product_basis = pickle.load(f)
    for t_idx in tqdm(range(len(tlist)), desc = "t loop"):
        rho_product = states_in_product_basis[t_idx]
        rho_qbt = qutip.Qobj(np.array(rho_product.ptrace(0)))
        leakage_arr[ql-1,t_idx] = 1-qutip.expect(op, rho_qbt)

for ql in [1,2]:
    plt.plot(leakage_arr[ql-1],label=f'{ql}')
plt.legend()
plt.yscale('log')
# Out:
# t loop: 100%|██████████| 400/400 [00:12<00:00, 31.21it/s]
# t loop: 100%|██████████| 400/400 [00:13<00:00, 29.21it/s]

# %%
for i, result in zip([0,1,2,3,4,5],results):
    with open(f'sesolve_large_dim_a015_tomo_product_part{i}.pkl', 'rb') as f:
        states_in_product_basis = pickle.load(f)
    result.states_in_product_basis = states_in_product_basis

# %%
def truncate_to_computational(state,i,j):
    arr = state.full()
    arr= arr[[i, j], :][:, [i, j]]
    dm = qutip.Qobj(arr)
    dm = dm/dm.tr()
    return dm
zero = qutip.basis(2, 0)
one = qutip.basis(2, 1)
states_ideal  = [zero,
                one,
                (zero +  one).unit(),
                (zero - one).unit(),
                (zero + 1j * one).unit(),
                (zero - 1j *one).unit()]

def calc_average_fidelity_with_phase(phase,dms,states_ideal):
    gate = qutip.qip.operations.phasegate(phase)
    fid=[]
    for dm,ket_ideal in zip(dms,states_ideal):
        fid.append(qutip.fidelity(gate*dm*gate.dag(), ket_ideal))
    return 1-sum(fid)/len(fid)

# %%
from scipy.optimize import minimize
infidelity = []
phase = []
original_phase = 2*np.pi*tlist*(system.evals[system.product_to_dressed[(2,0)]]-system.evals[system.product_to_dressed[(1,0)]]) + np.pi
original_phase = original_phase % (2*np.pi) 

for idx in tqdm(range(len(tlist)), desc='Processing'):
    dms = [truncate_to_computational(result.states_in_product_basis[idx].ptrace(0), 1,2) for result in results]
    def objective_function(phase):
        return calc_average_fidelity_with_phase(phase[0], dms, states_ideal)
    opt_result = minimize(objective_function,x0=  [original_phase[idx]],bounds = [(0, 2*np.pi)], method="Powell")
    infidelity.append(opt_result.fun)
    phase.append(opt_result.x[0])
# Out:
# Processing: 100%|██████████| 400/400 [02:24<00:00,  2.78it/s]

# %%
    
fig, axes = plt.subplots(1,2,figsize = (6,3))
axes[0].plot(tlist,phase)
axes[0].plot(tlist,original_phase)

axes[0].set_title('phase correction')
axes[1].plot(tlist,infidelity)
axes[1].set_yscale('log')
axes[1].set_title('infidelity')
# Out:
# Text(0.5, 1.0, 'infidelity')

# %%
with open(f'sesolve_large_dim_a015_tomo_infidelity.pkl', 'wb') as f:
    pickle.dump(infidelity,f)

# %%
leakage_arr = np.zeros(shape=(6,len(tlist)))
initial_qbt_state = qutip.basis(max_ql,  1)
op = initial_qbt_state * initial_qbt_state.dag()
for i in [0,1,2,3,4,5]:
    for t_idx in tqdm(range(len(tlist)), desc = "t loop"):
        rho_product = results[i].states_in_product_basis[t_idx]
        rho_qbt = qutip.Qobj(np.array(rho_product.ptrace(0)))
        leakage_arr[i,t_idx] = 1-qutip.expect(op, rho_qbt)

# %%
for i in [0,1,2,3,4,5]:
    plt.plot(leakage_arr[i],label=f'{i}',alpha=0.5)
plt.legend()
plt.yscale('log')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

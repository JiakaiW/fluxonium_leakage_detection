# %%
import subprocess

# Define the install and remove commands
install_command = ["conda", "install", "-y", "-c", "conda-forge", "scqubits"]
remove_command = ["conda", "remove", "-y", "scqubits"]

# Loop to install and remove the package 10,000 times
for i in range(10000):
    print(f"Iteration {i+1}: Installing scqubits")
    subprocess.run(install_command, check=True)
    
    print(f"Iteration {i+1}: Removing scqubits")
    subprocess.run(remove_command, check=True)
# Out:
# Iteration 1: Installing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   added / updated specs:
#     - scqubits
#
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-hd74edd7_2
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-hd74edd7_2
#   c-ares             conda-forge/osx-arm64::c-ares-1.34.2-h7ab814d_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0
#   contourpy          conda-forge/osx-arm64::contourpy-1.3.0-py310h6000651_2
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   dill               conda-forge/noarch::dill-0.3.9-pyhd8ed1ab_0
#   fonttools          conda-forge/osx-arm64::fonttools-4.54.1-py310h5799be4_1
#   freetype           conda-forge/osx-arm64::freetype-2.12.1-hadb7bae_2
#   gmp                conda-forge/osx-arm64::gmp-6.3.0-h7bae524_2
#   gmpy2              conda-forge/osx-arm64::gmpy2-2.1.5-py310heb17c8b_2
#   h5py               conda-forge/osx-arm64::h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5               conda-forge/osx-arm64::hdf5-1.14.3-nompi_hec07895_105
#   ipyvue             conda-forge/noarch::ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify         conda-forge/noarch::ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets         conda-forge/noarch::ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver         conda-forge/osx-arm64::kiwisolver-1.4.7-py310h7306fd8_0
#   krb5               conda-forge/osx-arm64::krb5-1.21.3-h237132a_0
#   lcms2              conda-forge/osx-arm64::lcms2-2.16-ha0e7c42_0
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-h9a09cb3_0
#   libaec             conda-forge/osx-arm64::libaec-1.1.3-hebf3989_0
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-hd74edd7_2
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-25_osxarm64_openblas
#   libcurl            conda-forge/osx-arm64::libcurl-8.8.0-h7b6f9a7_1
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.20-h93a5062_0
#   libedit            conda-forge/osx-arm64::libedit-3.1.20191231-hc8eb9b7_2
#   libev              conda-forge/osx-arm64::libev-4.33-h93a5062_2
#   libgfortran        conda-forge/osx-arm64::libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5       conda-forge/osx-arm64::libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo      conda-forge/osx-arm64::libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2         conda-forge/osx-arm64::libnghttp2-1.58.0-ha4dd798_1
#   libopenblas        conda-forge/osx-arm64::libopenblas-0.3.28-openmp_h517c56d_0
#   libpng             conda-forge/osx-arm64::libpng-1.6.43-h091b4b1_0
#   libssh2            conda-forge/osx-arm64::libssh2-1.11.0-h7a5bd25_0
#   libtiff            conda-forge/osx-arm64::libtiff-4.6.0-h07db509_3
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.4.0-h93a5062_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.15-hf346824_0
#   llvm-openmp        conda-forge/osx-arm64::llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib         conda-forge/osx-arm64::matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base    conda-forge/osx-arm64::matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc                conda-forge/osx-arm64::mpc-1.3.1-h8f1351a_1
#   mpfr               conda-forge/osx-arm64::mpfr-4.2.1-hb693164_3
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess       conda-forge/osx-arm64::multiprocess-0.70.17-py310hf9df320_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/osx-arm64::numpy-1.26.4-py310hd45542a_0
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.2-h9f1df11_0
#   pathos             conda-forge/noarch::pathos-0.3.3-pyhd8ed1ab_0
#   pillow             conda-forge/osx-arm64::pillow-10.3.0-py310h81a8c2e_0
#   pox                conda-forge/noarch::pox-0.3.5-pyhd8ed1ab_0
#   ppft               conda-forge/noarch::ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-hd74edd7_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull              conda-forge/osx-arm64::qhull-2020.2-h420ef59_5
#   qutip              conda-forge/osx-arm64::qutip-5.0.4-py310he5c2185_0
#   scipy              conda-forge/osx-arm64::scipy-1.14.1-py310hc05a576_1
#   scqubits           conda-forge/osx-arm64::scqubits-4.2.0-py310h7191f72_0
#   sympy              conda-forge/noarch::sympy-1.13.3-pypyh2585a3b_103
#   tqdm               conda-forge/noarch::tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2       conda-forge/osx-arm64::unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd               conda-forge/osx-arm64::zstd-1.5.6-hb46c0d2_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 1: Removing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   removed specs:
#     - scqubits
#
#
# The following packages will be REMOVED:
#
#   brotli-1.1.0-hd74edd7_2
#   brotli-bin-1.1.0-hd74edd7_2
#   c-ares-1.34.2-h7ab814d_0
#   cached-property-1.5.2-hd8ed1ab_1
#   cached_property-1.5.2-pyha770c72_1
#   colorama-0.4.6-pyhd8ed1ab_0
#   contourpy-1.3.0-py310h6000651_2
#   cycler-0.12.1-pyhd8ed1ab_0
#   dill-0.3.9-pyhd8ed1ab_0
#   fonttools-4.54.1-py310h5799be4_1
#   freetype-2.12.1-hadb7bae_2
#   gmp-6.3.0-h7bae524_2
#   gmpy2-2.1.5-py310heb17c8b_2
#   h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5-1.14.3-nompi_hec07895_105
#   ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver-1.4.7-py310h7306fd8_0
#   krb5-1.21.3-h237132a_0
#   lcms2-2.16-ha0e7c42_0
#   lerc-4.0.0-h9a09cb3_0
#   libaec-1.1.3-hebf3989_0
#   libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc-1.1.0-hd74edd7_2
#   libcblas-3.9.0-25_osxarm64_openblas
#   libcurl-8.8.0-h7b6f9a7_1
#   libdeflate-1.20-h93a5062_0
#   libedit-3.1.20191231-hc8eb9b7_2
#   libev-4.33-h93a5062_2
#   libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2-1.58.0-ha4dd798_1
#   libopenblas-0.3.28-openmp_h517c56d_0
#   libpng-1.6.43-h091b4b1_0
#   libssh2-1.11.0-h7a5bd25_0
#   libtiff-4.6.0-h07db509_3
#   libwebp-base-1.4.0-h93a5062_0
#   libxcb-1.15-hf346824_0
#   llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc-1.3.1-h8f1351a_1
#   mpfr-4.2.1-hb693164_3
#   mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess-0.70.17-py310hf9df320_0
#   munkres-1.1.4-pyh9f0ad1d_0
#   numpy-1.26.4-py310hd45542a_0
#   openjpeg-2.5.2-h9f1df11_0
#   pathos-0.3.3-pyhd8ed1ab_0
#   pillow-10.3.0-py310h81a8c2e_0
#   pox-0.3.5-pyhd8ed1ab_0
#   ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs-0.4-hd74edd7_1002
#   pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull-2020.2-h420ef59_5
#   qutip-5.0.4-py310he5c2185_0
#   scipy-1.14.1-py310hc05a576_1
#   scqubits-4.2.0-py310h7191f72_0
#   sympy-1.13.3-pypyh2585a3b_103
#   tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd-1.5.6-hb46c0d2_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 2: Installing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   added / updated specs:
#     - scqubits
#
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-hd74edd7_2
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-hd74edd7_2
#   c-ares             conda-forge/osx-arm64::c-ares-1.34.2-h7ab814d_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0
#   contourpy          conda-forge/osx-arm64::contourpy-1.3.0-py310h6000651_2
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   dill               conda-forge/noarch::dill-0.3.9-pyhd8ed1ab_0
#   fonttools          conda-forge/osx-arm64::fonttools-4.54.1-py310h5799be4_1
#   freetype           conda-forge/osx-arm64::freetype-2.12.1-hadb7bae_2
#   gmp                conda-forge/osx-arm64::gmp-6.3.0-h7bae524_2
#   gmpy2              conda-forge/osx-arm64::gmpy2-2.1.5-py310heb17c8b_2
#   h5py               conda-forge/osx-arm64::h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5               conda-forge/osx-arm64::hdf5-1.14.3-nompi_hec07895_105
#   ipyvue             conda-forge/noarch::ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify         conda-forge/noarch::ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets         conda-forge/noarch::ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver         conda-forge/osx-arm64::kiwisolver-1.4.7-py310h7306fd8_0
#   krb5               conda-forge/osx-arm64::krb5-1.21.3-h237132a_0
#   lcms2              conda-forge/osx-arm64::lcms2-2.16-ha0e7c42_0
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-h9a09cb3_0
#   libaec             conda-forge/osx-arm64::libaec-1.1.3-hebf3989_0
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-hd74edd7_2
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-25_osxarm64_openblas
#   libcurl            conda-forge/osx-arm64::libcurl-8.8.0-h7b6f9a7_1
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.20-h93a5062_0
#   libedit            conda-forge/osx-arm64::libedit-3.1.20191231-hc8eb9b7_2
#   libev              conda-forge/osx-arm64::libev-4.33-h93a5062_2
#   libgfortran        conda-forge/osx-arm64::libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5       conda-forge/osx-arm64::libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo      conda-forge/osx-arm64::libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2         conda-forge/osx-arm64::libnghttp2-1.58.0-ha4dd798_1
#   libopenblas        conda-forge/osx-arm64::libopenblas-0.3.28-openmp_h517c56d_0
#   libpng             conda-forge/osx-arm64::libpng-1.6.43-h091b4b1_0
#   libssh2            conda-forge/osx-arm64::libssh2-1.11.0-h7a5bd25_0
#   libtiff            conda-forge/osx-arm64::libtiff-4.6.0-h07db509_3
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.4.0-h93a5062_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.15-hf346824_0
#   llvm-openmp        conda-forge/osx-arm64::llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib         conda-forge/osx-arm64::matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base    conda-forge/osx-arm64::matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc                conda-forge/osx-arm64::mpc-1.3.1-h8f1351a_1
#   mpfr               conda-forge/osx-arm64::mpfr-4.2.1-hb693164_3
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess       conda-forge/osx-arm64::multiprocess-0.70.17-py310hf9df320_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/osx-arm64::numpy-1.26.4-py310hd45542a_0
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.2-h9f1df11_0
#   pathos             conda-forge/noarch::pathos-0.3.3-pyhd8ed1ab_0
#   pillow             conda-forge/osx-arm64::pillow-10.3.0-py310h81a8c2e_0
#   pox                conda-forge/noarch::pox-0.3.5-pyhd8ed1ab_0
#   ppft               conda-forge/noarch::ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-hd74edd7_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull              conda-forge/osx-arm64::qhull-2020.2-h420ef59_5
#   qutip              conda-forge/osx-arm64::qutip-5.0.4-py310he5c2185_0
#   scipy              conda-forge/osx-arm64::scipy-1.14.1-py310hc05a576_1
#   scqubits           conda-forge/osx-arm64::scqubits-4.2.0-py310h7191f72_0
#   sympy              conda-forge/noarch::sympy-1.13.3-pypyh2585a3b_103
#   tqdm               conda-forge/noarch::tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2       conda-forge/osx-arm64::unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd               conda-forge/osx-arm64::zstd-1.5.6-hb46c0d2_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 2: Removing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   removed specs:
#     - scqubits
#
#
# The following packages will be REMOVED:
#
#   brotli-1.1.0-hd74edd7_2
#   brotli-bin-1.1.0-hd74edd7_2
#   c-ares-1.34.2-h7ab814d_0
#   cached-property-1.5.2-hd8ed1ab_1
#   cached_property-1.5.2-pyha770c72_1
#   colorama-0.4.6-pyhd8ed1ab_0
#   contourpy-1.3.0-py310h6000651_2
#   cycler-0.12.1-pyhd8ed1ab_0
#   dill-0.3.9-pyhd8ed1ab_0
#   fonttools-4.54.1-py310h5799be4_1
#   freetype-2.12.1-hadb7bae_2
#   gmp-6.3.0-h7bae524_2
#   gmpy2-2.1.5-py310heb17c8b_2
#   h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5-1.14.3-nompi_hec07895_105
#   ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver-1.4.7-py310h7306fd8_0
#   krb5-1.21.3-h237132a_0
#   lcms2-2.16-ha0e7c42_0
#   lerc-4.0.0-h9a09cb3_0
#   libaec-1.1.3-hebf3989_0
#   libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc-1.1.0-hd74edd7_2
#   libcblas-3.9.0-25_osxarm64_openblas
#   libcurl-8.8.0-h7b6f9a7_1
#   libdeflate-1.20-h93a5062_0
#   libedit-3.1.20191231-hc8eb9b7_2
#   libev-4.33-h93a5062_2
#   libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2-1.58.0-ha4dd798_1
#   libopenblas-0.3.28-openmp_h517c56d_0
#   libpng-1.6.43-h091b4b1_0
#   libssh2-1.11.0-h7a5bd25_0
#   libtiff-4.6.0-h07db509_3
#   libwebp-base-1.4.0-h93a5062_0
#   libxcb-1.15-hf346824_0
#   llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc-1.3.1-h8f1351a_1
#   mpfr-4.2.1-hb693164_3
#   mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess-0.70.17-py310hf9df320_0
#   munkres-1.1.4-pyh9f0ad1d_0
#   numpy-1.26.4-py310hd45542a_0
#   openjpeg-2.5.2-h9f1df11_0
#   pathos-0.3.3-pyhd8ed1ab_0
#   pillow-10.3.0-py310h81a8c2e_0
#   pox-0.3.5-pyhd8ed1ab_0
#   ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs-0.4-hd74edd7_1002
#   pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull-2020.2-h420ef59_5
#   qutip-5.0.4-py310he5c2185_0
#   scipy-1.14.1-py310hc05a576_1
#   scqubits-4.2.0-py310h7191f72_0
#   sympy-1.13.3-pypyh2585a3b_103
#   tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd-1.5.6-hb46c0d2_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 3: Installing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   added / updated specs:
#     - scqubits
#
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-hd74edd7_2
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-hd74edd7_2
#   c-ares             conda-forge/osx-arm64::c-ares-1.34.2-h7ab814d_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0
#   contourpy          conda-forge/osx-arm64::contourpy-1.3.0-py310h6000651_2
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   dill               conda-forge/noarch::dill-0.3.9-pyhd8ed1ab_0
#   fonttools          conda-forge/osx-arm64::fonttools-4.54.1-py310h5799be4_1
#   freetype           conda-forge/osx-arm64::freetype-2.12.1-hadb7bae_2
#   gmp                conda-forge/osx-arm64::gmp-6.3.0-h7bae524_2
#   gmpy2              conda-forge/osx-arm64::gmpy2-2.1.5-py310heb17c8b_2
#   h5py               conda-forge/osx-arm64::h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5               conda-forge/osx-arm64::hdf5-1.14.3-nompi_hec07895_105
#   ipyvue             conda-forge/noarch::ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify         conda-forge/noarch::ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets         conda-forge/noarch::ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver         conda-forge/osx-arm64::kiwisolver-1.4.7-py310h7306fd8_0
#   krb5               conda-forge/osx-arm64::krb5-1.21.3-h237132a_0
#   lcms2              conda-forge/osx-arm64::lcms2-2.16-ha0e7c42_0
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-h9a09cb3_0
#   libaec             conda-forge/osx-arm64::libaec-1.1.3-hebf3989_0
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-hd74edd7_2
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-25_osxarm64_openblas
#   libcurl            conda-forge/osx-arm64::libcurl-8.8.0-h7b6f9a7_1
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.20-h93a5062_0
#   libedit            conda-forge/osx-arm64::libedit-3.1.20191231-hc8eb9b7_2
#   libev              conda-forge/osx-arm64::libev-4.33-h93a5062_2
#   libgfortran        conda-forge/osx-arm64::libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5       conda-forge/osx-arm64::libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo      conda-forge/osx-arm64::libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2         conda-forge/osx-arm64::libnghttp2-1.58.0-ha4dd798_1
#   libopenblas        conda-forge/osx-arm64::libopenblas-0.3.28-openmp_h517c56d_0
#   libpng             conda-forge/osx-arm64::libpng-1.6.43-h091b4b1_0
#   libssh2            conda-forge/osx-arm64::libssh2-1.11.0-h7a5bd25_0
#   libtiff            conda-forge/osx-arm64::libtiff-4.6.0-h07db509_3
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.4.0-h93a5062_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.15-hf346824_0
#   llvm-openmp        conda-forge/osx-arm64::llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib         conda-forge/osx-arm64::matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base    conda-forge/osx-arm64::matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc                conda-forge/osx-arm64::mpc-1.3.1-h8f1351a_1
#   mpfr               conda-forge/osx-arm64::mpfr-4.2.1-hb693164_3
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess       conda-forge/osx-arm64::multiprocess-0.70.17-py310hf9df320_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/osx-arm64::numpy-1.26.4-py310hd45542a_0
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.2-h9f1df11_0
#   pathos             conda-forge/noarch::pathos-0.3.3-pyhd8ed1ab_0
#   pillow             conda-forge/osx-arm64::pillow-10.3.0-py310h81a8c2e_0
#   pox                conda-forge/noarch::pox-0.3.5-pyhd8ed1ab_0
#   ppft               conda-forge/noarch::ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-hd74edd7_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull              conda-forge/osx-arm64::qhull-2020.2-h420ef59_5
#   qutip              conda-forge/osx-arm64::qutip-5.0.4-py310he5c2185_0
#   scipy              conda-forge/osx-arm64::scipy-1.14.1-py310hc05a576_1
#   scqubits           conda-forge/osx-arm64::scqubits-4.2.0-py310h7191f72_0
#   sympy              conda-forge/noarch::sympy-1.13.3-pypyh2585a3b_103
#   tqdm               conda-forge/noarch::tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2       conda-forge/osx-arm64::unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd               conda-forge/osx-arm64::zstd-1.5.6-hb46c0d2_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 3: Removing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   removed specs:
#     - scqubits
#
#
# The following packages will be REMOVED:
#
#   brotli-1.1.0-hd74edd7_2
#   brotli-bin-1.1.0-hd74edd7_2
#   c-ares-1.34.2-h7ab814d_0
#   cached-property-1.5.2-hd8ed1ab_1
#   cached_property-1.5.2-pyha770c72_1
#   colorama-0.4.6-pyhd8ed1ab_0
#   contourpy-1.3.0-py310h6000651_2
#   cycler-0.12.1-pyhd8ed1ab_0
#   dill-0.3.9-pyhd8ed1ab_0
#   fonttools-4.54.1-py310h5799be4_1
#   freetype-2.12.1-hadb7bae_2
#   gmp-6.3.0-h7bae524_2
#   gmpy2-2.1.5-py310heb17c8b_2
#   h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5-1.14.3-nompi_hec07895_105
#   ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver-1.4.7-py310h7306fd8_0
#   krb5-1.21.3-h237132a_0
#   lcms2-2.16-ha0e7c42_0
#   lerc-4.0.0-h9a09cb3_0
#   libaec-1.1.3-hebf3989_0
#   libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc-1.1.0-hd74edd7_2
#   libcblas-3.9.0-25_osxarm64_openblas
#   libcurl-8.8.0-h7b6f9a7_1
#   libdeflate-1.20-h93a5062_0
#   libedit-3.1.20191231-hc8eb9b7_2
#   libev-4.33-h93a5062_2
#   libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2-1.58.0-ha4dd798_1
#   libopenblas-0.3.28-openmp_h517c56d_0
#   libpng-1.6.43-h091b4b1_0
#   libssh2-1.11.0-h7a5bd25_0
#   libtiff-4.6.0-h07db509_3
#   libwebp-base-1.4.0-h93a5062_0
#   libxcb-1.15-hf346824_0
#   llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc-1.3.1-h8f1351a_1
#   mpfr-4.2.1-hb693164_3
#   mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess-0.70.17-py310hf9df320_0
#   munkres-1.1.4-pyh9f0ad1d_0
#   numpy-1.26.4-py310hd45542a_0
#   openjpeg-2.5.2-h9f1df11_0
#   pathos-0.3.3-pyhd8ed1ab_0
#   pillow-10.3.0-py310h81a8c2e_0
#   pox-0.3.5-pyhd8ed1ab_0
#   ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs-0.4-hd74edd7_1002
#   pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull-2020.2-h420ef59_5
#   qutip-5.0.4-py310he5c2185_0
#   scipy-1.14.1-py310hc05a576_1
#   scqubits-4.2.0-py310h7191f72_0
#   sympy-1.13.3-pypyh2585a3b_103
#   tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd-1.5.6-hb46c0d2_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 4: Installing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   added / updated specs:
#     - scqubits
#
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-hd74edd7_2
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-hd74edd7_2
#   c-ares             conda-forge/osx-arm64::c-ares-1.34.2-h7ab814d_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0
#   contourpy          conda-forge/osx-arm64::contourpy-1.3.0-py310h6000651_2
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   dill               conda-forge/noarch::dill-0.3.9-pyhd8ed1ab_0
#   fonttools          conda-forge/osx-arm64::fonttools-4.54.1-py310h5799be4_1
#   freetype           conda-forge/osx-arm64::freetype-2.12.1-hadb7bae_2
#   gmp                conda-forge/osx-arm64::gmp-6.3.0-h7bae524_2
#   gmpy2              conda-forge/osx-arm64::gmpy2-2.1.5-py310heb17c8b_2
#   h5py               conda-forge/osx-arm64::h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5               conda-forge/osx-arm64::hdf5-1.14.3-nompi_hec07895_105
#   ipyvue             conda-forge/noarch::ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify         conda-forge/noarch::ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets         conda-forge/noarch::ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver         conda-forge/osx-arm64::kiwisolver-1.4.7-py310h7306fd8_0
#   krb5               conda-forge/osx-arm64::krb5-1.21.3-h237132a_0
#   lcms2              conda-forge/osx-arm64::lcms2-2.16-ha0e7c42_0
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-h9a09cb3_0
#   libaec             conda-forge/osx-arm64::libaec-1.1.3-hebf3989_0
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-hd74edd7_2
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-25_osxarm64_openblas
#   libcurl            conda-forge/osx-arm64::libcurl-8.8.0-h7b6f9a7_1
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.20-h93a5062_0
#   libedit            conda-forge/osx-arm64::libedit-3.1.20191231-hc8eb9b7_2
#   libev              conda-forge/osx-arm64::libev-4.33-h93a5062_2
#   libgfortran        conda-forge/osx-arm64::libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5       conda-forge/osx-arm64::libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo      conda-forge/osx-arm64::libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2         conda-forge/osx-arm64::libnghttp2-1.58.0-ha4dd798_1
#   libopenblas        conda-forge/osx-arm64::libopenblas-0.3.28-openmp_h517c56d_0
#   libpng             conda-forge/osx-arm64::libpng-1.6.43-h091b4b1_0
#   libssh2            conda-forge/osx-arm64::libssh2-1.11.0-h7a5bd25_0
#   libtiff            conda-forge/osx-arm64::libtiff-4.6.0-h07db509_3
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.4.0-h93a5062_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.15-hf346824_0
#   llvm-openmp        conda-forge/osx-arm64::llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib         conda-forge/osx-arm64::matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base    conda-forge/osx-arm64::matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc                conda-forge/osx-arm64::mpc-1.3.1-h8f1351a_1
#   mpfr               conda-forge/osx-arm64::mpfr-4.2.1-hb693164_3
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess       conda-forge/osx-arm64::multiprocess-0.70.17-py310hf9df320_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/osx-arm64::numpy-1.26.4-py310hd45542a_0
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.2-h9f1df11_0
#   pathos             conda-forge/noarch::pathos-0.3.3-pyhd8ed1ab_0
#   pillow             conda-forge/osx-arm64::pillow-10.3.0-py310h81a8c2e_0
#   pox                conda-forge/noarch::pox-0.3.5-pyhd8ed1ab_0
#   ppft               conda-forge/noarch::ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-hd74edd7_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull              conda-forge/osx-arm64::qhull-2020.2-h420ef59_5
#   qutip              conda-forge/osx-arm64::qutip-5.0.4-py310he5c2185_0
#   scipy              conda-forge/osx-arm64::scipy-1.14.1-py310hc05a576_1
#   scqubits           conda-forge/osx-arm64::scqubits-4.2.0-py310h7191f72_0
#   sympy              conda-forge/noarch::sympy-1.13.3-pypyh2585a3b_103
#   tqdm               conda-forge/noarch::tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2       conda-forge/osx-arm64::unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd               conda-forge/osx-arm64::zstd-1.5.6-hb46c0d2_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 4: Removing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   removed specs:
#     - scqubits
#
#
# The following packages will be REMOVED:
#
#   brotli-1.1.0-hd74edd7_2
#   brotli-bin-1.1.0-hd74edd7_2
#   c-ares-1.34.2-h7ab814d_0
#   cached-property-1.5.2-hd8ed1ab_1
#   cached_property-1.5.2-pyha770c72_1
#   colorama-0.4.6-pyhd8ed1ab_0
#   contourpy-1.3.0-py310h6000651_2
#   cycler-0.12.1-pyhd8ed1ab_0
#   dill-0.3.9-pyhd8ed1ab_0
#   fonttools-4.54.1-py310h5799be4_1
#   freetype-2.12.1-hadb7bae_2
#   gmp-6.3.0-h7bae524_2
#   gmpy2-2.1.5-py310heb17c8b_2
#   h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5-1.14.3-nompi_hec07895_105
#   ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver-1.4.7-py310h7306fd8_0
#   krb5-1.21.3-h237132a_0
#   lcms2-2.16-ha0e7c42_0
#   lerc-4.0.0-h9a09cb3_0
#   libaec-1.1.3-hebf3989_0
#   libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc-1.1.0-hd74edd7_2
#   libcblas-3.9.0-25_osxarm64_openblas
#   libcurl-8.8.0-h7b6f9a7_1
#   libdeflate-1.20-h93a5062_0
#   libedit-3.1.20191231-hc8eb9b7_2
#   libev-4.33-h93a5062_2
#   libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2-1.58.0-ha4dd798_1
#   libopenblas-0.3.28-openmp_h517c56d_0
#   libpng-1.6.43-h091b4b1_0
#   libssh2-1.11.0-h7a5bd25_0
#   libtiff-4.6.0-h07db509_3
#   libwebp-base-1.4.0-h93a5062_0
#   libxcb-1.15-hf346824_0
#   llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc-1.3.1-h8f1351a_1
#   mpfr-4.2.1-hb693164_3
#   mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess-0.70.17-py310hf9df320_0
#   munkres-1.1.4-pyh9f0ad1d_0
#   numpy-1.26.4-py310hd45542a_0
#   openjpeg-2.5.2-h9f1df11_0
#   pathos-0.3.3-pyhd8ed1ab_0
#   pillow-10.3.0-py310h81a8c2e_0
#   pox-0.3.5-pyhd8ed1ab_0
#   ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs-0.4-hd74edd7_1002
#   pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull-2020.2-h420ef59_5
#   qutip-5.0.4-py310he5c2185_0
#   scipy-1.14.1-py310hc05a576_1
#   scqubits-4.2.0-py310h7191f72_0
#   sympy-1.13.3-pypyh2585a3b_103
#   tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd-1.5.6-hb46c0d2_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 5: Installing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   added / updated specs:
#     - scqubits
#
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-hd74edd7_2
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-hd74edd7_2
#   c-ares             conda-forge/osx-arm64::c-ares-1.34.2-h7ab814d_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0
#   contourpy          conda-forge/osx-arm64::contourpy-1.3.0-py310h6000651_2
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   dill               conda-forge/noarch::dill-0.3.9-pyhd8ed1ab_0
#   fonttools          conda-forge/osx-arm64::fonttools-4.54.1-py310h5799be4_1
#   freetype           conda-forge/osx-arm64::freetype-2.12.1-hadb7bae_2
#   gmp                conda-forge/osx-arm64::gmp-6.3.0-h7bae524_2
#   gmpy2              conda-forge/osx-arm64::gmpy2-2.1.5-py310heb17c8b_2
#   h5py               conda-forge/osx-arm64::h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5               conda-forge/osx-arm64::hdf5-1.14.3-nompi_hec07895_105
#   ipyvue             conda-forge/noarch::ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify         conda-forge/noarch::ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets         conda-forge/noarch::ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver         conda-forge/osx-arm64::kiwisolver-1.4.7-py310h7306fd8_0
#   krb5               conda-forge/osx-arm64::krb5-1.21.3-h237132a_0
#   lcms2              conda-forge/osx-arm64::lcms2-2.16-ha0e7c42_0
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-h9a09cb3_0
#   libaec             conda-forge/osx-arm64::libaec-1.1.3-hebf3989_0
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-hd74edd7_2
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-25_osxarm64_openblas
#   libcurl            conda-forge/osx-arm64::libcurl-8.8.0-h7b6f9a7_1
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.20-h93a5062_0
#   libedit            conda-forge/osx-arm64::libedit-3.1.20191231-hc8eb9b7_2
#   libev              conda-forge/osx-arm64::libev-4.33-h93a5062_2
#   libgfortran        conda-forge/osx-arm64::libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5       conda-forge/osx-arm64::libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo      conda-forge/osx-arm64::libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2         conda-forge/osx-arm64::libnghttp2-1.58.0-ha4dd798_1
#   libopenblas        conda-forge/osx-arm64::libopenblas-0.3.28-openmp_h517c56d_0
#   libpng             conda-forge/osx-arm64::libpng-1.6.43-h091b4b1_0
#   libssh2            conda-forge/osx-arm64::libssh2-1.11.0-h7a5bd25_0
#   libtiff            conda-forge/osx-arm64::libtiff-4.6.0-h07db509_3
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.4.0-h93a5062_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.15-hf346824_0
#   llvm-openmp        conda-forge/osx-arm64::llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib         conda-forge/osx-arm64::matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base    conda-forge/osx-arm64::matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc                conda-forge/osx-arm64::mpc-1.3.1-h8f1351a_1
#   mpfr               conda-forge/osx-arm64::mpfr-4.2.1-hb693164_3
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess       conda-forge/osx-arm64::multiprocess-0.70.17-py310hf9df320_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/osx-arm64::numpy-1.26.4-py310hd45542a_0
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.2-h9f1df11_0
#   pathos             conda-forge/noarch::pathos-0.3.3-pyhd8ed1ab_0
#   pillow             conda-forge/osx-arm64::pillow-10.3.0-py310h81a8c2e_0
#   pox                conda-forge/noarch::pox-0.3.5-pyhd8ed1ab_0
#   ppft               conda-forge/noarch::ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-hd74edd7_1002
# ...
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess       conda-forge/osx-arm64::multiprocess-0.70.17-py310hf9df320_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/osx-arm64::numpy-1.26.4-py310hd45542a_0
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.2-h9f1df11_0
#   pathos             conda-forge/noarch::pathos-0.3.3-pyhd8ed1ab_0
#   pillow             conda-forge/osx-arm64::pillow-10.3.0-py310h81a8c2e_0
#   pox                conda-forge/noarch::pox-0.3.5-pyhd8ed1ab_0
#   ppft               conda-forge/noarch::ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-hd74edd7_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull              conda-forge/osx-arm64::qhull-2020.2-h420ef59_5
#   qutip              conda-forge/osx-arm64::qutip-5.0.4-py310he5c2185_0
#   scipy              conda-forge/osx-arm64::scipy-1.14.1-py310hc05a576_1
#   scqubits           conda-forge/osx-arm64::scqubits-4.2.0-py310h7191f72_0
#   sympy              conda-forge/noarch::sympy-1.13.3-pypyh2585a3b_103
#   tqdm               conda-forge/noarch::tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2       conda-forge/osx-arm64::unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd               conda-forge/osx-arm64::zstd-1.5.6-hb46c0d2_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 9: Removing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   removed specs:
#     - scqubits
#
#
# The following packages will be REMOVED:
#
#   brotli-1.1.0-hd74edd7_2
#   brotli-bin-1.1.0-hd74edd7_2
#   c-ares-1.34.2-h7ab814d_0
#   cached-property-1.5.2-hd8ed1ab_1
#   cached_property-1.5.2-pyha770c72_1
#   colorama-0.4.6-pyhd8ed1ab_0
#   contourpy-1.3.0-py310h6000651_2
#   cycler-0.12.1-pyhd8ed1ab_0
#   dill-0.3.9-pyhd8ed1ab_0
#   fonttools-4.54.1-py310h5799be4_1
#   freetype-2.12.1-hadb7bae_2
#   gmp-6.3.0-h7bae524_2
#   gmpy2-2.1.5-py310heb17c8b_2
#   h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5-1.14.3-nompi_hec07895_105
#   ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver-1.4.7-py310h7306fd8_0
#   krb5-1.21.3-h237132a_0
#   lcms2-2.16-ha0e7c42_0
#   lerc-4.0.0-h9a09cb3_0
#   libaec-1.1.3-hebf3989_0
#   libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc-1.1.0-hd74edd7_2
#   libcblas-3.9.0-25_osxarm64_openblas
#   libcurl-8.8.0-h7b6f9a7_1
#   libdeflate-1.20-h93a5062_0
#   libedit-3.1.20191231-hc8eb9b7_2
#   libev-4.33-h93a5062_2
#   libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2-1.58.0-ha4dd798_1
#   libopenblas-0.3.28-openmp_h517c56d_0
#   libpng-1.6.43-h091b4b1_0
#   libssh2-1.11.0-h7a5bd25_0
#   libtiff-4.6.0-h07db509_3
#   libwebp-base-1.4.0-h93a5062_0
#   libxcb-1.15-hf346824_0
#   llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc-1.3.1-h8f1351a_1
#   mpfr-4.2.1-hb693164_3
#   mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess-0.70.17-py310hf9df320_0
#   munkres-1.1.4-pyh9f0ad1d_0
#   numpy-1.26.4-py310hd45542a_0
#   openjpeg-2.5.2-h9f1df11_0
#   pathos-0.3.3-pyhd8ed1ab_0
#   pillow-10.3.0-py310h81a8c2e_0
#   pox-0.3.5-pyhd8ed1ab_0
#   ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs-0.4-hd74edd7_1002
#   pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull-2020.2-h420ef59_5
#   qutip-5.0.4-py310he5c2185_0
#   scipy-1.14.1-py310hc05a576_1
#   scqubits-4.2.0-py310h7191f72_0
#   sympy-1.13.3-pypyh2585a3b_103
#   tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd-1.5.6-hb46c0d2_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 10: Installing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /Users/jiakaiwang/miniconda3/envs/qutip
#
#   added / updated specs:
#     - scqubits
#
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-hd74edd7_2
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-hd74edd7_2
#   c-ares             conda-forge/osx-arm64::c-ares-1.34.2-h7ab814d_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_0
#   contourpy          conda-forge/osx-arm64::contourpy-1.3.0-py310h6000651_2
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   dill               conda-forge/noarch::dill-0.3.9-pyhd8ed1ab_0
#   fonttools          conda-forge/osx-arm64::fonttools-4.54.1-py310h5799be4_1
#   freetype           conda-forge/osx-arm64::freetype-2.12.1-hadb7bae_2
#   gmp                conda-forge/osx-arm64::gmp-6.3.0-h7bae524_2
#   gmpy2              conda-forge/osx-arm64::gmpy2-2.1.5-py310heb17c8b_2
#   h5py               conda-forge/osx-arm64::h5py-3.12.1-nompi_py310h072ed46_102
#   hdf5               conda-forge/osx-arm64::hdf5-1.14.3-nompi_hec07895_105
#   ipyvue             conda-forge/noarch::ipyvue-1.11.0-pyhd8ed1ab_0
#   ipyvuetify         conda-forge/noarch::ipyvuetify-1.10.0-pyhd8ed1ab_0
#   ipywidgets         conda-forge/noarch::ipywidgets-8.1.5-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.13-pyhd8ed1ab_0
#   kiwisolver         conda-forge/osx-arm64::kiwisolver-1.4.7-py310h7306fd8_0
#   krb5               conda-forge/osx-arm64::krb5-1.21.3-h237132a_0
#   lcms2              conda-forge/osx-arm64::lcms2-2.16-ha0e7c42_0
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-h9a09cb3_0
#   libaec             conda-forge/osx-arm64::libaec-1.1.3-hebf3989_0
#   libblas            conda-forge/osx-arm64::libblas-3.9.0-25_osxarm64_openblas
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-hd74edd7_2
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-hd74edd7_2
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-hd74edd7_2
#   libcblas           conda-forge/osx-arm64::libcblas-3.9.0-25_osxarm64_openblas
#   libcurl            conda-forge/osx-arm64::libcurl-8.8.0-h7b6f9a7_1
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.20-h93a5062_0
#   libedit            conda-forge/osx-arm64::libedit-3.1.20191231-hc8eb9b7_2
#   libev              conda-forge/osx-arm64::libev-4.33-h93a5062_2
#   libgfortran        conda-forge/osx-arm64::libgfortran-5.0.0-13_2_0_hd922786_3
#   libgfortran5       conda-forge/osx-arm64::libgfortran5-13.2.0-hf226fd6_3
#   libjpeg-turbo      conda-forge/osx-arm64::libjpeg-turbo-3.0.0-hb547adb_1
#   liblapack          conda-forge/osx-arm64::liblapack-3.9.0-25_osxarm64_openblas
#   libnghttp2         conda-forge/osx-arm64::libnghttp2-1.58.0-ha4dd798_1
#   libopenblas        conda-forge/osx-arm64::libopenblas-0.3.28-openmp_h517c56d_0
#   libpng             conda-forge/osx-arm64::libpng-1.6.43-h091b4b1_0
#   libssh2            conda-forge/osx-arm64::libssh2-1.11.0-h7a5bd25_0
#   libtiff            conda-forge/osx-arm64::libtiff-4.6.0-h07db509_3
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.4.0-h93a5062_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.15-hf346824_0
#   llvm-openmp        conda-forge/osx-arm64::llvm-openmp-19.1.2-hb52a8e5_0
#   matplotlib         conda-forge/osx-arm64::matplotlib-3.9.2-py310hb6292c7_1
#   matplotlib-base    conda-forge/osx-arm64::matplotlib-base-3.9.2-py310h2a20ac7_1
#   mpc                conda-forge/osx-arm64::mpc-1.3.1-h8f1351a_1
#   mpfr               conda-forge/osx-arm64::mpfr-4.2.1-hb693164_3
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   multiprocess       conda-forge/osx-arm64::multiprocess-0.70.17-py310hf9df320_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/osx-arm64::numpy-1.26.4-py310hd45542a_0
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.2-h9f1df11_0
#   pathos             conda-forge/noarch::pathos-0.3.3-pyhd8ed1ab_0
#   pillow             conda-forge/osx-arm64::pillow-10.3.0-py310h81a8c2e_0
#   pox                conda-forge/noarch::pox-0.3.5-pyhd8ed1ab_0
#   ppft               conda-forge/noarch::ppft-1.7.6.9-pyhd8ed1ab_0
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-hd74edd7_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.0-pyhd8ed1ab_1
#   qhull              conda-forge/osx-arm64::qhull-2020.2-h420ef59_5
#   qutip              conda-forge/osx-arm64::qutip-5.0.4-py310he5c2185_0
#   scipy              conda-forge/osx-arm64::scipy-1.14.1-py310hc05a576_1
#   scqubits           conda-forge/osx-arm64::scqubits-4.2.0-py310h7191f72_0
#   sympy              conda-forge/noarch::sympy-1.13.3-pypyh2585a3b_103
#   tqdm               conda-forge/noarch::tqdm-4.66.6-pyhd8ed1ab_0
#   unicodedata2       conda-forge/osx-arm64::unicodedata2-15.1.0-py310hf9df320_1
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.13-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.11-hd74edd7_1
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-hd74edd7_0
#   zstd               conda-forge/osx-arm64::zstd-1.5.6-hb46c0d2_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Iteration 10: Removing scqubits
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /Users/jiakaiwang/miniconda3/lib/python3.12/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): ...working...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 13
#      10 subprocess.run(install_command, check=True)
#      12 print(f"Iteration {i+1}: Removing scqubits")
# ---> 13 subprocess.run(remove_command, check=True)
#
# File ~/miniconda3/envs/qutip/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/miniconda3/envs/qutip/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File ~/miniconda3/envs/qutip/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/miniconda3/envs/qutip/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File ~/miniconda3/envs/qutip/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

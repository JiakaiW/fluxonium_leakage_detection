# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *

# %%
EJ = 2.5
EC = 0.65
EL = 0.12

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.05]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1.062791307016031e-06
#              x: [ 7.059e+00]
#            nit: 13
#           nfev: 26
#  final_simplex: (array([[ 7.059e+00],
#                        [ 7.059e+00]]), array([ 1.063e-06,  1.319e-06]))
# Optimal solution: [7.05877808]
# Objective value: 1.062791307016031e-06

# %%
max_ol = 50
max_ql = 25
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.2
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.001,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  (non-linearity on qbt 0): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}  (non-linearity on qbt 3): {(dressed_ener(3,i+1)-dressed_ener(3,i))  -(dressed_ener(3,1)-dressed_ener(3,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.025862527801320923
# qbt freq at osc 1:	0.02585, 	diff to at osc ground -0.00001, 0.0294% diff
# qbt freq at osc 2:	0.02585, 	diff to at osc ground -0.00002, 0.0622% diff
# qbt freq at osc 3:	0.02584, 	diff to at osc ground -0.00003, 0.0985% diff
# qbt freq at osc 4:	0.02583, 	diff to at osc ground -0.00004, 0.1384% diff
# qbt freq at osc 5:	0.02582, 	diff to at osc ground -0.00005, 0.1822% diff
# qbt freq at osc 6:	0.02580, 	diff to at osc ground -0.00006, 0.2297% diff
# qbt freq at osc 7:	0.02579, 	diff to at osc ground -0.00007, 0.2812% diff
# qbt freq at osc 8:	0.02578, 	diff to at osc ground -0.00009, 0.3367% diff
# qbt freq at osc 9:	0.02576, 	diff to at osc ground -0.00010, 0.3964% diff
# qbt freq at osc 10:	0.02574, 	diff to at osc ground -0.00012, 0.4604% diff
# qbt freq at osc 11:	0.02573, 	diff to at osc ground -0.00014, 0.5287% diff
# qbt freq at osc 12:	0.02571, 	diff to at osc ground -0.00016, 0.6015% diff
# qbt freq at osc 13:	0.02569, 	diff to at osc ground -0.00018, 0.6788% diff
# qbt freq at osc 14:	0.02567, 	diff to at osc ground -0.00020, 0.7608% diff
# qbt freq at osc 15:	0.02564, 	diff to at osc ground -0.00022, 0.8475% diff
# qbt freq at osc 16:	0.02562, 	diff to at osc ground -0.00024, 0.9391% diff
# qbt freq at osc 17:	0.02559, 	diff to at osc ground -0.00027, 1.0357% diff
# qbt freq at osc 18:	0.02557, 	diff to at osc ground -0.00029, 1.1373% diff
# qbt freq at osc 19:	0.02554, 	diff to at osc ground -0.00032, 1.2441% diff
# qbt freq at osc 20:	0.02551, 	diff to at osc ground -0.00035, 1.3562% diff
# qbt freq at osc 21:	0.02548, 	diff to at osc ground -0.00038, 1.4736% diff
# qbt freq at osc 22:	0.02545, 	diff to at osc ground -0.00041, 1.5965% diff
# qbt freq at osc 23:	0.02542, 	diff to at osc ground -0.00045, 1.7250% diff
# qbt freq at osc 24:	0.02538, 	diff to at osc ground -0.00048, 1.8591% diff
# qbt freq at osc 25:	0.02535, 	diff to at osc ground -0.00052, 1.9991% diff
# qbt freq at osc 26:	0.02531, 	diff to at osc ground -0.00055, 2.1449% diff
# qbt freq at osc 27:	0.02527, 	diff to at osc ground -0.00059, 2.2966% diff
# qbt freq at osc 28:	0.02523, 	diff to at osc ground -0.00063, 2.4545% diff
# qbt freq at osc 29:	0.02519, 	diff to at osc ground -0.00068, 2.6185% diff
# qbt freq at osc 30:	0.02514, 	diff to at osc ground -0.00072, 2.7888% diff
# qbt freq at osc 31:	0.02510, 	diff to at osc ground -0.00077, 2.9654% diff
# qbt freq at osc 32:	0.02505, 	diff to at osc ground -0.00081, 3.1486% diff
# qbt freq at osc 33:	0.02500, 	diff to at osc ground -0.00086, 3.3383% diff
# qbt freq at osc 34:	0.02495, 	diff to at osc ground -0.00091, 3.5346% diff
# qbt freq at osc 35:	0.02490, 	diff to at osc ground -0.00097, 3.7377% diff
# qbt freq at osc 36:	0.02484, 	diff to at osc ground -0.00102, 3.9477% diff
# qbt freq at osc 37:	0.02479, 	diff to at osc ground -0.00108, 4.1647% diff
# qbt freq at osc 38:	0.02473, 	diff to at osc ground -0.00114, 4.3887% diff
# qbt freq at osc 39:	0.02467, 	diff to at osc ground -0.00119, 4.6198% diff
# qbt freq at osc 40:	0.02461, 	diff to at osc ground -0.00126, 4.8582% diff
# qbt freq at osc 41:	0.02454, 	diff to at osc ground -0.00132, 5.1040% diff
# qbt freq at osc 42:	0.02448, 	diff to at osc ground -0.00139, 5.3572% diff
# qbt freq at osc 43:	0.02441, 	diff to at osc ground -0.00145, 5.6179% diff
# qbt freq at osc 44:	0.02434, 	diff to at osc ground -0.00152, 5.8862% diff
# qbt freq at osc 45:	0.02427, 	diff to at osc ground -0.00159, 6.1623% diff
# qbt freq at osc 46:	0.02420, 	diff to at osc ground -0.00167, 6.4461% diff
# qbt freq at osc 47:	0.02412, 	diff to at osc ground -0.00174, 6.7366% diff
# qbt freq at osc 48:	0.02412, 	diff to at osc ground -0.00174, 6.7277% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.05908	7.06019	7.06018	7.05838
# oscillator transition 1-2: 	7.05905	7.06018	7.06017	7.05838  (non-linearity on qbt 0): -2.38445505535978e-05  (non-linearity on qbt 3): 4.628500011705228e-06
# oscillator transition 2-3: 	7.05903	7.06018	7.06017	7.05838  (non-linearity on qbt 0): -4.738044827234944e-05  (non-linearity on qbt 3): 9.19835031787386e-06
# oscillator transition 3-4: 	7.05900	7.06018	7.06017	7.05839  (non-linearity on qbt 0): -7.058465169329509e-05  (non-linearity on qbt 3): 1.3710467639427293e-05
# oscillator transition 4-5: 	7.05898	7.06018	7.06017	7.05839  (non-linearity on qbt 0): -9.343573609932321e-05  (non-linearity on qbt 3): 1.8165748320697617e-05
# oscillator transition 5-6: 	7.05896	7.06017	7.06016	7.05840  (non-linearity on qbt 0): -0.00011591396083510119  (non-linearity on qbt 3): 2.256507013775888e-05
# oscillator transition 6-7: 	7.05894	7.06017	7.06016	7.05840  (non-linearity on qbt 0): -0.00013800131834251772  (non-linearity on qbt 3): 2.6909291468868446e-05
# oscillator transition 7-8: 	7.05892	7.06017	7.06016	7.05841  (non-linearity on qbt 0): -0.00015968156854206939  (non-linearity on qbt 3): 3.1199252971347846e-05
# oscillator transition 8-9: 	7.05889	7.06017	7.06015	7.05841  (non-linearity on qbt 0): -0.00018094024978587697  (non-linearity on qbt 3): 3.543577689946176e-05
# oscillator transition 9-10: 	7.05887	7.06017	7.06015	7.05841  (non-linearity on qbt 0): -0.000201764678999794  (non-linearity on qbt 3): 3.961966871024458e-05
# oscillator transition 10-11: 	7.05885	7.06016	7.06015	7.05842  (non-linearity on qbt 0): -0.00022214392959263307  (non-linearity on qbt 3): 4.375171812220913e-05
# oscillator transition 11-12: 	7.05883	7.06016	7.06014	7.05842  (non-linearity on qbt 0): -0.0002420688049955544  (non-linearity on qbt 3): 4.783269757346886e-05
# oscillator transition 12-13: 	7.05881	7.06016	7.06014	7.05843  (non-linearity on qbt 0): -0.00026153178443344416  (non-linearity on qbt 3): 5.186336542628567e-05
# oscillator transition 13-14: 	7.05880	7.06016	7.06014	7.05843  (non-linearity on qbt 0): -0.00028052697646963054  (non-linearity on qbt 3): 5.584446274831123e-05
# oscillator transition 14-15: 	7.05878	7.06016	7.06013	7.05844  (non-linearity on qbt 0): -0.0002990500451023337  (non-linearity on qbt 3): 5.9776718158488507e-05
# oscillator transition 15-16: 	7.05876	7.06015	7.06013	7.05844  (non-linearity on qbt 0): -0.0003170981414246654  (non-linearity on qbt 3): 6.366084471487454e-05
# oscillator transition 16-17: 	7.05874	7.06015	7.06013	7.05844  (non-linearity on qbt 0): -0.00033466981911267624  (non-linearity on qbt 3): 6.749754244417261e-05
# oscillator transition 17-18: 	7.05872	7.06015	7.06012	7.05845  (non-linearity on qbt 0): -0.00035176495136290953  (non-linearity on qbt 3): 7.128749721907468e-05
# oscillator transition 18-19: 	7.05871	7.06015	7.06012	7.05845  (non-linearity on qbt 0): -0.000368384643694597  (non-linearity on qbt 3): 7.503138205144921e-05
# oscillator transition 19-20: 	7.05869	7.06014	7.06012	7.05845  (non-linearity on qbt 0): -0.0003845311400301199  (non-linearity on qbt 3): 7.872985794499243e-05
# oscillator transition 20-21: 	7.05868	7.06014	7.06011	7.05846  (non-linearity on qbt 0): -0.00040020773453086633  (non-linearity on qbt 3): 8.238357351153525e-05
# oscillator transition 21-22: 	7.05866	7.06014	7.06011	7.05846  (non-linearity on qbt 0): -0.00041541867777716845  (non-linearity on qbt 3): 8.599316332258411e-05
# oscillator transition 22-23: 	7.05865	7.06014	7.06011	7.05846  (non-linearity on qbt 0): -0.00043016908817783417  (non-linearity on qbt 3): 8.955925379261487e-05
# oscillator transition 23-24: 	7.05863	7.06014	7.06010	7.05847  (non-linearity on qbt 0): -0.00044446486337967883  (non-linearity on qbt 3): 9.308245740946575e-05
# oscillator transition 24-25: 	7.05862	7.06013	7.06010	7.05847  (non-linearity on qbt 0): -0.00045831259525819235  (non-linearity on qbt 3): 9.656337574703855e-05
# oscillator transition 25-26: 	7.05860	7.06013	7.06009	7.05848  (non-linearity on qbt 0): -0.0004717194853629536  (non-linearity on qbt 3): 0.00010000260264853011
# oscillator transition 26-27: 	7.05859	7.06013	7.06009	7.05848  (non-linearity on qbt 0): -0.0004846932725559583  (non-linearity on qbt 3): 0.00010340071589887145
# oscillator transition 27-28: 	7.05858	7.06013	7.06009	7.05848  (non-linearity on qbt 0): -0.0004972421482580813  (non-linearity on qbt 3): 0.00010675828865025494
# oscillator transition 28-29: 	7.05857	7.06013	7.06008	7.05849  (non-linearity on qbt 0): -0.0005093746972466562  (non-linearity on qbt 3): 0.00011007588191880302
# oscillator transition 29-30: 	7.05855	7.06012	7.06008	7.05849  (non-linearity on qbt 0): -0.000521099825350646  (non-linearity on qbt 3): 0.0001133540454372195
# oscillator transition 30-31: 	7.05854	7.06012	7.06008	7.05849  (non-linearity on qbt 0): -0.0005324266991113547  (non-linearity on qbt 3): 0.00011659332305491432
# oscillator transition 31-32: 	7.05853	7.06012	7.06007	7.05850  (non-linearity on qbt 0): -0.0005433646908432621  (non-linearity on qbt 3): 0.00011979424617258871
# oscillator transition 32-33: 	7.05852	7.06012	7.06007	7.05850  (non-linearity on qbt 0): -0.000553923325599115  (non-linearity on qbt 3): 0.00012295733976763756
# oscillator transition 33-34: 	7.05851	7.06012	7.06006	7.05850  (non-linearity on qbt 0): -0.000564112232284586  (non-linearity on qbt 3): 0.00012608311707928976
# oscillator transition 34-35: 	7.05850	7.06011	7.06006	7.05850  (non-linearity on qbt 0): -0.0005739411029015429  (non-linearity on qbt 3): 0.0001291720867993007
# oscillator transition 35-36: 	7.05849	7.06011	7.06006	7.05851  (non-linearity on qbt 0): -0.000583419651109196  (non-linearity on qbt 3): 0.00013222474582441635
# oscillator transition 36-37: 	7.05848	7.06011	7.06005	7.05851  (non-linearity on qbt 0): -0.0005925575772938174  (non-linearity on qbt 3): 0.00013524158528177566
# oscillator transition 37-38: 	7.05847	7.06011	7.06005	7.05851  (non-linearity on qbt 0): -0.000601364537049065  (non-linearity on qbt 3): 0.00013822308689093177
# oscillator transition 38-39: 	7.05847	7.06010	7.06005	7.05852  (non-linearity on qbt 0): -0.0006098501136921897  (non-linearity on qbt 3): 0.0001411697251239019
# oscillator transition 39-40: 	7.05846	7.06010	7.06004	7.05852  (non-linearity on qbt 0): -0.0006180237936224131  (non-linearity on qbt 3): 0.00014408196785886673
# oscillator transition 40-41: 	7.05845	7.06010	7.06004	7.05852  (non-linearity on qbt 0): -0.0006258949432140781  (non-linearity on qbt 3): 0.00014696027393590327
# oscillator transition 41-42: 	7.05844	7.06010	7.06003	7.05853  (non-linearity on qbt 0): -0.0006334727926446959  (non-linearity on qbt 3): 0.00014980509582862567
# oscillator transition 42-43: 	7.05843	7.06010	7.06003	7.05853  (non-linearity on qbt 0): -0.0006407664157723758  (non-linearity on qbt 3): 0.00015261688032630616
# oscillator transition 43-44: 	7.05843	7.06009	7.06003	7.05853  (non-linearity on qbt 0): -0.0006477847205292875  (non-linearity on qbt 3): 0.00015539606483905288
# oscillator transition 44-45: 	7.05842	7.06009	7.06002	7.05853  (non-linearity on qbt 0): -0.0006545363801411241  (non-linearity on qbt 3): 0.00015814362985899777
# oscillator transition 45-46: 	7.05841	7.06009	7.06002	7.05854  (non-linearity on qbt 0): -0.0006610126079227285  (non-linearity on qbt 3): 0.00016100736890045653
# oscillator transition 46-47: 	7.05841	7.06009	7.06002	7.05857  (non-linearity on qbt 0): -0.0006633437113965357  (non-linearity on qbt 3): 0.00019294977552242187
# oscillator transition 47-48: 	7.05897	7.06052	7.06052	7.06229  (non-linearity on qbt 0): -0.00010859043591615603  (non-linearity on qbt 3): 0.003917327468355936
# oscillator transition 48-49: 	7.26089	7.10511	7.11020	7.25213  (non-linearity on qbt 0): 0.20181507304151403  (non-linearity on qbt 3): 0.19375897511612372
#
# 10-11: 7.0602, diff to 00-01: 0.0011097564015614125, diff to 30-31: 0.0018100292613638658
# 20-21: 7.0602, diff to 00-01: 0.0011021635137282715, diff to 30-31: 0.0018024363735307247

# %%
dressed_osc_frequencies = [[] for _ in range(4)]
for j in [0,1,2,3]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [0,1,2,3]:
    plt.plot(list(range(max_ol-1))[:44], dressed_osc_frequencies[j][:44],label=f'{j}')
plt.legend()

# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *

# %%
EJ = 2.5
EC = 0.65
EL = 0.12

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.05]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1.062791311005895e-06
#              x: [ 7.059e+00]
#            nit: 13
#           nfev: 26
#  final_simplex: (array([[ 7.059e+00],
#                        [ 7.059e+00]]), array([ 1.063e-06,  1.319e-06]))
# Optimal solution: [7.05877808]
# Objective value: 1.062791311005895e-06

# %%
max_ol = 50
max_ql = 25
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.17
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.001,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  (non-linearity on qbt 0): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}  (non-linearity on qbt 3): {(dressed_ener(3,i+1)-dressed_ener(3,i))  -(dressed_ener(3,1)-dressed_ener(3,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.025883154008382148
# qbt freq at osc 1:	0.02588, 	diff to at osc ground -0.00000, 0.0152% diff
# qbt freq at osc 2:	0.02587, 	diff to at osc ground -0.00001, 0.0321% diff
# qbt freq at osc 3:	0.02587, 	diff to at osc ground -0.00001, 0.0507% diff
# qbt freq at osc 4:	0.02586, 	diff to at osc ground -0.00002, 0.0712% diff
# qbt freq at osc 5:	0.02586, 	diff to at osc ground -0.00002, 0.0934% diff
# qbt freq at osc 6:	0.02585, 	diff to at osc ground -0.00003, 0.1176% diff
# qbt freq at osc 7:	0.02585, 	diff to at osc ground -0.00004, 0.1436% diff
# qbt freq at osc 8:	0.02584, 	diff to at osc ground -0.00004, 0.1716% diff
# qbt freq at osc 9:	0.02583, 	diff to at osc ground -0.00005, 0.2015% diff
# qbt freq at osc 10:	0.02582, 	diff to at osc ground -0.00006, 0.2335% diff
# qbt freq at osc 11:	0.02581, 	diff to at osc ground -0.00007, 0.2675% diff
# qbt freq at osc 12:	0.02580, 	diff to at osc ground -0.00008, 0.3037% diff
# qbt freq at osc 13:	0.02579, 	diff to at osc ground -0.00009, 0.3419% diff
# qbt freq at osc 14:	0.02578, 	diff to at osc ground -0.00010, 0.3823% diff
# qbt freq at osc 15:	0.02577, 	diff to at osc ground -0.00011, 0.4250% diff
# qbt freq at osc 16:	0.02576, 	diff to at osc ground -0.00012, 0.4699% diff
# qbt freq at osc 17:	0.02575, 	diff to at osc ground -0.00013, 0.5170% diff
# qbt freq at osc 18:	0.02574, 	diff to at osc ground -0.00015, 0.5665% diff
# qbt freq at osc 19:	0.02572, 	diff to at osc ground -0.00016, 0.6184% diff
# qbt freq at osc 20:	0.02571, 	diff to at osc ground -0.00017, 0.6726% diff
# qbt freq at osc 21:	0.02569, 	diff to at osc ground -0.00019, 0.7293% diff
# qbt freq at osc 22:	0.02568, 	diff to at osc ground -0.00020, 0.7884% diff
# qbt freq at osc 23:	0.02566, 	diff to at osc ground -0.00022, 0.8501% diff
# qbt freq at osc 24:	0.02565, 	diff to at osc ground -0.00024, 0.9143% diff
# qbt freq at osc 25:	0.02563, 	diff to at osc ground -0.00025, 0.9811% diff
# qbt freq at osc 26:	0.02561, 	diff to at osc ground -0.00027, 1.0505% diff
# qbt freq at osc 27:	0.02559, 	diff to at osc ground -0.00029, 1.1226% diff
# qbt freq at osc 28:	0.02557, 	diff to at osc ground -0.00031, 1.1974% diff
# qbt freq at osc 29:	0.02555, 	diff to at osc ground -0.00033, 1.2749% diff
# qbt freq at osc 30:	0.02553, 	diff to at osc ground -0.00035, 1.3552% diff
# qbt freq at osc 31:	0.02551, 	diff to at osc ground -0.00037, 1.4383% diff
# qbt freq at osc 32:	0.02549, 	diff to at osc ground -0.00039, 1.5243% diff
# qbt freq at osc 33:	0.02547, 	diff to at osc ground -0.00042, 1.6131% diff
# qbt freq at osc 34:	0.02544, 	diff to at osc ground -0.00044, 1.7049% diff
# qbt freq at osc 35:	0.02542, 	diff to at osc ground -0.00047, 1.7996% diff
# qbt freq at osc 36:	0.02539, 	diff to at osc ground -0.00049, 1.8973% diff
# qbt freq at osc 37:	0.02537, 	diff to at osc ground -0.00052, 1.9981% diff
# qbt freq at osc 38:	0.02534, 	diff to at osc ground -0.00054, 2.1019% diff
# qbt freq at osc 39:	0.02531, 	diff to at osc ground -0.00057, 2.2089% diff
# qbt freq at osc 40:	0.02528, 	diff to at osc ground -0.00060, 2.3190% diff
# qbt freq at osc 41:	0.02525, 	diff to at osc ground -0.00063, 2.4322% diff
# qbt freq at osc 42:	0.02522, 	diff to at osc ground -0.00066, 2.5487% diff
# qbt freq at osc 43:	0.02519, 	diff to at osc ground -0.00069, 2.6685% diff
# qbt freq at osc 44:	0.02516, 	diff to at osc ground -0.00072, 2.7915% diff
# qbt freq at osc 45:	0.02513, 	diff to at osc ground -0.00076, 2.9179% diff
# qbt freq at osc 46:	0.02509, 	diff to at osc ground -0.00079, 3.0477% diff
# qbt freq at osc 47:	0.02506, 	diff to at osc ground -0.00082, 3.1807% diff
# qbt freq at osc 48:	0.02505, 	diff to at osc ground -0.00083, 3.2063% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.05901	7.05980	7.05979	7.05849
# oscillator transition 1-2: 	7.05900	7.05979	7.05979	7.05849  (non-linearity on qbt 0): -1.2346120376705016e-05  (non-linearity on qbt 3): 2.4161234133401877e-06
# oscillator transition 2-3: 	7.05899	7.05979	7.05979	7.05849  (non-linearity on qbt 0): -2.4591555728648018e-05  (non-linearity on qbt 3): 4.810080202588551e-06
# oscillator transition 3-4: 	7.05897	7.05979	7.05979	7.05850  (non-linearity on qbt 0): -3.672985356928393e-05  (non-linearity on qbt 3): 7.182120640436551e-06
# oscillator transition 4-5: 	7.05896	7.05979	7.05979	7.05850  (non-linearity on qbt 0): -4.875482586186308e-05  (non-linearity on qbt 3): 9.532489261943056e-06
# oscillator transition 5-6: 	7.05895	7.05979	7.05978	7.05850  (non-linearity on qbt 0): -6.066056698017519e-05  (non-linearity on qbt 3): 1.186142950260205e-05
# oscillator transition 6-7: 	7.05894	7.05979	7.05978	7.05850  (non-linearity on qbt 0): -7.244146279816732e-05  (non-linearity on qbt 3): 1.4169179220147043e-05
# oscillator transition 7-8: 	7.05893	7.05979	7.05978	7.05851  (non-linearity on qbt 0): -8.409219998384287e-05  (non-linearity on qbt 3): 1.645597366106699e-05
# oscillator transition 8-9: 	7.05892	7.05979	7.05978	7.05851  (non-linearity on qbt 0): -9.560777515105201e-05  (non-linearity on qbt 3): 1.8722043567009905e-05
# oscillator transition 9-10: 	7.05890	7.05979	7.05978	7.05851  (non-linearity on qbt 0): -0.00010698350033777615  (non-linearity on qbt 3): 2.09676170577211e-05
# oscillator transition 10-11: 	7.05889	7.05978	7.05978	7.05851  (non-linearity on qbt 0): -0.00011821500643804939  (non-linearity on qbt 3): 2.3192917563363835e-05
# oscillator transition 11-12: 	7.05888	7.05978	7.05977	7.05851  (non-linearity on qbt 0): -0.00012929824821128477  (non-linearity on qbt 3): 2.5398167021961626e-05
# oscillator transition 12-13: 	7.05887	7.05978	7.05977	7.05852  (non-linearity on qbt 0): -0.00014022950345804475  (non-linearity on qbt 3): 2.758358217747059e-05
# oscillator transition 13-14: 	7.05886	7.05978	7.05977	7.05852  (non-linearity on qbt 0): -0.00015100537306977913  (non-linearity on qbt 3): 2.9749377826959744e-05
# oscillator transition 14-15: 	7.05885	7.05978	7.05977	7.05852  (non-linearity on qbt 0): -0.0001616227809506654  (non-linearity on qbt 3): 3.189576419160289e-05
# oscillator transition 15-16: 	7.05884	7.05978	7.05977	7.05852  (non-linearity on qbt 0): -0.00017207896883064677  (non-linearity on qbt 3): 3.402295156362811e-05
# oscillator transition 16-17: 	7.05883	7.05978	7.05977	7.05852  (non-linearity on qbt 0): -0.0001823714932669418  (non-linearity on qbt 3): 3.6131142092443724e-05
# oscillator transition 17-18: 	7.05882	7.05978	7.05976	7.05853  (non-linearity on qbt 0): -0.0001924982179843937  (non-linearity on qbt 3): 3.8220541096478655e-05
# oscillator transition 18-19: 	7.05881	7.05978	7.05976	7.05853  (non-linearity on qbt 0): -0.0002024573118291073  (non-linearity on qbt 3): 4.029134569449866e-05
# oscillator transition 19-20: 	7.05880	7.05977	7.05976	7.05853  (non-linearity on qbt 0): -0.00021224723577972782  (non-linearity on qbt 3): 4.2343752564732995e-05
# oscillator transition 20-21: 	7.05879	7.05977	7.05976	7.05853  (non-linearity on qbt 0): -0.00022186673730573148  (non-linearity on qbt 3): 4.437795811540468e-05
# oscillator transition 21-22: 	7.05878	7.05977	7.05976	7.05853  (non-linearity on qbt 0): -0.00023131484302041372  (non-linearity on qbt 3): 4.6394149617157154e-05
# oscillator transition 22-23: 	7.05877	7.05977	7.05975	7.05854  (non-linearity on qbt 0): -0.00024059084346106374  (non-linearity on qbt 3): 4.8392516671214025e-05
# oscillator transition 23-24: 	7.05876	7.05977	7.05975	7.05854  (non-linearity on qbt 0): -0.0002496942880014785  (non-linearity on qbt 3): 5.037324575241087e-05
# oscillator transition 24-25: 	7.05875	7.05977	7.05975	7.05854  (non-linearity on qbt 0): -0.00025862497106743376  (non-linearity on qbt 3): 5.233651989655641e-05
# oscillator transition 25-26: 	7.05874	7.05977	7.05975	7.05854  (non-linearity on qbt 0): -0.00026738292395123153  (non-linearity on qbt 3): 5.428252211103768e-05
# oscillator transition 26-27: 	7.05874	7.05977	7.05975	7.05854  (non-linearity on qbt 0): -0.0002759683969628668  (non-linearity on qbt 3): 5.62114239777145e-05
# oscillator transition 27-28: 	7.05873	7.05977	7.05975	7.05855  (non-linearity on qbt 0): -0.00028438185661627813  (non-linearity on qbt 3): 5.812341020927647e-05
# oscillator transition 28-29: 	7.05872	7.05976	7.05974	7.05855  (non-linearity on qbt 0): -0.0002926239652794038  (non-linearity on qbt 3): 6.001864775484478e-05
# oscillator transition 29-30: 	7.05871	7.05976	7.05974	7.05855  (non-linearity on qbt 0): -0.00030069557637091293  (non-linearity on qbt 3): 6.189731035632917e-05
# oscillator transition 30-31: 	7.05870	7.05976	7.05974	7.05855  (non-linearity on qbt 0): -0.000308597718643  (non-linearity on qbt 3): 6.37595687429382e-05
# oscillator transition 31-32: 	7.05870	7.05976	7.05974	7.05855  (non-linearity on qbt 0): -0.0003163315829937119  (non-linearity on qbt 3): 6.560558733426092e-05
# oscillator transition 32-33: 	7.05869	7.05976	7.05974	7.05856  (non-linearity on qbt 0): -0.000323898519113186  (non-linearity on qbt 3): 6.743553072041664e-05
# oscillator transition 33-34: 	7.05868	7.05976	7.05974	7.05856  (non-linearity on qbt 0): -0.0003313000107567632  (non-linearity on qbt 3): 6.924956351994638e-05
# oscillator transition 34-35: 	7.05867	7.05976	7.05973	7.05856  (non-linearity on qbt 0): -0.00033853767918401445  (non-linearity on qbt 3): 7.104784469547099e-05
# oscillator transition 35-36: 	7.05867	7.05976	7.05973	7.05856  (non-linearity on qbt 0): -0.00034561326260984515  (non-linearity on qbt 3): 7.283053181694754e-05
# oscillator transition 36-37: 	7.05866	7.05976	7.05973	7.05856  (non-linearity on qbt 0): -0.000352528607393765  (non-linearity on qbt 3): 7.459778541019091e-05
# oscillator transition 37-38: 	7.05865	7.05975	7.05973	7.05856  (non-linearity on qbt 0): -0.00035928566235554626  (non-linearity on qbt 3): 7.634975659343013e-05
# oscillator transition 38-39: 	7.05865	7.05975	7.05973	7.05857  (non-linearity on qbt 0): -0.0003658864633422354  (non-linearity on qbt 3): 7.808659821861852e-05
# oscillator transition 39-40: 	7.05864	7.05975	7.05972	7.05857  (non-linearity on qbt 0): -0.0003723331248153272  (non-linearity on qbt 3): 7.980845961341743e-05
# oscillator transition 40-41: 	7.05863	7.05975	7.05972	7.05857  (non-linearity on qbt 0): -0.00037862783922548715  (non-linearity on qbt 3): 8.151549658563795e-05
# oscillator transition 41-42: 	7.05863	7.05975	7.05972	7.05857  (non-linearity on qbt 0): -0.0003847728539909667  (non-linearity on qbt 3): 8.320784527526826e-05
# oscillator transition 42-43: 	7.05862	7.05975	7.05972	7.05857  (non-linearity on qbt 0): -0.0003907704749082086  (non-linearity on qbt 3): 8.488566035325107e-05
# oscillator transition 43-44: 	7.05861	7.05975	7.05972	7.05858  (non-linearity on qbt 0): -0.000396623052225209  (non-linearity on qbt 3): 8.654908085858892e-05
# oscillator transition 44-45: 	7.05861	7.05975	7.05971	7.05858  (non-linearity on qbt 0): -0.00040233296643066296  (non-linearity on qbt 3): 8.81983569023248e-05
# oscillator transition 45-46: 	7.05860	7.05975	7.05971	7.05858  (non-linearity on qbt 0): -0.0004078983326536445  (non-linearity on qbt 3): 8.987438789276325e-05
# oscillator transition 46-47: 	7.05860	7.05975	7.05971	7.05859  (non-linearity on qbt 0): -0.00041195281438888287  (non-linearity on qbt 3): 0.00010280488217162542
# oscillator transition 47-48: 	7.05888	7.05998	7.05997	7.06061  (non-linearity on qbt 0): -0.00013229707140283153  (non-linearity on qbt 3): 0.002123306482214815
# oscillator transition 48-49: 	7.09070	7.09337	7.09669	7.20392  (non-linearity on qbt 0): 0.03169333420872533  (non-linearity on qbt 3): 0.14542777558918019
#
# 10-11: 7.0598, diff to 00-01: 0.0007838018552046577, diff to 30-31: 0.0013067221922486993
# 20-21: 7.0598, diff to 00-01: 0.0007798708875048632, diff to 30-31: 0.0013027912245489048

# %%
dressed_osc_frequencies = [[] for _ in range(4)]
for j in [0,1,2,3]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [0,1,2,3]:
    plt.plot(list(range(max_ol-1))[:44], dressed_osc_frequencies[j][:44],label=f'{j}')
plt.legend()

# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
sys.path.append('../')
from utils_models import *

# %%
EJ = 2.75
EC = 0.6
EL = 0.13

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.17391479]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2.289441904661238e-06
#              x: [ 7.207e+00]
#            nit: 13
#           nfev: 27
#  final_simplex: (array([[ 7.207e+00],
#                        [ 7.207e+00]]), array([ 2.289e-06,  4.710e-06]))
# Optimal solution: [7.20701708]
# Objective value: 2.289441904661238e-06

# %%
max_ol = 60
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.23
system = FluxoniumOscillatorSystem(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.01679705745951421
# qbt freq at osc 1:	0.01680, 	diff to at osc ground 0.00000, 0.0265% diff
# qbt freq at osc 2:	0.01681, 	diff to at osc ground 0.00001, 0.0635% diff
# qbt freq at osc 3:	0.01682, 	diff to at osc ground 0.00002, 0.1106% diff
# qbt freq at osc 4:	0.01683, 	diff to at osc ground 0.00003, 0.1674% diff
# qbt freq at osc 5:	0.01684, 	diff to at osc ground 0.00004, 0.2334% diff
# qbt freq at osc 6:	0.01685, 	diff to at osc ground 0.00005, 0.3073% diff
# qbt freq at osc 7:	0.01686, 	diff to at osc ground 0.00006, 0.3862% diff
# qbt freq at osc 8:	0.01687, 	diff to at osc ground 0.00008, 0.4588% diff
# qbt freq at osc 9:	0.01687, 	diff to at osc ground 0.00007, 0.4092% diff
# qbt freq at osc 10:	0.01695, 	diff to at osc ground 0.00015, 0.9091% diff
# qbt freq at osc 11:	0.01696, 	diff to at osc ground 0.00016, 0.9433% diff
# qbt freq at osc 12:	0.01698, 	diff to at osc ground 0.00018, 1.0599% diff
# qbt freq at osc 13:	0.01700, 	diff to at osc ground 0.00020, 1.1983% diff
# qbt freq at osc 14:	0.01702, 	diff to at osc ground 0.00023, 1.3504% diff
# qbt freq at osc 15:	0.01705, 	diff to at osc ground 0.00025, 1.5136% diff
# qbt freq at osc 16:	0.01708, 	diff to at osc ground 0.00028, 1.6870% diff
# qbt freq at osc 17:	0.01711, 	diff to at osc ground 0.00031, 1.8699% diff
# qbt freq at osc 18:	0.01714, 	diff to at osc ground 0.00035, 2.0621% diff
# qbt freq at osc 19:	0.01718, 	diff to at osc ground 0.00038, 2.2633% diff
# qbt freq at osc 20:	0.01721, 	diff to at osc ground 0.00042, 2.4734% diff
# qbt freq at osc 21:	0.01725, 	diff to at osc ground 0.00045, 2.6921% diff
# qbt freq at osc 22:	0.01729, 	diff to at osc ground 0.00049, 2.9192% diff
# qbt freq at osc 23:	0.01733, 	diff to at osc ground 0.00053, 3.1548% diff
# qbt freq at osc 24:	0.01737, 	diff to at osc ground 0.00057, 3.3986% diff
# qbt freq at osc 25:	0.01741, 	diff to at osc ground 0.00061, 3.6506% diff
# qbt freq at osc 26:	0.01745, 	diff to at osc ground 0.00066, 3.9106% diff
# qbt freq at osc 27:	0.01750, 	diff to at osc ground 0.00070, 4.1785% diff
# qbt freq at osc 28:	0.01755, 	diff to at osc ground 0.00075, 4.4542% diff
# qbt freq at osc 29:	0.01759, 	diff to at osc ground 0.00080, 4.7376% diff
# qbt freq at osc 30:	0.01764, 	diff to at osc ground 0.00084, 5.0286% diff
# qbt freq at osc 31:	0.01769, 	diff to at osc ground 0.00089, 5.3272% diff
# qbt freq at osc 32:	0.01774, 	diff to at osc ground 0.00095, 5.6331% diff
# qbt freq at osc 33:	0.01780, 	diff to at osc ground 0.00100, 5.9464% diff
# qbt freq at osc 34:	0.01785, 	diff to at osc ground 0.00105, 6.2669% diff
# qbt freq at osc 35:	0.01790, 	diff to at osc ground 0.00111, 6.5946% diff
# qbt freq at osc 36:	0.01796, 	diff to at osc ground 0.00116, 6.9293% diff
# qbt freq at osc 37:	0.01802, 	diff to at osc ground 0.00122, 7.2709% diff
# qbt freq at osc 38:	0.01808, 	diff to at osc ground 0.00128, 7.6195% diff
# qbt freq at osc 39:	0.01814, 	diff to at osc ground 0.00134, 7.9748% diff
# qbt freq at osc 40:	0.01820, 	diff to at osc ground 0.00140, 8.3369% diff
# qbt freq at osc 41:	0.01826, 	diff to at osc ground 0.00146, 8.7055% diff
# qbt freq at osc 42:	0.01832, 	diff to at osc ground 0.00153, 9.0807% diff
# qbt freq at osc 43:	0.01839, 	diff to at osc ground 0.00159, 9.4624% diff
# qbt freq at osc 44:	0.01845, 	diff to at osc ground 0.00165, 9.8505% diff
# qbt freq at osc 45:	0.01852, 	diff to at osc ground 0.00172, 10.2448% diff
# qbt freq at osc 46:	0.01859, 	diff to at osc ground 0.00179, 10.6455% diff
# qbt freq at osc 47:	0.01865, 	diff to at osc ground 0.00186, 11.0522% diff
# qbt freq at osc 48:	0.01872, 	diff to at osc ground 0.00193, 11.4651% diff
# qbt freq at osc 49:	0.01879, 	diff to at osc ground 0.00200, 11.8839% diff
# qbt freq at osc 50:	0.01886, 	diff to at osc ground 0.00207, 12.3087% diff
# qbt freq at osc 51:	0.01894, 	diff to at osc ground 0.00214, 12.7394% diff
# qbt freq at osc 52:	0.01901, 	diff to at osc ground 0.00221, 13.1758% diff
# qbt freq at osc 53:	0.01908, 	diff to at osc ground 0.00229, 13.6180% diff
# qbt freq at osc 54:	0.01916, 	diff to at osc ground 0.00236, 14.0659% diff
# qbt freq at osc 55:	0.01924, 	diff to at osc ground 0.00244, 14.5193% diff
# qbt freq at osc 56:	0.01931, 	diff to at osc ground 0.00252, 14.9783% diff
# qbt freq at osc 57:	0.01939, 	diff to at osc ground 0.00259, 15.4405% diff
# qbt freq at osc 58:	0.01946, 	diff to at osc ground 0.00266, 15.8273% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.20666	7.20824	7.20824	7.20679
# oscillator transition 1-2: 	7.20665	7.20824	7.20824	7.20679  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.485535294726731e-06
# oscillator transition 2-3: 	7.20664	7.20823	7.20824	7.20679  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.4422145728332225e-05
# oscillator transition 3-4: 	7.20664	7.20823	7.20824	7.20679  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.0844382838447473e-05
# oscillator transition 4-5: 	7.20663	7.20823	7.20824	7.20680  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.6784707049642975e-05
# oscillator transition 5-6: 	7.20663	7.20822	7.20824	7.20680  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.227356003776549e-05
# oscillator transition 6-7: 	7.20662	7.20822	7.20823	7.20680  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.733944738826267e-05
# oscillator transition 7-8: 	7.20662	7.20822	7.20823	7.20680  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.200902880313606e-05
# oscillator transition 8-9: 	7.20661	7.20821	7.20821	7.20680  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.630721232956603e-05
# oscillator transition 9-10: 	7.20661	7.20821	7.20830	7.20681  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.0257250997276515e-05
# oscillator transition 10-11: 	7.20660	7.20821	7.20822	7.20681  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.388083883417494e-05
# oscillator transition 11-12: 	7.20660	7.20821	7.20823	7.20681  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.719820659066954e-05
# oscillator transition 12-13: 	7.20660	7.20820	7.20823	7.20681  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.022821364126685e-05
# oscillator transition 13-14: 	7.20660	7.20820	7.20823	7.20681  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.298843636898255e-05
# oscillator transition 14-15: 	7.20659	7.20820	7.20823	7.20682  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.549525393495514e-05
# oscillator transition 15-16: 	7.20659	7.20820	7.20823	7.20682  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.776393068719244e-05
# oscillator transition 16-17: 	7.20659	7.20819	7.20822	7.20682  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.980869049755256e-05
# oscillator transition 17-18: 	7.20659	7.20819	7.20822	7.20682  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.164279102767068e-05
# oscillator transition 18-19: 	7.20659	7.20819	7.20822	7.20682  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.327859083261501e-05
# oscillator transition 19-20: 	7.20658	7.20819	7.20822	7.20683  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.472761362237179e-05
# oscillator transition 20-21: 	7.20658	7.20818	7.20822	7.20683  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.600060732215752e-05
# oscillator transition 21-22: 	7.20658	7.20818	7.20822	7.20683  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.710759973633685e-05
# oscillator transition 22-23: 	7.20658	7.20818	7.20822	7.20683  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.805794933801735e-05
# oscillator transition 23-24: 	7.20658	7.20818	7.20822	7.20683  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.88603962007528e-05
# oscillator transition 24-25: 	7.20658	7.20817	7.20822	7.20684  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.952310139103247e-05
# oscillator transition 25-26: 	7.20658	7.20817	7.20821	7.20684  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.005369454622269e-05
# oscillator transition 26-27: 	7.20658	7.20817	7.20821	7.20684  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.045930599109852e-05
# oscillator transition 27-28: 	7.20658	7.20817	7.20821	7.20684  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.07466093988296e-05
# oscillator transition 28-29: 	7.20658	7.20816	7.20821	7.20684  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.092184603469832e-05
# oscillator transition 29-30: 	7.20658	7.20816	7.20821	7.20684  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.099086247170817e-05
# oscillator transition 30-31: 	7.20658	7.20816	7.20821	7.20685  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.09591355732664e-05
# oscillator transition 31-32: 	7.20658	7.20816	7.20821	7.20685  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.083179906748228e-05
# oscillator transition 32-33: 	7.20658	7.20815	7.20821	7.20685  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.061366733613795e-05
# oscillator transition 33-34: 	7.20658	7.20815	7.20820	7.20685  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.030925800994737e-05
# oscillator transition 34-35: 	7.20658	7.20815	7.20820	7.20685  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.992281334168183e-05
# oscillator transition 35-36: 	7.20658	7.20815	7.20820	7.20685  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.945831677602655e-05
# oscillator transition 36-37: 	7.20658	7.20814	7.20820	7.20686  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.891951469218839e-05
# oscillator transition 37-38: 	7.20658	7.20814	7.20820	7.20686  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.830992848312235e-05
# oscillator transition 38-39: 	7.20658	7.20814	7.20820	7.20686  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.763287470652358e-05
# oscillator transition 39-40: 	7.20658	7.20814	7.20820	7.20686  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.689147236078497e-05
# oscillator transition 40-41: 	7.20658	7.20814	7.20820	7.20686  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.608866127384317e-05
# oscillator transition 41-42: 	7.20658	7.20813	7.20820	7.20687  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.522721540453858e-05
# oscillator transition 42-43: 	7.20658	7.20813	7.20819	7.20687  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.430974659428102e-05
# oscillator transition 43-44: 	7.20659	7.20813	7.20819	7.20687  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.333872270010033e-05
# oscillator transition 44-45: 	7.20659	7.20813	7.20819	7.20687  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.23164727673975e-05
# oscillator transition 45-46: 	7.20659	7.20812	7.20819	7.20687  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.124519845547184e-05
# oscillator transition 46-47: 	7.20659	7.20812	7.20819	7.20687  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.012697960817604e-05
# oscillator transition 47-48: 	7.35269	7.20812	7.20819	7.20688  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.14602629026808245
# oscillator transition 48-49: 	7.20816	7.20812	7.20819	7.20688  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015008821170567899
# oscillator transition 49-50: 	7.20816	7.20812	7.20819	7.20688  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015011381521503608
# oscillator transition 50-51: 	7.20816	7.20811	7.20819	7.20688  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.001501359280609904
# oscillator transition 51-52: 	7.20816	7.20811	7.20818	7.20688  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.001501547066538933
# oscillator transition 52-53: 	7.20816	7.20811	7.20818	7.20688  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015017029926411851
# oscillator transition 53-54: 	7.20816	7.20811	7.20818	7.20689  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015018284595385012
# oscillator transition 54-55: 	7.20816	7.20811	7.20818	7.20689  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015019248014027653
# oscillator transition 55-56: 	7.20816	7.20810	7.20818	7.20689  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.001501994593127165
# oscillator transition 56-57: 	7.20816	7.20810	7.20818	7.20691  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0015025334716938232
# oscillator transition 57-58: 	7.20830	7.20842	7.20849	7.20976  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.001640579411514409
# oscillator transition 58-59: 	7.23254	7.24597	7.24922	7.37522  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.025885840148077932
#
# 10-11: 7.2082, diff to 00-01: 0.0015791990958842206
# 20-21: 7.2082, diff to 00-01: 0.0015836535910063176

# %%
plt.figure(figsize = (3,3))
n_osc_lvls = 20
dressed_osc_frequencies = [[] for _ in range(3)]
for j in [0,1,2]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [0,1,2]:
    plt.plot(list(range(max_ol-1))[:n_osc_lvls], dressed_osc_frequencies[j][:n_osc_lvls],label=rf'$\omega_{{{j},n+1}} - \omega_{{{j},n}}$')

plt.xticks(list(range(n_osc_lvls))[::2])
# plt.xticklabels([str(i) for i in range(n_osc_lvls)])
plt.legend(loc='lower right')

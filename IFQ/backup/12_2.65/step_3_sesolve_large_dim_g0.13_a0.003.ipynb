# %%
import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *
# sys.path = original_sys_path

# %%
max_ql = 25
max_ol = 50
system = fluxonium_oscillator_system(
    EJ = 2.65,
    EC = 0.6,
    EL = 0.13,
    Er = 7.17391479,
    g_strength = 0.13,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.001,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2',
    )

# %%
t_stop = 400
tot_time =450
tlist = np.linspace(0, tot_time, tot_time)

results = system.run_mesolve_on_driving_osc(
    intial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(i, 0)])) for i in range(3)],
    tlist = tlist,
    osc_decay = False,
    amp = 0.003,
    t_stop = t_stop
)
# Out:
#  ******   28%           ] Elapsed 1265.01s / Remaining 00:00:54:12         0%           ] Elapsed 0.00s / Remaining 00:00:00:00[          0%           ] Elapsed 0.00s / Remaining 00:00:00:00[          0%           ] Elapsed 0.96s / Remaining 00:00:00:00[          0%           ] Elapsed 1.02s / Remaining 00:00:00:00[          0%           ] Elapsed 2.17s / Remaining 00:00:00:00[          1%           ] Elapsed 3.78s / Remaining 00:00:06:13[          0%           ] Elapsed 4.00s / Remaining 00:00:00:00[          1%           ] Elapsed 5.33s / Remaining 00:00:08:47[          0%           ] Elapsed 6.10s / Remaining 00:00:00:00[          1%           ] Elapsed 6.57s / Remaining 00:00:10:50[          1%           ] Elapsed 7.91s / Remaining 00:00:13:02[          0%           ] Elapsed 7.96s / Remaining 00:00:00:00[          2%           ] Elapsed 9.04s / Remaining 00:00:07:22[          1%           ] Elapsed 10.31s / Remaining 00:00:17:00[          2%           ] Elapsed 10.54s / Remaining 00:00:08:36[          2%           ] Elapsed 11.70s / Remaining 00:00:09:33[          1%           ] Elapsed 12.11s / Remaining 00:00:19:58[          2%           ] Elapsed 12.90s / Remaining 00:00:10:31[          1%           ] Elapsed 13.98s / Remaining 00:00:23:03[          2%           ] Elapsed 14.15s / Remaining 00:00:11:33[*         3%           ] Elapsed 15.38s / Remaining 00:00:08:17[          1%           ] Elapsed 15.99s / Remaining 00:00:26:23[*         3%           ] Elapsed 17.26s / Remaining 00:00:09:18[          1%           ] Elapsed 18.64s / Remaining 00:00:30:44[          1%           ] Elapsed 20.72s / Remaining 00:00:34:10[*         3%           ] Elapsed 21.93s / Remaining 00:00:11:49[          1%           ] Elapsed 22.86s / Remaining 00:00:37:43[          1%           ] Elapsed 24.82s / Remaining 00:00:40:56[*         3%           ] Elapsed 26.03s / Remaining 00:00:14:01[          2%           ] Elapsed 26.86s / Remaining 00:00:21:55[          2%           ] Elapsed 28.75s / Remaining 00:00:23:28[*         4%           ] Elapsed 30.64s / Remaining 00:00:12:15[          2%           ] Elapsed 31.12s / Remaining 00:00:25:24[          2%           ] Elapsed 32.68s / Remaining 00:00:26:41[*         4
00:00:05:20[*********94%********** ] Elapsed 5018.84s / Remaining 00:00:05:20[*********94%********** ] Elapsed 5023.27s / Remaining 00:00:05:20[*********94%********** ] Elapsed 5027.17s / Remaining 00:00:05:20[*********94%********** ] Elapsed 5031.59s / Remaining 00:00:05:21[*********95%********** ] Elapsed 5035.40s / Remaining 00:00:04:25[*********95%********** ] Elapsed 5039.93s / Remaining 00:00:04:25[*********95%********** ] Elapsed 5044.00s / Remaining 00:00:04:25[*********95%********** ] Elapsed 5048.07s / Remaining 00:00:04:25[*********96%********** ] Elapsed 5051.63s / Remaining 00:00:03:30[*********96%********** ] Elapsed 5055.70s / Remaining 00:00:03:30[*********96%********** ] Elapsed 5059.24s / Remaining 00:00:03:30[*********96%********** ] Elapsed 5063.30s / Remaining 00:00:03:30[*********96%********** ] Elapsed 5066.92s / Remaining 00:00:03:31[*********97%********** ] Elapsed 5070.93s / Remaining 00:00:02:36[*********97%********** ] Elapsed 5074.47s / Remaining 00:00:02:36[*********97%********** ] Elapsed 5078.59s / Remaining 00:00:02:37[*********97%********** ] Elapsed 5082.09s / Remaining 00:00:02:37[*********98%***********] Elapsed 5086.07s / Remaining 00:00:01:43[*********98%***********] Elapsed 5089.78s / Remaining 00:00:01:43[*********98%***********] Elapsed 5093.86s / Remaining 00:00:01:43[*********98%***********] Elapsed 5097.36s / Remaining 00:00:01:44[*********98%***********] Elapsed 5101.51s / Remaining 00:00:01:44[*********99%***********] Elapsed 5105.04s / Remaining 00:00:00:51[*********99%***********] Elapsed 5109.19s / Remaining 00:00:00:51[*********99%***********] Elapsed 5112.74s / Remaining 00:00:00:51[*********99%***********] Elapsed 5116.76s / Remaining 00:00:00:51[********100%***********] Elapsed 5120.28s / Remaining 00:00:00:00[********100%***********] Elapsed 5124.16s / Remaining 00:00:00:00Total run time: 5124.16s

# %%
import pickle
with open('../pickles/sesolve_12_large_dim_2.65_g0.13_a0.003.pkl', 'wb') as file:
    pickle.dump(results, file)

# %%
with open('../pickles/sesolve_12_large_dim_2.65_g0.13_a0.003.pkl', 'rb') as file:
    results = pickle.load(file)

# %%
lists = []
for ql in [0,1,2]:
    pop_list = []
    for t_idx in tqdm(range(len(tlist)), desc = "t loop"):
        dm = results[ql].states[t_idx]
        pop_sum = 0
        for q in range(system.qbt.truncated_dim):
            if q != ql:
                for o in range(system.osc.truncated_dim):
                    product_state = (q, o)
                    dressed_state = system.product_to_dressed[product_state]
                    basis_state = qutip.basis(dm.dims[0][0], dressed_state)
                    expectation_value = qutip.expect(basis_state * basis_state.dag(), dm)
                    pop_sum += expectation_value

        pop_list.append(pop_sum)
    # print(pop_list)
    lists.append(pop_list)
# Out:
# t loop: 100%|██████████| 450/450 [01:13<00:00,  6.09it/s]
# t loop: 100%|██████████| 450/450 [01:12<00:00,  6.19it/s]
# t loop: 100%|██████████| 450/450 [01:11<00:00,  6.29it/s]

# %%
with open('../pickles/sesolve_12_large_dim_leakage_list_2.65_g0.13_a0.003.pkl', 'wb') as file:
    pickle.dump(lists, file)

# %%
for ql,pop_list in enumerate(lists): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.title('expecation of qubit not being in initial state, sesolve with 15 level qbt, 40 level osc')
plt.xlabel('t (ns)')
# Out:
# Text(0.5, 0, 't (ns)')

# %%
lists = []
for ql in [0,1,2]:
    pops_list = [[] for _ in range(system.qbt.truncated_dim)]
    for t_idx in tqdm(range(len(tlist)), desc = "t loop"):
        dm = results[ql].states[t_idx]
        for q in range(system.qbt.truncated_dim):
            sum_at_this_t_for_this_q = 0
            for o in range(system.osc.truncated_dim):
                product_state = (q, o)
                dressed_state = system.product_to_dressed[product_state]
                basis_state = qutip.basis(dm.dims[0][0], dressed_state)
                expectation_value = qutip.expect(basis_state * basis_state.dag(), dm)
                sum_at_this_t_for_this_q += expectation_value
            pops_list[q].append(sum_at_this_t_for_this_q)
    lists.append(pops_list)


for ql,pop_list in enumerate(lists[2][:]): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.xlabel('t (ns)')
# Out:
# t loop: 100%|██████████| 450/450 [01:15<00:00,  5.93it/s]
# t loop: 100%|██████████| 450/450 [01:17<00:00,  5.80it/s]
# t loop: 100%|██████████| 450/450 [01:16<00:00,  5.89it/s]
# Text(0.5, 0, 't (ns)')

# %%
with open('../pickles/sesolve_12_large_dim_qubit_pop_list_g0.13_a0.003.pkl', 'wb') as file:
    pickle.dump(lists, file)

# %%
for ql,pop_list in enumerate(lists[0][:17]): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.xlabel('t (ns)')
# Out:
# Text(0.5, 0, 't (ns)')

# %%
for ql,pop_list in enumerate(lists[1][:]): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.xlabel('t (ns)')
# Out:
# Text(0.5, 0, 't (ns)')

# %%
interactive_heatmap(results[0], system.product_to_dressed, system.qbt.truncated_dim, system.osc.truncated_dim)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Time Index:', max=409), Output(…

# %%
plot_heatmap(results[0], time_index=440, product_to_dressed = product_to_dressed, qubit_levels=qubit_level, oscillator_levels=osc_level)

# %%
plot_heatmap(results[1], time_index=200, product_to_dressed = product_to_dressed, qubit_levels=qubit_level, oscillator_levels=osc_level)

# %%
plot_heatmap(results[2], time_index=200, product_to_dressed = product_to_dressed, qubit_levels=qubit_level, oscillator_levels=osc_level)

# %%
qbt.plot_matrixelements('n_operator',evals_count=15)
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

# %%
scqubits.Transmon(EJ=30,EC=1.2,ng=0.3,ncut=31).plot_matrixelements('n_operator',evals_count=15)
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

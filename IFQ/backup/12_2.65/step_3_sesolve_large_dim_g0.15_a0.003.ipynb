# %%
import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *
# sys.path = original_sys_path

# %%
max_ql = 25
max_ol = 50
system = fluxonium_oscillator_system(
    EJ = 2.65,
    EC = 0.6,
    EL = 0.13,
    Er = 7.17391479,
    g_strength = 0.15,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.001,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2',
    )

# %%
t_stop = 294
tot_time =300
tlist = np.linspace(0, tot_time, tot_time)

results = system.run_mesolve_on_driving_osc(
    intial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(i, 0)])) for i in range(3)],
    tlist = tlist,
    osc_decay = False,
    amp = 0.003,
    t_stop = t_stop
)
# Out:
#  [          0%           ] Elapsed 0.00s / Remaining 00:00:00:00[          0%           ] Elapsed 0.00s / Remaining 00:00:00:00[          0%           ] Elapsed 0.00s / Remaining 00:00:00:00[          0%           ] Elapsed 4.53s / Remaining 00:00:00:00[          0%           ] Elapsed 8.25s / Remaining 00:00:00:00[          1%           ] Elapsed 9.48s / Remaining 00:00:15:38[          0%           ] Elapsed 12.66s / Remaining 00:00:00:00[          1%           ] Elapsed 13.67s / Remaining 00:00:22:33[          1%           ] Elapsed 17.98s / Remaining 00:00:29:40[          2%           ] Elapsed 21.54s / Remaining 00:00:17:35[          1%           ] Elapsed 21.63s / Remaining 00:00:35:41[          1%           ] Elapsed 25.33s / Remaining 00:00:41:47[          2%           ] Elapsed 26.28s / Remaining 00:00:21:27[          2%           ] Elapsed 30.93s / Remaining 00:00:25:15[*         3%           ] Elapsed 35.39s / Remaining 00:00:19:04[          1%           ] Elapsed 36.14s / Remaining 00:00:59:37[*         3%           ] Elapsed 39.29s / Remaining 00:00:21:10[          1%           ] Elapsed 41.44s / Remaining 00:01:08:22[          1%           ] Elapsed 51.73s / Remaining 00:01:25:21[          1%           ] Elapsed 54.43s / Remaining 00:01:29:48[*         3%           ] Elapsed 54.70s / Remaining 00:00:29:28[          2%           ] Elapsed 65.39s / Remaining 00:00:53:24[*         4%           ] Elapsed 67.09s / Remaining 00:00:26:50[          2%           ] Elapsed 67.40s / Remaining 00:00:55:02[          2%           ] Elapsed 79.20s / Remaining 00:01:04:40[          2%           ] Elapsed 80.46s / Remaining 00:01:05:42[*         4%           ] Elapsed 80.67s / Remaining 00:00:32:16[          2%           ] Elapsed 89.74s / Remaining 00:01:13:17[          2%           ] Elapsed 90.51s / Remaining 00:01:13:54[*         4%           ] Elapsed 90.59s / Remaining 00:00:36:14[*         3%           ] Elapsed 101.00s / Remaining 00:00:54:25[*         5%           ] Elapsed 102.57s / Remaining 00:00:32:28[*         3%           ] Elapsed 102.84s / Remaining 00:00:55:25[*         3%           ] Elapsed 116.27s / Remaining 00:01:02:39[*         3%           ] Elapsed 117.20s / Remaining 00:01:03:09[*         5%           ] Elapsed 117.42s / Remaining 00:00:37:11[*         3%           ] Elapsed 129.32s / Remaining 00:01:09:41[*         5%           ] Elapsed 132.17s / Remaining 00:00:41:51[*         3%           ] Elapsed 132.53s / Remaining 00:01:11:25[*         4%           ] Elapsed 143.04s / Remaining 00:00:57:13[*         6%           ] Elapsed 144.55s / Remaining 00:00:37:44[*         4%           ] Elapsed 145.77s / Remaining 
.20s / Remaining 00:00:05:22[*********96%********** ] Elapsed 4281.90s / Remaining 00:00:02:58[*********93%*********  ] Elapsed 4291.42s / Remaining 00:00:05:23[*********97%********** ] Elapsed 4295.12s / Remaining 00:00:02:12[*********94%********** ] Elapsed 4301.61s / Remaining 00:00:04:34[*********97%********** ] Elapsed 4305.70s / Remaining 00:00:02:13[*********94%********** ] Elapsed 4313.53s / Remaining 00:00:04:35[*********97%********** ] Elapsed 4317.93s / Remaining 00:00:02:13[*********94%********** ] Elapsed 4323.59s / Remaining 00:00:04:35[*********98%***********] Elapsed 4328.26s / Remaining 00:00:01:28[*********95%********** ] Elapsed 4334.31s / Remaining 00:00:03:48[*********98%***********] Elapsed 4339.83s / Remaining 00:00:01:28[*********95%********** ] Elapsed 4346.11s / Remaining 00:00:03:48[*********98%***********] Elapsed 4349.76s / Remaining 00:00:01:28[*********95%********** ] Elapsed 4358.83s / Remaining 00:00:03:49[*********99%***********] Elapsed 4362.91s / Remaining 00:00:00:44[*********96%********** ] Elapsed 4370.91s / Remaining 00:00:03:02[*********99%***********] Elapsed 4375.55s / Remaining 00:00:00:44[*********96%********** ] Elapsed 4384.69s / Remaining 00:00:03:02[*********99%***********] Elapsed 4388.49s / Remaining 00:00:00:44[*********96%********** ] Elapsed 4396.00s / Remaining 00:00:03:03[********100%***********] Elapsed 4400.53s / Remaining 00:00:00:00Total run time: 4400.53s
#  [*********97%********** ] Elapsed 4406.53s / Remaining 00:00:02:16[*********97%********** ] Elapsed 4414.45s / Remaining 00:00:02:16[*********97%********** ] Elapsed 4423.05s / Remaining 00:00:02:16[*********98%***********] Elapsed 4430.57s / Remaining 00:00:01:30[*********98%***********] Elapsed 4438.94s / Remaining 00:00:01:30[*********98%***********] Elapsed 4446.43s / Remaining 00:00:01:30[*********99%***********] Elapsed 4455.78s / Remaining 00:00:00:45[*********99%***********] Elapsed 4464.00s / Remaining 00:00:00:45[*********99%***********] Elapsed 4472.43s / Remaining 00:00:00:45[********100%***********] Elapsed 4480.51s / Remaining 00:00:00:00Total run time: 4480.52s

# %%
import pickle
with open('../pickles/sesolve_12_large_dim_2.65_g0.15_a0.003.pkl', 'wb') as file:
    pickle.dump(results, file)

# %%
with open('../pickles/sesolve_12_large_dim_2.65_g0.15_a0.003.pkl', 'rb') as file:
    results = pickle.load(file)

# %%
lists = []
for ql in [0,1,2]:
    pop_list = []
    for t_idx in tqdm(range(len(tlist)), desc = "t loop"):
        dm = results[ql].states[t_idx]
        pop_sum = 0
        for q in range(system.qbt.truncated_dim):
            if q != ql:
                for o in range(system.osc.truncated_dim):
                    product_state = (q, o)
                    dressed_state = system.product_to_dressed[product_state]
                    basis_state = qutip.basis(dm.dims[0][0], dressed_state)
                    expectation_value = qutip.expect(basis_state * basis_state.dag(), dm)
                    pop_sum += expectation_value

        pop_list.append(pop_sum)
    # print(pop_list)
    lists.append(pop_list)
# Out:
# t loop:   0%|          | 0/300 [00:00<?, ?it/s]
# t loop: 100%|██████████| 300/300 [01:16<00:00,  3.93it/s]
# t loop: 100%|██████████| 300/300 [01:09<00:00,  4.30it/s]
# t loop: 100%|██████████| 300/300 [01:08<00:00,  4.37it/s]

# %%
with open('../pickles/sesolve_12_large_dim_leakage_list_2.65_g0.15_a0.003.pkl', 'wb') as file:
    pickle.dump(lists, file)

# %%
for ql,pop_list in enumerate(lists): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.title('expecation of qubit not being in initial state, sesolve with 15 level qbt, 40 level osc')
plt.xlabel('t (ns)')
# Out:
# Text(0.5, 0, 't (ns)')

# %%
lists = []
for ql in [0,1,2]:
    pops_list = [[] for _ in range(system.qbt.truncated_dim)]
    for t_idx in tqdm(range(len(tlist)), desc = "t loop"):
        dm = results[ql].states[t_idx]
        for q in range(system.qbt.truncated_dim):
            sum_at_this_t_for_this_q = 0
            for o in range(system.osc.truncated_dim):
                product_state = (q, o)
                dressed_state = system.product_to_dressed[product_state]
                basis_state = qutip.basis(dm.dims[0][0], dressed_state)
                expectation_value = qutip.expect(basis_state * basis_state.dag(), dm)
                sum_at_this_t_for_this_q += expectation_value
            pops_list[q].append(sum_at_this_t_for_this_q)
    lists.append(pops_list)


for ql,pop_list in enumerate(lists[2][:]): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.xlabel('t (ns)')
# Out:
# t loop:   0%|          | 0/300 [00:00<?, ?it/s]
# t loop: 100%|██████████| 300/300 [01:03<00:00,  4.71it/s]
# t loop: 100%|██████████| 300/300 [01:02<00:00,  4.81it/s]
# t loop: 100%|██████████| 300/300 [00:56<00:00,  5.35it/s]
# Text(0.5, 0, 't (ns)')

# %%
with open('../pickles/sesolve_12_large_dim_qubit_pop_list_g0.15_a0.003.pkl', 'wb') as file:
    pickle.dump(lists, file)

# %%
for ql,pop_list in enumerate(lists[0][:17]): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.xlabel('t (ns)')
# Out:
# Text(0.5, 0, 't (ns)')

# %%
for ql,pop_list in enumerate(lists[1][:]): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.xlabel('t (ns)')
# Out:
# Text(0.5, 0, 't (ns)')

# %%
interactive_heatmap(results[0], system.product_to_dressed, system.qbt.truncated_dim, system.osc.truncated_dim)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Time Index:', max=409), Output(…

# %%
plot_heatmap(results[0], time_index=440, product_to_dressed = product_to_dressed, qubit_levels=qubit_level, oscillator_levels=osc_level)

# %%
plot_heatmap(results[1], time_index=200, product_to_dressed = product_to_dressed, qubit_levels=qubit_level, oscillator_levels=osc_level)

# %%
plot_heatmap(results[2], time_index=200, product_to_dressed = product_to_dressed, qubit_levels=qubit_level, oscillator_levels=osc_level)

# %%
qbt.plot_matrixelements('n_operator',evals_count=15)
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

# %%
scqubits.Transmon(EJ=30,EC=1.2,ng=0.3,ncut=31).plot_matrixelements('n_operator',evals_count=15)
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

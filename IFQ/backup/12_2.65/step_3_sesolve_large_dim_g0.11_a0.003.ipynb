# %%
import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *
# sys.path = original_sys_path

# %%
max_ql = 25
max_ol = 50
system = fluxonium_oscillator_system(
    EJ = 2.65,
    EC = 0.6,
    EL = 0.13,
    Er = 7.17391479,
    g_strength = 0.11,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.001,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2',
    )

# %%
t_stop = 569
tot_time =600
tlist = np.linspace(0, tot_time, tot_time)

results = system.run_mesolve_on_driving_osc(
    intial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(i, 0)])) for i in range(3)],
    tlist = tlist,
    osc_decay = False,
    amp = 0.003,
    t_stop = t_stop
)
# Out:
#  [          0%           ] Elapsed 0.00s / Remaining 00:00:00:00[          0%           ] Elapsed 0.00s / Remaining 00:00:00:00[          0%           ] Elapsed 0.00s / Remaining 00:00:00:00[          0%           ] Elapsed 1.59s / Remaining 00:00:00:00[          0%           ] Elapsed 3.33s / Remaining 00:00:00:00[          0%           ] Elapsed 3.55s / Remaining 00:00:00:00[          0%           ] Elapsed 4.91s / Remaining 00:00:00:00[          0%           ] Elapsed 5.21s / Remaining 00:00:00:00[          1%           ] Elapsed 8.27s / Remaining 00:00:13:38[          1%           ] Elapsed 10.28s / Remaining 00:00:16:57[          0%           ] Elapsed 10.97s / Remaining 00:00:00:00[          0%           ] Elapsed 12.09s / Remaining 00:00:00:00[          1%           ] Elapsed 12.07s / Remaining 00:00:19:55[          1%           ] Elapsed 14.18s / Remaining 00:00:23:24[          1%           ] Elapsed 16.25s / Remaining 00:00:26:48[          0%           ] Elapsed 17.78s / Remaining 00:00:00:00[          0%           ] Elapsed 18.41s / Remaining 00:00:00:00[          1%           ] Elapsed 24.18s / Remaining 00:00:39:53[          2%           ] Elapsed 24.92s / Remaining 00:00:20:21[          1%           ] Elapsed 25.15s / Remaining 00:00:41:29[          1%           ] Elapsed 29.11s / Remaining 00:00:48:02[          1%           ] Elapsed 29.36s / Remaining 00:00:48:26[          2%           ] Elapsed 29.33s / Remaining 00:00:23:57[          1%           ] Elapsed 35.75s / Remaining 00:00:58:59[          1%           ] Elapsed 37.19s / Remaining 00:01:01:22[          2%           ] Elapsed 37.86s / Remaining 00:00:30:55[          1%           ] Elapsed 43.33s / Remaining 00:01:11:29[          1%           ] Elapsed 44.28s / Remaining 00:01:13:04[          2%           ] Elapsed 44.94s / Remaining 00:00:36:41[          1%           ] Elapsed 47.68s / Remaining 00:01:18:40[          1%           ] Elapsed 49.91s / Remaining 00:01:22:21[          2%           ] Elapsed 51.67s / Remaining 00:00:42:11[          2%           ] Elapsed 59.23s / Remaining 00:00:48:22[          2%           ] Elapsed 59.97s / Remaining 00:00:48:58[          2%           ] Elapsed 61
elapsed 5194.77s / Remaining 00:00:07:31[*********92%*********  ] Elapsed 5197.92s / Remaining 00:00:07:31[*********92%*********  ] Elapsed 5201.44s / Remaining 00:00:07:32[*********92%*********  ] Elapsed 5204.49s / Remaining 00:00:07:32[*********92%*********  ] Elapsed 5208.01s / Remaining 00:00:07:32[*********93%*********  ] Elapsed 5211.08s / Remaining 00:00:06:32[*********93%*********  ] Elapsed 5214.61s / Remaining 00:00:06:32[*********93%*********  ] Elapsed 5217.69s / Remaining 00:00:06:32[*********93%*********  ] Elapsed 5221.20s / Remaining 00:00:06:32[*********93%*********  ] Elapsed 5224.27s / Remaining 00:00:06:33[*********94%********** ] Elapsed 5227.78s / Remaining 00:00:05:33[*********94%********** ] Elapsed 5230.92s / Remaining 00:00:05:33[*********94%********** ] Elapsed 5234.46s / Remaining 00:00:05:34[*********94%********** ] Elapsed 5237.62s / Remaining 00:00:05:34[*********94%********** ] Elapsed 5241.18s / Remaining 00:00:05:34[*********94%********** ] Elapsed 5244.31s / Remaining 00:00:05:34[*********94%********** ] Elapsed 5247.89s / Remaining 00:00:05:34[*********95%********** ] Elapsed 5251.01s / Remaining 00:00:04:36[*********95%********** ] Elapsed 5254.49s / Remaining 00:00:04:36[*********95%********** ] Elapsed 5257.55s / Remaining 00:00:04:36[*********95%********** ] Elapsed 5261.39s / Remaining 00:00:04:36[*********95%********** ] Elapsed 5264.46s / Remaining 00:00:04:37[*********96%********** ] Elapsed 5267.95s / Remaining 00:00:03:39[*********96%********** ] Elapsed 5271.02s / Remaining 00:00:03:39[*********96%********** ] Elapsed 5274.50s / Remaining 00:00:03:39[*********96%********** ] Elapsed 5277.57s / Remaining 00:00:03:39[*********96%********** ] Elapsed 5281. ...

# %%
import pickle
with open('../pickles/sesolve_12_large_dim_2.65_g0.11_a0.003.pkl', 'wb') as file:
    pickle.dump(results, file)

# %%
with open('../pickles/sesolve_12_large_dim_2.65_g0.11_a0.003.pkl', 'rb') as file:
    results = pickle.load(file)

# %%
lists = []
for ql in [0,1,2]:
    pop_list = []
    for t_idx in tqdm(range(len(tlist)), desc = "t loop"):
        dm = results[ql].states[t_idx]
        pop_sum = 0
        for q in range(system.qbt.truncated_dim):
            if q != ql:
                for o in range(system.osc.truncated_dim):
                    product_state = (q, o)
                    dressed_state = system.product_to_dressed[product_state]
                    basis_state = qutip.basis(dm.dims[0][0], dressed_state)
                    expectation_value = qutip.expect(basis_state * basis_state.dag(), dm)
                    pop_sum += expectation_value

        pop_list.append(pop_sum)
    # print(pop_list)
    lists.append(pop_list)
# Out:
# t loop: 100%|██████████| 600/600 [01:37<00:00,  6.15it/s]
# t loop: 100%|██████████| 600/600 [01:36<00:00,  6.19it/s]
# t loop: 100%|██████████| 600/600 [01:34<00:00,  6.32it/s]

# %%
with open('../pickles/sesolve_12_large_dim_leakage_list_2.65_g0.11_a0.003.pkl', 'wb') as file:
    pickle.dump(lists, file)

# %%
for ql,pop_list in enumerate(lists): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.title('expecation of qubit not being in initial state, sesolve with 15 level qbt, 40 level osc')
plt.xlabel('t (ns)')
# Out:
# Text(0.5, 0, 't (ns)')

# %%
lists = []
for ql in [0,1,2]:
    pops_list = [[] for _ in range(system.qbt.truncated_dim)]
    for t_idx in tqdm(range(len(tlist)), desc = "t loop"):
        dm = results[ql].states[t_idx]
        for q in range(system.qbt.truncated_dim):
            sum_at_this_t_for_this_q = 0
            for o in range(system.osc.truncated_dim):
                product_state = (q, o)
                dressed_state = system.product_to_dressed[product_state]
                basis_state = qutip.basis(dm.dims[0][0], dressed_state)
                expectation_value = qutip.expect(basis_state * basis_state.dag(), dm)
                sum_at_this_t_for_this_q += expectation_value
            pops_list[q].append(sum_at_this_t_for_this_q)
    lists.append(pops_list)


for ql,pop_list in enumerate(lists[2][:]): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.xlabel('t (ns)')
# Out:
# t loop: 100%|██████████| 600/600 [01:40<00:00,  5.97it/s]
# t loop: 100%|██████████| 600/600 [01:40<00:00,  5.98it/s]
# t loop: 100%|██████████| 600/600 [01:44<00:00,  5.75it/s]
# Text(0.5, 0, 't (ns)')

# %%
with open('../pickles/sesolve_12_large_dim_qubit_pop_list_g0.11_a0.003.pkl', 'wb') as file:
    pickle.dump(lists, file)

# %%
for ql,pop_list in enumerate(lists[0][:17]): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.xlabel('t (ns)')
# Out:
# Text(0.5, 0, 't (ns)')

# %%
for ql,pop_list in enumerate(lists[1][:]): 
    plt.plot(tlist,pop_list,label = f"{ql}")
plt.yscale('log')
plt.legend()
plt.xlabel('t (ns)')
# Out:
# Text(0.5, 0, 't (ns)')

# %%
interactive_heatmap(results[0], system.product_to_dressed, system.qbt.truncated_dim, system.osc.truncated_dim)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Time Index:', max=409), Output(…

# %%
plot_heatmap(results[0], time_index=440, product_to_dressed = product_to_dressed, qubit_levels=qubit_level, oscillator_levels=osc_level)

# %%
plot_heatmap(results[1], time_index=200, product_to_dressed = product_to_dressed, qubit_levels=qubit_level, oscillator_levels=osc_level)

# %%
plot_heatmap(results[2], time_index=200, product_to_dressed = product_to_dressed, qubit_levels=qubit_level, oscillator_levels=osc_level)

# %%
qbt.plot_matrixelements('n_operator',evals_count=15)
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

# %%
scqubits.Transmon(EJ=30,EC=1.2,ng=0.3,ncut=31).plot_matrixelements('n_operator',evals_count=15)
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

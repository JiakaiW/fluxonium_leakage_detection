# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *
# sys.path = original_sys_path

# %%
EJ = 2.65
EC = 0.6
EL = 0.13

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.15]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2.177946977592604e-06
#              x: [ 7.174e+00]
#            nit: 14
#           nfev: 29
#  final_simplex: (array([[ 7.174e+00],
#                        [ 7.174e+00]]), array([ 2.178e-06,  6.172e-06]))
# Optimal solution: [7.17391479]
# Objective value: 2.177946977592604e-06

# %%
max_ol = 50
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.11
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states= '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.021615343592458425
# qbt freq at osc 1:	0.02162, 	diff to at osc ground 0.00000, 0.0053% diff
# qbt freq at osc 2:	0.02162, 	diff to at osc ground 0.00000, 0.0132% diff
# qbt freq at osc 3:	0.02162, 	diff to at osc ground 0.00001, 0.0238% diff
# qbt freq at osc 4:	0.02162, 	diff to at osc ground 0.00001, 0.0369% diff
# qbt freq at osc 5:	0.02163, 	diff to at osc ground 0.00001, 0.0526% diff
# qbt freq at osc 6:	0.02163, 	diff to at osc ground 0.00002, 0.0708% diff
# qbt freq at osc 7:	0.02164, 	diff to at osc ground 0.00002, 0.0915% diff
# qbt freq at osc 8:	0.02164, 	diff to at osc ground 0.00002, 0.1147% diff
# qbt freq at osc 9:	0.02165, 	diff to at osc ground 0.00003, 0.1403% diff
# qbt freq at osc 10:	0.02165, 	diff to at osc ground 0.00004, 0.1683% diff
# qbt freq at osc 11:	0.02166, 	diff to at osc ground 0.00004, 0.1987% diff
# qbt freq at osc 12:	0.02167, 	diff to at osc ground 0.00005, 0.2315% diff
# qbt freq at osc 13:	0.02167, 	diff to at osc ground 0.00006, 0.2666% diff
# qbt freq at osc 14:	0.02168, 	diff to at osc ground 0.00007, 0.3040% diff
# qbt freq at osc 15:	0.02169, 	diff to at osc ground 0.00007, 0.3437% diff
# qbt freq at osc 16:	0.02170, 	diff to at osc ground 0.00008, 0.3856% diff
# qbt freq at osc 17:	0.02171, 	diff to at osc ground 0.00009, 0.4298% diff
# qbt freq at osc 18:	0.02172, 	diff to at osc ground 0.00010, 0.4761% diff
# qbt freq at osc 19:	0.02173, 	diff to at osc ground 0.00011, 0.5246% diff
# qbt freq at osc 20:	0.02174, 	diff to at osc ground 0.00012, 0.5753% diff
# qbt freq at osc 21:	0.02175, 	diff to at osc ground 0.00014, 0.6280% diff
# qbt freq at osc 22:	0.02176, 	diff to at osc ground 0.00015, 0.6828% diff
# qbt freq at osc 23:	0.02178, 	diff to at osc ground 0.00016, 0.7397% diff
# qbt freq at osc 24:	0.02179, 	diff to at osc ground 0.00017, 0.7985% diff
# qbt freq at osc 25:	0.02180, 	diff to at osc ground 0.00019, 0.8594% diff
# qbt freq at osc 26:	0.02181, 	diff to at osc ground 0.00020, 0.9221% diff
# qbt freq at osc 27:	0.02183, 	diff to at osc ground 0.00021, 0.9868% diff
# qbt freq at osc 28:	0.02184, 	diff to at osc ground 0.00023, 1.0533% diff
# qbt freq at osc 29:	0.02186, 	diff to at osc ground 0.00024, 1.1216% diff
# qbt freq at osc 30:	0.02187, 	diff to at osc ground 0.00026, 1.1917% diff
# qbt freq at osc 31:	0.02189, 	diff to at osc ground 0.00027, 1.2634% diff
# qbt freq at osc 32:	0.02190, 	diff to at osc ground 0.00029, 1.3369% diff
# qbt freq at osc 33:	0.02192, 	diff to at osc ground 0.00031, 1.4119% diff
# qbt freq at osc 34:	0.02194, 	diff to at osc ground 0.00032, 1.4884% diff
# qbt freq at osc 35:	0.02195, 	diff to at osc ground 0.00034, 1.5663% diff
# qbt freq at osc 36:	0.02197, 	diff to at osc ground 0.00036, 1.6456% diff
# qbt freq at osc 37:	0.02199, 	diff to at osc ground 0.00037, 1.7260% diff
# qbt freq at osc 38:	0.02201, 	diff to at osc ground 0.00039, 1.8076% diff
# qbt freq at osc 39:	0.02202, 	diff to at osc ground 0.00041, 1.8901% diff
# qbt freq at osc 40:	0.02204, 	diff to at osc ground 0.00043, 1.9733% diff
# qbt freq at osc 41:	0.02206, 	diff to at osc ground 0.00044, 2.0570% diff
# qbt freq at osc 42:	0.02208, 	diff to at osc ground 0.00046, 2.1409% diff
# qbt freq at osc 43:	0.02210, 	diff to at osc ground 0.00048, 2.2247% diff
# qbt freq at osc 44:	0.02211, 	diff to at osc ground 0.00050, 2.3078% diff
# qbt freq at osc 45:	0.02213, 	diff to at osc ground 0.00052, 2.3896% diff
# qbt freq at osc 46:	0.02215, 	diff to at osc ground 0.00053, 2.4693% diff
# qbt freq at osc 47:	0.02217, 	diff to at osc ground 0.00055, 2.5455% diff
# qbt freq at osc 48:	0.02218, 	diff to at osc ground 0.00056, 2.6046% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.17269	7.17445	7.17445	7.17384
# oscillator transition 1-2: 	7.17280	7.17445	7.17445	7.17384  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00010739223022593336
# oscillator transition 2-3: 	7.17288	7.17445	7.17445	7.17384  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000191563199207323
# oscillator transition 3-4: 	7.17295	7.17445	7.17445	7.17384  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002597689797294578
# oscillator transition 4-5: 	7.17301	7.17445	7.17445	7.17384  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00031644595132185316
# oscillator transition 5-6: 	7.17306	7.17445	7.17445	7.17384  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00036447954997065324
# oscillator transition 6-7: 	7.17310	7.17445	7.17445	7.17384  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004058382265466065
# oscillator transition 7-8: 	7.17314	7.17444	7.17445	7.17384  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00044191690882477985
# oscillator transition 8-9: 	7.17317	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00047373526397187504
# oscillator transition 9-10: 	7.17320	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005020581555026382
# oscillator transition 10-11: 	7.17322	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005274719852277343
# oscillator transition 11-12: 	7.17324	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005504348321831998
# oscillator transition 12-13: 	7.17326	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005713103843500988
# oscillator transition 13-14: 	7.17328	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005903915211913358
# oscillator transition 14-15: 	7.17330	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006079170738839679
# oscillator transition 15-16: 	7.17332	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000624083982662782
# oscillator transition 16-17: 	7.17333	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006390562764035934
# oscillator transition 17-18: 	7.17335	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006529717998855489
# oscillator transition 18-19: 	7.17336	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006659473436823049
# oscillator transition 19-20: 	7.17337	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000678082596712315
# oscillator transition 20-21: 	7.17338	7.17444	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000689463220671982
# oscillator transition 21-22: 	7.17339	7.17443	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00070016328816358
# oscillator transition 22-23: 	7.17340	7.17443	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007102472122451076
# oscillator transition 23-24: 	7.17341	7.17443	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000719771306043171
# oscillator transition 24-25: 	7.17342	7.17443	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007287850380262029
# oscillator transition 25-26: 	7.17343	7.17443	7.17445	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007373320629167068
# oscillator transition 26-27: 	7.17344	7.17443	7.17444	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007454510704203443
# oscillator transition 27-28: 	7.17345	7.17443	7.17444	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007531764803641039
# oscillator transition 28-29: 	7.17345	7.17443	7.17444	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007605390319920247
# oscillator transition 29-30: 	7.17346	7.17443	7.17444	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007675662689248242
# oscillator transition 30-31: 	7.17347	7.17443	7.17444	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007742829529231443
# oscillator transition 31-32: 	7.17347	7.17443	7.17444	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007807114150661931
# oscillator transition 32-33: 	7.17348	7.17443	7.17444	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007868718492911597
# oscillator transition 33-34: 	7.17349	7.17443	7.17444	7.17385  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007927825680749123
# oscillator transition 34-35: 	7.17349	7.17443	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007984602215369563
# oscillator transition 35-36: 	7.17350	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0008039199839711131
# oscillator transition 36-37: 	7.17350	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0008091757183503745
# oscillator transition 37-38: 	7.17351	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0008142401137458677
# oscillator transition 38-39: 	7.17351	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0008191248154982844
# oscillator transition 39-40: 	7.17352	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0008238405272802396
# oscillator transition 40-41: 	7.26373	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0910351362052122
# oscillator transition 41-42: 	7.17463	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.001937550339951244
# oscillator transition 42-43: 	7.17463	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.001933638417645156
# oscillator transition 43-44: 	7.17462	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0019298617402707663
# oscillator transition 44-45: 	7.17462	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0019262130901918084
# oscillator transition 45-46: 	7.17462	7.17442	7.17444	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.001922685798311008
# oscillator transition 46-47: 	7.17461	7.17442	7.17443	7.17386  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.001919304696505364
# oscillator transition 47-48: 	7.17463	7.17447	7.17448	7.17429  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0019370081611693735
# oscillator transition 48-49: 	7.18362	7.18995	7.19126	7.24285  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.010929523575773814
#
# 10-11: 7.1745, diff to 00-01: 0.0017574249912408746
# 20-21: 7.1745, diff to 00-01: 0.0017585717772004017

# %%
system.qbt.plot_matrixelements(operator = 'n_operator',evals_count = 15)
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

# %%
elements = system.qbt.matrixelement_table(operator="n_operator",evals_count=15)

for i in [1,3,5,7,9,11,13]:
    print(f"{i}-0: {elements[0,i]}")
# Out:
# 1-0: 0.0865397614576715j
# 3-0: 0.5596610034395441j
# 5-0: -0.08845727677113235j
# 7-0: -0.06743576672587895j
# 9-0: -0.022174241970136063j
# 11-0: 0.02347037669455564j
# 13-0: -0.013243825690125745j

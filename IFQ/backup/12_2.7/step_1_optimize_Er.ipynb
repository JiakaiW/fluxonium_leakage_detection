# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *
sys.path = original_sys_path

# %%
EJ = 2.7
EC = 0.6
EL = 0.13

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.18]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 3.647253088899516e-06
#              x: [ 7.191e+00]
#            nit: 13
#           nfev: 27
#  final_simplex: (array([[ 7.191e+00],
#                        [ 7.191e+00]]), array([ 3.647e-06,  3.988e-06]))
# Optimal solution: [7.19095581]
# Objective value: 3.647253088899516e-06

# %%
max_ol = 50
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.17
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states= '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.019032036583070733
# qbt freq at osc 1:	0.01904, 	diff to at osc ground 0.00001, 0.0310% diff
# qbt freq at osc 2:	0.01905, 	diff to at osc ground 0.00001, 0.0753% diff
# qbt freq at osc 3:	0.01906, 	diff to at osc ground 0.00003, 0.1327% diff
# qbt freq at osc 4:	0.01907, 	diff to at osc ground 0.00004, 0.2028% diff
# qbt freq at osc 5:	0.01909, 	diff to at osc ground 0.00005, 0.2852% diff
# qbt freq at osc 6:	0.01910, 	diff to at osc ground 0.00007, 0.3795% diff
# qbt freq at osc 7:	0.01912, 	diff to at osc ground 0.00009, 0.4852% diff
# qbt freq at osc 8:	0.01915, 	diff to at osc ground 0.00011, 0.6017% diff
# qbt freq at osc 9:	0.01917, 	diff to at osc ground 0.00014, 0.7280% diff
# qbt freq at osc 10:	0.01920, 	diff to at osc ground 0.00016, 0.8625% diff
# qbt freq at osc 11:	0.01922, 	diff to at osc ground 0.00019, 1.0026% diff
# qbt freq at osc 12:	0.01925, 	diff to at osc ground 0.00022, 1.1422% diff
# qbt freq at osc 13:	0.01927, 	diff to at osc ground 0.00024, 1.2651% diff
# qbt freq at osc 14:	0.01928, 	diff to at osc ground 0.00025, 1.3023% diff
# qbt freq at osc 15:	0.01909, 	diff to at osc ground 0.00006, 0.3092% diff
# qbt freq at osc 16:	0.01952, 	diff to at osc ground 0.00048, 2.5394% diff
# qbt freq at osc 17:	0.01951, 	diff to at osc ground 0.00048, 2.5093% diff
# qbt freq at osc 18:	0.01954, 	diff to at osc ground 0.00051, 2.6665% diff
# qbt freq at osc 19:	0.01958, 	diff to at osc ground 0.00055, 2.8742% diff
# qbt freq at osc 20:	0.01962, 	diff to at osc ground 0.00059, 3.1074% diff
# qbt freq at osc 21:	0.01967, 	diff to at osc ground 0.00064, 3.3579% diff
# qbt freq at osc 22:	0.01972, 	diff to at osc ground 0.00069, 3.6224% diff
# qbt freq at osc 23:	0.01977, 	diff to at osc ground 0.00074, 3.8990% diff
# qbt freq at osc 24:	0.01983, 	diff to at osc ground 0.00080, 4.1867% diff
# qbt freq at osc 25:	0.01989, 	diff to at osc ground 0.00085, 4.4848% diff
# qbt freq at osc 26:	0.01994, 	diff to at osc ground 0.00091, 4.7928% diff
# qbt freq at osc 27:	0.02000, 	diff to at osc ground 0.00097, 5.1105% diff
# qbt freq at osc 28:	0.02007, 	diff to at osc ground 0.00103, 5.4374% diff
# qbt freq at osc 29:	0.02013, 	diff to at osc ground 0.00110, 5.7734% diff
# qbt freq at osc 30:	0.02020, 	diff to at osc ground 0.00116, 6.1182% diff
# qbt freq at osc 31:	0.02026, 	diff to at osc ground 0.00123, 6.4717% diff
# qbt freq at osc 32:	0.02033, 	diff to at osc ground 0.00130, 6.8337% diff
# qbt freq at osc 33:	0.02040, 	diff to at osc ground 0.00137, 7.2039% diff
# qbt freq at osc 34:	0.02048, 	diff to at osc ground 0.00144, 7.5824% diff
# qbt freq at osc 35:	0.02055, 	diff to at osc ground 0.00152, 7.9689% diff
# qbt freq at osc 36:	0.02062, 	diff to at osc ground 0.00159, 8.3632% diff
# qbt freq at osc 37:	0.02070, 	diff to at osc ground 0.00167, 8.7654% diff
# qbt freq at osc 38:	0.02078, 	diff to at osc ground 0.00175, 9.1751% diff
# qbt freq at osc 39:	0.02086, 	diff to at osc ground 0.00183, 9.5924% diff
# qbt freq at osc 40:	0.02094, 	diff to at osc ground 0.00191, 10.0171% diff
# qbt freq at osc 41:	0.02102, 	diff to at osc ground 0.00199, 10.4491% diff
# qbt freq at osc 42:	0.02110, 	diff to at osc ground 0.00207, 10.8882% diff
# qbt freq at osc 43:	0.02119, 	diff to at osc ground 0.00216, 11.3345% diff
# qbt freq at osc 44:	0.02128, 	diff to at osc ground 0.00224, 11.7877% diff
# qbt freq at osc 45:	0.02136, 	diff to at osc ground 0.00233, 12.2478% diff
# qbt freq at osc 46:	0.02145, 	diff to at osc ground 0.00242, 12.7146% diff
# qbt freq at osc 47:	0.02154, 	diff to at osc ground 0.00251, 13.1865% diff
# qbt freq at osc 48:	0.02162, 	diff to at osc ground 0.00259, 13.5860% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.18973	7.19226	7.19227	7.19074
# oscillator transition 1-2: 	7.18979	7.19226	7.19226	7.19074  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 6.399898244957569e-05
# oscillator transition 2-3: 	7.18984	7.19225	7.19226	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00011796732633140294
# oscillator transition 3-4: 	7.18989	7.19225	7.19226	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00016421742793593097
# oscillator transition 4-5: 	7.18993	7.19224	7.19226	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002043895464565182
# oscillator transition 5-6: 	7.18997	7.19224	7.19226	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00023968264626628155
# oscillator transition 6-7: 	7.19000	7.19224	7.19226	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00027099535390018303
# oscillator transition 7-8: 	7.19002	7.19223	7.19225	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00029901563885115223
# oscillator transition 8-9: 	7.19005	7.19223	7.19225	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00032427987691985294
# oscillator transition 9-10: 	7.19007	7.19223	7.19225	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003472129146961933
# oscillator transition 10-11: 	7.19009	7.19222	7.19225	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003681559536721224
# oscillator transition 11-12: 	7.19011	7.19222	7.19224	7.19077  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0003873863901935337
# oscillator transition 12-13: 	7.19013	7.19221	7.19224	7.19077  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.
# %%
import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *

# %%
ql = 20
ol = 30
system = fluxonium_oscillator_system(
    EJ = 2.33,
    EC = 0.69,
    EL = 0.12,
    Er = 7.16518677,
    g_strength = 0.18,
    qubit_level = ql,
    osc_level = ol,
    kappa = 0.0005,
    products_to_keep=[[ql, ol] for ql in [1,2] for ol in range(25) ],
    computaional_states = '1,2',
    w_d = 7.16475
    )

tot_time =733 + 20
tlist = np.linspace(0, tot_time, tot_time)

# %%
system.qbt.plot_matrixelements('n_operator')
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

# %%
evals = system.qbt.eigenvals()
freq = (evals[2] - evals[1])

freq
# Out:
# 0.04352235073997557

# %% [markdown]
# # 1 load result, truncate to 2-level

# %%
with open('../pickles/mesolve_temp_kappa1em3.pkl', 'rb') as file:
    results1 = pickle.load(file)

with open('../pickles/mesolve_temp_kappa5em4.pkl', 'rb') as file:
    results2 = pickle.load(file)

# %%
plt.plot(results1[0].expect[0],color = 'red')
plt.plot(results1[1].expect[0],color = 'red')

plt.plot(results2[0].expect[0],color = 'blue')
plt.plot(results2[1].expect[0],color = 'blue')

# plt.ylim(0,0.1)

# %%
plt.plot(results1[0].expect[0],color = 'red')
plt.plot(results1[1].expect[0],color = 'red')

plt.plot(results2[0].expect[0],color = 'blue')
plt.plot(results2[1].expect[0],color = 'blue')

plt.ylim(0,0.1)
# Out:
# (0.0, 0.1)

# %%
from tqdm.notebook import tqdm
for result in [results1[0],results1[1],results2[0],results2[1]]:
    result.twolevel_states = [dressed_to_2_level_dm(state, 
                                                    system.product_to_dressed, 
                                                    system.qbt.truncated_dim,
                                                    system.osc.truncated_dim,
                                                    system.computaional_states[0],
                                                    system.computaional_states[1],
                                                    products_to_keep=None)
                               for state in tqdm(result.states, desc=f"Processing states with {dressed_to_2_level_dm.__name__}")]
# Out:
# Processing states with dressed_to_2_level_dm:   0%|          | 0/753 [00:00<?, ?it/s]
# Processing states with dressed_to_2_level_dm:   0%|          | 0/753 [00:00<?, ?it/s]
# Processing states with dressed_to_2_level_dm:   0%|          | 0/753 [00:00<?, ?it/s]
# Processing states with dressed_to_2_level_dm:   0%|          | 0/753 [00:00<?, ?it/s]

# %%
# with open('../pickles/mesolve_temp_kappa1em3_results1_2_level.pkl', 'wb') as file:
#     pickle.dump(results1, file)

# with open('../pickles/mesolve_temp_kappa1em3_results2_2_level.pkl', 'wb') as file:
#     pickle.dump(results2, file)

# %%
with open('../pickles/mesolve_temp_kappa1em3_results1_2_level.pkl', 'rb') as file:
    results1 = pickle.load(file)
with open('../pickles/mesolve_temp_kappa1em3_results2_2_level.pkl', 'rb') as file:
    results2 = pickle.load(file)

# %%
zero = qutip.basis(2, 0)
one = qutip.basis(2, 1)


states_ideal  = [(zero +  one).unit(),
                (zero - one).unit(), ]

def calc_average_fidelity_with_phase(phase,dms,states_ideal):
    gate = qutip.qip.operations.phasegate(phase)
    fid=[]
    for dm,dm_ideal in zip(dms,states_ideal):
        # new_dm = gate*dm*gate.dag()
        # fid.append(qutip.fidelity(new_dm, dm_ideal))
        fid.append(qutip.fidelity(dm, gate*dm_ideal))
    return 1-sum(fid)/len(fid)

results = results1
infidelity = []
for idx in range(tot_time):
    phase = -results[0].times[idx] * freq * (2 *np.pi)
    dms = [result.twolevel_states[idx] for result in results]    
    infidelity.append(calc_average_fidelity_with_phase(phase, dms, states_ideal))
results = results2
infidelity2 = []
for idx in range(tot_time):
    phase = -results[0].times[idx] * freq * (2 *np.pi)
    dms = [result.twolevel_states[idx] for result in results]    
    infidelity2.append(calc_average_fidelity_with_phase(phase, dms, states_ideal))

plt.plot(results[0].times,infidelity,label = rf"infidelity with $kappa=10^{-3}$")
plt.plot(results[0].times,infidelity2,label = rf"infidelity with $kappa=5\times 10^{-4}$")


plt.grid(which='major', linestyle='-', linewidth='0.5', color='black')
plt.minorticks_on()
plt.gca().xaxis.grid(False, which='minor')
plt.grid(which='minor', linestyle='--', linewidth='0.5', color='gray', axis='y') # Specify axis='y' for y-axis minor grid

plt.legend()
plt.yscale('log')
plt.title("averaged infidelity of computational subspace \n during three-outcome leakage detection")
plt.xlabel("ns")
# Out:
# Text(0.5, 0, 'ns')

# %%
results = results1

zero = qutip.basis(2, 0)
one = qutip.basis(2, 1)


states_ideal  = [(zero +  one).unit(),
                (zero - one).unit(), ]


def calc_average_fidelity_with_phase(phase,dms,states_ideal):
    gate = qutip.qip.operations.phasegate(phase)
    fid=[]
    for dm,dm_ideal in zip(dms,states_ideal):
        # new_dm = gate*dm*gate.dag()
        # fid.append(qutip.fidelity(new_dm, dm_ideal))
        fid.append(qutip.fidelity(dm, gate*dm_ideal))
    return 1-sum(fid)/len(fid)


from scipy.optimize import minimize

infidelity = []
phase = []
for idx in range(tot_time):
    dms = [result.twolevel_states[idx] for result in results]
    def objective_function(phase):
        return calc_average_fidelity_with_phase(phase[0], dms, states_ideal)
    initial_phase = [0.0]
    bounds = [(0, 2 * 3.141592653589793)]
    opt_result = minimize(objective_function, initial_phase,method="COBYLA")
    infidelity.append(opt_result.fun)
    phase.append(opt_result.x[0])
results = results2

infidelity2 = []
phase2 = []
for idx in range(tot_time):
    dms = [result.twolevel_states[idx] for result in results]
    def objective_function(phase):
        return calc_average_fidelity_with_phase(phase[0], dms, states_ideal)
    initial_phase = [0.0]
    bounds = [(0, 2 * 3.141592653589793)]
    opt_result = minimize(objective_function, initial_phase,method="COBYLA")
    infidelity2.append(opt_result.fun)
    phase2.append(opt_result.x[0])

plt.plot(results[0].times,infidelity,label = rf"infidelity with $kappa=10^{-3}$")
# plt.plot(results[0].times,phase,label = rf"phase $kappa=10^{-3}$")
plt.plot(results[0].times,infidelity2,label = rf"infidelity with $kappa=5\times 10^{-4}$")
# plt.plot(results[0].times,phase2,label = rf"phase $kappa=10^{-3}$")


plt.grid(which='major', linestyle='-', linewidth='0.5', color='black')
plt.minorticks_on()
plt.gca().xaxis.grid(False, which='minor')
plt.grid(which='minor', linestyle='--', linewidth='0.5', color='gray', axis='y') # Specify axis='y' for y-axis minor grid

plt.legend()
# plt.yscale('log')
plt.title("averaged infidelity of computational subspace \n during three-outcome leakage detection")
plt.xlabel("ns")
# Out:
# Text(0.5, 0, 'ns')

# %%
idx = 720
qutip.qip.operations.phasegate(-phase[idx]) * results[0].twolevel_states[idx] * qutip.qip.operations.phasegate(-phase[idx]).dag()
# Out:
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[0.49999995+0.j         0.49655988+0.00868516j]
#  [0.49655988-0.00868516j 0.50000005+0.j        ]]

# %%
qutip.qip.operations.phasegate(-phase[idx]) * results[1].twolevel_states[idx] * qutip.qip.operations.phasegate(-phase[idx]).dag()
# Out:
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.50000006+0.j         -0.49656378-0.00867785j]
#  [-0.49656378+0.00867785j  0.49999994+0.j        ]]

# %%
with open('../pickles/sesolve_threeoutcome_reference_states_g0.18_2.33.pkl', 'rb') as file:
    results_combined = pickle.load(file)
results = [results_combined[2],results_combined[3]]
num_time_steps = len(results[0].times)
infidelity = []
phase = []
for idx in tqdm(range(num_time_steps), desc='Processing'):
    dms = [result.states[idx] for result in results]
    def objective_function(phase):
        return calc_average_fidelity_with_phase(phase[0], dms, states_ideal)
    initial_phase = [0.0]
    bounds = [(0, 2 * 3.141592653589793)]
    opt_result = minimize(objective_function, initial_phase,method="COBYLA")
    infidelity.append(opt_result.fun)
    phase.append(opt_result.x[0])


plt.plot(results[0].times,infidelity,label = rf"infidelity with $kappa=10^{-3}$")


plt.grid(which='major', linestyle='-', linewidth='0.5', color='black')
plt.minorticks_on()
plt.gca().xaxis.grid(False, which='minor')
plt.grid(which='minor', linestyle='--', linewidth='0.5', color='gray', axis='y') # Specify axis='y' for y-axis minor grid

plt.legend()
plt.yscale('log')
plt.title("averaged infidelity of computational subspace \n during three-outcome leakage detection")
plt.xlabel("ns")
# Out:
# Processing:   0%|          | 0/733 [00:00<?, ?it/s]
# Text(0.5, 0, 'ns')

# %%
with open('../pickles/sesolve_threeoutcome_reference_states_g0.18_2.33.pkl', 'rb') as file:
    results_combined = pickle.load(file)
results = [results_combined[2],results_combined[3]]
num_time_steps = len(results[0].times)
infidelity = []
phase = []
for idx in tqdm(range(num_time_steps), desc='Processing'):
    phase = -results[0].times[idx] * freq * (2 *np.pi)
    dms = [result.states[idx] for result in results]    
    infidelity.append(calc_average_fidelity_with_phase(phase, dms, states_ideal))


plt.plot(results[0].times,infidelity,label = rf"infidelity with $kappa=10^{-3}$")


plt.grid(which='major', linestyle='-', linewidth='0.5', color='black')
plt.minorticks_on()
plt.gca().xaxis.grid(False, which='minor')
plt.grid(which='minor', linestyle='--', linewidth='0.5', color='gray', axis='y') # Specify axis='y' for y-axis minor grid

plt.legend()
plt.yscale('log')
plt.title("averaged infidelity of computational subspace \n during three-outcome leakage detection")
plt.xlabel("ns")
# Out:
# Processing:   0%|          | 0/733 [00:00<?, ?it/s]
# Text(0.5, 0, 'ns')

# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *

# %%
EJ = 2.3
EC = 0.69
EL = 0.12

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.15]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2.4287034762218718e-05
#              x: [ 6.792e+00]
#            nit: 14
#           nfev: 31
#  final_simplex: (array([[ 6.792e+00],
#                        [ 6.792e+00]]), array([ 2.429e-05,  3.412e-05]))
# Optimal solution: [6.79223816]
# Objective value: 2.4287034762218718e-05

# %%
max_ol = 50
max_ql = 25
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.14
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.001,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  (non-linearity on qbt 0): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}  (non-linearity on qbt 3): {(dressed_ener(3,i+1)-dressed_ener(3,i))  -(dressed_ener(3,1)-dressed_ener(3,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}, diff to 30-31: {abs((dressed_ener(3,1)-dressed_ener(3,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
# plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.046380952743962256
# qbt freq at osc 1:	0.04641, 	diff to at osc ground 0.00003, 0.0689% diff
# qbt freq at osc 2:	0.04645, 	diff to at osc ground 0.00007, 0.1501% diff
# qbt freq at osc 3:	0.04649, 	diff to at osc ground 0.00011, 0.2421% diff
# qbt freq at osc 4:	0.04654, 	diff to at osc ground 0.00016, 0.3435% diff
# qbt freq at osc 5:	0.04659, 	diff to at osc ground 0.00021, 0.4534% diff
# qbt freq at osc 6:	0.04665, 	diff to at osc ground 0.00026, 0.5707% diff
# qbt freq at osc 7:	0.04670, 	diff to at osc ground 0.00032, 0.6946% diff
# qbt freq at osc 8:	0.04676, 	diff to at osc ground 0.00038, 0.8243% diff
# qbt freq at osc 9:	0.04683, 	diff to at osc ground 0.00044, 0.9591% diff
# qbt freq at osc 10:	0.04689, 	diff to at osc ground 0.00051, 1.0986% diff
# qbt freq at osc 11:	0.04696, 	diff to at osc ground 0.00058, 1.2420% diff
# qbt freq at osc 12:	0.04703, 	diff to at osc ground 0.00064, 1.3891% diff
# qbt freq at osc 13:	0.04709, 	diff to at osc ground 0.00071, 1.5393% diff
# qbt freq at osc 14:	0.04717, 	diff to at osc ground 0.00078, 1.6923% diff
# qbt freq at osc 15:	0.04724, 	diff to at osc ground 0.00086, 1.8477% diff
# qbt freq at osc 16:	0.04731, 	diff to at osc ground 0.00093, 2.0051% diff
# qbt freq at osc 17:	0.04738, 	diff to at osc ground 0.00100, 2.1644% diff
# qbt freq at osc 18:	0.04746, 	diff to at osc ground 0.00108, 2.3251% diff
# qbt freq at osc 19:	0.04753, 	diff to at osc ground 0.00115, 2.4871% diff
# qbt freq at osc 20:	0.04761, 	diff to at osc ground 0.00123, 2.6501% diff
# qbt freq at osc 21:	0.04769, 	diff to at osc ground 0.00131, 2.8139% diff
# qbt freq at osc 22:	0.04776, 	diff to at osc ground 0.00138, 2.9782% diff
# qbt freq at osc 23:	0.04784, 	diff to at osc ground 0.00146, 3.1430% diff
# qbt freq at osc 24:	0.04792, 	diff to at osc ground 0.00153, 3.3079% diff
# qbt freq at osc 25:	0.04799, 	diff to at osc ground 0.00161, 3.4729% diff
# qbt freq at osc 26:	0.04807, 	diff to at osc ground 0.00169, 3.6377% diff
# qbt freq at osc 27:	0.04814, 	diff to at osc ground 0.00176, 3.8023% diff
# qbt freq at osc 28:	0.04822, 	diff to at osc ground 0.00184, 3.9664% diff
# qbt freq at osc 29:	0.04830, 	diff to at osc ground 0.00192, 4.1299% diff
# qbt freq at osc 30:	0.04837, 	diff to at osc ground 0.00199, 4.2928% diff
# qbt freq at osc 31:	0.04845, 	diff to at osc ground 0.00207, 4.4548% diff
# qbt freq at osc 32:	0.04852, 	diff to at osc ground 0.00214, 4.6158% diff
# qbt freq at osc 33:	0.04860, 	diff to at osc ground 0.00222, 4.7757% diff
# qbt freq at osc 34:	0.04867, 	diff to at osc ground 0.00229, 4.9345% diff
# qbt freq at osc 35:	0.04874, 	diff to at osc ground 0.00236, 5.0919% diff
# qbt freq at osc 36:	0.04881, 	diff to at osc ground 0.00243, 5.2479% diff
# qbt freq at osc 37:	0.04889, 	diff to at osc ground 0.00251, 5.4024% diff
# qbt freq at osc 38:	0.04896, 	diff to at osc ground 0.00258, 5.5553% diff
# qbt freq at osc 39:	0.04903, 	diff to at osc ground 0.00265, 5.7064% diff
# qbt freq at osc 40:	0.04910, 	diff to at osc ground 0.00272, 5.8557% diff
# qbt freq at osc 41:	0.04917, 	diff to at osc ground 0.00278, 6.0031% diff
# qbt freq at osc 42:	0.04923, 	diff to at osc ground 0.00285, 6.1485% diff
# qbt freq at osc 43:	0.04930, 	diff to at osc ground 0.00292, 6.2917% diff
# qbt freq at osc 44:	0.04936, 	diff to at osc ground 0.00298, 6.4328% diff
# qbt freq at osc 45:	0.04943, 	diff to at osc ground 0.00305, 6.5716% diff
# qbt freq at osc 46:	0.04949, 	diff to at osc ground 0.00311, 6.7080% diff
# qbt freq at osc 47:	0.04955, 	diff to at osc ground 0.00317, 6.8417% diff
# qbt freq at osc 48:	0.04961, 	diff to at osc ground 0.00323, 6.9714% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	6.79287	6.79301	6.79304	6.79230
# oscillator transition 1-2: 	6.79287	6.79300	6.79304	6.79230  (non-linearity on qbt 0): -1.0926355029639012e-06  (non-linearity on qbt 3): -3.363911780240869e-07
# oscillator transition 2-3: 	6.79287	6.79300	6.79304	6.79230  (non-linearity on qbt 0): -2.1879041014472023e-06  (non-linearity on qbt 3): -6.696953143148221e-07
# oscillator transition 3-4: 	6.79287	6.79299	6.79304	6.79230  (non-linearity on qbt 0): -3.2858172200889157e-06  (non-linearity on qbt 3): -9.99918851718462e-07
# oscillator transition 4-5: 	6.79286	6.79299	6.79304	6.79230  (non-linearity on qbt 0): -4.386384803822807e-06  (non-linearity on qbt 3): -1.3270672116760807e-06
# oscillator transition 5-6: 	6.79286	6.79298	6.79303	6.79230  (non-linearity on qbt 0): -5.489616912157658e-06  (non-linearity on qbt 3): -1.6511480982472904e-06
# oscillator transition 6-7: 	6.79286	6.79298	6.79303	6.79230  (non-linearity on qbt 0): -6.5955237449344395e-06  (non-linearity on qbt 3): -1.972166687735921e-06
# oscillator transition 7-8: 	6.79286	6.79297	6.79303	6.79230  (non-linearity on qbt 0): -7.704115953188762e-06  (non-linearity on qbt 3): -2.2901300003042024e-06
# oscillator transition 8-9: 	6.79286	6.79297	6.79303	6.79230  (non-linearity on qbt 0): -8.81540274555448e-06  (non-linearity on qbt 3): -2.6050439831948324e-06
# oscillator transition 9-10: 	6.79286	6.79296	6.79303	6.79230  (non-linearity on qbt 0): -9.929394702012928e-06  (non-linearity on qbt 3): -2.9169151449792707e-06
# oscillator transition 10-11: 	6.79286	6.79296	6.79303	6.79230  (non-linearity on qbt 0): -1.1046102111222922e-05  (non-linearity on qbt 3): -3.2257497313281647e-06
# oscillator transition 11-12: 	6.79286	6.79296	6.79302	6.79230  (non-linearity on qbt 0): -1.2165534593933103e-05  (non-linearity on qbt 3): -3.531554137126136e-06
# oscillator transition 12-13: 	6.79286	6.79295	6.79302	6.79230  (non-linearity on qbt 0): -1.3287702012476643e-05  (non-linearity on qbt 3): -3.8343353683245596e-06
# oscillator transition 13-14: 	6.79285	6.79295	6.79302	6.79230  (non-linearity on qbt 0): -1.4412614399716972e-05  (non-linearity on qbt 3): -4.134098427144295e-06
# oscillator transition 14-15: 	6.79285	6.79295	6.79302	6.79230  (non-linearity on qbt 0): -1.55402818879935e-05  (non-linearity on qbt 3): -4.4308510727120165e-06
# oscillator transition 15-16: 	6.79285	6.79294	6.79302	6.79230  (non-linearity on qbt 0): -1.667071421174171e-05  (non-linearity on qbt 3): -4.724599174110722e-06
# oscillator transition 16-17: 	6.79285	6.79294	6.79301	6.79230  (non-linearity on qbt 0): -1.7803920522752037e-05  (non-linearity on qbt 3): -5.01534899832734e-06
# oscillator transition 17-18: 	6.79285	6.79294	6.79301	6.79230  (non-linearity on qbt 0): -1.8939911507587226e-05  (non-linearity on qbt 3): -5.3031073949938445e-06
# oscillator transition 18-19: 	6.79285	6.79294	6.79301	6.79230  (non-linearity on qbt 0): -2.0078695778025235e-05  (non-linearity on qbt 3): -5.587880503199472e-06
# oscillator transition 19-20: 	6.79285	6.79293	6.79301	6.79230  (non-linearity on qbt 0): -2.1220283850098554e-05  (non-linearity on qbt 3): -5.869674575720296e-06
# oscillator transition 20-21: 	6.79285	6.79293	6.79301	6.79230  (non-linearity on qbt 0): -2.2364685117182148e-05  (non-linearity on qbt 3): -6.148496206392906e-06
# oscillator transition 21-22: 	6.79285	6.79293	6.79301	6.79230  (non-linearity on qbt 0): -2.351190883054244e-05  (non-linearity on qbt 3): -6.424353509615344e-06
# oscillator transition 22-23: 	6.79284	6.79293	6.79300	6.79230  (non-linearity on qbt 0): -2.466196422723499e-05  (non-linearity on qbt 3): -6.697249611775646e-06
# oscillator transition 23-24: 	6.79284	6.79292	6.79300	6.79230  (non-linearity on qbt 0): -2.5814861510653486e-05  (non-linearity on qbt 3): -6.967193266760319e-06
# oscillator transition 24-25: 	6.79284	6.79292	6.79300	6.79230  (non-linearity on qbt 0): -2.697060866729828e-05  (non-linearity on qbt 3): -7.234191238936205e-06
# oscillator transition 25-26: 	6.79284	6.79292	6.79300	6.79230  (non-linearity on qbt 0): -2.812921666794921e-05  (non-linearity on qbt 3): -7.498248985271516e-06
# oscillator transition 26-27: 	6.79284	6.79292	6.79300	6.79230  (non-linearity on qbt 0): -2.9290693356998077e-05  (non-linearity on qbt 3): -7.759373525928481e-06
# oscillator transition 27-28: 	6.79284	6.79292	6.79299	6.79230  (non-linearity on qbt 0): -3.0455048284139252e-05  (non-linearity on qbt 3): -8.017571511587107e-06
# oscillator transition 28-29: 	6.79284	6.79292	6.79299	6.79230  (non-linearity on qbt 0): -3.162229082853685e-05  (non-linearity on qbt 3): -8.27284910975834e-06
# oscillator transition 29-30: 	6.79284	6.79291	6.79299	6.79229  (non-linearity on qbt 0): -3.279242951670369e-05  (non-linearity on qbt 3): -8.525212942700477e-06
# oscillator transition 30-31: 	6.79283	6.79291	6.79299	6.79229  (non-linearity on qbt 0): -3.3965472818309195e-05  (non-linearity on qbt 3): -8.774670172684296e-06
# oscillator transition 31-32: 	6.79283	6.79291	6.79299	6.79229  (non-linearity on qbt 0): -3.514143105043388e-05  (non-linearity on qbt 3): -9.021225915617492e-06
# oscillator transition 32-33: 	6.79283	6.79291	6.79298	6.79229  (non-linearity on qbt 0): -3.632031197220442e-05  (non-linearity on qbt 3): -9.264889067495119e-06
# oscillator transition 33-34: 	6.79283	6.79291	6.79298	6.79229  (non-linearity on qbt 0): -3.750212419539878e-05  (non-linearity on qbt 3): -9.505663578934787e-06
# oscillator transition 34-35: 	6.79283	6.79291	6.79298	6.79229  (non-linearity on qbt 0): -3.868687604757781e-05  (non-linearity on qbt 3): -9.74355865857035e-06
# oscillator transition 35-36: 	6.79283	6.79290	6.79298	6.79229  (non-linearity on qbt 0): -3.987457699317076e-05  (non-linearity on qbt 3): -9.97857885387532e-06
# oscillator transition 36-37: 	6.79283	6.79290	6.79297	6.79229  (non-linearity on qbt 0): -4.1065235359738494e-05  (non-linearity on qbt 3): -1.0210732208193463e-05
# oscillator transition 37-38: 	6.79283	6.79290	6.79297	6.79229  (non-linearity on qbt 0): -4.2258857712695885e-05  (non-linearity on qbt 3): -1.0440024405866666e-05
# oscillator transition 38-39: 	6.79283	6.79290	6.79297	6.79229  (non-linearity on qbt 0): -4.3455455534413545e-05  (non-linearity on qbt 3): -1.0666462495478868e-05
# oscillator transition 39-40: 	6.79282	6.79290	6.79297	6.79229  (non-linearity on qbt 0): -4.465503442396823e-05  (non-linearity on qbt 3): -1.0890053241396913e-05
# oscillator transition 40-41: 	6.79282	6.79290	6.79297	6.79229  (non-linearity on qbt 0): -4.585760100361824e-05  (non-linearity on qbt 3): -1.1110802839553457e-05
# oscillator transition 41-42: 	6.79282	6.79290	6.79296	6.79229  (non-linearity on qbt 0): -4.706316772207231e-05  (non-linearity on qbt 3): -1.1328718679592953e-05
# oscillator transition 42-43: 	6.79282	6.79289	6.79296	6.79229  (non-linearity on qbt 0): -4.8271739638394706e-05  (non-linearity on qbt 3): -1.1543807639569081e-05
# oscillator transition 43-44: 	6.79282	6.79289	6.79296	6.79229  (non-linearity on qbt 0): -4.948332471066408e-05  (non-linearity on qbt 3): -1.175607483538954e-05
# oscillator transition 44-45: 	6.79282	6.79289	6.79296	6.79229  (non-linearity on qbt 0): -5.069792947587359e-05  (non-linearity on qbt 3): -1.1965516458545267e-05
# oscillator transition 45-46: 	6.79282	6.79289	6.79295	6.79229  (non-linearity on qbt 0): -5.1914863570701186e-05  (non-linearity on qbt 3): -1.2164619400678589e-05
# oscillator transition 46-47: 	6.79282	6.79289	6.79295	6.79229  (non-linearity on qbt 0): -5.27816003117465e-05  (non-linearity on qbt 3): -9.125241868801481e-06
# oscillator transition 47-48: 	6.79294	6.79300	6.79306	6.79320  (non-linearity on qbt 0): 6.825556724798787e-05  (non-linearity on qbt 3): 0.0008999839158914114
# oscillator transition 48-49: 	6.81790	6.81433	6.81690	6.89194  (non-linearity on qbt 0): 0.025027474748616996  (non-linearity on qbt 3): 0.09963236801362108
#
# 10-11: 6.7930, diff to 00-01: 0.0001428371974352416, diff to 30-31: 0.0007084415311791048
# 20-21: 6.7930, diff to 00-01: 0.00017478108824953154, diff to 30-31: 0.0007403854219933947

# %%
import sys
sys.path.append('../')
from utils_models import *

w_d = 7.1648
def plot_frequencies_qbt_osc(dressed_ener: Callable, ols):
    colors = ['green', 'red', 'blue', 'orange']

    # Create a figure and a set of subplots
    fig, axs = plt.subplots(1, 2, figsize=(8, 4))  # Adjusted for better spacing

    # Second subplot for oscillator frequencies
    for ql in [0, 1, 2, 3]:
        osc_energies = []
        for ol in range(0, ols - 8):
            osc_energies.append(dressed_ener(ql, ol + 1) - dressed_ener(ql, ol))
        axs[0].plot(list(range(ols - 8)), osc_energies, label=f'{ql}', color=colors[ql])
    
    axs[0].plot([0,50],[w_d,w_d])

    axs[0].set_title('Oscillator Frequency vs Oscillator Level')
    axs[0].legend()



    qbt_energies = []
    for ol in range(ols-8):
        qbt_energies.append(dressed_ener(2, ol) - dressed_ener(1, ol))
    axs[1].plot(list(range(ols-8)), qbt_energies, label=f'qbt_freq', color=colors[ql])
    axs[1].set_title('Qbt Frequency vs Oscillator Level')
    axs[1].legend()

    # Show the plots
    plt.tight_layout()  # Adjust the layout to make room for the legend
    plt.show()
    
    
ql = 20
max_ol = 60

system = FluxoniumOscillatorSystem(
    computaional_states = '1,2',
    EJ = 2.33,
    EC = 0.69,
    EL = 0.12,
    Er = 7.16518677 ,
    qubit_level = ql,
    osc_level = max_ol,
    g_strength = 0.18,
    products_to_keep=[[ql,ol] for ql in [0,1,2,3] for ol in range(max_ol)] 
    )


energies=  system.hilbertspace.eigenvals(system.qbt.truncated_dim * system.osc.truncated_dim )


def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]


ols = system.osc.truncated_dim

plot_frequencies_qbt_osc(dressed_ener, ols)

# %%
dressed_ener(0,1)-dressed_ener(0,0)
# Out:
# 7.164739955739689

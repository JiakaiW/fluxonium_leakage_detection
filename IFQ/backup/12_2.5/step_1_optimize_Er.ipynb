# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *
sys.path = original_sys_path

# %%
EJ = 2.5
EC = 0.6
EL = 0.13

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.12]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 4.055586878860817e-06
#              x: [ 7.118e+00]
#            nit: 13
#           nfev: 28
#  final_simplex: (array([[ 7.118e+00],
#                        [ 7.118e+00]]), array([ 4.056e-06,  7.846e-06]))
# Optimal solution: [7.11774023]
# Objective value: 4.055586878860817e-06

# %%
max_ol = 50
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.17
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states= '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.03178175464250832
# qbt freq at osc 1:	0.03179, 	diff to at osc ground 0.00001, 0.0330% diff
# qbt freq at osc 2:	0.03181, 	diff to at osc ground 0.00003, 0.0838% diff
# qbt freq at osc 3:	0.03183, 	diff to at osc ground 0.00005, 0.1516% diff
# qbt freq at osc 4:	0.03186, 	diff to at osc ground 0.00007, 0.2357% diff
# qbt freq at osc 5:	0.03189, 	diff to at osc ground 0.00011, 0.3357% diff
# qbt freq at osc 6:	0.03193, 	diff to at osc ground 0.00014, 0.4508% diff
# qbt freq at osc 7:	0.03197, 	diff to at osc ground 0.00018, 0.5807% diff
# qbt freq at osc 8:	0.03201, 	diff to at osc ground 0.00023, 0.7248% diff
# qbt freq at osc 9:	0.03206, 	diff to at osc ground 0.00028, 0.8825% diff
# qbt freq at osc 10:	0.03212, 	diff to at osc ground 0.00033, 1.0535% diff
# qbt freq at osc 11:	0.03217, 	diff to at osc ground 0.00039, 1.2373% diff
# qbt freq at osc 12:	0.03224, 	diff to at osc ground 0.00046, 1.4336% diff
# qbt freq at osc 13:	0.03230, 	diff to at osc ground 0.00052, 1.6418% diff
# qbt freq at osc 14:	0.03237, 	diff to at osc ground 0.00059, 1.8617% diff
# qbt freq at osc 15:	0.03245, 	diff to at osc ground 0.00067, 2.0928% diff
# qbt freq at osc 16:	0.03252, 	diff to at osc ground 0.00074, 2.3349% diff
# qbt freq at osc 17:	0.03260, 	diff to at osc ground 0.00082, 2.5876% diff
# qbt freq at osc 18:	0.03269, 	diff to at osc ground 0.00091, 2.8505% diff
# qbt freq at osc 19:	0.03277, 	diff to at osc ground 0.00099, 3.1234% diff
# qbt freq at osc 20:	0.03286, 	diff to at osc ground 0.00108, 3.4060% diff
# qbt freq at osc 21:	0.03296, 	diff to at osc ground 0.00118, 3.6980% diff
# qbt freq at osc 22:	0.03305, 	diff to at osc ground 0.00127, 3.9991% diff
# qbt freq at osc 23:	0.03315, 	diff to at osc ground 0.00137, 4.3090% diff
# qbt freq at osc 24:	0.03325, 	diff to at osc ground 0.00147, 4.6275% diff
# qbt freq at osc 25:	0.03336, 	diff to at osc ground 0.00157, 4.9543% diff
# qbt freq at osc 26:	0.03346, 	diff to at osc ground 0.00168, 5.2891% diff
# qbt freq at osc 27:	0.03357, 	diff to at osc ground 0.00179, 5.6316% diff
# qbt freq at osc 28:	0.03368, 	diff to at osc ground 0.00190, 5.9817% diff
# qbt freq at osc 29:	0.03380, 	diff to at osc ground 0.00201, 6.3390% diff
# qbt freq at osc 30:	0.03391, 	diff to at osc ground 0.00213, 6.7032% diff
# qbt freq at osc 31:	0.03403, 	diff to at osc ground 0.00225, 7.0741% diff
# qbt freq at osc 32:	0.03415, 	diff to at osc ground 0.00237, 7.4514% diff
# qbt freq at osc 33:	0.03427, 	diff to at osc ground 0.00249, 7.8348% diff
# qbt freq at osc 34:	0.03440, 	diff to at osc ground 0.00261, 8.2239% diff
# qbt freq at osc 35:	0.03452, 	diff to at osc ground 0.00274, 8.6184% diff
# qbt freq at osc 36:	0.03465, 	diff to at osc ground 0.00287, 9.0178% diff
# qbt freq at osc 37:	0.03478, 	diff to at osc ground 0.00299, 9.4217% diff
# qbt freq at osc 38:	0.03491, 	diff to at osc ground 0.00312, 9.8295% diff
# qbt freq at osc 39:	0.03504, 	diff to at osc ground 0.00325, 10.2406% diff
# qbt freq at osc 40:	0.03517, 	diff to at osc ground 0.00339, 10.6543% diff
# qbt freq at osc 41:	0.03530, 	diff to at osc ground 0.00352, 11.0695% diff
# qbt freq at osc 42:	0.03543, 	diff to at osc ground 0.00365, 11.4849% diff
# qbt freq at osc 43:	0.03556, 	diff to at osc ground 0.00378, 11.8990% diff
# qbt freq at osc 44:	0.03569, 	diff to at osc ground 0.00391, 12.3095% diff
# qbt freq at osc 45:	0.03582, 	diff to at osc ground 0.00404, 12.7133% diff
# qbt freq at osc 46:	0.03595, 	diff to at osc ground 0.00417, 13.1059% diff
# qbt freq at osc 47:	0.03607, 	diff to at osc ground 0.00428, 13.4783% diff
# qbt freq at osc 48:	0.03612, 	diff to at osc ground 0.00434, 13.6621% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.12154	7.11892	7.11893	7.11769
# oscillator transition 1-2: 	7.12111	7.11892	7.11893	7.11770  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0004213361027156637
# oscillator transition 2-3: 	7.12083	7.11891	7.11893	7.11770  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.000710289562942279
# oscillator transition 3-4: 	7.12061	7.11890	7.11893	7.11770  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0009239090124282257
# oscillator transition 4-5: 	7.12045	7.11890	7.11893	7.11770  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0010898527376319578
# oscillator transition 5-6: 	7.12031	7.11889	7.11893	7.11771  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0012233843924356336
# oscillator transition 6-7: 	7.12020	7.11889	7.11893	7.11771  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0013337098825978444
# oscillator transition 7-8: 	7.12011	7.11888	7.11892	7.11771  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0014267549213009545
# oscillator transition 8-9: 	7.12003	7.11887	7.11892	7.11771  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0015065289643878543
# oscillator transition 9-10: 	7.11996	7.11887	7.11892	7.11771  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0015758543146766613
# oscillator transition 10-11: 	7.11990	7.11886	7.11892	7.11772  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0016367825214622655
# oscillator transition 11-12: 	7.11985	7.11886	7.11892	7.11772  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0016908451676478364
# oscillator transition 12-13: 	7.11980	7.11885	7.11892	7.11772  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0017392116618175635
# oscillator transition 13-14: 	7.11975	7.11885	7.11892	7.11772  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.001782792208377515
# oscillator transition 14-15: 	7.11971	7.11884	7.11892	7.11772  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.
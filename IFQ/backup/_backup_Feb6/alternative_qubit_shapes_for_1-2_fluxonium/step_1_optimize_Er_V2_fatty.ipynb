# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *
sys.path = original_sys_path

# %%
EJ = 3.4
EC = 0.8923
EL = 0.03

qubit_level = 30




def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.2]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 0.00047544384590004346
#              x: [ 7.197e+00]
#            nit: 13
#           nfev: 26
#  final_simplex: (array([[ 7.197e+00],
#                        [ 7.197e+00]]), array([ 4.754e-04,  4.754e-04]))
# Optimal solution: [7.19701172]
# Objective value: 0.00047544384590004346

# %%
max_ol = 40
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.3
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ]
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.006079848451639447
# qbt freq at osc 1:	0.00613, 	diff to at osc ground 0.00005, 0.7810% diff
# qbt freq at osc 2:	0.00618, 	diff to at osc ground 0.00010, 1.6027% diff
# qbt freq at osc 3:	0.00623, 	diff to at osc ground 0.00015, 2.5316% diff
# qbt freq at osc 4:	0.00630, 	diff to at osc ground 0.00022, 3.6270% diff
# qbt freq at osc 5:	0.00638, 	diff to at osc ground 0.00030, 4.9417% diff
# qbt freq at osc 6:	0.00648, 	diff to at osc ground 0.00040, 6.5238% diff
# qbt freq at osc 7:	0.00659, 	diff to at osc ground 0.00051, 8.4171% diff
# qbt freq at osc 8:	0.00673, 	diff to at osc ground 0.00065, 10.6619% diff
# qbt freq at osc 9:	0.00689, 	diff to at osc ground 0.00081, 13.2954% diff
# qbt freq at osc 10:	0.00707, 	diff to at osc ground 0.00099, 16.3526% diff
# qbt freq at osc 11:	0.00729, 	diff to at osc ground 0.00121, 19.8661% diff
# qbt freq at osc 12:	0.00753, 	diff to at osc ground 0.00145, 23.8667% diff
# qbt freq at osc 13:	0.00781, 	diff to at osc ground 0.00173, 28.3839% diff
# qbt freq at osc 14:	0.00811, 	diff to at osc ground 0.00203, 33.4456% diff
# qbt freq at osc 15:	0.00846, 	diff to at osc ground 0.00238, 39.0784% diff
# qbt freq at osc 16:	0.00883, 	diff to at osc ground 0.00275, 45.3080% diff
# qbt freq at osc 17:	0.00925, 	diff to at osc ground 0.00317, 52.1592% diff
# qbt freq at osc 18:	0.00971, 	diff to at osc ground 0.00363, 59.6558% diff
# qbt freq at osc 19:	0.01020, 	diff to at osc ground 0.00412, 67.8208% diff
# qbt freq at osc 20:	0.01074, 	diff to at osc ground 0.00466, 76.6765% diff
# qbt freq at osc 21:	0.01132, 	diff to at osc ground 0.00524, 86.2444% diff
# qbt freq at osc 22:	0.01195, 	diff to at osc ground 0.00587, 96.5454% diff
# qbt freq at osc 23:	0.01262, 	diff to at osc ground 0.00654, 107.5996% diff
# qbt freq at osc 24:	0.01334, 	diff to at osc ground 0.00726, 119.4265% diff
# qbt freq at osc 25:	0.01411, 	diff to at osc ground 0.00803, 132.0447% diff
# qbt freq at osc 26:	0.01492, 	diff to at osc ground 0.00884, 145.4723% diff
# qbt freq at osc 27:	0.01579, 	diff to at osc ground 0.00971, 159.7264% diff
# qbt freq at osc 28:	0.01671, 	diff to at osc ground 0.01063, 174.8235% diff
# qbt freq at osc 29:	0.01768, 	diff to at osc ground 0.01160, 190.7791% diff
# qbt freq at osc 30:	0.01870, 	diff to at osc ground 0.01262, 207.6079% diff
# qbt freq at osc 31:	0.01978, 	diff to at osc ground 0.01370, 225.3238% diff
# qbt freq at osc 32:	0.02091, 	diff to at osc ground 0.01483, 243.9395% diff
# qbt freq at osc 33:	0.02210, 	diff to at osc ground 0.01602, 263.4668% diff
# qbt freq at osc 34:	0.02334, 	diff to at osc ground 0.01726, 283.9164% diff
# qbt freq at osc 35:	0.02464, 	diff to at osc ground 0.01856, 305.2980% diff
# qbt freq at osc 36:	0.02600, 	diff to at osc ground 0.01992, 327.6198% diff
# qbt freq at osc 37:	0.02741, 	diff to at osc ground 0.02133, 350.8803% diff
# qbt freq at osc 38:	0.02888, 	diff to at osc ground 0.02280, 375.0475% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.20047	7.20167	7.20172	7.20377
# oscillator transition 1-2: 	7.20039	7.20161	7.20166	7.20366  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.405802133371054e-05
# oscillator transition 2-3: 	7.20030	7.20155	7.20161	7.20356  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0001698353304337985
# oscillator transition 3-4: 	7.20021	7.20150	7.20156	7.20346  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0002573554717830717
# oscillator transition 4-5: 	7.20012	7.20144	7.20152	7.20337  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0003466347547114168
# oscillator transition 5-6: 	7.20003	7.20138	7.20147	7.20329  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0004376812321584822
# oscillator transition 6-7: 	7.19994	7.20132	7.20143	7.20321  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0005304936176333541
# oscillator transition 7-8: 	7.19984	7.20125	7.20139	7.20313  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.000625060145297951
# oscillator transition 8-9: 	7.19975	7.20119	7.20135	7.20306  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0007213573963600339
# oscillator transition 9-10: 	7.19965	7.20113	7.20132	7.20299  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0008193491050452195
# oscillator transition 10-11: 	7.19955	7.20107	7.20128	7.20293  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0009189849733193256
# oscillator transition 11-12: 	7.19945	7.20100	7.20125	7.20287  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0010201995316752033
# oscillator transition 12-13: 	7.19935	7.20094	7.20121	7.20281  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0011229110788608665
# oscillator transition 13-14: 	7.19924	7.20087	7.20118	7.20275  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0012270207569518021
# oscillator transition 14-15: 	7.19914	7.20081	7.20115	7.20269  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0013324118084288017
# oscillator transition 15-16: 	7.19903	7.20074	7.20112	7.20264  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0014389490715220887
# oscillator transition 16-17: 	7.19892	7.20067	7.20109	7.20259  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0015464787875263397
# oscillator transition 17-18: 	7.19881	7.20061	7.20106	7.20253  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0016548287616959811
# oscillator transition 18-19: 	7.19871	7.20054	7.20103	7.20249  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0017638089476239571
# oscillator transition 19-20: 	7.19860	7.20047	7.20101	7.20244  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0018732124927343108
# oscillator transition 20-21: 	7.19849	7.20040	7.20098	7.20239  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.001982817280543614
# oscillator transition 21-22: 	7.19838	7.20033	7.20095	7.20235  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0020923879788714572
# oscillator transition 22-23: 	7.19827	7.20025	7.20093	7.20230  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.002201678580343369
# oscillator transition 23-24: 	7.19816	7.20018	7.20090	7.20226  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.002310435404007549
# oscillator transition 24-25: 	7.19805	7.20011	7.20087	7.20222  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.002418400478086724
# oscillator transition 25-26: 	7.19794	7.20003	7.20085	7.20218  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.002525315221953761
# oscillator transition 26-27: 	7.19784	7.19996	7.20082	7.20214  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0026309242948858724
# oscillator transition 27-28: 	7.19773	7.19988	7.20080	7.20210  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0027349794936188943
# oscillator transition 28-29: 	7.19763	7.19981	7.20078	7.20206  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0028372435394263817
# oscillator transition 29-30: 	7.19753	7.19973	7.20075	7.20202  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.002937493615656095
# oscillator transition 30-31: 	7.19743	7.19965	7.20073	7.20199  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.003035524529730438
# oscillator transition 31-32: 	7.19734	7.19957	7.20070	7.20195  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0031311513765448495
# oscillator transition 32-33: 	7.19725	7.19949	7.20068	7.20191  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.003224211628941376
# oscillator transition 33-34: 	7.19715	7.19942	7.20066	7.20188  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0033145665949181335
# oscillator transition 34-35: 	7.19707	7.19934	7.20064	7.20184  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.003402102015536812
# oscillator transition 35-36: 	7.19698	7.19926	7.20061	7.20181  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.003486672448469008
# oscillator transition 36-37: 	7.19691	7.19919	7.20060	7.20178  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.0035581512048512565
# oscillator transition 37-38: 	7.19794	7.20023	7.20170	7.20271  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -0.002524439008306345
# oscillator transition 38-39: 	7.30397	7.27080	7.27858	7.26971  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.10350034489306914
#
# 10-11: 7.2017, diff to 00-01: 0.0012015340173512357
# 20-21: 7.2017, diff to 00-01: 0.0012490167559882082

# %%
system.qbt.plot_matrixelements(operator = 'n_operator',evals_count = 15)
# Out:
# (<Figure size 1000x500 with 3 Axes>, (<Axes3D: >, <Axes: >))

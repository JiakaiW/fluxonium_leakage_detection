# %%
from utils import *

# %%
g_strength = 0.35
EJ = 4.0
EC = 1.5
EL = 0.25
E_osc = 3


qubit_level = 30
osc_level = 15

# %%
qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
osc = scqubits.Oscillator(E_osc=E_osc,truncated_dim=osc_level)
hilbertspace = scqubits.HilbertSpace([qbt, osc])
hilbertspace.add_interaction(g_strength=g_strength,op1=qbt.n_operator,op2=osc.creation_operator,add_hc=True)
hilbertspace.generate_lookup()
product_to_dressed = generate_single_mapping(hilbertspace.hamiltonian())


energies=  hilbertspace.eigenvals(qubit_level*osc_level)
def stark(ql1,ql2,ol):
    return abs(energies[product_to_dressed[(ql2,ol)]]-energies[product_to_dressed[(ql1,ol)]])
def lamb(ol1,ol2,ql):
    return abs(energies[product_to_dressed[(ql,ol2)]]-energies[product_to_dressed[(ql,ol1)]])
def detuning(ql1,ql2):
    return abs((energies[product_to_dressed[(ql1,1)]]-energies[product_to_dressed[(ql1,0)]])  -
                    (energies[product_to_dressed[(ql2,1)]]-energies[product_to_dressed[(ql2,0)]]))
    
differential_stark_on_qubit_12_from_osc01 = abs(stark(1,2,0)-stark(1,2,1)) # For reducing differential phase on off-diagonal elements of the qubit
differential_stark_on_qubit_12_from_osc12 = abs(stark(1,2,1)-stark(1,2,2))
qubit_zero_lamb_on_osc01_12 = abs(lamb(0,1,0)-lamb(1,2,0)) # For easy populating photons
qubit_zero_lamb_on_osc01_23 = abs(lamb(0,1,0)-lamb(2,3,0))
detunning_qubit01 = detuning(0,1) + detuning(0, 2)

print(f"differential_stark_on_qubit_12_from_osc01  {differential_stark_on_qubit_12_from_osc01}")
print(f"differential_stark_on_qubit_12_from_osc12  {differential_stark_on_qubit_12_from_osc12}")
print(f"qubit_zero_lamb_on_osc01_12  {abs(lamb(0,1,0)-lamb(1,2,0))}")
print(f"qubit_zero_lamb_on_osc01_23  {abs(lamb(0,1,0)-lamb(2,3,0))}")
print(f"qubit_zero_lamb_on_osc01_34  {abs(lamb(0,1,0)-lamb(3,4,0))}")
print(f"qubit_zero_lamb_on_osc01_45  {abs(lamb(0,1,0)-lamb(4,5,0))}")
print(f"qubit_zero_lamb_on_osc01_56  {abs(lamb(0,1,0)-lamb(5,6,0))}")
print(f"qubit_zero_lamb_on_osc01_67  {abs(lamb(0,1,0)-lamb(6,7,0))}")
print(f"qubit_zero_lamb_on_osc01_78  {abs(lamb(0,1,0)-lamb(7,8,0))}")
print(f"qubit_zero_lamb_on_osc01_89  {abs(lamb(0,1,0)-lamb(8,9,0))}")
print(f"qubit_zero_lamb_on_osc01_90  {abs(lamb(0,1,0)-lamb(9,10,0))}")
print(f"detunning 01 {detuning(0,1) }")
print(f"detunning 02 {detuning(0,2) }")
# plot_specturum(qbt, osc, hilbertspace)
# Out:
# max overlap^2 0.015328690151923162 below threshold for dressed state 140 with eval 36.550299289176074
# max overlap^2 0.015926648408536272 below threshold for dressed state 163 with eval 39.55007459971383
# max overlap^2 0.016508642542357406 below threshold for dressed state 188 with eval 42.55239428861372
# max overlap^2 0.012395836236117936 below threshold for dressed state 231 with eval 47.69028093840482
# max overlap^2 0.015087800891722666 below threshold for dressed state 253 with eval 50.147202221964235
# max overlap^2 0.008794637820221994 below threshold for dressed state 276 with eval 52.74843708100674
# max overlap^2 0.0010930680546868306 below threshold for dressed state 289 with eval 54.554201918409234
# max overlap^2 0.011953475394858833 below threshold for dressed state 291 with eval 54.596557791597434
# max overlap^2 0.015547266977023263 below threshold for dressed state 304 with eval 56.47036663814191
# max overlap^2 0.018821130269181936 below threshold for dressed state 310 with eval 57.13960109641523
# max overlap^2 0.001454957340935042 below threshold for dressed state 316 with eval 58.15127066947553
# max overlap^2 0.008588274338540581 below threshold for dressed state 319 with eval 58.6220408913616
# max overlap^2 0.004686324544914836 below threshold for dressed state 325 with eval 59.14946942952098
# max overlap^2 0.006385213590286747 below threshold for dressed state 332 with eval 60.38192445701697
# max overlap^2 0.0011848786492010186 below threshold for dressed state 333 with eval 60.426653595756605
# max overlap^2 0.004013193686284844 below threshold for dressed state 344 with eval 62.268699681848815
# max overlap^2 0.0009504144160675166 below threshold for dressed state 345 with eval 62.27270636499431
# max overlap^2 0.0014287183472573943 below threshold for dressed state 355 with eval 64.14491138390039
# max overlap^2 0.0034348746374234466 below threshold for dressed state 356 with eval 64.19198657375094
# max overlap^2 0.0069131154549006485 below threshold for dressed state 365 with eval 66.01255777369916
# max overlap^2 0.0022372108073366094 below threshold for dressed state 368 with eval 66.16835168580775
# max overlap^2 0.003165943523227771 below threshold for dressed state 380 with eval 68.60925967016692
# max overlap^2 0.004113613769399395 below threshold for dressed state 386 with eval 69.99203723829734
# max overlap^2 0.016446513602155547 below threshold for dressed state 388 with eval 70.39870828226182
# max overlap^2 0.01661197362993352 below threshold for dressed state 395 with eval 71.97602741275631
# max overlap^2 0.019461902799362735 below threshold for dressed state 398 with eval 72.26304347189004
# max overlap^2 0.013746758900514912 below threshold for dressed state 399 with eval 72.40221922210617
# max overlap^2 0.01672491802174975 below threshold for dressed state 406 with eval 74.07804322370406
# max overlap^2 0.005440395462707218 below threshold for dressed state 407 with eval 74.21405265189537
# max overlap^2 0.019971545256018422 below threshold for dressed state 410 with eval 75.39543816234887
# max overlap^2 0.0016886249815331645 below threshold for dressed state 412 with eval 75.66954645822071
# max overlap^2 0.0017136384213050067 below threshold for dressed state 413 with eval 76.20889831334955
# max overlap^2 0.0019091357343432942 below threshold for dressed state 418 with eval 77.22403423067747
# max overlap^2 0.00033800177386746234 below threshold for dressed state 419 with eval 78.08101108348498
# max overlap^2 0.002921213008766419 below threshold for dressed state 423 with eval 78.67365662248223
# max overlap^2 0.001369826543723601 below threshold for dressed state 425 with eval 79.72239104324217
# max overlap^2 0.007716943972782221 below threshold for dressed state 428 with eval 80.12758081964446
# max overlap^2 0.002930287233336685 below threshold for dressed state 429 with eval 81.18150663229639
# max overlap^2 0.0009458117326960601 below threshold for dressed state 432 with eval 81.66888074015176
# max overlap^2 1.1129135306114348e-05 below threshold for dressed state 434 with eval 82.51536399794938
# max overlap^2 9.50172663303408e-10 below threshold for dressed state 436 with eval 83.34405007281454
# max overlap^2 0.00016113646370914184 below threshold for dressed state 437 with eval 83.99873518323197
# max overlap^2 1.374395930353831e-09 below threshold for dressed state 438 with eval 84.63685377322322
# max overlap^2 4.23571984057736e-12 below threshold for dressed state 439 with eval 85.06231111795229
# max overlap^2 1.0214582268251348e-15 below threshold for dressed state 440 with eval 85.45748783515766
# max overlap^2 2.6866777173046123e-12 below threshold for dressed state 441 with eval 85.64422853601465
# max overlap^2 5.713739311488256e-14 below threshold for dressed state 442 with eval 86.79763535730591
# max overlap^2 2.8099875866111693e-15 below threshold for dressed state 443 with eval 87.3704046744047
# max overlap^2 1.5133993577364713e-16 below threshold for dressed state 444 with eval 88.42136800636462
# max overlap^2 1.9268768620457514e-15 below threshold for dressed state 445 with eval 88.79604774586264
# max overlap^2 5.2858365605574503e-20 below threshold for dressed state 446 with eval 89.39622372575273
# max overlap^2 2.8080530047621194e-18 below threshold for dressed state 447 with eval 90.84853520000439
# max overlap^2 1.4986280242350437e-23 below threshold for dressed state 448 with eval 92.94448621873448
# max overlap^2 1.169154872614672e-24 below threshold for dressed state 449 with eval 93.53993551662786
# differential_stark_on_qubit_12_from_osc01  0.004730925391737806
# differential_stark_on_qubit_12_from_osc12  0.007694419533541996
# qubit_zero_lamb_on_osc01_12  0.00019641146069870885
# qubit_zero_lamb_on_osc01_23  0.0003734136645876518
# qubit_zero_lamb_on_osc01_34  0.00052824646163252
# qubit_zero_lamb_on_osc01_45  0.0006683164698486621
# qubit_zero_lamb_on_osc01_56  0.0007953280680510488
# qubit_zero_lamb_on_osc01_67  0.0009118836251182927
# qubit_zero_lamb_on_osc01_78  0.001020314615946205
# qubit_zero_lamb_on_osc01_89  0.0011227255522747726
# qubit_zero_lamb_on_osc01_90  0.0012210336303866143
# detunning 01 0.016664187051903756
# detunning 02 0.01193326166016595

# %%
a = hilbertspace.op_in_dressed_eigenbasis(op=osc.annihilation_operator)
a = qutip.Qobj(a[:, :])
 
(evals,) = hilbertspace["evals"]
diag_dressed_hamiltonian = (
        2 * np.pi * qutip.Qobj(np.diag(evals),
        dims=[hilbertspace.subsystem_dims] * 2)
)
diag_dressed_hamiltonian = qutip.Qobj(diag_dressed_hamiltonian[:, :])

leakage_dressed_state_osc_0 = product_to_dressed[(0,0)]
leakage_dressed_state_osc_1 = product_to_dressed[(0,1)]
w_d = transition_frequency(hilbertspace,leakage_dressed_state_osc_0,leakage_dressed_state_osc_1 )
print(w_d)

amp = 0.003
def square_cos(t,*args):
    cos = np.cos(w_d * 2*np.pi * t)
    return  2*np.pi *amp * cos


t_stop = 213 
def square_cos_with_ring_down(t,*args):
    if t > t_stop:
        return 0
    else:
        cos = np.cos(w_d * 2*np.pi * t)
        return  2*np.pi *amp * cos

        
H_with_drive = [
    diag_dressed_hamiltonian,
    [a+a.dag(), square_cos_with_ring_down]]

kappa = 0.07
decay_term = kappa*a

tot_time = 400
tlist = np.linspace(0, tot_time, tot_time)[::4]


state_0_dressed = qutip.basis(hilbertspace.dimension, product_to_dressed[(1,0)])
state_1_dressed = qutip.basis(hilbertspace.dimension, product_to_dressed[(2,0)])
state_plus_dressed = (state_0_dressed + 1j * state_1_dressed).unit()
state_minus_dressed = (state_0_dressed - state_1_dressed).unit()
initial_states  = [state_0_dressed,state_1_dressed,state_plus_dressed,state_minus_dressed ]


existing_chunk_num = 0
for ini_state in initial_states:
    existing_chunk_num = pack_mcsolve_chunks(H = H_with_drive,
                    state0 = ini_state,
                    tlist = tlist,
                    c_ops  = [decay_term],
                    ntraj = 500,
                    existing_chunk_num = existing_chunk_num,
                    chunk_size = 4)

def pack_pkl_files_to_zip(zip_filename="mcsolve_input.zip"):
    # Create a new ZIP file
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        # Loop through all files in the current directory
        for filename in os.listdir('.'):
            # Check if the file is a .pkl file with an integer name
            name, ext = os.path.splitext(filename)
            if ext == '.pkl' and name.isdigit():
                # Add the file to the ZIP
                zipf.write(filename)
                # Delete the .pkl file
                os.remove(filename)
                
pack_pkl_files_to_zip()
# Out:
# 2.9881524128281285

# %%
# !unzip mcsolve_input.zipx

# %%
# List of zip files containing the results
zip_files = [f"mcsolve large dim 4-1.5-0.25-3/result_{i}.zip" for i in range(500)]

# Divide the files into four equal parts
n_parts = 4
part_length = len(zip_files) // n_parts
zip_file_parts = [zip_files[i * part_length: (i + 1) * part_length] for i in range(n_parts)]

# Initialize an empty list to store the four results
results = []

# Merge the results for each part and append to the results list
for part in zip_file_parts:
    results.append(merge_results(part))
# Out:
# done:125/125

# %%
import pickle

# Unpickle the dictionary
with open('mcsolve large dim 4-1.5-0.25-3/averaged.pkl', 'wb') as f:
    pickle.dump(results,f)

# %%
import pickle

with open('mcsolve large dim 4-1.5-0.25-3/averaged.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
interactive_heatmap(results[3], product_to_dressed, qubit_levels=6, oscillator_levels=50)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='Time Index:', max=99), Output()…

# %% [markdown]
# # 1. Partial trace out qubit, truncate to 2 level

# %%
tasks = [(results, 
          f'mcsolve large dim 4-1.5-0.25-3/res_{i}_state_{j}.pkl',
          i, j,  product_to_dressed, qubit_level, osc_level, 1, 2) 
         for i in range(len(results)) 
         for j in range(len(results[i].states))]

from multiprocessing import Pool

with Pool(processes=6) as pool:
    pool.map(compute_and_store_2_level_dm, tasks)

# %% [markdown]
# # 2 optimize a phase on the final state and get qutip fidelity for each initial states

# %%
zero = qutip.basis(2, 0)
one = qutip.basis(2, 1)

states_ideal  = [zero,
              one,
              (zero + 1j * one).unit(),
              (zero - one).unit() ]


num_initial_states = len(results)
num_time_steps = len(results[0].times)
two_level_states = []
for i in range(num_initial_states) :
    two_level_states.append([])
    for j in range(num_time_steps):
        with open(f'mcsolve large dim 4-1.5-0.25-3/res_{i}_state_{j}.pkl', 'rb') as f:
            state = pickle.load(f)
        two_level_states[-1].append(state)

# %%
def calc_average_fidelity_with_phase(phase,dms,states_ideal):
    gate = qutip.qip.operations.phasegate(phase)
    fid=[]
    for dm,dm_ideal in zip(dms,states_ideal):
        # new_dm = gate*dm*gate.dag()
        fid.append(qutip.fidelity(dm, gate*dm_ideal))

    return 1-sum(fid)/len(fid)
    




from scipy.optimize import minimize

infidelity = []
phase = []
for idx in range(num_time_steps):
    dms = [states[idx] for states in two_level_states]
    def objective_function(phase):
        return calc_average_fidelity_with_phase(phase[0], dms, states_ideal)
    initial_phase = [0.0]
    bounds = [(0, 2 * 3.141592653589793)]
    opt_result = minimize(objective_function, initial_phase,method="COBYLA")
    infidelity.append(opt_result.fun)
    phase.append(opt_result.x)


plt.plot(results[0].times,infidelity)
plt.title("averaged infidelity")
plt.xlabel("ns")
# Out:
# Text(0.5, 0, 'ns')

# %%
plt.plot(results[0].times,phase,label = f'phase')

# %%
def calc_fidelity_with_phase(phase,dm,state_ideal):
    gate = qutip.qip.operations.phasegate(phase)
    return 1-qutip.fidelity(dm, gate*state_ideal)

    

phases = []
infidelities = []
for i, states in enumerate(two_level_states):
    phases.append([])
    infidelities.append([])
    for idx in range(num_time_steps):
        dm = states[idx]
        def objective_function(params):
            return calc_fidelity_with_phase(params[0], dm, states_ideal[i])
        initial_phase = [0.0]
        opt_result = minimize(objective_function, initial_phase,method="COBYLA")
        phases[-1].append(opt_result.x)
        infidelities[-1].append(opt_result.fun)
for i in range(4):
    plt.plot(results[0].times,infidelities[i],label = f'{i}th infidelities',alpha = 0.4)
plt.title("infidelities")
plt.xlabel("ns")
plt.legend()

# %%
plt.plot(results[0].times,[abs(state.full()[1][0]) for state in two_level_states[2]])

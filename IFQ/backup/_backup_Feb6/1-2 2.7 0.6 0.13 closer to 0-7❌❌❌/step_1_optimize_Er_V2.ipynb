# %%
import scqubits
import numpy as np
from scipy.optimize import minimize


import sys
original_sys_path = sys.path.copy()
sys.path.append('../')
from utils import *
sys.path = original_sys_path

# %%
EJ = 2.7
EC = 0.6
EL = 0.13

qubit_level = 30


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]

    shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_one-shift_from_two)

initial_guess = [7.2]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2.903775243853768e-06
#              x: [ 7.191e+00]
#            nit: 13
#           nfev: 28
#  final_simplex: (array([[ 7.191e+00],
#                        [ 7.191e+00]]), array([ 2.904e-06,  4.754e-06]))
# Optimal solution: [7.19094727]
# Objective value: 2.903775243853768e-06

# %%
max_ol = 50
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.2
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ]
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.01901956709018071
# qbt freq at osc 1:	0.01903, 	diff to at osc ground 0.00001, 0.0580% diff
# qbt freq at osc 2:	0.01905, 	diff to at osc ground 0.00003, 0.1410% diff
# qbt freq at osc 3:	0.01907, 	diff to at osc ground 0.00005, 0.2480% diff
# qbt freq at osc 4:	0.01909, 	diff to at osc ground 0.00007, 0.3781% diff
# qbt freq at osc 5:	0.01912, 	diff to at osc ground 0.00010, 0.5302% diff
# qbt freq at osc 6:	0.01915, 	diff to at osc ground 0.00013, 0.7025% diff
# qbt freq at osc 7:	0.01919, 	diff to at osc ground 0.00017, 0.8923% diff
# qbt freq at osc 8:	0.01923, 	diff to at osc ground 0.00021, 1.0932% diff
# qbt freq at osc 9:	0.01926, 	diff to at osc ground 0.00024, 1.2851% diff
# qbt freq at osc 10:	0.01927, 	diff to at osc ground 0.00025, 1.3327% diff
# qbt freq at osc 11:	0.01952, 	diff to at osc ground 0.00050, 2.6339% diff
# qbt freq at osc 12:	0.01949, 	diff to at osc ground 0.00047, 2.4802% diff
# qbt freq at osc 13:	0.01954, 	diff to at osc ground 0.00052, 2.7328% diff
# qbt freq at osc 14:	0.01960, 	diff to at osc ground 0.00058, 3.0498% diff
# qbt freq at osc 15:	0.01967, 	diff to at osc ground 0.00065, 3.3997% diff
# qbt freq at osc 16:	0.01974, 	diff to at osc ground 0.00072, 3.7742% diff
# qbt freq at osc 17:	0.01981, 	diff to at osc ground 0.00079, 4.1698% diff
# qbt freq at osc 18:	0.01989, 	diff to at osc ground 0.00087, 4.5849% diff
# qbt freq at osc 19:	0.01997, 	diff to at osc ground 0.00095, 5.0185% diff
# qbt freq at osc 20:	0.02006, 	diff to at osc ground 0.00104, 5.4696% diff
# qbt freq at osc 21:	0.02015, 	diff to at osc ground 0.00113, 5.9378% diff
# qbt freq at osc 22:	0.02024, 	diff to at osc ground 0.00122, 6.4225% diff
# qbt freq at osc 23:	0.02034, 	diff to at osc ground 0.00132, 6.9233% diff
# qbt freq at osc 24:	0.02043, 	diff to at osc ground 0.00142, 7.4398% diff
# qbt freq at osc 25:	0.02054, 	diff to at osc ground 0.00152, 7.9716% diff
# qbt freq at osc 26:	0.02064, 	diff to at osc ground 0.00162, 8.5184% diff
# qbt freq at osc 27:	0.02075, 	diff to at osc ground 0.00173, 9.0798% diff
# qbt freq at osc 28:	0.02086, 	diff to at osc ground 0.00184, 9.6555% diff
# qbt freq at osc 29:	0.02097, 	diff to at osc ground 0.00195, 10.2452% diff
# qbt freq at osc 30:	0.02108, 	diff to at osc ground 0.00206, 10.8487% diff
# qbt freq at osc 31:	0.02120, 	diff to at osc ground 0.00218, 11.4657% diff
# qbt freq at osc 32:	0.02132, 	diff to at osc ground 0.00230, 12.0958% diff
# qbt freq at osc 33:	0.02144, 	diff to at osc ground 0.00242, 12.7389% diff
# qbt freq at osc 34:	0.02157, 	diff to at osc ground 0.00255, 13.3946% diff
# qbt freq at osc 35:	0.02169, 	diff to at osc ground 0.00267, 14.0628% diff
# qbt freq at osc 36:	0.02182, 	diff to at osc ground 0.00280, 14.7432% diff
# qbt freq at osc 37:	0.02196, 	diff to at osc ground 0.00294, 15.4356% diff
# qbt freq at osc 38:	0.02209, 	diff to at osc ground 0.00307, 16.1397% diff
# qbt freq at osc 39:	0.02223, 	diff to at osc ground 0.00321, 16.8553% diff
# qbt freq at osc 40:	0.02236, 	diff to at osc ground 0.00334, 17.5822% diff
# qbt freq at osc 41:	0.02250, 	diff to at osc ground 0.00348, 18.3203% diff
# qbt freq at osc 42:	0.02265, 	diff to at osc ground 0.00363, 19.0693% diff
# qbt freq at osc 43:	0.02279, 	diff to at osc ground 0.00377, 19.8289% diff
# qbt freq at osc 44:	0.02294, 	diff to at osc ground 0.00392, 20.5992% diff
# qbt freq at osc 45:	0.02309, 	diff to at osc ground 0.00407, 21.3797% diff
# qbt freq at osc 46:	0.02324, 	diff to at osc ground 0.00422, 22.1704% diff
# qbt freq at osc 47:	0.02339, 	diff to at osc ground 0.00437, 22.9660% diff
# qbt freq at osc 48:	0.02350, 	diff to at osc ground 0.00448, 23.5701% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.18911	7.19275	7.19276	7.19065
# oscillator transition 1-2: 	7.18925	7.19274	7.19276	7.19065  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00014307162525284411
# oscillator transition 2-3: 	7.18937	7.19273	7.19275	7.19066  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002548164461027014
# oscillator transition 3-4: 	7.18946	7.19273	7.19275	7.19066  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000344998129681251
# oscillator transition 4-5: 	7.18953	7.19272	7.19275	7.19066  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000419639903747715
# oscillator transition 5-6: 	7.18959	7.19271	7.19274	7.19067  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004826799233379475
# oscillator transition 6-7: 	7.18965	7.19270	7.19274	7.19067  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005368120743662885
# oscillator transition 7-8: 	7.18970	7.19270	7.19274	7.19068  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005839469874056036
# oscillator transition 8-9: 	7.18974	7.19269	7.19273	7.19068  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006254805413172804
# oscillator transition 9-10: 	7.18977	7.19268	7.19269	7.19069  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006624581018224163
# oscillator transition 10-11: 	7.18981	7.19268	7.19293	7.19069  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006956791342469515
# oscillator transition 11-12: 	7.18984	7.19267	7.19264	7.19070  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000725766164344499
# oscillator transition 12-13: 	7.18986	7.19266	7.19271	7.19070  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000753211582058988
# oscillator transition 13-14: 	7.18989	7.19266	7.19272	7.19070  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0007784102256858105
# oscillator transition 14-15: 	7.18991	7.19265	7.19272	7.19071  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000801682567165507
# oscillator transition 15-16: 	7.18993	7.19265	7.19272	7.19071  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000823291543860627
# oscillator transition 16-17: 	7.18995	7.19264	7.19272	7.19072  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0008434549816280779
# oscillator transition 17-18: 	7.18997	7.19263	7.19271	7.19072  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0008623549154060939
# oscillator transition 18-19: 	7.18999	7.19263	7.19271	7.19072  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0008801446717479067
# oscillator transition 19-20: 	7.30537	7.19262	7.19271	7.19073  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.11625607775504765
# oscillator transition 20-21: 	7.19294	7.19262	7.19271	7.19073  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0038301994698537456
# oscillator transition 21-22: 	7.19293	7.19261	7.19270	7.19074  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003818568889692564
# oscillator transition 22-23: 	7.19292	7.19261	7.19270	7.19074  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0038076569452636377
# oscillator transition 23-24: 	7.19291	7.19260	7.19270	7.19074  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0037973920012968065
# oscillator transition 24-25: 	7.19290	7.19259	7.19270	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0037877115467717104
# oscillator transition 25-26: 	7.19289	7.19259	7.19269	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0037785607841209767
# oscillator transition 26-27: 	7.19288	7.19258	7.19269	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003769891482783727
# oscillator transition 27-28: 	7.19287	7.19258	7.19269	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003761661023014007
# oscillator transition 28-29: 	7.19287	7.19257	7.19269	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0037538316096226154
# oscillator transition 29-30: 	7.19286	7.19257	7.19268	7.19077  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003746369607761757
# oscillator transition 30-31: 	7.19285	7.19256	7.19268	7.19077  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0037392449910322867
# oscillator transition 31-32: 	7.19284	7.19256	7.19268	7.19078  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00373243087127495
# oscillator transition 32-33: 	7.19284	7.19255	7.19268	7.19078  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0037259031034517776
# oscillator transition 33-34: 	7.19283	7.19255	7.19267	7.19078  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0037196399428802707
# oscillator transition 34-35: 	7.19283	7.19254	7.19267	7.19079  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003713621761272101
# oscillator transition 35-36: 	7.19282	7.19254	7.19267	7.19079  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0037078307939220068
# oscillator transition 36-37: 	7.19281	7.19253	7.19267	7.19079  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0037022509278523685
# oscillator transition 37-38: 	7.19281	7.19253	7.19266	7.19080  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0036968675107624804
# oscillator transition 38-39: 	7.19280	7.19252	7.19266	7.19080  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0036916671996829464
# oscillator transition 39-40: 	7.19280	7.19252	7.19266	7.19081  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0036866378101700903
# oscillator transition 40-41: 	7.19279	7.19252	7.19266	7.19081  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0036817681985263917
# oscillator transition 41-42: 	7.19279	7.19251	7.19265	7.19081  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003677048156185414
# oscillator transition 42-43: 	7.19278	7.19251	7.19265	7.19082  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003672468310747412
# oscillator transition 43-44: 	7.19278	7.19250	7.19265	7.19082  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0036680200436700616
# oscillator transition 44-45: 	7.19278	7.19250	7.19265	7.19082  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0036636954316628945
# oscillator transition 45-46: 	7.19277	7.19249	7.19264	7.19083  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0036594912308425265
# oscillator transition 46-47: 	7.19277	7.19249	7.19264	7.19087  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0036565960716012924
# oscillator transition 47-48: 	7.19302	7.19299	7.19311	7.19516  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003910835583547545
# oscillator transition 48-49: 	7.22774	7.23862	7.24268	7.39426  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.03863253265046129
#
# 10-11: 7.1927, diff to 00-01: 0.0036361953506309774
# 20-21: 7.1928, diff to 00-01: 0.0036472353858236772

# %%
max_ol = 50
max_ql = 30
# g = abs(evals[7]-evals[0]-result.x[0])
# print(f"g:{g}")
g = 0.18
system = fluxonium_oscillator_system(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = result.x[0],
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ]
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.01902810142634026
# qbt freq at osc 1:	0.01904, 	diff to at osc ground 0.00001, 0.0386% diff
# qbt freq at osc 2:	0.01905, 	diff to at osc ground 0.00002, 0.0938% diff
# qbt freq at osc 3:	0.01906, 	diff to at osc ground 0.00003, 0.1652% diff
# qbt freq at osc 4:	0.01908, 	diff to at osc ground 0.00005, 0.2523% diff
# qbt freq at osc 5:	0.01910, 	diff to at osc ground 0.00007, 0.3546% diff
# qbt freq at osc 6:	0.01912, 	diff to at osc ground 0.00009, 0.4715% diff
# qbt freq at osc 7:	0.01914, 	diff to at osc ground 0.00011, 0.6020% diff
# qbt freq at osc 8:	0.01917, 	diff to at osc ground 0.00014, 0.7449% diff
# qbt freq at osc 9:	0.01920, 	diff to at osc ground 0.00017, 0.8981% diff
# qbt freq at osc 10:	0.01923, 	diff to at osc ground 0.00020, 1.0575% diff
# qbt freq at osc 11:	0.01926, 	diff to at osc ground 0.00023, 1.2124% diff
# qbt freq at osc 12:	0.01928, 	diff to at osc ground 0.00025, 1.3237% diff
# qbt freq at osc 13:	0.01922, 	diff to at osc ground 0.00020, 1.0331% diff
# qbt freq at osc 14:	0.01952, 	diff to at osc ground 0.00049, 2.5861% diff
# qbt freq at osc 15:	0.01950, 	diff to at osc ground 0.00047, 2.4929% diff
# qbt freq at osc 16:	0.01954, 	diff to at osc ground 0.00051, 2.6738% diff
# qbt freq at osc 17:	0.01958, 	diff to at osc ground 0.00055, 2.9132% diff
# qbt freq at osc 18:	0.01963, 	diff to at osc ground 0.00061, 3.1812% diff
# qbt freq at osc 19:	0.01969, 	diff to at osc ground 0.00066, 3.4689% diff
# qbt freq at osc 20:	0.01975, 	diff to at osc ground 0.00072, 3.7727% diff
# qbt freq at osc 21:	0.01981, 	diff to at osc ground 0.00078, 4.0908% diff
# qbt freq at osc 22:	0.01987, 	diff to at osc ground 0.00084, 4.4221% diff
# qbt freq at osc 23:	0.01993, 	diff to at osc ground 0.00091, 4.7660% diff
# qbt freq at osc 24:	0.02000, 	diff to at osc ground 0.00097, 5.1218% diff
# qbt freq at osc 25:	0.02007, 	diff to at osc ground 0.00104, 5.4893% diff
# qbt freq at osc 26:	0.02014, 	diff to at osc ground 0.00112, 5.8680% diff
# qbt freq at osc 27:	0.02022, 	diff to at osc ground 0.00119, 6.2577% diff
# qbt freq at osc 28:	0.02030, 	diff to at osc ground 0.00127, 6.6582% diff
# qbt freq at osc 29:	0.02037, 	diff to at osc ground 0.00135, 7.0692% diff
# qbt freq at osc 30:	0.02045, 	diff to at osc ground 0.00143, 7.4905% diff
# qbt freq at osc 31:	0.02054, 	diff to at osc ground 0.00151, 7.9219% diff
# qbt freq at osc 32:	0.02062, 	diff to at osc ground 0.00159, 8.3632% diff
# qbt freq at osc 33:	0.02071, 	diff to at osc ground 0.00168, 8.8142% diff
# qbt freq at osc 34:	0.02079, 	diff to at osc ground 0.00176, 9.2748% diff
# qbt freq at osc 35:	0.02088, 	diff to at osc ground 0.00185, 9.7447% diff
# qbt freq at osc 36:	0.02097, 	diff to at osc ground 0.00195, 10.2239% diff
# qbt freq at osc 37:	0.02107, 	diff to at osc ground 0.00204, 10.7122% diff
# qbt freq at osc 38:	0.02116, 	diff to at osc ground 0.00213, 11.2094% diff
# qbt freq at osc 39:	0.02126, 	diff to at osc ground 0.00223, 11.7153% diff
# qbt freq at osc 40:	0.02136, 	diff to at osc ground 0.00233, 12.2299% diff
# qbt freq at osc 41:	0.02145, 	diff to at osc ground 0.00243, 12.7530% diff
# qbt freq at osc 42:	0.02156, 	diff to at osc ground 0.00253, 13.2845% diff
# qbt freq at osc 43:	0.02166, 	diff to at osc ground 0.00263, 13.8242% diff
# qbt freq at osc 44:	0.02176, 	diff to at osc ground 0.00273, 14.3719% diff
# qbt freq at osc 45:	0.02187, 	diff to at osc ground 0.00284, 14.9277% diff
# qbt freq at osc 46:	0.02198, 	diff to at osc ground 0.00295, 15.4913% diff
# qbt freq at osc 47:	0.02208, 	diff to at osc ground 0.00306, 16.0602% diff
# qbt freq at osc 48:	0.02217, 	diff to at osc ground 0.00314, 16.5274% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	7.18953	7.19241	7.19242	7.19071
# oscillator transition 1-2: 	7.18962	7.19240	7.19241	7.19071  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 8.45654374641569e-05
# oscillator transition 2-3: 	7.18969	7.19240	7.19241	7.19071  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00015421613305655058
# oscillator transition 3-4: 	7.18975	7.19239	7.19241	7.19071  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0002127808008847154
# oscillator transition 4-5: 	7.18980	7.19239	7.19241	7.19072  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00026285909970091836
# oscillator transition 5-6: 	7.18984	7.19238	7.19241	7.19072  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00030628434386947845
# oscillator transition 6-7: 	7.18988	7.19238	7.19240	7.19072  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00034439000697084055
# oscillator transition 7-8: 	7.18991	7.19237	7.19240	7.19073  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00037817126511008325
# oscillator transition 8-9: 	7.18994	7.19237	7.19240	7.19073  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00040838714422442024
# oscillator transition 9-10: 	7.18997	7.19237	7.19240	7.19073  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00043562743567626683
# oscillator transition 10-11: 	7.19000	7.19236	7.19239	7.19073  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0004603578857977908
# oscillator transition 11-12: 	7.19002	7.19236	7.19238	7.19074  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00048295150948085563
# oscillator transition 12-13: 	7.19004	7.19235	7.19230	7.19074  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005037107991920919
# oscillator transition 13-14: 	7.19006	7.19235	7.19264	7.19074  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005228837881343651
# oscillator transition 14-15: 	7.19008	7.19234	7.19233	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005406758807549039
# oscillator transition 15-16: 	7.19009	7.19234	7.19237	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005572587019013753
# oscillator transition 16-17: 	7.19011	7.19234	7.19238	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005727768155434632
# oscillator transition 17-18: 	7.19012	7.19233	7.19238	7.19075  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0005873528870647959
# oscillator transition 18-19: 	7.19014	7.19233	7.19238	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.000601091702860046
# oscillator transition 19-20: 	7.19015	7.19232	7.19238	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006140833258410083
# oscillator transition 20-21: 	7.19016	7.19232	7.19238	7.19076  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006264056046045852
# oscillator transition 21-22: 	7.19017	7.19232	7.19238	7.19077  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006381261806875926
# oscillator transition 22-23: 	7.19018	7.19231	7.19238	7.19077  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006493041148853962
# oscillator transition 23-24: 	7.19019	7.19231	7.19238	7.19077  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006599912036318045
# oscillator transition 24-25: 	7.19020	7.19230	7.19237	7.19077  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0006702330648504784
# oscillator transition 25-26: 	7.30858	7.19230	7.19237	7.19078  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.11904837154454917
# oscillator transition 26-27: 	7.19254	7.19230	7.19237	7.19078  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003007951352229199
# oscillator transition 27-28: 	7.19254	7.19229	7.19237	7.19078  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.003001171047570139
# oscillator transition 28-29: 	7.19253	7.19229	7.19237	7.19078  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.002994714407860144
# oscillator transition 29-30: 	7.19252	7.19229	7.19237	7.19079  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.00298855590068392
# oscillator transition 30-31: 	7.19252	7.19228	7.19236	7.19079  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.002982672580655432
# oscillator transition 31-32: 	7.19251	7.19228	7.19236	7.19079  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029770437639324854
# oscillator transition 32-33: 	7.19251	7.19227	7.19236	7.19079  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029716507674475423
# oscillator transition 33-34: 	7.19250	7.19227	7.19236	7.19080  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.002966476663344153
# oscillator transition 34-35: 	7.19250	7.19227	7.19236	7.19080  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.002961506086903043
# oscillator transition 35-36: 	7.19249	7.19226	7.19236	7.19080  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029567250558653058
# oscillator transition 36-37: 	7.19249	7.19226	7.19235	7.19080  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029521208229237317
# oscillator transition 37-38: 	7.19248	7.19226	7.19235	7.19081  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.002947681737536456
# oscillator transition 38-39: 	7.19248	7.19225	7.19235	7.19081  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029433971402266224
# oscillator transition 39-40: 	7.19247	7.19225	7.19235	7.19081  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029392572521640403
# oscillator transition 40-41: 	7.19247	7.19225	7.19235	7.19081  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029352530893032025
# oscillator transition 41-42: 	7.19247	7.19224	7.19235	7.19082  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.002931376385189921
# oscillator transition 42-43: 	7.19246	7.19224	7.19234	7.19082  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029276195220102608
# oscillator transition 43-44: 	7.19246	7.19224	7.19234	7.19082  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.002923975463685835
# oscillator transition 44-45: 	7.19246	7.19223	7.19234	7.19082  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029204377115359392
# oscillator transition 45-46: 	7.19245	7.19223	7.19234	7.19083  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.002917001918630646
# oscillator transition 46-47: 	7.19245	7.19223	7.19234	7.19085  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0029142707274143476
# oscillator transition 47-48: 	7.19261	7.19257	7.19265	7.19375  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.0030734332152331234
# oscillator transition 48-49: 	7.21976	7.23057	7.23393	7.36127  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.03022407993418419
#
# 10-11: 7.1924, diff to 00-01: 0.002873223718558471
# 20-21: 7.1924, diff to 00-01: 0.0028805611711444357

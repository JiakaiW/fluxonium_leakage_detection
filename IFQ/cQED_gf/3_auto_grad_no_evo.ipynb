# %%
import sys
sys.path.append('../utils')
from utils_models import *
from scipy.optimize import minimize

from utils_jax import *
dq.set_device('cpu')
import optax
# Out:
# WARNING:jax._src.xla_bridge:An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %% [markdown]
# # Get some initial params

# %%
EJ = 4
EC = 4/5.9
EL = 4/29.2

n_lvls_transmon  = 4
n_lvls_fluxonium = 20

qsf = qs.Fluxonium.create(
    n_lvls_fluxonium,
    {"Ej": EJ, "Ec": EC, "El": EL, "phi_ext": 0.0},
    N_pre_diag=100,
    use_linear = False
    )

# %%
def detuned_rabi_period(amp_with_2pi, element, detunning):
    # element: obtained from scqubit operator
    # detunning: obtained from scqubit
    return 2*jnp.pi / jnp.sqrt(
        (amp_with_2pi*element)**2
        + (2*jnp.pi*detunning)**2
    )

# %%
def objective(params):    
    one_period_mult = 0.5
    zero_period_mult = 1
    two_period_mult = 1

    Ej_t, g_tf, amp_with_2pi = params
    

    qst = MyTransmon.create(
        N = n_lvls_transmon,
        params = {"Ej": Ej_t, "Ec": 0.2,"ng":0.0},
        N_max_charge=10
        )

    devices = [qsf, qst]
    f_indx = 0
    t_indx = 1
    Ns = [device.N for device in devices]
    fn = qs.promote(qsf.ops["n"], f_indx, Ns)
    tn = qs.promote(qst.ops['n'], t_indx, Ns)

    system = qs.System.create(devices, couplings=[
        g_tf *  fn @ tn
        ])
    system.params["g_tf"] = g_tf
    system_evals_in_product_indices, system_evecs_in_product_indices = system.calculate_eig_linear()
    system_evals_sorted, system_evecs_sorted, product_indices_sorted_by_eval = calculate_eig(Ns, system.get_H())
    driven_op = transform_op_into_dressed_basis_jax(tn, system_evecs_sorted.T)

    def get_dressed_idx(ql,tl):
        return find_closest_dressed_index(ql*qst.N+tl, product_indices_sorted_by_eval)
    zero = system_evals_in_product_indices[0,1] - system_evals_in_product_indices[0,0]
    one = system_evals_in_product_indices[1,1] - system_evals_in_product_indices[1,0]
    two = system_evals_in_product_indices[2,1] - system_evals_in_product_indices[2,0]
    zero_period = detuned_rabi_period(amp_with_2pi, jnp.abs(driven_op[get_dressed_idx(0,0),get_dressed_idx(0,1)]),one -zero)
    one_period = detuned_rabi_period(amp_with_2pi, jnp.abs(driven_op[get_dressed_idx(1,0),get_dressed_idx(1,1)]),one -one)
    two_period = detuned_rabi_period(amp_with_2pi, jnp.abs(driven_op[get_dressed_idx(2,0),get_dressed_idx(2,1)]),one -two)

    return jnp.abs(one_period*one_period_mult - zero_period*zero_period_mult)/one_period + \
        jnp.abs(one_period*one_period_mult - two_period*two_period_mult)/one_period

func = jax.value_and_grad(objective)

# %% [markdown]
# # Analyze the parameters I found from param sweep with g=0.2

# %%
params = jnp.array( [35.40918,  0.2,  0.05909091, ]) #     Ej_t, g_tf, amp_with_2pi = params

optimizer = optax.nadam(learning_rate=jnp.array([1e-2,1e-2,1e-2])) 
opt_state = optimizer.init(params)

num_steps = 1000
for step in range(num_steps):
    val, grads = func(params)
    # clear_output()
    print(f"iter: {step}, val={val:.4f} grads: {grads}, params: {params}")
    if val < 1e-4:
        break
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)

print(f'Optimized params: {params}')
# Out:
# iter: 0, val=0.0274 grads: [3.80413049 7.98515988 8.22463391], params: [35.40918     0.2         0.05909091]
# iter: 1, val=0.0643 grads: [ -3.74479588 -13.98981965  12.75800173], params: [35.39444316  0.18526316  0.04435407]
# iter: 2, val=0.2594 grads: [  3.2739316   12.31676391 -17.43974178], params: [3.53999473e+01 1.93709992e-01 3.18616339e-02]
# iter: 3, val=0.0927 grads: [  3.61039667  13.6749098  -16.13159385], params: [35.39444485  0.18844383  0.03654347]
# iter: 4, val=0.1120 grads: [ -3.71386474 -14.17224079  13.51255557], params: [35.38771072  0.18173362  0.04228621]
# iter: 5, val=0.0421 grads: [ -3.71386012 -14.17306063  14.67116869], params: [35.38917378  0.18399192  0.03998631]
# iter: 6, val=0.0852 grads: [  3.61037458  13.75450833 -16.46433531], params: [35.39227172  0.1878492   0.03601881]
# iter: 7, val=0.0167 grads: [-0.07603808 -0.10992385 -0.10357792], params: [35.38956909  0.18539614  0.03859556]
# iter: 8, val=0.0168 grads: [-0.07444397 -0.10252044 -0.11430045], params: [35.38892291  0.18503994  0.03897345]
# iter: 9, val=0.0248 grads: [ -3.69922821 -14.14898688  15.00024284], params: [35.38837733  0.18473275  0.03932776]
# iter: 10, val=0.0765 grads: [  3.61498087  13.794016   -16.33997109], params: [35.39111426  0.18788274  0.0363257 ]
# iter: 11, val=0.0167 grads: [-0.07639168 -0.11220541 -0.10024746], params: [35.38898991  0.1858673   0.03861753]
# iter: 12, val=0.0167 grads: [-0.07467032 -0.10454751 -0.11074468], params: [35.38857663  0.18558715  0.03909562]
# iter: 13, val=0.0198 grads: [ -3.69392985 -14.1166953   14.89992902], params: [35.38823338  0.18534475  0.03954156]
# iter: 14, val=0.0683 grads: [  3.62249282  13.80750001 -16.00484204], params: [35.39082088  0.18817095  0.03701036]
# iter: 15, val=0.0166 grads: [-0.07548611 -0.10973619 -0.10171201], params: [35.38897463  0.18635881  0.03913814]
# iter: 16, val=0.0166 grads: [-0.07374676 -0.10216917 -0.11161994], params: [35.38868183  0.18611399  0.03965287]
# iter: 17, val=0.0199 grads: [ -3.69342593 -14.08249339  14.62120039], params: [35.38844441  0.18590168  0.04013302]
# iter: 18, val=0.0606 grads: [  3.63102076  13.80736543 -15.58629078], params: [35.39095967  0.18855414  0.03786782]
# iter: 19, val=0.0165 grads: [-0.07403378 -0.10522592 -0.10502035], params: [35.38926065  0.18684733  0.03988736]
# iter: 20, val=0.0164 grads: [-0.07231465 -0.09785851 -0.11425492], params: [35.38903421  0.18661896  0.04041454]
# iter: 21, val=0.0223 grads: [ -3.69511677 -14.04681391  14.26738207], params: [35.3888552   0.18642041  0.04090654]
# iter: 22, val=0.0533 grads: [  3.63946234  13.79827035 -15.14090845], params: [35.39133369  0.18897168  0.03880603]
# iter: 23, val=0.0163 grads: [-0.07234031 -0.09984001 -0.10889497], params: [35.38971489  0.18732136  0.0407484 ]
# iter: 24, val=0.0163 grads: [-0.07065502 -0.09269966 -0.11747686], params: [35.38952556  0.18709965  0.0412777 ]
# iter: 25, val=0.0257 grads: [ -3.69766528 -14.00970032  13.88581303], params: [35.38937909  0.18690632  0.04177191]
# iter: 26, val=0.0464 grads: [  3.64733135  13.78286459 -14.69472755], params: [35.39183903  0.18939568  0.03978064]
# iter: 27, val=0.0161 grads: [-0.0705497  -0.09412046 -0.11278491], params: [35.39026309  0.18777515  0.04166482]
# iter: 28, val=0.0198 grads: [ -3.69599823 -13.963931    13.70665683], params: [35.39009399  0.18755471  0.04219161]
# iter: 29, val=0.0487 grads: [  3.64545401  13.73893679 -14.4487117 ], params: [35.39247454  0.18994596  0.04030397]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[123], line 8
#       6 num_steps = 1000
#       7 for step in range(num_steps):
# ----> 8     val, grads = func(params)
#       9     # clear_output()
#      10     print(f"iter: {step}, val={val:.4f} grads: {grads}, params: {params}")
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/api.py:691, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     689   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     690 if not has_aux:
# --> 691   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     692 else:
#     693   ans, vjp_py, aux = _vjp(
#     694       f_partial, *dyn_args, has_aux=True)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/api.py:2178, in _vjp(fun, has_aux, *primals)
#    2176 if not has_aux:
#    2177   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2178   out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    2179   out_tree = out_tree()
#    2180 else:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:143, in vjp(traceable, primals, has_aux)
#     141 def vjp(traceable, primals, has_aux=False):
#     142   if not has_aux:
# --> 143     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144   else:
#     145     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:132, in linearize(traceable, *primals, **kwargs)
#     130 _, in_tree = tree_flatten(((primals, primals), {}))
#     131 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# Cell In[120], line 16, in objective(params)
#       9 qst = MyTransmon.create(
#      10     N = n_lvls_transmon,
#      11     params = {"Ej": Ej_t, "Ec": 0.2,"ng":0.0},
#      12     N_max_charge=10
#      13     )
#      15 devices = [qsf, qst]
# ---> 16 fn = qs.promote(qsf.ops["n"], f_indx, Ns)
#      17 tn = qs.promote(qst.ops['n'], t_indx, Ns)
#      19 system = qs.System.create(devices, couplings=[
#      20     g_tf *  fn @ tn
#      21     ])
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:42, in Device.ops(self)
#      40 @property
#      41 def ops(self):
# ---> 42     return self.full_ops()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:111, in Device.full_ops(self)
#     109 ops = {}
#     110 for name, op in linear_ops.items():
# --> 111     ops[name] = self.get_op_in_H_eigenbasis(op)
#     113 return ops
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:85, in Device.get_op_in_H_eigenbasis(self, op)
#      84 def get_op_in_H_eigenbasis(self, op: jqt.Qarray):
# ---> 85     evecs = self.eig_systems["vecs"][:, : self.N]
#      86     dims = [[self.N], [self.N]]
#      87     return get_op_in_new_basis(op, evecs, dims)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:78, in Device.eig_systems(self)
#      75 @property
#      76 def eig_systems(self):
#      77     eig_systems = {}
# ---> 78     eig_systems["vals"], eig_systems["vecs"] = self._calculate_eig_systems()
#      80     eig_systems["vecs"] = eig_systems["vecs"]
#      81     eig_systems["vals"] = eig_systems["vals"]
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:70, in Device._calculate_eig_systems(self)
#      69 def _calculate_eig_systems(self):
# ---> 70     data = self._get_H_in_linear_basis().data
#      71     evs, evecs = jnp.linalg.eigh(data)  # Hermitian
#      72     idxs_sorted = jnp.argsort(evs)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:67, in Device._get_H_in_linear_basis(self)
#      66 def _get_H_in_linear_basis(self):
# ---> 67     return self.get_H_linear() if self._use_linear else self.get_H_full()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/fluxonium.py:58, in Fluxonium.get_H_full(self)
#      56 """Return full H in linear basis."""
#      57 op_cos_phi = jqt.cosm(self.linear_ops["phi"])
# ---> 58 op_sin_phi = jqt.sinm(self.linear_ops["phi"])
#      60 phi_ext = self.params["phi_ext"]
#      61 Hcos = op_cos_phi * jnp.cos(2.0 * jnp.pi * phi_ext) + op_sin_phi * jnp.sin(
#      62     2.0 * jnp.pi * phi_ext
#      63 )
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:38, in Device.linear_ops(self)
#      36 @property
#      37 def linear_ops(self):
# ---> 38     return self.common_ops()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/fluxonium.py:31, in Fluxonium.common_ops(self)
#      28 ops["n"] = 1j * self.n_zpf() * (ops["a_dag"] - ops["a"])
#      30 ops["cos(φ/2)"] = jqt.cosm(ops["phi"] / 2)
# ---> 31 ops["sin(φ/2)"] = jqt.sinm(ops["phi"] / 2)
#      33 return ops
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jaxquantum/core/qarray.py:363, in sinm(qarr)
#     362 def sinm(qarr: Qarray) -> Qarray:
# --> 363     return (expm(1j*qarr) - expm(-1j*qarr))/(2j)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jaxquantum/core/qarray.py:354, in expm(qarr, **kwargs)
#     348 def expm(qarr: Qarray, **kwargs) -> Qarray:
#     349     """Matrix exponential wrapper.
#     350
#     351     Returns:
#     352         matrix exponential
#     353     """
# --> 354     data = jsp.linalg.expm(qarr.data, **kwargs)
#     355     dims = deepcopy(qarr.dims)
#     356     return Qarray.create(data, dims=dims)
#
# KeyboardInterrupt:

# %% [markdown]
# # Let's check the short period one

# %%
transmon_EJ,g,amp =  [35.38952556 , 0.18709965,  0.0412777 ]

fluxonium = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=n_lvls_fluxonium)
transmon = scqubits.Transmon(
    EJ=transmon_EJ,
    EC=0.2,
    ng=0.0,
    ncut=10,
    truncated_dim = 4
    )

system = FluxoniumTransmonSystem(
    fluxonium  = fluxonium,
    transmon = transmon,
    computaional_states = '0,2',
    g_strength = g,
    )

e_ops = []
for ql in range(n_lvls_fluxonium):
    for tl in range(4):
        e_ops.append(system.truncate_function(qutip.ket2dm(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,tl)]))))


amp_with_2pi = amp
t_tot = 100
tlist = np.linspace(0,t_tot,int(t_tot))


results = system.run_qutip_mesolve_parrallel(
        initial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, i)) for i in range(3)],
        tlist = tlist,
        drive_terms = [DriveTerm( 
                driven_op=system.truncate_function(system.hilbertspace.op_in_dressed_eigenbasis(system.transmon.n_operator)),
                pulse_shape_func=square_pulse_with_rise_fall,
                pulse_shape_args={
                    'w_d':system.evals[system.product_to_dressed[(1,1)]] - system.evals[system.product_to_dressed[(1,0)]],
                    'amp': amp_with_2pi/(2*np.pi),
                    't_rise': 4,
                    't_square': 1000
                  },
                )],
        c_ops = None,
        e_ops = e_ops
    )
# Out:
# RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#  /home/kai/miniconda3/envs/test/lib/python3.10/site-packages/loky/backend/fork_exec.py: 38An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
#  Total run time:  39.27s*] Elapsed 39.27s / Remaining 00:00:00:00[          0%           ] Elapsed 0.00s / Remaining 00:00:00:00
#  [*********98%***********] Elapsed 39.41s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 100/100 [00:00<00:00, 7199.41it/s]
#  Total run time:  39.50s*] Elapsed 39.50s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 100/100 [00:00<00:00, 4647.58it/s]
#  Total run time:  39.88s*] Elapsed 39.88s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 100/100 [00:00<00:00, 6756.62it/s]

# %%
colors = ['green','red','darkorange']
fig,axes = plt.subplots(2,3,figsize = (12,6))
for col, levels_list in zip([0,1,2],
                    [
                        [(0,0),(0,1)],
                        [(1,0),(1,1),(8,0)],
                        [(2,0),(2,1)]
                    ]):
    for row in [0,1]:
        for (ql,tl) in levels_list:
            i = ql*4+tl
            # if (ql,tl) not in [(0,0), (1,1),(2,0)]:
            axes[row, col].plot(tlist,results[col].expect[i],label = rf"$\langle{ql}{tl}\rangle$",alpha=0.5)
            # else:
            #     axes[row, col].plot(tlist,1 - results[col].expect[i],label = rf"1 - $\langle{ql}{tl}\rangle$",alpha=0.5)
    axes[0,col].legend()
    # axes[1,col].axvline(x=270, color='b', linestyle='--')
    # axes[1,col].set_xlim(260,280)
axes[0,0].set_ylim(-1e-3,1)
axes[0,1].set_ylim(-1e-5,1)
axes[0,2].set_ylim(-1e-5,1)
axes[1,0].set_ylim(-1e-5,1e-2)
axes[1,1].set_ylim(-1e-5,1e-2)
axes[1,2].set_ylim(-1e-5,1e-2)

axes[1,0].set_xlim(65,70)
axes[1,1].set_xlim(65,70)
axes[1,2].set_xlim(65,70)
# Out:
# (65.0, 70.0)

# %% [markdown]
# # Let's check the long one

# %%
params = jnp.array( [49.55102,  0.2,  0.006742424 ]) #     Ej_t, g_tf, amp_with_2pi = params

optimizer = optax.nadam(learning_rate=jnp.array([1e-2,1e-2,2e-3])) 
opt_state = optimizer.init(params)

num_steps = 1000
for step in range(num_steps):
    val, grads = func(params)
    # clear_output()
    print(f"iter: {step}, val={val:.4f} grads: {grads}, params: {params}")
    if val < 1e-4:
        break
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)

print(f'Optimized params: {params}')
# Out:
# iter: 0, val=0.0044 grads: [-0.93565776 -3.39494641 -0.69477193], params: [4.955102e+01 2.000000e-01 6.742424e-03]
# iter: 1, val=0.2117 grads: [ 0.38612889 -5.07898832 80.79679346], params: [4.95657568e+01 2.14736842e-01 9.68979238e-03]
# iter: 2, val=0.0928 grads: [0.76312136 2.77930991 5.14469197], params: [4.95650330e+01 2.27177420e-01 7.26978069e-03]
# iter: 3, val=0.1715 grads: [  -0.34013894    4.05769374 -108.88369676], params: [4.95599235e+01 2.27598090e-01 6.32301864e-03]
# iter: 4, val=0.0839 grads: [0.78752746 2.90431177 4.0943911 ], params: [4.95615070e+01 2.24605919e-01 7.51063832e-03]
# iter: 5, val=0.0705 grads: [0.81570408 3.03510852 3.14607377], params: [4.95565444e+01 2.21231637e-01 7.67566769e-03]
# iter: 6, val=0.0519 grads: [0.85135673 3.18307559 2.2378804 ], params: [4.95504162e+01 2.16776001e-01 7.80714421e-03]
# iter: 7, val=0.0608 grads: [ 0.44896439 -4.92013237 97.92174816], params: [4.95434067e+01 2.11418328e-01 7.91530571e-03]
# iter: 8, val=0.0486 grads: [  -0.4394752     4.65653924 -107.42198026], params: [4.95371806e+01 2.12736421e-01 6.93907555e-03]
# iter: 9, val=0.0422 grads: [  0.47765528  -4.91403201 101.33954005], params: [4.95346643e+01 2.08312871e-01 7.61648423e-03]
# iter: 10, val=0.0404 grads: [  -0.46482041    4.70456075 -108.20548416], params: [4.95294684e+01 2.09774702e-01 6.91908089e-03]
# iter: 11, val=0.0364 grads: [  0.49868378  -4.91045171 102.83210125], params: [4.95278253e+01 2.06272930e-01 7.49423915e-03]
# iter: 12, val=0.0324 grads: [  -0.48419251    4.73333858 -108.37383825], params: [4.95234051e+01 2.07815324e-01 6.93360500e-03]
# iter: 13, val=0.0358 grads: [  0.51482209  -4.90632051 103.42510224], params: [4.95224134e+01 2.04886977e-01 7.44900633e-03]
# iter: 14, val=0.0246 grads: [  -0.4993921     4.75154464 -108.17075862], params: [4.95185848e+01 2.06476298e-01 6.96953432e-03]
# iter: 15, val=0.0378 grads: [  0.52749066  -4.90156919 103.52006092], params: [4.95180872e+01 2.03931253e-01 7.44505438e-03]
# iter: 16, val=0.0191 grads: [-0.94455537 -3.57624449 -0.08687398], params: [4.95147150e+01 2.05548087e-01 7.01874665e-03]
# iter: 17, val=0.0386 grads: [  -0.49299693    4.68524207 -108.58158736], params: [4.95161568e+01 2.07635250e-01 6.90147895e-03]
# iter: 18, val=0.0187 grads: [  0.51097809  -4.82498168 104.00580665], params: [4.95175913e+01 2.06176660e-01 7.36829039e-03]
# iter: 19, val=0.0335 grads: [  -0.48957041    4.67836138 -107.55626928], params: [4.95162354e+01 2.08447212e-01 6.98384953e-03]
# iter: 20, val=0.0204 grads: [  0.50627844  -4.81021863 103.29894921], params: [4.95175989e+01 2.07006967e-01 7.42391203e-03]
# iter: 21, val=0.0281 grads: [  -0.48684461    4.67395268 -106.57903418], params: [4.95162338e+01 2.09147131e-01 7.06492793e-03]
# iter: 22, val=0.0232 grads: [  0.50253999  -4.7991804  102.56591784], params: [4.95175459e+01 2.07718536e-01 7.48443548e-03]
# iter: 23, val=0.0225 grads: [  -0.48463842    4.67129799 -105.64774814], params: [4.95161732e+01 2.09757859e-01 7.14429739e-03]
# iter: 24, val=0.0267 grads: [  0.49950363  -4.79083028 101.82750638], params: [4.95174479e+01 2.08336627e-01 7.54754728e-03]
# iter: 25, val=0.0169 grads: [  -0.48282315    4.66988943 -104.75947919], params: [4.95160689e+01 2.10296657e-01 7.22174962e-03]
# iter: 26, val=0.0305 grads: [  0.49699096  -4.7844436  101.09512156], params: [4.95173168e+01 2.08879979e-01 7.61185213e-03]
# iter: 27, val=0.0114 grads: [  -0.48130527    4.66936452 -103.91093867], params: [4.95159323e+01 2.10776817e-01 7.29721351e-03]
# iter: 28, val=0.0347 grads: [  0.49487526  -4.77950397 100.37495141], params: [4.95171613e+01 2.09362817e-01 7.67649297e-03]
# iter: 29, val=0.0059 grads: [  -0.48001556    4.66946226 -103.09876804], params: [4.95157722e+01 2.11208727e-01 7.37070505e-03]
# iter: 30, val=0.0389 grads: [ 0.49306423 -4.77563761 99.67017475], params: [4.95169880e+01 2.09796141e-01 7.74094220e-03]
# iter: 31, val=0.0033 grads: [0.91381236 3.480238   0.95792016], params: [4.95155949e+01 2.11600609e-01 7.44229360e-03]
# iter: 32, val=0.0055 grads: [  -0.48771615    4.66007296 -103.14433219], params: [4.95120942e+01 2.10701099e-01 7.36895314e-03]
# iter: 33, val=0.0426 grads: [ 0.50805913 -4.77446087 99.72707185], params: [4.95120348e+01 2.08578071e-01 7.74452625e-03]
# iter: 34, val=0.0090 grads: [-0.93437529 -3.56677401 -0.57385265], params: [4.95094951e+01 2.09719555e-01 7.45127510e-03]
# iter: 35, val=0.0067 grads: [  -0.4852697     4.63988846 -102.81567268], params: [4.95111192e+01 2.11318282e-01 7.38929707e-03]
# iter: 36, val=0.0388 grads: [ 0.49782732 -4.74582763 99.29602922], params: [4.95127226e+01 2.09996896e-01 7.77046032e-03]
# iter: 37, val=0.0010 grads: [  0.48283484  -4.64668783 101.80661287], params: [4.95117724e+01 2.11822889e-01 7.48452781e-03]
# iter: 38, val=0.0625 grads: [  -0.45905614    4.45772795 -105.91398273], params: [4.95101008e+01 2.14496861e-01 6.99780133e-03]
# iter: 39, val=0.0379 grads: [  -0.46527948    4.52416269 -104.02875367], params: [4.95108688e+01 2.14026288e-01 7.20841681e-03]
# iter: 40, val=0.0117 grads: [  0.47938743  -4.65302657 100.36537005], params: [4.95123845e+01 2.12565531e-01 7.62137271e-03]
# iter: 41, val=0.0217 grads: [  -0.46660795    4.55645019 -102.46829205], params: [4.95114220e+01 2.14173734e-01 7.36998315e-03]
# iter: 42, val=0.0256 grads: [ 0.47968723 -4.67444314 98.9640697 ], params: [4.95128699e+01 2.12719216e-01 7.76537156e-03]
# iter: 43, val=0.0094 grads: [0.90055351 3.45351225 1.160229  ], params: [4.95118303e+01 2.14336958e-01 7.51157495e-03]
# iter: 44, val=0.0089 grads: [  -0.47652082    4.58170657 -101.6096311 ], params: [4.95086974e+01 2.13363890e-01 7.47145022e-03]
# iter: 45, val=0.0399 grads: [ 0.49593652 -4.70000438 98.21091757], params: [4.95088485e+01 2.11226632e-01 7.86002944e-03]
# iter: 46, val=0.0084 grads: [  0.48837779  -4.6211316  100.51546925], params: [4.95065994e+01 2.12247306e-01 7.60208752e-03]
# iter: 47, val=0.0484 grads: [  -0.47093131    4.46245431 -104.43091125], params: [4.95037309e+01 2.14187479e-01 7.14739256e-03]
# iter: 48, val=0.0209 grads: [  -0.48253908    4.53658585 -102.5718026 ], params: [4.95034753e+01 2.13091918e-01 7.36611290e-03]
# iter: 49, val=0.0304 grads: [ 0.5021747  -4.6613736  98.93280648], params: [4.95041086e+01 2.11073375e-01 7.78047774e-03]
# iter: 50, val=0.0069 grads: [-0.92748514 -3.57544251 -0.62404321], params: [4.95022409e+01 2.12160997e-01 7.54778955e-03]
# iter: 51, val=0.0064 grads: [  -0.48035852    4.55541929 -100.88954753], params: [4.95044126e+01 2.13727183e-01 7.53298141e-03]
# iter: 52, val=0.0403 grads: [ 0.49171789 -4.66293795 97.30320487], params: [4.95065072e+01 2.12466790e-01 7.93515276e-03]
# iter: 53, val=0.0086 grads: [ 0.47765412 -4.5796507  99.27337903], params: [4.95060240e+01 2.14243138e-01 7.69816247e-03]
# iter: 54, val=0.0474 grads: [  -0.45600693    4.41735212 -102.76340104], params: [4.95047786e+01 2.16850733e-01 7.26635497e-03]
# iter: 55, val=0.0217 grads: [  -0.46137324    4.48409792 -100.78791886], params: [4.95059181e+01 2.16390572e-01 7.49381852e-03]
# iter: 56, val=0.0271 grads: [ 0.47363123 -4.60482536 97.19612249], params: [4.95077631e+01 2.14957933e-01 7.91168871e-03]
# iter: 57, val=0.0130 grads: [0.89553989 3.45826776 1.26406084], params: [4.95071184e+01 2.16533679e-01 7.69395490e-03]
# iter: 58, val=0.0071 grads: [0.90498555 3.49847681 1.07242063], params: [4.95043354e+01 2.15548144e-01 7.68122124e-03]
# iter: 59, val=0.0045 grads: [ 0.48670923 -4.54787045 99.53331835], params: [4.95002990e+01 2.13861460e-01 7.66768927e-03]
# iter: 60, val=0.0454 grads: [  -0.47588226    4.41448334 -103.2000616 ], params: [4.94964683e+01 2.15001063e-01 7.24378036e-03]
# iter: 61, val=0.0132 grads: [  -0.49374763    4.50201582 -101.24735898], params: [4.94953204e+01 2.13214360e-01 7.48683187e-03]
# iter: 62, val=0.0421 grads: [ 0.51989232 -4.62868367 97.49874051], params: [4.94951639e+01 2.10575190e-01 7.92190398e-03]
# iter: 63, val=0.0198 grads: [-0.951229   -3.68569659 -0.30808546], params: [4.94925500e+01 2.11093109e-01 7.71154333e-03]
# iter: 64, val=0.0143 grads: [-0.94129805 -3.65016714 -0.44796367], params: [4.94941047e+01 2.12200329e-01 7.71449411e-03]
# iter: 65, val=0.0073 grads: [ 0.49052493 -4.53057826 98.98296967], params: [4.94970551e+01 2.14017522e-01 7.71843971e-03]
# iter: 66, val=0.0471 grads: [  -0.46542239    4.37711722 -102.24744954], params: [4.94967165e+01 2.16855437e-01 7.30592541e-03]
# iter: 67, val=0.0194 grads: [  -0.46941411    4.44597201 -100.02801854], params: [4.94986531e+01 2.16607839e-01 7.55963814e-03]
# iter: 68, val=0.0309 grads: [ 0.48044238 -4.56542814 96.22299948], params: [4.95012031e+01 2.15366119e-01 8.00315834e-03]
# iter: 69, val=0.0099 grads: [0.90073713 3.49845    1.15451388], params: [4.95012335e+01 2.17112799e-01 7.80250857e-03]
# iter: 70, val=0.0069 grads: [ 0.4748857  -4.50076254 97.84641328], params: [4.94991075e+01 2.16252553e-01 7.80740277e-03]
# iter: 71, val=0.0426 grads: [  -0.45920904    4.36394886 -101.11222545], params: [4.94970347e+01 2.18128100e-01 7.40318229e-03]
# iter: 72, val=0.0120 grads: [ -0.46992489   4.44476255 -99.04077587], params: [4.94973639e+01 2.17021039e-01 7.65819737e-03]
# iter: 73, val=0.0407 grads: [ 0.48751106 -4.56921566 95.34329408], params: [4.94984747e+01 2.15001864e-01 8.10147750e-03]
# iter: 74, val=0.0164 grads: [ 0.47985237 -4.50842317 96.96545469], params: [4.94971822e+01 2.16055825e-01 7.90508475e-03]
# iter: 75, val=0.0320 grads: [  -0.46384709    4.37791193 -100.1313831 ], params: [4.94952102e+01 2.18011746e-01 7.51204368e-03]
# iter: 76, val=0.0043 grads: [0.90660541 3.53697777 0.97985287], params: [4.94956748e+01 2.16971911e-01 7.76827762e-03]
# iter: 77, val=0.0065 grads: [ 0.48835978 -4.47767463 97.97313565], params: [4.94924663e+01 2.15403229e-01 7.79708620e-03]
# iter: 78, val=0.0386 grads: [  -0.47696217    4.35926405 -101.16706912], params: [4.94893828e+01 2.16642871e-01 7.41384989e-03]
# iter: 79, val=0.0091 grads: [-0.92576676 -3.62353974 -0.53780706], params: [4.94888894e+01 2.14966238e-01 7.68769250e-03]
# iter: 80, val=0.0040 grads: [-0.91849681 -3.59361367 -0.70922608], params: [4.94906889e+01 2.15910490e-01 7.73597595e-03]
# iter: 81, val=0.0048 grads: [0.90467911 3.53777486 0.99264395], params: [4.94938163e+01 2.17574449e-01 7.78164060e-03]
# iter: 82, val=0.0022 grads: [ 0.47967164 -4.44554443 97.57177981], params: [4.94923935e+01 2.16802757e-01 7.81732738e-03]
# iter: 83, val=0.0449 grads: [  -0.46254265    4.31639803 -100.58491693], params: [4.94909488e+01 2.18762639e-01 7.43524349e-03]
# iter: 84, val=0.0120 grads: [ -0.47280435   4.40162725 -98.3010861 ], params: [4.94918257e+01 2.17741643e-01 7.71703564e-03]
# iter: 85, val=0.0426 grads: [ 0.48984982 -4.52739699 94.42785399], params: [4.94934207e+01 2.15800691e-01 8.18571729e-03]
# iter: 86, val=0.0202 grads: [ 0.48136638 -4.47253847 95.85545932], params: [4.94925927e+01 2.16920837e-01 8.00811546e-03]
# iter: 87, val=0.0261 grads: [ -0.46484864   4.35057854 -98.82969991], params: [4.94910526e+01 2.18937554e-01 7.63136439e-03]
# iter: 88, val=0.0053 grads: [ 0.47424631 -4.42745217 96.61195043], params: [4.94918730e+01 2.17949057e-01 7.90427372e-03]
# iter: 89, val=0.0393 grads: [ -0.45837698   4.30485891 -99.41765268], params: [4.94903935e+01 2.19871141e-01 7.54212630e-03]
# iter: 90, val=0.0070 grads: [0.89996313 3.53245373 1.06001373], params: [4.94912469e+01 2.18826531e-01 7.83077484e-03]
# iter: 91, val=0.0052 grads: [ 0.48272099 -4.42032413 96.82291965], params: [4.94884571e+01 2.17235947e-01 7.88718675e-03]
# iter: 92, val=0.0366 grads: [ -0.47191052   4.31109304 -99.72788903], params: [4.94857616e+01 2.18450719e-01 7.52850110e-03]
# iter: 93, val=0.0056 grads: [-0.92046889 -3.62021042 -0.66520527], params: [4.94855673e+01 2.16762428e-01 7.82410397e-03]
# iter: 94, val=0.0033 grads: [ 0.4808172  -4.40431702 96.68829266], params: [4.94876018e+01 2.17703843e-01 7.89284100e-03]
# iter: 95, val=0.0405 grads: [ -0.46346466   4.2851371  -99.38779624], params: [4.94865260e+01 2.19721047e-01 7.54100434e-03]
# iter: 96, val=0.0061 grads: [ -0.47309878   4.37143608 -96.95764567], params: [4.94877548e+01 2.18764563e-01 7.84305246e-03]
# iter: 97, val=0.0491 grads: [ 0.48915272 -4.49449741 93.0110633 ], params: [4.94896712e+01 2.16884862e-01 8.32683152e-03]
# iter: 98, val=0.0290 grads: [ 0.48045205 -4.44576018 94.22294652], params: [4.94891213e+01 2.18049365e-01 8.17121502e-03]
# iter: 99, val=0.0144 grads: [ -0.46426701   4.33436452 -96.94931686], params: [4.94878296e+01 2.20104765e-01 7.81804938e-03]
# iter: 100, val=0.0175 grads: [ 0.47281188 -4.40893768 94.67127875], params: [4.94888827e+01 2.19153738e-01 8.10163840e-03]
# iter: 101, val=0.0244 grads: [ -0.45751996   4.29738778 -97.26301365], params: [4.94876073e+01 2.21108140e-01 7.76012506e-03]
# iter: 102, val=0.0093 grads: [0.90005983 3.54610203 1.1234057 ], params: [4.94886505e+01 2.20089842e-01 8.05549292e-03]
# iter: 103, val=0.0208 grads: [ 0.4807414  -4.40819244 94.5529014 ], params: [4.94860126e+01 2.18513632e-01 8.12158353e-03]
# iter: 104, val=0.0185 grads: [ -0.47090193   4.30961884 -97.26359545], params: [4.94834601e+01 2.19747496e-01 7.78064148e-03]
# iter: 105, val=0.0174 grads: [ 0.48632103 -4.39534009 94.95218454], params: [4.94834003e+01 2.18070523e-01 8.07843842e-03]
# iter: 106, val=0.0213 grads: [ -0.47546178   4.29807253 -97.58033223], params: [4.94810665e+01 2.19365728e-01 7.74668622e-03]
# iter: 107, val=0.0154 grads: [ 0.49077824 -4.38490765 95.17698351], params: [4.94812348e+01 2.17751515e-01 8.05393338e-03]
# iter: 108, val=0.0227 grads: [ -0.47914494   4.28913269 -97.73396729], params: [4.94790779e+01 2.19096469e-01 7.73004353e-03]
# iter: 109, val=0.0146 grads: [ 0.49434741 -4.37651242 95.26089915], params: [4.94794317e+01 2.17532827e-01 8.04450615e-03]
# iter: 110, val=0.0230 grads: [ -0.48213643   4.28235126 -97.75632114], params: [4.94774178e+01 2.18918097e-01 7.72737986e-03]
# iter: 111, val=0.0147 grads: [ 0.49720854 -4.36980436 95.23153561], params: [4.94779227e+01 2.17395085e-01 8.04725581e-03]
# iter: 112, val=0.0224 grads: [ -0.4845764    4.27733185 -97.67345325], params: [4.94760243e+01 2.18812981e-01 7.73598216e-03]
# iter: 113, val=0.0156 grads: [ 0.49950092 -4.3644756  95.11147566], params: [4.94766522e+01 2.17322502e-01 8.05982177e-03]
# iter: 114, val=0.0210 grads: [ -0.48657216   4.2737337  -97.5066287 ], params: [4.94748470e+01 2.18766751e-01 7.75364433e-03]
# iter: 115, val=0.0171 grads: [ 0.50133332 -4.36026252 94.91913404], params: [4.94755753e+01 2.17302214e-01 8.08028437e-03]
# iter: 116, val=0.0191 grads: [ -0.48820685   4.27126981 -97.27315092], params: [4.94738453e+01 2.18767700e-01 7.77857383e-03]
# iter: 117, val=0.0191 grads: [ 0.50279142 -4.35694353 94.66948732], params: [4.94746557e+01 2.17323747e-01 8.10708354e-03]
# iter: 118, val=0.0167 grads: [ -0.48954568   4.26970206 -96.98706639], params: [4.94729863e+01 2.18806292e-01 7.80931525e-03]
# iter: 119, val=0.0214 grads: [ 0.50394333 -4.35433494 94.37468865], params: [4.94738639e+01 2.17378573e-01 8.13895213e-03]
# iter: 120, val=0.0139 grads: [ -0.4906404    4.2688351  -96.65975408], params: [4.94722434e+01 2.18874765e-01 7.84468772e-03]
# iter: 121, val=0.0241 grads: [ 0.50484366 -4.3522861  94.04458051], params: [4.94731760e+01 2.17459752e-01 8.17486157e-03]
# iter: 122, val=0.0109 grads: [ -0.49153248   4.26851014 -96.30041427], params: [4.94715949e+01 2.18966807e-01 7.88373382e-03]
# iter: 123, val=0.0270 grads: [ 0.50553643 -4.3506744  93.68711917], params: [4.94725728e+01 2.17561642e-01 8.21397752e-03]
# iter: 124, val=0.0105 grads: [-0.92207139 -3.68218783 -0.48649743], params: [4.94710234e+01 2.19077286e-01 7.92567792e-03]
# iter: 125, val=0.0221 grads: [ -0.47471617   4.22513151 -96.22889435], params: [4.94734363e+01 2.21151257e-01 7.85444923e-03]
# iter: 126, val=0.0145 grads: [ 0.48211647 -4.30868804 93.52858959], params: [4.94757353e+01 2.20410133e-01 8.19530106e-03]
# iter: 127, val=0.0210 grads: [ -0.46496573   4.21643151 -95.52957476], params: [4.94754889e+01 2.22500301e-01 7.91539333e-03]
# iter: 128, val=0.0154 grads: [ 0.47266783 -4.30103201 92.90256129], params: [4.94775436e+01 2.21647028e-01 8.25292109e-03]
# iter: 129, val=0.0194 grads: [ -0.45709467   4.2096308  -94.87632359], params: [4.94771169e+01 2.23632022e-01 7.97452852e-03]
# iter: 130, val=0.0168 grads: [ 0.4649977  -4.29481403 92.31277684], params: [4.94789750e+01 2.22687705e-01 8.30899241e-03]
# iter: 131, val=0.0174 grads: [ -0.45069284   4.20446846 -94.26397058], params: [4.94784020e+01 2.24587581e-01 8.03201381e-03]
# iter: 132, val=0.0186 grads: [ 0.45872185 -4.28986464 91.75548015], params: [4.94801018e+01 2.23569226e-01 8.36365269e-03]
# iter: 133, val=0.0199 grads: [0.87380353 3.48966401 1.47548286], params: [4.94794102e+01 2.25400205e-01 8.08800458e-03]
# iter: 134, val=0.0198 grads: [ -0.45218793   4.19012979 -94.3592382 ], params: [4.94766304e+01 2.24631734e-01 8.01634496e-03]
# iter: 135, val=0.0194 grads: [ 0.46702771 -4.28529321 91.90879347], params: [4.94769794e+01 2.22828287e-01 8.35338308e-03]
# iter: 136, val=0.0117 grads: [ -0.458945     4.20704495 -93.93897145], params: [4.94750456e+01 2.23952519e-01 8.07977180e-03]
# iter: 137, val=0.0268 grads: [ 0.47325895 -4.29707443 91.47779656], params: [4.94755507e+01 2.22230986e-01 8.41396966e-03]
# iter: 138, val=0.0080 grads: [0.89449002 3.58192005 1.07841574], params: [4.94737203e+01 2.23438474e-01 8.14075117e-03]
# iter: 139, val=0.0068 grads: [ -0.47664464   4.21656081 -94.21678343], params: [4.94698759e+01 2.22061331e-01 8.07294575e-03]
# iter: 140, val=0.0346 grads: [ 0.49776401 -4.30788192 91.71136862], params: [4.94693785e+01 2.19715586e-01 8.41318446e-03]
# iter: 141, val=0.0097 grads: [-0.92389127 -3.70563878 -0.56064058], params: [4.94665438e+01 2.20372053e-01 8.14194647e-03]
# iter: 142, val=0.0052 grads: [ -0.48160486   4.21299047 -94.14843983], params: [4.94678102e+01 2.21695098e-01 8.08396479e-03]
# iter: 143, val=0.0337 grads: [ 0.49463661 -4.29703252 91.50025588], params: [4.94690957e+01 2.20263096e-01 8.43074186e-03]
# iter: 144, val=0.0034 grads: [-0.91323176 -3.66598787 -0.73802561], params: [4.94678786e+01 2.21739885e-01 8.16456736e-03]
# iter: 145, val=0.0101 grads: [ -0.46555415   4.18814974 -93.64120846], params: [4.94705395e+01 2.23787758e-01 8.11209441e-03]
# iter: 146, val=0.0267 grads: [ 0.47181081 -4.27046238 90.95476885], params: [4.94730454e+01 2.23024050e-01 8.46256737e-03]
# iter: 147, val=0.0133 grads: [0.88539126 3.55427863 1.24216972], params: [4.94730351e+01 2.25089141e-01 8.20123230e-03]
# iter: 148, val=0.0099 grads: [ -0.46125999   4.17937691 -93.27718101], params: [4.94708676e+01 2.24492569e-01 8.14415763e-03]
# iter: 149, val=0.0297 grads: [ 0.47480241 -4.26983546 90.70719538], params: [4.94717896e+01 2.22855637e-01 8.49418904e-03]
# iter: 150, val=0.0076 grads: [0.89556809 3.59891412 1.06254437], params: [4.94703540e+01 2.24136693e-01 8.23244724e-03]
# iter: 151, val=0.0017 grads: [ -0.4769239    4.19626422 -93.22118096], params: [4.94668866e+01 2.22810628e-01 8.17583674e-03]
# iter: 152, val=0.0402 grads: [ 0.49726181 -4.28630631 90.65057996], params: [4.94666971e+01 2.20517470e-01 8.52690545e-03]
# iter: 153, val=0.0119 grads: [ 0.49198243 -4.22417089 92.67636289], params: [4.94641688e+01 2.21222319e-01 8.26469861e-03]
# iter: 154, val=0.0387 grads: [ -0.47710739   4.10117819 -96.02942793], params: [4.94610542e+01 2.22825036e-01 7.81556739e-03]
# iter: 155, val=0.0151 grads: [ -0.48957272   4.15729873 -94.63513141], params: [4.94605680e+01 2.21573835e-01 8.01111056e-03]
# iter: 156, val=0.0300 grads: [ 0.51010789 -4.25281203 91.74525125], params: [4.94609920e+01 2.19469495e-01 8.39748413e-03]
# iter: 157, val=0.0170 grads: [-0.93289549 -3.76435345 -0.34037094], params: [4.94589453e+01 2.20323363e-01 8.16041971e-03]
# iter: 158, val=0.0094 grads: [-0.91868333 -3.71015077 -0.53830104], params: [4.94609368e+01 2.21865895e-01 8.13449149e-03]
# iter: 159, val=0.0143 grads: [ -0.47071979   4.14176893 -93.49157922], params: [4.94642646e+01 2.24107861e-01 8.11270182e-03]
# iter: 160, val=0.0248 grads: [ 0.47602549 -4.22785242 90.57037473], params: [4.94673785e+01 2.23515797e-01 8.49485174e-03]
# iter: 161, val=0.0111 grads: [0.88770375 3.58096327 1.16982363], params: [4.94679147e+01 2.25722035e-01 8.25774238e-03]
# iter: 162, val=0.0078 grads: [0.89181983 3.60039096 1.07025583], params: [4.94662544e+01 2.25236227e-01 8.22401906e-03]
# iter: 163, val=0.0068 grads: [ -0.47407951   4.15063196 -92.87310487], params: [4.94632493e+01 2.23954241e-01 8.19132825e-03]
# iter: 164, val=0.0370 grads: [ 0.49383769 -4.24541717 90.15674114], params: [4.94634308e+01 2.21715762e-01 8.56674841e-03]
# iter: 165, val=0.0107 grads: [ 0.48818559 -4.18734837 91.99844294], params: [4.94612769e+01 2.22456022e-01 8.32309668e-03]
# iter: 166, val=0.0379 grads: [ -0.47334198   4.0695413  -95.16363254], params: [4.94585153e+01 2.24087782e-01 7.89029600e-03]
# iter: 167, val=0.0130 grads: [ -0.48532735   4.12837926 -93.66678001], params: [4.94583048e+01 2.22870873e-01 8.10182658e-03]
# iter: 168, val=0.0329 grads: [ 0.50504707 -4.22496479 90.71362136], params: [4.94589603e+01 2.20798649e-01 8.50244128e-03]
# iter: 169, val=0.0135 grads: [-0.92825833 -3.75594784 -0.46580682], params: [4.94571702e+01 2.21676874e-01 8.27832866e-03]
# iter: 170, val=0.0056 grads: [-0.9141677  -3.70157639 -0.67015344], params: [4.94593302e+01 2.23247278e-01 8.26455626e-03]
# iter: 171, val=0.0077 grads: [ -0.46565744   4.12368848 -92.13731246], params: [4.94627882e+01 2.25516408e-01 8.25407931e-03]
# iter: 172, val=0.0316 grads: [ 0.47011234 -4.20870025 89.19976293], params: [4.94660091e+01 2.24945805e-01 8.64442154e-03]
# iter: 173, val=0.0154 grads: [0.88312352 3.57254639 1.28164395], params: [4.94666894e+01 2.27172447e-01 8.41738228e-03]
# iter: 174, val=0.0123 grads: [0.8872297  3.59121335 1.19572713], params: [4.94651830e+01 2.26700735e-01 8.39132052e-03]
# iter: 175, val=0.0052 grads: [0.89829608 3.63836437 0.98870203], params: [4.94623357e+01 2.25429783e-01 8.36521305e-03]
# iter: 176, val=0.0067 grads: [ 0.48569342 -4.1501572  91.69284534], params: [4.94582633e+01 2.23421140e-01 8.33978755e-03]
# iter: 177, val=0.0380 grads: [ -0.47739375   4.04466565 -94.85336373], params: [4.94544027e+01 2.24232509e-01 7.91620911e-03]
# iter: 178, val=0.0150 grads: [-0.92389775 -3.75763037 -0.34277196], params: [4.94531786e+01 2.22281648e-01 8.14227418e-03]
# iter: 179, val=0.0113 grads: [ -0.48961515   4.1051319  -93.18266998], params: [4.94542955e+01 2.23057373e-01 8.15002561e-03]
# iter: 180, val=0.0355 grads: [ 0.50822204 -4.20119382 90.11241473], params: [4.94554667e+01 2.21127998e-01 8.56638264e-03]
# iter: 181, val=0.0145 grads: [-0.93013066 -3.77345949 -0.45297165], params: [4.94541691e+01 2.22135701e-01 8.35031823e-03]
# iter: 182, val=0.0058 grads: [-0.91490601 -3.71415302 -0.67640167], params: [4.94567122e+01 2.23840084e-01 8.34564544e-03]
# iter: 183, val=0.0064 grads: [0.89395002 3.62974431 1.02313802], params: [4.94604875e+01 2.26236626e-01 8.34347155e-03]
# iter: 184, val=0.0048 grads: [0.89630144 3.64048471 0.97415701], params: [4.94597032e+01 2.25983654e-01 8.33554447e-03]
# iter: 185, val=0.0012 grads: [-0.90597124 -3.68117511 -0.79873229], params: [4.94575195e+01 2.24895426e-01 8.32620921e-03]
# iter: 186, val=0.0061 grads: [ -0.46500503   4.09741287 -91.43309781], params: [4.94597116e+01 2.26337964e-01 8.32341049e-03]
# iter: 187, val=0.0367 grads: [ 0.4757526  -4.1897129  88.50331176], params: [4.94617989e+01 2.25018151e-01 8.72735357e-03]
# iter: 188, val=0.0100 grads: [ 0.46368174 -4.12913652 90.04150923], params: [4.94615035e+01 2.26578527e-01 8.50254992e-03]
# iter: 189, val=0.0382 grads: [ -0.44496418   4.00691229 -92.83750767], params: [4.94604911e+01 2.28944590e-01 8.08562168e-03]
# iter: 190, val=0.0152 grads: [0.87701015 3.56577234 1.30312906], params: [4.94616621e+01 2.28400410e-01 8.31472230e-03]
# iter: 191, val=0.0101 grads: [ -0.46027747   4.07699346 -91.33798487], params: [4.94593135e+01 2.27161628e-01 8.31903108e-03]
# iter: 192, val=0.0365 grads: [ 0.47845839 -4.17907885 88.43804537], params: [4.94599370e+01 2.24974395e-01 8.73392855e-03]
# iter: 193, val=0.0134 grads: [ 0.4729384  -4.12767393 89.98923864], params: [4.94583173e+01 2.25749234e-01 8.51869919e-03]
# iter: 194, val=0.0318 grads: [ -0.45921779   4.01855333 -92.8469965 ], params: [4.94560857e+01 2.27411309e-01 8.11019566e-03]
# iter: 195, val=0.0051 grads: [ -0.47007341   4.08129507 -91.21416601], params: [4.94562197e+01 2.26224287e-01 8.34760600e-03]
# iter: 196, val=0.0419 grads: [ 0.48774985 -4.17912927 88.19839542], params: [4.94571342e+01 2.24177358e-01 8.77198979e-03]
# iter: 197, val=0.0193 grads: [ 0.48104632 -4.12992937 89.66339263], params: [4.94557232e+01 2.25081276e-01 8.56752093e-03]
# iter: 198, val=0.0252 grads: [ -0.46621989   4.02509882 -92.44095817], params: [4.94536646e+01 2.26861174e-01 8.16995269e-03]
# iter: 199, val=0.0017 grads: [ 0.47648879 -4.08537361 90.73560019], params: [4.94539980e+01 2.25775034e-01 8.41382894e-03]
# iter: 200, val=0.0411 grads: [ -0.46169893   3.97947017 -93.34883654], params: [4.94520978e+01 2.27491057e-01 8.03368279e-03]
# iter: 201, val=0.0119 grads: [ -0.47257403   4.04786521 -91.51016772], params: [4.94525574e+01 2.26376179e-01 8.29900731e-03]
# iter: 202, val=0.0372 grads: [ 0.4902877  -4.15001115 88.31983061], params: [4.94537744e+01 2.24399722e-01 8.74827545e-03]
# iter: 203, val=0.0166 grads: [ 0.48306124 -4.10419546 89.59800855], params: [4.94526100e+01 2.25350096e-01 8.56639071e-03]
# iter: 204, val=0.0259 grads: [ -0.4678235    4.00377195 -92.19068966], params: [4.94507663e+01 2.27167640e-01 8.19017210e-03]
# iter: 205, val=0.0023 grads: [ 0.47789777 -4.06606706 90.36702259], params: [4.94513150e+01 2.26127169e-01 8.45064172e-03]
# iter: 206, val=0.0386 grads: [ -0.46297604   3.96519498 -92.82184558], params: [4.94495883e+01 2.27874420e-01 8.08891433e-03]
# iter: 207, val=0.0085 grads: [ -0.4736045    4.03430614 -90.9001407 ], params: [4.94502237e+01 2.26794871e-01 8.36637658e-03]
# iter: 208, val=0.0410 grads: [ 0.49090867 -4.13523996 87.6613509 ], params: [4.94516052e+01 2.24852053e-01 8.82454470e-03]
# iter: 209, val=0.0216 grads: [ 0.48359281 -4.09261464 88.82808858], params: [4.94505720e+01 2.25826599e-01 8.65607591e-03]
# iter: 210, val=0.0192 grads: [ -0.46852113   3.99756083 -91.29524987], params: [4.94488411e+01 2.27665062e-01 8.29436369e-03]
# iter: 211, val=0.0093 grads: [ 0.47823229 -4.0588323  89.4340245 ], params: [4.94495074e+01 2.26645299e-01 8.56115144e-03]
# iter: 212, val=0.0302 grads: [ -0.4636039    3.96356526 -91.77985572], params: [4.94478717e+01 2.28409994e-01 8.21220965e-03]
# iter: 213, val=0.0000 grads: [-0.90229503 -3.70226387 -0.83108703], params: [4.94486042e+01 2.27345094e-01 8.49354527e-03]
# Optimized params: [4.94486042e+01 2.27345094e-01 8.49354527e-03]

# %%
transmon_EJ,g,amp =  [4.94486042e+01, 2.27345094e-01, 8.49354527e-03]

fluxonium = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=n_lvls_fluxonium)
transmon = scqubits.Transmon(
    EJ=transmon_EJ,
    EC=0.2,
    ng=0.0,
    ncut=10,
    truncated_dim = 4
    )

system = FluxoniumTransmonSystem(
    fluxonium  = fluxonium,
    transmon = transmon,
    computaional_states = '0,2',
    g_strength = g,
    )

e_ops = []
for ql in range(n_lvls_fluxonium):
    for tl in range(4):
        e_ops.append(system.truncate_function(qutip.ket2dm(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,tl)]))))


amp_with_2pi = amp
t_tot = 350
tlist = np.linspace(0,t_tot,int(t_tot))


results = system.run_qutip_mesolve_parrallel(
        initial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, i)) for i in range(3)],
        tlist = tlist,
        drive_terms = [DriveTerm( 
                driven_op=system.truncate_function(system.hilbertspace.op_in_dressed_eigenbasis(system.transmon.n_operator)),
                pulse_shape_func=square_pulse_with_rise_fall,
                pulse_shape_args={
                    'w_d':system.evals[system.product_to_dressed[(1,1)]] - system.evals[system.product_to_dressed[(1,0)]],
                    'amp': amp_with_2pi/(2*np.pi),
                    't_rise': 4,
                    't_square': 1000
                  },
                )],
        c_ops = None,
        e_ops = e_ops
    )
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
#  Total run time: 184.18s*] Elapsed 184.18s / Remaining 00:00:00:00
#  [*********98%***********] Elapsed 184.36s / Remaining 00:00:00:03
# Processing states with pad_back_custom: 100%|██████████| 350/350 [00:00<00:00, 5866.14it/s]
#  Total run time: 187.92s*] Elapsed 187.92s / Remaining 00:00:00:00
#  [*********99%***********] Elapsed 188.05s / Remaining 00:00:00:01
# Processing states with pad_back_custom: 100%|██████████| 350/350 [00:00<00:00, 6050.07it/s]
#  Total run time: 189.94s*] Elapsed 189.94s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 350/350 [00:00<00:00, 6255.70it/s]

# %%
colors = ['green','red','darkorange']
fig,axes = plt.subplots(2,3,figsize = (12,6))
for col, levels_list in zip([0,1,2],
                    [
                        [(0,0),(0,1)],
                        [(1,0),(1,1),(8,0)],
                        [(2,0),(2,1)]
                    ]):
    for row in [0,1]:
        for (ql,tl) in levels_list:
            i = ql*4+tl
            # if (ql,tl) not in [(0,0), (1,1),(2,0)]:
            axes[row, col].plot(tlist,results[col].expect[i],label = rf"$\langle{ql}{tl}\rangle$",alpha=0.5)
            # else:
            #     axes[row, col].plot(tlist,1 - results[col].expect[i],label = rf"1 - $\langle{ql}{tl}\rangle$",alpha=0.5)
    axes[0,col].legend()
    # axes[1,col].axvline(x=270, color='b', linestyle='--')
    # axes[1,col].set_xlim(260,280)
axes[0,0].set_ylim(-1e-3,1)
axes[0,1].set_ylim(-1e-5,1)
axes[0,2].set_ylim(-1e-5,1)
axes[1,0].set_ylim(-1e-5,1e-2)
axes[1,1].set_ylim(1-1e-2,1)
axes[1,2].set_ylim(-1e-5,1e-2)

xa = 210
xb = 240
axes[1,0].set_xlim(xa,xb)
axes[1,1].set_xlim(xa,xb)
axes[1,2].set_xlim(xa,xb)
# Out:
# (210.0, 240.0)

# %% [markdown]
# # Checking params for g=0.1

# %%
params = jnp.array( [35.6161, 0.1,0.02718593 ]) #     Ej_t, g_tf, amp_with_2pi = params

optimizer = optax.nadam(learning_rate=jnp.array([3e-4,3e-4,3e-4])) 
opt_state = optimizer.init(params)

num_steps = 1000
for step in range(num_steps):
    val, grads = func(params)
    # clear_output()
    print(f"iter: {step}, val={val:.4f} grads: {grads}, params: {params}")
    if val < 1e-4:
        break
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)

print(f'Optimized params: {params}')
# Out:
# iter: 0, val=0.0070 grads: [ 0.05302022  0.1744077  -0.12031546], params: [3.561610e+01 1.000000e-01 2.718593e-02]
# iter: 1, val=0.0105 grads: [ 7.67181196  5.17500265 18.28145498], params: [3.56156579e+01 1.00000000e-01 2.76280352e-02]
# iter: 2, val=0.0070 grads: [ 0.05306389  0.17377884 -0.11778096], params: [3.56152929e+01 1.00000000e-01 2.72647721e-02]
# iter: 3, val=0.0070 grads: [ 0.05357746  0.17409041 -0.11639487], params: [3.56151675e+01 1.00000000e-01 2.71452267e-02]
# iter: 4, val=0.0070 grads: [ 0.05402331  0.17435565 -0.11516541], params: [3.56150571e+01 1.00000000e-01 2.70417443e-02]
# iter: 5, val=0.0075 grads: [ -7.67234106  -5.17001338 -18.96354262], params: [3.56149589e+01 1.00000000e-01 2.69515857e-02]
# iter: 6, val=0.0070 grads: [ 0.05378199  0.17419771 -0.11577839], params: [3.56150987e+01 1.00000000e-01 2.70996936e-02]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 8
#       6 num_steps = 1000
#       7 for step in range(num_steps):
# ----> 8     val, grads = func(params)
#       9     # clear_output()
#      10     print(f"iter: {step}, val={val:.4f} grads: {grads}, params: {params}")
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/api.py:691, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     689   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     690 if not has_aux:
# --> 691   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     692 else:
#     693   ans, vjp_py, aux = _vjp(
#     694       f_partial, *dyn_args, has_aux=True)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/api.py:2178, in _vjp(fun, has_aux, *primals)
#    2176 if not has_aux:
#    2177   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2178   out_primal, out_vjp = ad.vjp(flat_fun, primals_flat)
#    2179   out_tree = out_tree()
#    2180 else:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:143, in vjp(traceable, primals, has_aux)
#     141 def vjp(traceable, primals, has_aux=False):
#     142   if not has_aux:
# --> 143     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     144   else:
#     145     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:132, in linearize(traceable, *primals, **kwargs)
#     130 _, in_tree = tree_flatten(((primals, primals), {}))
#     131 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 132 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     133 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     134 assert all(out_primal_pval.is_known() for out_primal_pval in out_primals_pvals)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/profiler.py:335, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     332 @wraps(func)
#     333 def wrapper(*args, **kwargs):
#     334   with TraceAnnotation(name, **decorator_kwargs):
# --> 335     return func(*args, **kwargs)
#     336   return wrapper
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:774, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     772 with core.new_main(JaxprTrace, name_stack=current_name_stack) as main:
#     773   fun = trace_to_subjaxpr_nounits(fun, main, instantiate)
# --> 774   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     775   assert not env
#     776   del main, fun, env
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jax/_src/linear_util.py:192, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     189 gen = gen_static_args = out_store = None
#     191 try:
# --> 192   ans = self.f(*args, **dict(self.params, **kwargs))
#     193 except:
#     194   # Some transformations yield from inside context managers, so we have to
#     195   # interrupt them before reraising the exception. Otherwise they will only
#     196   # get garbage-collected at some later time, running their cleanup tasks
#     197   # only after this exception is handled, which can corrupt the global
#     198   # state.
#     199   while stack:
#
# Cell In[17], line 27, in objective(params)
#      25 system.params["g_tf"] = g_tf
#      26 system_evals_in_product_indices, system_evecs_in_product_indices = system.calculate_eig_linear()
# ---> 27 system_evals_sorted, system_evecs_sorted, product_indices_sorted_by_eval = calculate_eig(Ns, system.get_H())
#      28 driven_op = transform_op_into_dressed_basis_jax(tn, system_evecs_sorted.T)
#      30 def get_dressed_idx(ql,tl):
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/system.py:87, in System.get_H(self)
#      86 def get_H(self):
# ---> 87     H_bare = self.get_H_bare()
#      88     H_couplings = self.get_H_couplings()
#      89     return H_bare + H_couplings
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/system.py:77, in System.get_H_bare(self)
#      75 H = 0
#      76 for j, device in enumerate(self.devices):
# ---> 77     H += self.promote(device.get_H(), j)
#      78 return H
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:64, in Device.get_H(self)
#      60 def get_H(self):
#      61     """
#      62     Return diagonalized H. Explicitly keep only diagonal elements of matrix.
#      63     """
# ---> 64     return self.get_op_in_H_eigenbasis(self._get_H_in_linear_basis()).keep_only_diag_elements()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/base.py:67, in Device._get_H_in_linear_basis(self)
#      66 def _get_H_in_linear_basis(self):
# ---> 67     return self.get_H_linear() if self._use_linear else self.get_H_full()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qcsys/devices/fluxonium.py:57, in Fluxonium.get_H_full(self)
#      55 def get_H_full(self):
#      56     """Return full H in linear basis."""
# ---> 57     op_cos_phi = jqt.cosm(self.linear_ops["phi"])
#      58     op_sin_phi = jqt.sinm(self.linear_ops["phi"])
#      60     phi_ext = self.params["phi_ext"]
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jaxquantum/core/qarray.py:360, in cosm(qarr)
#     359 def cosm(qarr: Qarray) -> Qarray:
# --> 360     return (expm(1j*qarr) + expm(-1j*qarr))/2
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/jaxquantum/core/qarray.py:354, in expm(qarr, **kwargs)
#     348 def expm(qarr: Qarray, **kwargs) -> Qarray:
#     349     """Matrix exponential wrapper.
#     350
#     351     Returns:
#     352         matrix exponential
#     353     """
# --> 354     data = jsp.linalg.expm(qarr.data, **kwargs)
#     355     dims = deepcopy(qarr.dims)
#     356     return Qarray.create(data, dims=dims)
#
# KeyboardInterrupt:

# %%
transmon_EJ,g,amp =  [3.56153334e+01, 9.91957369e-02, 2.73280218e-02]

fluxonium = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=n_lvls_fluxonium)
transmon = scqubits.Transmon(
    EJ=transmon_EJ,
    EC=0.2,
    ng=0.0,
    ncut=10,
    truncated_dim = 4
    )

system = FluxoniumTransmonSystem(
    fluxonium  = fluxonium,
    transmon = transmon,
    computaional_states = '0,2',
    g_strength = g,
    )

e_ops = []
for ql in range(n_lvls_fluxonium):
    for tl in range(4):
        e_ops.append(system.truncate_function(qutip.ket2dm(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,tl)]))))


amp_with_2pi = amp
t_tot = 150
tlist = np.linspace(0,t_tot,int(t_tot)*5)


results = system.run_qutip_mesolve_parrallel(
        initial_states = [system.truncate_function(qutip.basis(system.hilbertspace.dimension, i)) for i in range(3)],
        tlist = tlist,
        drive_terms = [DriveTerm( 
                driven_op=system.truncate_function(system.hilbertspace.op_in_dressed_eigenbasis(system.transmon.n_operator)),
                pulse_shape_func=square_pulse_with_rise_fall,
                pulse_shape_args={
                    'w_d':system.evals[system.product_to_dressed[(1,1)]] - system.evals[system.product_to_dressed[(1,0)]],
                    'amp': amp_with_2pi/(2*np.pi),
                    't_rise': 1e-5,
                    't_square': 1000
                  },
                )],
        c_ops = None,
        e_ops = e_ops
    )
# Out:
# RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#  /home/kai/miniconda3/envs/test/lib/python3.10/site-packages/loky/backend/fork_exec.py: 38An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
#  Total run time:  55.97s*] Elapsed 55.97s / Remaining 00:00:00:00 [*******  30%           ] Elapsed 17.46s / Remaining 00:00:00:40
#  [*********98%***********] Elapsed 55.96s / Remaining 00:00:00:01
# Processing states with pad_back_custom: 100%|██████████| 750/750 [00:00<00:00, 7238.75it/s]
#  Total run time:  56.44s*] Elapsed 56.44s / Remaining 00:00:00:00
#  [*********99%***********] Elapsed 56.41s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 750/750 [00:00<00:00, 7293.92it/s]
#  Total run time:  57.16s*] Elapsed 57.16s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 750/750 [00:00<00:00, 7111.01it/s]

# %%
colors = ['green','red','darkorange']
fig,axes = plt.subplots(2,3,figsize = (12,6))
for col, levels_list in zip([0,1,2],
                    [
                        [(0,0),(0,1)],
                        [(1,0),(1,1),(8,0),(8,1)],
                        [(2,0),(2,1)]
                    ]):
    for row in [0,1]:
        for (ql,tl) in levels_list:
            i = ql*4+tl
            if (ql,tl) not in [(0,0), (1,1),(2,0)]:
                axes[row, col].plot(tlist,results[col].expect[i],label = rf"$\langle{ql}{tl}\rangle$",alpha=0.5)
            else:
                axes[row, col].plot(tlist,1 - results[col].expect[i],label = rf"1 - $\langle{ql}{tl}\rangle$",alpha=0.5)
    axes[0,col].legend()
    # axes[1,col].axvline(x=270, color='b', linestyle='--')
    # axes[1,col].set_xlim(260,280)
axes[0,0].set_ylim(-1e-3,1)
axes[0,1].set_ylim(-1e-5,1)
axes[0,2].set_ylim(-1e-5,1)
axes[1,0].set_ylim(-1e-5,1e-3)
axes[1,1].set_ylim(-1e-5,1e-1)
axes[1,2].set_ylim(-1e-5,1e-3)

xa = 100
xb = 115
axes[1,0].set_xlim(108,110)
axes[1,1].set_xlim(xa,xb)
axes[1,2].set_xlim(108,110)
# Out:
# (108.0, 110.0)

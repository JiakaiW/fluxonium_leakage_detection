# %%
import scqubits
import numpy as np
from scipy.optimize import minimize
from CoupledQuantumSystems.systems import *

# %%
EJ = 4
EC = EJ/2.7
EL = EJ/45

qubit_level = 20


def get_shift_accurate(ele,omega_i, omega_j, omega_r):
    return abs(ele)**2 / (omega_j-omega_i-omega_r) - abs(ele)**2 / (omega_i-omega_j-omega_r)


qbt = scqubits.Fluxonium(EJ=EJ,EC=EC,EL=EL,flux=0,cutoff=110,truncated_dim=qubit_level)
evals = qbt.eigenvals(qubit_level)
elements = qbt.matrixelement_table('n_operator',evals_count = qubit_level)

def shift_diff(x):
    Er = x[0]
    shifts_from_zero = [get_shift_accurate(elements[0,ql2],evals[ql2],evals[0],Er) for ql2 in range(qubit_level)] 
    shift_from_zero = sum(shifts_from_zero)
    # shifts_from_one = [get_shift_accurate(elements[1,ql2],evals[ql2],evals[1],Er) for ql2 in range(qubit_level)] 
    # shift_from_one = sum(shifts_from_one)
    shifts_from_two = [get_shift_accurate(elements[2,ql2],evals[ql2],evals[2],Er) for ql2 in range(qubit_level)] 
    shift_from_two = sum(shifts_from_two)
    return abs(shift_from_zero-shift_from_two)

initial_guess = [10.38695526]

# Call the optimizer
result = minimize(shift_diff, initial_guess, method='Nelder-Mead')

print("Result:", result)
print("Optimal solution:", result.x)
print("Objective value:", result.fun)
# Out:
# Result:        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 3.4078469070275563e-07
#              x: [ 1.039e+01]
#            nit: 14
#           nfev: 28
#  final_simplex: (array([[ 1.039e+01],
#                        [ 1.039e+01]]), array([ 3.408e-07,  3.978e-07]))
# Optimal solution: [10.38695526]
# Objective value: 3.4078469070275563e-07

# %%
Er = result.x[0]

g = 0.2



max_ol = 80
max_ql = 30
system = FluxoniumOscillatorSystem(
    EJ = EJ,
    EC = EC,
    EL = EL,
    Er = Er,
    g_strength = g,
    qubit_level = max_ql,
    osc_level = max_ol,
    # kappa = 0.004,
    products_to_keep=[[ql, ol] for ql in range(max_ql) for ol in range(max_ol) ],
    computaional_states = '1,2'
    )


energies=  system.hilbertspace.eigenvals(max_ql * max_ol)
def dressed_ener(ql,ol):
    return energies[system.product_to_dressed[(ql,ol)]]
def print_stats():
    print(f"\nqubit 12 transition and differential stark at different oscillator level")
    print(f"qbt freq at osc {0}:\t{(dressed_ener(2,0)-dressed_ener(1,0))}")
    ground_freq = dressed_ener(2,0)-dressed_ener(1,0)
    for i in range(1,max_ol-1):
        freq = dressed_ener(2,i)-dressed_ener(1,i)
        print(f"qbt freq at osc {i}:\t{freq:.5f}, \tdiff to at osc ground {freq - ground_freq:.5f}, {abs(freq - ground_freq)/ground_freq*100:.4f}% diff")

    print(f"\noscillator freq at qubit level:\t0 \t 1 \t 2 \t 3:")
    print(f"oscillator transition 0-1: \t{dressed_ener(0,1)-dressed_ener(0,0):.5f}\t{dressed_ener(1,1)-dressed_ener(1,0):.5f}\t{dressed_ener(2,1)-dressed_ener(2,0):.5f}\t{dressed_ener(3,1)-dressed_ener(3,0):.5f}")
    for i in range(1,max_ol-1):
        print(f"oscillator transition {i}-{i+1}: \t{dressed_ener(0,i+1)-dressed_ener(0,i):.5f}\t{dressed_ener(1,i+1)-dressed_ener(1,i):.5f}\t{dressed_ener(2,i+1)-dressed_ener(2,i):.5f}\t{dressed_ener(3,i+1)-dressed_ener(3,i):.5f}  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): {(dressed_ener(0,i+1)-dressed_ener(0,i))  -(dressed_ener(0,1)-dressed_ener(0,0))}")

    print(f"")
    print(f"10-11: {(dressed_ener(1,1)-dressed_ener(1,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(1,1)-dressed_ener(1,0)))}")
    print(f"20-21: {(dressed_ener(2,1)-dressed_ener(2,0)):.4f}, diff to 00-01: {abs((dressed_ener(0,1)-dressed_ener(0,0))    -(dressed_ener(2,1)-dressed_ener(2,0)))}")
print_stats()
# plot_specturum(system.qbt, system.osc, system.hilbertspace,num_levels = 50)
# Out:
# qubit 12 transition and differential stark at different oscillator level
# qbt freq at osc 0:	0.0375677383667431
# qbt freq at osc 1:	0.03539, 	diff to at osc ground -0.00218, 5.7916% diff
# qbt freq at osc 2:	0.03330, 	diff to at osc ground -0.00426, 11.3504% diff
# qbt freq at osc 3:	0.03129, 	diff to at osc ground -0.00627, 16.7004% diff
# qbt freq at osc 4:	0.02935, 	diff to at osc ground -0.00821, 21.8619% diff
# qbt freq at osc 5:	0.02748, 	diff to at osc ground -0.01009, 26.8520% diff
# qbt freq at osc 6:	0.02566, 	diff to at osc ground -0.01190, 31.6854% diff
# qbt freq at osc 7:	0.02390, 	diff to at osc ground -0.01367, 36.3749% diff
# qbt freq at osc 8:	0.02219, 	diff to at osc ground -0.01538, 40.9316% diff
# qbt freq at osc 9:	0.02053, 	diff to at osc ground -0.01704, 45.3653% diff
# qbt freq at osc 10:	0.01890, 	diff to at osc ground -0.01867, 49.6845% diff
# qbt freq at osc 11:	0.01732, 	diff to at osc ground -0.02025, 53.8969% diff
# qbt freq at osc 12:	0.01577, 	diff to at osc ground -0.02179, 58.0093% diff
# qbt freq at osc 13:	0.01427, 	diff to at osc ground -0.02330, 62.0280% diff
# qbt freq at osc 14:	0.01279, 	diff to at osc ground -0.02478, 65.9585% diff
# qbt freq at osc 15:	0.01134, 	diff to at osc ground -0.02622, 69.8057% diff
# qbt freq at osc 16:	0.00993, 	diff to at osc ground -0.02764, 73.5743% diff
# qbt freq at osc 17:	0.00854, 	diff to at osc ground -0.02903, 77.2684% diff
# qbt freq at osc 18:	0.00718, 	diff to at osc ground -0.03039, 80.8919% diff
# qbt freq at osc 19:	0.00584, 	diff to at osc ground -0.03173, 84.4482% diff
# qbt freq at osc 20:	0.00453, 	diff to at osc ground -0.03304, 87.9406% diff
# qbt freq at osc 21:	0.00324, 	diff to at osc ground -0.03433, 91.3720% diff
# qbt freq at osc 22:	0.00197, 	diff to at osc ground -0.03559, 94.7452% diff
# qbt freq at osc 23:	0.00073, 	diff to at osc ground -0.03684, 98.0628% diff
# qbt freq at osc 24:	-0.00050, 	diff to at osc ground -0.03807, 101.3271% diff
# qbt freq at osc 25:	-0.00171, 	diff to at osc ground -0.03927, 104.5404% diff
# qbt freq at osc 26:	-0.00289, 	diff to at osc ground -0.04046, 107.7046% diff
# qbt freq at osc 27:	-0.00407, 	diff to at osc ground -0.04163, 110.8218% diff
# qbt freq at osc 28:	-0.00522, 	diff to at osc ground -0.04279, 113.8937% diff
# qbt freq at osc 29:	-0.00636, 	diff to at osc ground -0.04392, 116.9220% diff
# qbt freq at osc 30:	-0.00748, 	diff to at osc ground -0.04505, 119.9084% diff
# qbt freq at osc 31:	-0.00859, 	diff to at osc ground -0.04615, 122.8543% diff
# qbt freq at osc 32:	-0.00968, 	diff to at osc ground -0.04725, 125.7612% diff
# qbt freq at osc 33:	-0.01076, 	diff to at osc ground -0.04832, 128.6303% diff
# qbt freq at osc 34:	-0.01182, 	diff to at osc ground -0.04939, 131.4630% diff
# qbt freq at osc 35:	-0.01287, 	diff to at osc ground -0.05044, 134.2604% diff
# qbt freq at osc 36:	-0.01391, 	diff to at osc ground -0.05148, 137.0237% diff
# qbt freq at osc 37:	-0.01493, 	diff to at osc ground -0.05250, 139.7539% diff
# qbt freq at osc 38:	-0.01595, 	diff to at osc ground -0.05352, 142.4520% diff
# qbt freq at osc 39:	-0.01695, 	diff to at osc ground -0.05452, 145.1191% diff
# qbt freq at osc 40:	-0.01794, 	diff to at osc ground -0.05551, 147.7560% diff
# qbt freq at osc 41:	-0.01892, 	diff to at osc ground -0.05649, 150.3636% diff
# qbt freq at osc 42:	-0.01989, 	diff to at osc ground -0.05746, 152.9428% diff
# qbt freq at osc 43:	-0.02085, 	diff to at osc ground -0.05842, 155.4943% diff
# qbt freq at osc 44:	-0.02180, 	diff to at osc ground -0.05936, 158.0189% diff
# qbt freq at osc 45:	-0.02273, 	diff to at osc ground -0.06030, 160.5173% diff
# qbt freq at osc 46:	-0.02366, 	diff to at osc ground -0.06123, 162.9903% diff
# qbt freq at osc 47:	-0.02458, 	diff to at osc ground -0.06215, 165.4384% diff
# qbt freq at osc 48:	-0.02549, 	diff to at osc ground -0.06306, 167.8624% diff
# qbt freq at osc 49:	-0.02640, 	diff to at osc ground -0.06396, 170.2628% diff
# qbt freq at osc 50:	-0.02729, 	diff to at osc ground -0.06486, 172.6402% diff
# qbt freq at osc 51:	-0.02817, 	diff to at osc ground -0.06574, 174.9953% diff
# qbt freq at osc 52:	-0.02905, 	diff to at osc ground -0.06662, 177.3284% diff
# qbt freq at osc 53:	-0.02992, 	diff to at osc ground -0.06749, 179.6402% diff
# qbt freq at osc 54:	-0.03078, 	diff to at osc ground -0.06835, 181.9311% diff
# qbt freq at osc 55:	-0.03163, 	diff to at osc ground -0.06920, 184.2017% diff
# qbt freq at osc 56:	-0.03248, 	diff to at osc ground -0.07005, 186.4523% diff
# qbt freq at osc 57:	-0.03332, 	diff to at osc ground -0.07088, 188.6835% diff
# qbt freq at osc 58:	-0.03415, 	diff to at osc ground -0.07172, 190.8956% diff
# qbt freq at osc 59:	-0.03497, 	diff to at osc ground -0.07254, 193.0891% diff
# qbt freq at osc 60:	-0.03579, 	diff to at osc ground -0.07336, 195.2644% diff
# qbt freq at osc 61:	-0.03660, 	diff to at osc ground -0.07417, 197.4218% diff
# qbt freq at osc 62:	-0.03740, 	diff to at osc ground -0.07497, 199.5617% diff
# qbt freq at osc 63:	-0.03820, 	diff to at osc ground -0.07577, 201.6846% diff
# qbt freq at osc 64:	-0.03899, 	diff to at osc ground -0.07656, 203.7907% diff
# qbt freq at osc 65:	-0.03978, 	diff to at osc ground -0.07734, 205.8803% diff
# qbt freq at osc 66:	-0.04056, 	diff to at osc ground -0.07812, 207.9539% diff
# qbt freq at osc 67:	-0.04133, 	diff to at osc ground -0.07890, 210.0117% diff
# qbt freq at osc 68:	-0.04210, 	diff to at osc ground -0.07966, 212.0540% diff
# qbt freq at osc 69:	-0.04286, 	diff to at osc ground -0.08043, 214.0811% diff
# qbt freq at osc 70:	-0.04361, 	diff to at osc ground -0.08118, 216.0933% diff
# qbt freq at osc 71:	-0.04436, 	diff to at osc ground -0.08193, 218.0909% diff
# qbt freq at osc 72:	-0.04511, 	diff to at osc ground -0.08268, 220.0741% diff
# qbt freq at osc 73:	-0.04585, 	diff to at osc ground -0.08342, 222.0433% diff
# qbt freq at osc 74:	-0.04658, 	diff to at osc ground -0.08415, 223.9986% diff
# qbt freq at osc 75:	-0.04731, 	diff to at osc ground -0.08488, 225.9403% diff
# qbt freq at osc 76:	-0.04804, 	diff to at osc ground -0.08561, 227.8687% diff
# qbt freq at osc 77:	-0.04876, 	diff to at osc ground -0.08632, 229.7838% diff
# qbt freq at osc 78:	-0.04944, 	diff to at osc ground -0.08701, 231.6149% diff
#
# oscillator freq at qubit level:	0 	 1 	 2 	 3:
# oscillator transition 0-1: 	10.38733	10.38951	10.38733	10.39581
# oscillator transition 1-2: 	10.38733	10.38942	10.38733	10.39027  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.882213424181828e-07
# oscillator transition 2-3: 	10.38733	10.38934	10.38733	10.38919  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.577529610941042e-06
# oscillator transition 3-4: 	10.38733	10.38927	10.38733	10.38862  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.3679260809927882e-06
# oscillator transition 4-5: 	10.38733	10.38921	10.38733	10.38825  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.159412608866319e-06
# oscillator transition 5-6: 	10.38733	10.38915	10.38733	10.38798  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.951989656414412e-06
# oscillator transition 6-7: 	10.38733	10.38909	10.38733	10.38779  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.745657557592153e-06
# oscillator transition 7-8: 	10.38733	10.38904	10.38733	10.38764  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.540414990790055e-06
# oscillator transition 8-9: 	10.38733	10.38900	10.38733	10.38752  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.336267022177822e-06
# oscillator transition 9-10: 	10.38732	10.38895	10.38733	10.38743  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.133210461418571e-06
# oscillator transition 10-11: 	10.38732	10.38891	10.38733	10.38735  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -7.931247980152989e-06
# oscillator transition 11-12: 	10.38732	10.38887	10.38733	10.38729  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -8.730377887289364e-06
# oscillator transition 12-13: 	10.38732	10.38884	10.38733	10.38724  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -9.53060383501736e-06
# oscillator transition 13-14: 	10.38732	10.38881	10.38733	10.38720  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.0331922867479193e-05
# oscillator transition 14-15: 	10.38732	10.38877	10.38733	10.38716  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.1134338295804014e-05
# oscillator transition 15-16: 	10.38732	10.38874	10.38733	10.38713  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.1937847306242588e-05
# oscillator transition 16-17: 	10.38732	10.38872	10.38733	10.38710  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.2742453053604663e-05
# oscillator transition 17-18: 	10.38732	10.38869	10.38733	10.38708  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.354815394627451e-05
# oscillator transition 18-19: 	10.38732	10.38866	10.38733	10.38706  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.4354952343254013e-05
# oscillator transition 19-20: 	10.38732	10.38864	10.38733	10.38704  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.5162845004468295e-05
# oscillator transition 20-21: 	10.38732	10.38862	10.38733	10.38703  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.5971835141570523e-05
# oscillator transition 21-22: 	10.38731	10.38860	10.38733	10.38702  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.67819206513542e-05
# oscillator transition 22-23: 	10.38731	10.38857	10.38733	10.38700  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.7593103807556076e-05
# oscillator transition 23-24: 	10.38731	10.38855	10.38733	10.38699  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.8405382165909145e-05
# oscillator transition 24-25: 	10.38731	10.38853	10.38733	10.38698  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.9218757147498877e-05
# oscillator transition 25-26: 	10.38731	10.38852	10.38733	10.38698  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.0033227928095698e-05
# oscillator transition 26-27: 	10.38731	10.38850	10.38733	10.44490  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.084879439401277e-05
# oscillator transition 27-28: 	10.38731	10.38848	10.38733	10.38809  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.166545782422702e-05
# oscillator transition 28-29: 	10.38731	10.38846	10.38733	10.38808  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.248321531972408e-05
# oscillator transition 29-30: 	10.38731	10.38845	10.38733	10.38806  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.3302068585806524e-05
# oscillator transition 30-31: 	10.38731	10.38843	10.38733	10.38805  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.4122016599292806e-05
# oscillator transition 31-32: 	10.38731	10.38842	10.38733	10.38804  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.4943059473869766e-05
# oscillator transition 32-33: 	10.38731	10.38840	10.38733	10.38802  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.5765195390548e-05
# oscillator transition 33-34: 	10.38730	10.38839	10.38733	10.38801  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.6588425201978794e-05
# oscillator transition 34-35: 	10.38730	10.38838	10.38733	10.38800  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.741274799866744e-05
# oscillator transition 35-36: 	10.38730	10.38836	10.38733	10.38799  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.8238163325866594e-05
# oscillator transition 36-37: 	10.38730	10.38835	10.38733	10.38797  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.906467021723813e-05
# oscillator transition 37-38: 	10.38730	10.38834	10.38733	10.38796  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -2.9892268672782052e-05
# oscillator transition 38-39: 	10.38730	10.38833	10.38733	10.38795  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.0720956305074765e-05
# oscillator transition 39-40: 	10.38730	10.38832	10.38733	10.38794  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.1550734364671484e-05
# oscillator transition 40-41: 	10.38730	10.38830	10.38733	10.38793  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.238160188523409e-05
# oscillator transition 41-42: 	10.38730	10.38829	10.38732	10.38792  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.321355596774822e-05
# oscillator transition 42-43: 	10.38730	10.38828	10.38732	10.38791  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.404659803329935e-05
# oscillator transition 43-44: 	10.38730	10.38827	10.38732	10.38790  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.488072558077704e-05
# oscillator transition 44-45: 	10.38730	10.38826	10.38732	10.38789  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.5715937700686595e-05
# oscillator transition 45-46: 	10.38729	10.38825	10.38732	10.38788  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.6552235416209555e-05
# oscillator transition 46-47: 	10.38729	10.38824	10.38732	10.38787  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.738961406618557e-05
# oscillator transition 47-48: 	10.38729	10.38823	10.38732	10.38787  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.822807751596713e-05
# oscillator transition 48-49: 	10.38729	10.38823	10.38732	10.38786  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.906761917171764e-05
# oscillator transition 49-50: 	10.38729	10.38822	10.38732	10.38785  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -3.99082399429318e-05
# oscillator transition 50-51: 	10.38729	10.38821	10.38732	10.38784  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.07499385790544e-05
# oscillator transition 51-52: 	10.38729	10.38820	10.38732	10.38783  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.1592716387484074e-05
# oscillator transition 52-53: 	10.38729	10.38819	10.38732	10.38783  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.2436567058601327e-05
# oscillator transition 53-54: 	10.38729	10.38818	10.38732	10.38782  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.328149013765881e-05
# oscillator transition 54-55: 	10.38729	10.38818	10.38732	10.38781  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.412749324167464e-05
# oscillator transition 55-56: 	10.38729	10.38817	10.38732	10.38780  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.497455795338112e-05
# oscillator transition 56-57: 	10.38729	10.38816	10.38732	10.38780  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.582269575514886e-05
# oscillator transition 57-58: 	10.38728	10.38815	10.38732	10.38779  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.667190346374639e-05
# oscillator transition 58-59: 	10.38728	10.38815	10.38732	10.38778  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.752217221160038e-05
# oscillator transition 59-60: 	10.38728	10.38814	10.38732	10.38778  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.837350904729476e-05
# oscillator transition 60-61: 	10.38728	10.38813	10.38732	10.38777  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -4.9225906694871924e-05
# oscillator transition 61-62: 	10.38728	10.38813	10.38732	10.38776  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.007936560907922e-05
# oscillator transition 62-63: 	10.38728	10.38812	10.38732	10.38776  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.0933882265624675e-05
# oscillator transition 63-64: 	10.38728	10.38811	10.38732	10.38775  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.178945780137667e-05
# oscillator transition 64-65: 	10.38728	10.38811	10.38732	10.38775  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.264608550881178e-05
# oscillator transition 65-66: 	10.38728	10.38810	10.38732	10.38774  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.3503764819495814e-05
# oscillator transition 66-67: 	10.38728	10.38809	10.38732	10.38773  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.436250096302331e-05
# oscillator transition 67-68: 	10.38728	10.38809	10.38732	10.38773  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.522227768217647e-05
# oscillator transition 68-69: 	10.38728	10.38808	10.38732	10.38772  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.608310668669958e-05
# oscillator transition 69-70: 	10.38727	10.38808	10.38732	10.38772  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.6944974447858954e-05
# oscillator transition 70-71: 	10.38727	10.38807	10.38732	10.38771  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.7807889151106906e-05
# oscillator transition 71-72: 	10.38727	10.38807	10.38732	10.38771  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.867183749508342e-05
# oscillator transition 72-73: 	10.38727	10.38806	10.38732	10.38770  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -5.9536829938977576e-05
# oscillator transition 73-74: 	10.38727	10.38805	10.38732	10.38770  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.040285215824781e-05
# oscillator transition 74-75: 	10.38727	10.38805	10.38732	10.38769  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.126990494870199e-05
# oscillator transition 75-76: 	10.38727	10.38804	10.38732	10.38769  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.213789838405148e-05
# oscillator transition 76-77: 	10.38727	10.38804	10.38732	10.38768  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -6.292198502144686e-05
# oscillator transition 77-78: 	10.38732	10.38806	10.38738	10.38777  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): -1.0103465159616576e-05
# oscillator transition 78-79: 	10.40766	10.40265	10.41080	10.41625  oscillator frequency coupled to qubit 0th state compared to 00-01 (non-linearity): 0.02033093127984209
#
# 10-11: 10.3895, diff to 00-01: 0.002175920738714865
# 20-21: 10.3873, diff to 00-01: 1.3192954106955312e-07

# %%
dressed_ener(1,1)-dressed_ener(1,0)
# Out:
# 10.389507326769158

# %% [markdown]
# # g0.2

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8,3))
n_osc_lvls = max_ol-1
dressed_osc_frequencies = [[] for _ in range(3)]
for j in [0,1,2]:
    for i in range(0,max_ol-1):
        dressed_osc_frequencies[j].append(dressed_ener(j,i+1)-dressed_ener(j,i))
        
for j in [0,1,2]:
    plt.plot(list(range(max_ol-1))[:n_osc_lvls], dressed_osc_frequencies[j][:n_osc_lvls],label=rf'$\omega_{{{j},n+1}} - \omega_{{{j},n}}$')

plt.xticks(list(range(n_osc_lvls))[::5])
plt.ylim(Er-0.005, Er+0.005)
# plt.ylim(7.9,7.92)

# plt.xticklabels([str(i) for i in range(n_osc_lvls)])
plt.legend(loc='lower right')

# %%
evals, evecs = system.hilbertspace.hamiltonian().eigenstates()
overlap_matrix = scqubits.utils.spectrum_utils.convert_evecs_to_ndarray(evecs)
def print_top_two_dressed_state(product_index):
    overlaps_with_product_state = np.abs(overlap_matrix[:, product_index])
    sorted_indices = np.argsort(overlaps_with_product_state)[::-1]
    sorted_overlaps = overlaps_with_product_state[sorted_indices]
    print(list(sorted_indices)[:2])
    print(list(sorted_overlaps)[:2])

print(f"\t\tqubit 0\t\t\tqubit 1 \t\t qubit 2")

print(f"osc lvl\t\tdressed-overlap^2\tdressed-overlap^2\tdressed-overlap^2")
for i in range(max_ol-1):
    product_index_q0 = 0 * system.osc.truncated_dim + i
    product_index_q1 = 1 * system.osc.truncated_dim + i
    product_index_q2 = 2 * system.osc.truncated_dim + i

    overlaps_with_product_state_q0 = np.abs(overlap_matrix[:, product_index_q0])
    sorted_indices_q0 = np.argsort(overlaps_with_product_state_q0)[::-1]
    sorted_overlaps_q0 = overlaps_with_product_state_q0[sorted_indices_q0]

    overlaps_with_product_state_q1 = np.abs(overlap_matrix[:, product_index_q1])
    sorted_indices_q1 = np.argsort(overlaps_with_product_state_q1)[::-1]
    sorted_overlaps_q1 = overlaps_with_product_state_q1[sorted_indices_q1]
    
    overlaps_with_product_state_q2 = np.abs(overlap_matrix[:, product_index_q2])
    sorted_indices_q2 = np.argsort(overlaps_with_product_state_q2)[::-1]
    sorted_overlaps_q2 = overlaps_with_product_state_q2[sorted_indices_q2]

    print(f"ol-{i}:\t\t{list(sorted_indices_q0)[0]}-{list(sorted_overlaps_q0)[0]**2:.3f} \t\t{list(sorted_indices_q1)[0]}-{list(sorted_overlaps_q1)[0]**2:.3f} \t\t{list(sorted_indices_q2)[0]}-{list(sorted_overlaps_q2)[0]**2:.3f}")
# Out:
# 		qubit 0			qubit 1 		 qubit 2
# osc lvl		dressed-overlap^2	dressed-overlap^2	dressed-overlap^2
# ol-0:		0-1.000 		1-1.000 		2-1.000
# ol-1:		9-0.999 		12-0.983 		13-1.000
# ol-2:		28-0.999 		33-0.969 		34-0.999
# ol-3:		58-0.998 		63-0.955 		64-0.999
# ol-4:		88-0.998 		93-0.943 		94-0.999
# ol-5:		118-0.997 		123-0.932 		124-0.998
# ol-6:		148-0.997 		153-0.923 		154-0.998
# ol-7:		178-0.996 		183-0.913 		184-0.998
# ol-8:		208-0.996 		213-0.905 		214-0.998
# ol-9:		238-0.995 		243-0.897 		244-0.997
# ol-10:		268-0.995 		273-0.890 		274-0.997
# ol-11:		298-0.994 		303-0.884 		304-0.997
# ol-12:		328-0.994 		333-0.877 		334-0.996
# ol-13:		358-0.993 		363-0.872 		364-0.996
# ol-14:		388-0.993 		393-0.866 		394-0.996
# ol-15:		418-0.992 		423-0.861 		424-0.996
# ol-16:		448-0.991 		453-0.856 		454-0.995
# ol-17:		478-0.991 		483-0.852 		484-0.995
# ol-18:		508-0.990 		513-0.847 		514-0.995
# ol-19:		538-0.990 		543-0.843 		544-0.994
# ol-20:		568-0.989 		573-0.839 		574-0.994
# ol-21:		598-0.989 		603-0.836 		604-0.994
# ol-22:		628-0.988 		633-0.832 		634-0.993
# ol-23:		658-0.988 		663-0.829 		664-0.993
# ol-24:		688-0.987 		694-0.826 		693-0.993
# ol-25:		718-0.986 		724-0.823 		723-0.993
# ol-26:		748-0.986 		754-0.820 		753-0.992
# ol-27:		778-0.985 		784-0.817 		783-0.992
# ol-28:		808-0.985 		814-0.814 		813-0.992
# ol-29:		838-0.984 		844-0.812 		843-0.991
# ol-30:		868-0.984 		874-0.809 		873-0.991
# ol-31:		898-0.983 		904-0.807 		903-0.991
# ol-32:		928-0.982 		934-0.805 		933-0.990
# ol-33:		958-0.982 		964-0.803 		963-0.990
# ol-34:		988-0.981 		994-0.800 		993-0.990
# ol-35:		1018-0.981 		1024-0.798 		1023-0.990
# ol-36:		1048-0.980 		1054-0.796 		1053-0.989
# ol-37:		1078-0.980 		1084-0.795 		1083-0.989
# ol-38:		1108-0.979 		1114-0.793 		1113-0.989
# ol-39:		1138-0.978 		1144-0.791 		1143-0.988
# ol-40:		1168-0.978 		1174-0.789 		1173-0.988
# ol-41:		1198-0.977 		1204-0.788 		1203-0.988
# ol-42:		1228-0.977 		1234-0.786 		1233-0.987
# ol-43:		1258-0.976 		1264-0.785 		1263-0.987
# ol-44:		1288-0.976 		1294-0.783 		1293-0.987
# ol-45:		1318-0.975 		1324-0.782 		1323-0.987
# ol-46:		1348-0.974 		1354-0.780 		1353-0.986
# ol-47:		1378-0.974 		1384-0.779 		1383-0.986
# ol-48:		1408-0.973 		1414-0.778 		1413-0.986
# ol-49:		1438-0.973 		1444-0.776 		1443-0.985
# ol-50:		1468-0.972 		1474-0.775 		1473-0.985
# ol-51:		1498-0.971 		1504-0.774 		1503-0.985
# ol-52:		1528-0.971 		1534-0.773 		1533-0.984
# ol-53:		1558-0.970 		1564-0.771 		1563-0.984
# ol-54:		1588-0.970 		1594-0.770 		1593-0.984
# ol-55:		1618-0.969 		1624-0.769 		1623-0.984
# ol-56:		1648-0.968 		1654-0.768 		1653-0.983
# ol-57:		1678-0.968 		1684-0.767 		1683-0.983
# ol-58:		1708-0.967 		1714-0.766 		1713-0.983
# ol-59:		1738-0.967 		1744-0.765 		1743-0.982
# ol-60:		1768-0.966 		1774-0.764 		1773-0.982
# ol-61:		1798-0.965 		1804-0.763 		1803-0.982
# ol-62:		1828-0.965 		1834-0.762 		1833-0.981
# ol-63:		1858-0.964 		1864-0.762 		1863-0.981
# ol-64:		1888-0.963 		1894-0.761 		1893-0.981
# ol-65:		1918-0.963 		1924-0.760 		1923-0.981
# ol-66:		1948-0.962 		1954-0.759 		1953-0.980
# ol-67:		1978-0.962 		1984-0.758 		1983-0.980
# ol-68:		2008-0.961 		2014-0.757 		2013-0.980
# ol-69:		2038-0.960 		2044-0.757 		2043-0.979
# ol-70:		2068-0.960 		2074-0.756 		2073-0.979
# ol-71:		2098-0.959 		2104-0.755 		2103-0.979
# ol-72:		2128-0.958 		2134-0.754 		2133-0.978
# ol-73:		2158-0.958 		2164-0.754 		2163-0.978
# ol-74:		2188-0.957 		2194-0.753 		2193-0.978
# ol-75:		2218-0.957 		2224-0.752 		2223-0.977
# ol-76:		2248-0.956 		2254-0.752 		2253-0.977
# ol-77:		2278-0.955 		2284-0.751 		2283-0.977
# ol-78:		2308-0.955 		2314-0.750 		2313-0.977

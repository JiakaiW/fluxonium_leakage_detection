# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import scqubits
from functools import partial
import qutip
import concurrent
from loky import get_reusable_executor
import numpy as np
import qutip
import scqubits
from typing import List, Union,Any

from CoupledQuantumSystems.qobj_manip import *
from CoupledQuantumSystems.drive import *
from CoupledQuantumSystems.evo import ODEsolve_and_post_process
from CoupledQuantumSystems.noise import *
from CoupledQuantumSystems.qobj_manip import *
from CoupledQuantumSystems.IFQ import gfIFQ

# %%
from scipy.optimize import minimize

EJ = 4
EC = EJ/2.7
EL = EJ/45

qbt = gfIFQ(EJ = EJ,EC =EC,EL = EL,truncated_dim=20)

temp_in_mK = 20
loss_tangent_ref = 5e-6
one_over_f_flux_noise_amplitude = 1e-6

c_ops=qbt.get_T1_c_ops(temp_in_mK,
                        loss_tangent_ref,
                        one_over_f_flux_noise_amplitude)
e_ops = [qutip.ket2dm(qutip.basis(qbt.truncated_dim, i)) for i in range(12)]
# Out:
# RuntimeWarning: divide by zero encountered in scalar divide
#  /tmp/ipykernel_580323/1980754626.py: 38

# %%
from IPython.display import clear_output

t_duration = 50
tlist = np.linspace(0,t_duration,t_duration)
detuning = 0.3

# %%
def objective(x):
    amp1_scaling_factor = x[0]
    amp2_scaling_factor = x[1]
    amp1_correction_scaling_factor = x[2]
    amp2_correction_scaling_factor = x[3]
    results  = qbt.run_qutip_mesolve_parrallel(
        initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
        tlist = tlist,
        drive_terms = qbt.get_Raman_DRAG_drive_terms(
            i = 0,
            j = 3,
            k = 2,
            detuning1=detuning,
            detuning2 = detuning,
            t_duration=t_duration,
            shape='sin^2',
            amp_scaling_factor = 1,
            amp1_scaling_factor = amp1_scaling_factor,
            amp2_scaling_factor = amp2_scaling_factor,
            amp1_correction_scaling_factor = amp1_correction_scaling_factor,
            amp2_correction_scaling_factor = amp2_correction_scaling_factor,
        ),
        c_ops = c_ops,
        e_ops = e_ops
    )
    clear_output()
    print(x)
    fig, axes = plt.subplots(1,2,figsize = (10,5))
    for i, exp in enumerate(results[0].expect):
        axes[0].plot(tlist,exp,label= f"{i}")
    for i, exp in enumerate(results[1].expect):
        axes[1].plot(tlist,exp,label= f"{i}")
    axes[0].legend()
    axes[0].set_yscale('log')
    axes[0].set_ylim(1e-8,1e1)
    axes[1].legend()
    axes[1].set_yscale('log')
    axes[1].set_ylim(1e-8,1e1)
    plt.show()
    
    one_minus_pop2 = 1- (results[0].expect[2][-1] + 0.95* results[0].expect[1][-1])
    one_minus_pop0 = 1- (results[1].expect[0][-1] +  0.95* results[1].expect[1][-1])
    print((one_minus_pop2, one_minus_pop0))
    return one_minus_pop2 + one_minus_pop0

initial_guess = [2.19369573, 2.16677757 ,0.10174757, 0.10451909]




result = minimize(objective, initial_guess, method='Nelder-Mead')
# Out:
# [2.19360814 2.16602898 0.10204908 0.10411559]
# (-5.208528866118556e-05, 3.0504447648405097e-05)

# %%
def objective(x):
    
    amp1_scaling_factor = x[0]
    amp2_scaling_factor = x[1]
    amp1_correction_scaling_factor = x[2]
    amp2_correction_scaling_factor = x[3]
    detuning1 =x[4]
    detuning2 =x[5]
    results  = qbt.run_qutip_mesolve_parrallel(
        initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
        tlist = tlist,
        drive_terms = qbt.get_Raman_DRAG_drive_terms(
            i = 0,
            j = 3,
            k = 2,
            detuning1=detuning1,
            detuning2 = detuning2,
            t_duration=t_duration,
            shape='sin^2',
            amp_scaling_factor = 1,
            amp1_scaling_factor = amp1_scaling_factor,
            amp2_scaling_factor = amp2_scaling_factor,
            amp1_correction_scaling_factor = amp1_correction_scaling_factor,
            amp2_correction_scaling_factor = amp2_correction_scaling_factor,
        ),
        c_ops = c_ops,
        e_ops = e_ops
    )
    clear_output()
    print(x)
    fig, axes = plt.subplots(1,2,figsize = (10,5))
    for i, exp in enumerate(results[0].expect):
        axes[0].plot(tlist,exp,label= f"{i}")
    for i, exp in enumerate(results[1].expect):
        axes[1].plot(tlist,exp,label= f"{i}")
    axes[0].legend()
    axes[0].set_yscale('log')
    axes[0].set_ylim(1e-8,1e1)
    axes[1].legend()
    axes[1].set_yscale('log')
    axes[1].set_ylim(1e-8,1e1)
    plt.show()
    
    one_minus_pop2 = np.abs( 1- (results[0].expect[2][-1] + 0.98* results[0].expect[1][-1]))
    one_minus_pop0 = np.abs(1- (results[1].expect[0][-1] +  0.98* results[1].expect[1][-1]))
    print((one_minus_pop2, one_minus_pop0))
    return one_minus_pop2 + one_minus_pop0

initial_guess = [2.19442754, 2.16568642, 0.10266431, 0.10325003, 0.30007191, 0.30007318]





result = minimize(objective, initial_guess, method='Nelder-Mead')
# Out:
# [2.19359055 2.16770401 0.10269584 0.10755618 0.30012506 0.30012848]
# (6.541363146039814e-06, 3.092499144474736e-05)
#  Total run time:   4.07s*] Elapsed 4.07s / Remaining 00:00:00:00
#  Total run time:   4.92s*] Elapsed 4.92s / Remaining 00:00:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 55
#      47     return one_minus_pop2 + one_minus_pop0
#      49 initial_guess = [2.19442754, 2.16568642, 0.10266431, 0.10325003, 0.30007191, 0.30007318]
# ---> 55 result = minimize(objective, initial_guess, method='Nelder-Mead')
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698 callback = _wrap_callback(callback, meth)
#     700 if meth == 'nelder-mead':
# --> 701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
#     704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:999, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     996                     if bounds is not None:
#     997                         sim[j] = np.clip(
#     998                             sim[j], lower_bound, upper_bound)
# --> 999                     fsim[j] = func(sim[j])
#    1000     iterations += 1
#    1001 except _MaxFuncCallError:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:640, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     638 ncalls[0] += 1
#     639 # A copy of x is sent to the user function (gh13740)
# --> 640 fx = function(np.copy(x), *(wrapper_args + args))
#     641 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     642 # backwards-compatibility, also allow np.array([1.3]),
#     643 # np.array([[1.3]]) etc.
#     644 if not np.isscalar(fx):
#
# Cell In[8], line 9, in objective(x)
#       7 detuning1 =x[4]
#       8 detuning2 =x[5]
# ----> 9 results  = qbt.run_qutip_mesolve_parrallel(
#      10     initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
#      11     tlist = tlist,
#      12     drive_terms = qbt.get_Raman_DRAG_drive_terms(
#      13         i = 0,
#      14         j = 3,
#      15         k = 2,
#      16         detuning1=detuning1,
#      17         detuning2 = detuning2,
#      18         t_duration=t_duration,
#      19         shape='sin^2',
#      20         amp_scaling_factor = 1,
#      21         amp1_scaling_factor = amp1_scaling_factor,
#      22         amp2_scaling_factor = amp2_scaling_factor,
#      23         amp1_correction_scaling_factor = amp1_correction_scaling_factor,
#      24         amp2_correction_scaling_factor = amp2_correction_scaling_factor,
#      25     ),
#      26     c_ops = c_ops,
#      27     e_ops = e_ops
#      28 )
#      29 clear_output()
#      30 print(x)
#
# Cell In[2], line 180, in gfIFQ.run_qutip_mesolve_parrallel(self, initial_states, tlist, drive_terms, c_ops, e_ops, post_processing)
#     178 post_processing_args = []
#     179 results = [None] * len(initial_states)
# --> 180 with get_reusable_executor(max_workers=None, context='loky') as executor:
#     181     futures = {executor.submit(ODEsolve_and_post_process,
#     182                                y0=initial_states[i],
#     183                                tlist=tlist,
#    (...)
#     189                                post_processing_args=post_processing_args,
#     190                                ): i for i in range(len(initial_states))}
#     192     for future in concurrent.futures.as_completed(futures):
#
# File ~/miniconda3/envs/test/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/loky/process_executor.py:1303, in ProcessPoolExecutor.shutdown(self, wait, kill_workers)
#    1299 if executor_manager_thread is not None and wait:
#    1300     # This locks avoids concurrent join if the interpreter
#    1301     # is shutting down.
#    1302     with _global_shutdown_lock:
# -> 1303         executor_manager_thread.join()
#    1304         _threads_wakeups.pop(executor_manager_thread, None)
#    1306 # To reduce the risk of opening too many files, remove references to
#    1307 # objects that use file descriptors.
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %% [markdown]
# # what is idling error rate?

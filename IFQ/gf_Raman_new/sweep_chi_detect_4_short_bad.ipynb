# %%
import matplotlib.gridspec as gridspec
import scqubits
import numpy as np
from CoupledQuantumSystems.visualization import *
from CoupledQuantumSystems.systems import *
from tqdm import tqdm
from CoupledQuantumSystems.qobj_manip import *
from CoupledQuantumSystems.drive import *
from  IPython.display import  clear_output

# %%
max_ql = 13
EJ_over_EC = 2
EJ_over_EL = 30
fluxonium = scqubits.Fluxonium(EJ = 4,EC = 4/EJ_over_EC,EL = 4/EJ_over_EL, cutoff = 110,flux = 0,truncated_dim=max_ql)

# %%
max_tl = 4
transmon = scqubits.Transmon(
    EJ= 50.03015,
    EC=0.5,
    ng=0.0,
    ncut=10,
    truncated_dim = max_tl
    )

system = FluxoniumTransmonSystem(
    fluxonium  = fluxonium,
    transmon = transmon,
    computaional_states = '0,2',
    g_strength = 0.1,
    )
driven_op = qutip.Qobj(system.hilbertspace.op_in_dressed_eigenbasis(transmon.n_operator)[:, :])

e_ops = []
for ql in range(max_ql):
    for tl in range(max_tl):
        e_ops.append(system.truncate_function(qutip.ket2dm(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,tl)]))))

# %% [markdown]
# # first, square pulse

# %%
amp = 0.01385  / (2*np.pi)
t = 180
tlist = np.linspace(0,t,500)
results  = system.run_qutip_mesolve_parrallel(
    initial_states = [qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,0)]) for ql in [0,2,3]],
    tlist = tlist,
    drive_terms = [DriveTerm( 
                            driven_op= driven_op,
                            pulse_shape_func=square_pulse_with_rise_fall,
                            pulse_id = 'sdaas',
                            pulse_shape_args={
                                'w_d': system.evals[system.product_to_dressed[(3,1)]] - system.evals[system.product_to_dressed[(3,0)]] ,
                                'amp': amp,
                                't_square': 1000
                            })],
    # c_ops = c_ops,
    e_ops =  e_ops
)

fig, axes = plt.subplots(1,3,figsize = (15,5))
for i, (result,ql) in enumerate(zip(results,[0,2,3])):
    axes[i].plot(tlist,result.expect[ql*max_tl+0],label= rf"$\langle${ql}$_f0_t\rangle$")
    axes[i].plot(tlist,result.expect[ql*max_tl+1],label= rf"$\langle${ql}$_f1_t\rangle$")
    axes[i].plot(tlist,result.expect[ql*max_tl+2],label= rf"$\langle${ql}$_f2_t\rangle$")
    axes[i].legend()
    axes[i].set_yscale('log')
    axes[i].set_ylim(1e-4,1+2)
    # axes[i].set_xlim(0,102)
plt.show()
# Out:
#  Total run time:   2.18s*] Elapsed 2.18s / Remaining 00:00:00:00 [*********84%*******    ] Elapsed 1.99s / Remaining 00:00:00:00
#  Total run time:   2.19s*] Elapsed 2.19s / Remaining 00:00:00:00
#  [*********92%*********  ] Elapsed 2.17s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 500/500 [00:00<00:00, 7675.77it/s]
# Processing states with pad_back_custom: 100%|██████████| 500/500 [00:00<00:00, 7735.94it/s]
#  Total run time:   2.36s*] Elapsed 2.36s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 500/500 [00:00<00:00, 8467.05it/s]

# %%
from scipy.optimize import minimize

def objective(x):
    
    EJ = x[0]
    amp = x[1]
    t_duration = x[2]
    tlist = np.linspace(0,t_duration,1000)

    transmon = scqubits.Transmon(
        EJ= EJ,
        EC=0.5,
        ng=0.0,
        ncut=10,
        truncated_dim = max_tl
        )

    system = FluxoniumTransmonSystem(
        fluxonium  = fluxonium,
        transmon = transmon,
        computaional_states = '0,2',
        g_strength = 0.1,
        )
    driven_op = qutip.Qobj(system.hilbertspace.op_in_dressed_eigenbasis(transmon.n_operator)[:, :])

    e_ops = []
    for ql in range(max_ql):
        for tl in range(max_tl):
            e_ops.append(system.truncate_function(qutip.ket2dm(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,tl)]))))

    results  = system.run_qutip_mesolve_parrallel(
        initial_states = [qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,0)]) for ql in [0,2,3]],
        tlist = tlist,
        drive_terms = [DriveTerm( 
                            driven_op= driven_op,
                            pulse_shape_func=square_pulse_with_rise_fall,
                            pulse_id = 'sdaas',
                            pulse_shape_args={
                                'w_d': system.evals[system.product_to_dressed[(3,1)]] - system.evals[system.product_to_dressed[(3,0)]] ,
                                'amp': amp,
                                't_square': 1000
                            })],
        # c_ops = c_ops,
        e_ops =  e_ops
    )
    
    fig, axes = plt.subplots(1,3,figsize = (15,5))
    for i, (result,ql) in enumerate(zip(results,[0,2,3])):
        axes[i].plot(tlist,result.expect[ql*max_tl+0],label= rf"$\langle${ql}$_f0_t\rangle$")
        axes[i].plot(tlist,result.expect[ql*max_tl+1],label= rf"$\langle${ql}$_f1_t\rangle$")
        axes[i].plot(tlist,result.expect[ql*max_tl+2],label= rf"$\langle${ql}$_f2_t\rangle$")
        axes[i].legend()
        axes[i].set_yscale('log')
        axes[i].set_ylim(1e-4,1+2)
    clear_output()
    plt.show()
    obj =  -results[0].expect[0*max_tl+0][-1] ** 2 \
            -results[1].expect[2*max_tl+0][-1] ** 2\
            + results[2].expect[3*max_tl+0][-1] ** 2 / 50
    print(f"x = {x}, obj  = {obj}")
    return obj


initial_guess = [50.03015, 0.01385  / (2*np.pi) , 180]

 
result = minimize(objective, initial_guess, method='Nelder-Mead')

objective(initial_guess)
# Out:
# x = [5.00209791e+01 2.20625027e-03 1.80889267e+02], obj  = -1.9405570018251195
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 67
#      61     return obj
#      64 initial_guess = [50.03015, 0.01385  / (2*np.pi) , 180]
# ---> 67 result = minimize(objective, initial_guess, method='Nelder-Mead')
#      69 objective(initial_guess)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698 callback = _wrap_callback(callback, meth)
#     700 if meth == 'nelder-mead':
# --> 701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
#     704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:973, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     971 if bounds is not None:
#     972     xc = np.clip(xc, lower_bound, upper_bound)
# --> 973 fxc = func(xc)
#     975 if fxc <= fxr:
#     976     sim[-1] = xc
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:640, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     638 ncalls[0] += 1
#     639 # A copy of x is sent to the user function (gh13740)
# --> 640 fx = function(np.copy(x), *(wrapper_args + args))
#     641 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     642 # backwards-compatibility, also allow np.array([1.3]),
#     643 # np.array([[1.3]]) etc.
#     644 if not np.isscalar(fx):
#
# Cell In[5], line 18, in objective(x)
#       8 tlist = np.linspace(0,t_duration,1000)
#      10 transmon = scqubits.Transmon(
#      11     EJ= EJ,
#      12     EC=0.5,
#    (...)
#      15     truncated_dim = max_tl
#      16     )
# ---> 18 system = FluxoniumTransmonSystem(
#      19     fluxonium  = fluxonium,
#      20     transmon = transmon,
#      21     computaional_states = '0,2',
#      22     g_strength = 0.1,
#      23     )
#      24 driven_op = qutip.Qobj(system.hilbertspace.op_in_dressed_eigenbasis(transmon.n_operator)[:, :])
#      26 e_ops = []
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/CoupledQuantumSystems/systems.py:410, in FluxoniumTransmonSystem.__init__(self, fluxonium, transmon, computaional_states, g_strength, products_to_keep)
#     406 hilbertspace = scqubits.HilbertSpace([self.fluxonium, self.transmon])
#     407 hilbertspace.add_interaction(
#     408     g_strength=g_strength, op1=self.fluxonium.n_operator, op2=self.transmon.n_operator, add_hc=False)
# --> 410 super().__init__(hilbertspace=hilbertspace,
#     411                  products_to_keep=products_to_keep,
#     412                  qbt_position=0,
#     413                  computaional_states=[int(computaional_states[0]), int(computaional_states[-1])])
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/CoupledQuantumSystems/systems.py:45, in CoupledSystem.__init__(self, hilbertspace, products_to_keep, qbt_position, computaional_states)
#      42 self.evals = hilbertspace["evals"][0]
#      43 self.evecs = hilbertspace["evecs"][0]
#      44 self.product_to_dressed = generate_single_mapping(
# ---> 45     self.hilbertspace.hamiltonian(), evals=self.evals, evecs=self.evecs)
#      47 self.set_new_product_to_keep(products_to_keep)
#      49 self.set_sign_multiplier()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scqubits/core/hilbert_space.py:813, in HilbertSpace.hamiltonian(self, bare_esys)
#     797 def hamiltonian(
#     798     self,
#     799     bare_esys: Optional[Dict[int, ndarray]] = None,
#     800 ) -> qt.Qobj:
#     801     """
#     802     Parameters
#     803     ----------
#    (...)
#     811         components
#     812     """
# --> 813     hamiltonian = self.bare_hamiltonian(bare_esys=bare_esys)
#     814     hamiltonian += self.interaction_hamiltonian(bare_esys=bare_esys)
#     815     return hamiltonian
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scqubits/core/hilbert_space.py:841, in HilbertSpace.bare_hamiltonian(self, bare_esys)
#     839         evals = bare_esys[subsys_index][0]
#     840     else:
# --> 841         evals = subsys.eigenvals(evals_count=subsys.truncated_dim)
#     842     bare_hamiltonian += self.diag_hamiltonian(subsys, evals)
#     843 return bare_hamiltonian
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scqubits/core/qubit_base.py:359, in QubitBaseClass.eigenvals(self, evals_count, filename, return_spectrumdata)
#     340 """Calculates eigenvalues using `scipy.linalg.eigh`, returns numpy array of
#     341 eigenvalues.
#     342
#    (...)
#     356     eigenvalues as ndarray or in form of a SpectrumData object
#     357 """
#     358 if not hasattr(self, "evals_method") or self.evals_method is None:
# --> 359     evals = self._evals_calc(evals_count)
#     360 else:
#     361     diagonalizer = (
#     362         diag.DIAG_METHODS[self.evals_method]
#     363         if isinstance(self.evals_method, str)
#     364         else self.evals_method
#     365     )
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scqubits/core/qubit_base.py:298, in QubitBaseClass._evals_calc(self, evals_count)
#     297 def _evals_calc(self, evals_count: int) -> ndarray:
# --> 298     hamiltonian_mat = self.hamiltonian()
#     299     evals = sp.linalg.eigh(
#     300         hamiltonian_mat,
#     301         eigvals_only=True,
#     302         subset_by_index=(0, evals_count - 1),
#     303         check_finite=False,
#     304     )
#     305     return np.sort(evals)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scqubits/core/fluxonium.py:330, in Fluxonium.hamiltonian(self, energy_esys)
#     327 diag_elements = [(i + 0.5) * self.plasma_energy() for i in range(dimension)]
#     328 lc_osc_matrix = np.diag(diag_elements)
# --> 330 cos_matrix = self.cos_phi_operator(beta=2 * np.pi * self.flux)
#     332 hamiltonian_mat = lc_osc_matrix - self.EJ * cos_matrix
#     333 return self.process_hamiltonian(
#     334     native_hamiltonian=hamiltonian_mat, energy_esys=energy_esys
#     335 )
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scqubits/core/fluxonium.py:273, in Fluxonium.cos_phi_operator(self, alpha, beta, energy_esys)
#     254 """
#     255 Returns the :math:`\\cos (\\alpha \\phi + \\beta)` operator with :math:`\\alpha` and :math:`\\beta` being
#     256 numbers, in the LC harmonic oscillator or eigenenergy basis.
#    (...)
#     270     x `truncated_dim`. Otherwise, if eigenenergy basis is chosen, :math:`\\cos (\\alpha \\phi + \\beta)` has dimensions of m x m, for m given eigenvectors.
#     271 """
#     272 argument = alpha * self.phi_operator() + beta * np.eye(self.hilbertdim())
# --> 273 native = sp.linalg.cosm(argument)
#     274 return self.process_op(native_op=native, energy_esys=energy_esys)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/linalg/_matfuncs.py:438, in cosm(A)
#     436     return 0.5*(expm(1j*A) + expm(-1j*A))
#     437 else:
# --> 438     return expm(1j*A).real
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/linalg/_matfuncs.py:353, in expm(A)
#     350 if s != 0:  # scaling needed
#     351     Am[:4] *= [[[2**(-s)]], [[4**(-s)]], [[16**(-s)]], [[64**(-s)]]]
# --> 353 pade_UV_calc(Am, n, m)
#     354 eAw = Am[0]
#     356 if s != 0:  # squaring needed
#
# KeyboardInterrupt:

# %%
x = [3.43920642e+01, 1.28335117e-03 , 2.58812987e+02]#, obj  = -1.9861439557305098

EJ = x[0]
amp = x[1]
t_duration = x[2]
tlist = np.linspace(0,t_duration,1000)

transmon = scqubits.Transmon(
    EJ= EJ,
    EC=0.2,
    ng=0.0,
    ncut=10,
    truncated_dim = max_tl
    )

system = FluxoniumTransmonSystem(
    fluxonium  = fluxonium,
    transmon = transmon,
    computaional_states = '0,2',
    g_strength = 0.1,
    )
driven_op = qutip.Qobj(system.hilbertspace.op_in_dressed_eigenbasis(transmon.n_operator)[:, :])

e_ops = []
for ql in range(max_ql):
    for tl in range(max_tl):
        e_ops.append(system.truncate_function(qutip.ket2dm(qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,tl)]))))

results  = system.run_qutip_mesolve_parrallel(
    initial_states = [qutip.basis(system.hilbertspace.dimension, system.product_to_dressed[(ql,0)]) for ql in [0,2,3,1]],
    tlist = tlist,
    drive_terms = [DriveTerm( 
                        driven_op= driven_op,
                        pulse_shape_func=square_pulse_with_rise_fall,
                        pulse_id = 'sdaas',
                        pulse_shape_args={
                            'w_d': system.evals[system.product_to_dressed[(3,1)]] - system.evals[system.product_to_dressed[(3,0)]] ,
                            'amp': amp,
                            't_square': 1000
                        })],
    # c_ops = c_ops,
    e_ops =  e_ops
)
# Out:
#  Total run time:   2.37s*] Elapsed 2.37s / Remaining 00:00:00:00 [*********90%*********  ] Elapsed 2.26s / Remaining 00:00:00:00
#  [*********95%********** ] Elapsed 2.39s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 1000/1000 [00:00<00:00, 8670.40it/s]
# Processing states with pad_back_custom:   0%|          | 0/1000 [00:00<?, ?it/s]
#  Total run time:   2.45s*] Elapsed 2.45s / Remaining 00:00:00:00 [*********99%***********] Elapsed 2.43s / Remaining 00:00:00:00
#  Total run time:   2.52s*] Elapsed 2.52s / Remaining 00:00:00:00
#  [*********87%********   ] Elapsed 2.60s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 1000/1000 [00:00<00:00, 7944.62it/s]
# Processing states with pad_back_custom: 100%|██████████| 1000/1000 [00:00<00:00, 8166.77it/s]
#  Total run time:   2.95s*] Elapsed 2.95s / Remaining 00:00:00:00
# Processing states with pad_back_custom: 100%|██████████| 1000/1000 [00:00<00:00, 8621.23it/s]

# %%
fig = plt.figure(figsize=(5, 2.3)) 
bottom = 0.15
top = 0.95
left = 0.15
l = 0.3

gs0 = fig.add_gridspec(nrows=1, ncols=1,left=left, right=left+l,
                       bottom=bottom,top = top)
gs1 = fig.add_gridspec(nrows=1, ncols=1,left=left+l, right=left+l*2,
                       bottom=bottom,top = top)
gs2 = fig.add_gridspec(nrows=1, ncols=1,left=left+l*2, right=left+l*3,
                       bottom=bottom,top = top)

axes = [fig.add_subplot(gs0[0]),
        fig.add_subplot(gs1[0]),
        fig.add_subplot(gs2[0])]

alpha=0.6
for i, (result,ql) in enumerate(zip(results,[0,2,3])):
    line, =axes[i].plot(tlist,result.expect[ql*max_tl+0],label= rf"$\langle${ql}$_f0_t\rangle$",alpha=alpha)
    axes[i].text(tlist[400],result.expect[ql*max_tl+0][400],s= rf"{ql}$_f0_t$",va='top',ha='center',color=line.get_color())

    line, =axes[i].plot(tlist,result.expect[ql*max_tl+1],label= rf"$\langle${ql}$_f1_t\rangle$",alpha=alpha)
    axes[i].text(tlist[-300],result.expect[ql*max_tl+1][-300],s= rf"{ql}$_f1_t$",va='top',ha='center',color=line.get_color())

    axes[i].set_yscale('log')
    axes[i].set_ylim(1e-4,2)

for i in [0,1,2]:
    axes[i].set_xlabel(f"t (ns)")

for i in [1,2]:
    axes[i].yaxis.set_visible(False)


plt.show()
fig.savefig('detect3.pdf')

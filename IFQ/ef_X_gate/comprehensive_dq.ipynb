# %%
import numpy as np
import qutip
import pickle
import functools

import dynamiqs as dq
dq.set_device('cpu')

from CoupledQuantumSystems.drive import DriveTerm
from CoupledQuantumSystems.IFQ import gfIFQ

import jax
import jax.numpy as jnp
import optax
import warnings
warnings.filterwarnings("ignore")

# %%
def square_pulse_with_rise_fall_jnp(t,
                                args = {}):
    
    w_d = args['w_d']
    amp = args['amp']
    t_start = args.get('t_start', 0)  # Default start time is 0
    t_rise = args.get('t_rise', 1e-10)  # Default rise time is 0 for no rise
    t_square = args.get('t_square', 0)  # Duration of constant amplitude

    def cos_modulation():
        return 2 * jnp.pi * amp * jnp.cos(w_d * 2 * jnp.pi * t)
    
    t_fall_start = t_start + t_rise + t_square  # Start of fall
    t_end = t_fall_start + t_rise  # End of the pulse

    before_pulse_start = jnp.less(t, t_start)
    during_rise_segment = jnp.logical_and(jnp.greater(t_rise, 0), jnp.logical_and(jnp.greater_equal(t, t_start), jnp.less_equal(t, t_start + t_rise)))
    constant_amplitude_segment = jnp.logical_and(jnp.greater(t, t_start + t_rise), jnp.less_equal(t, t_fall_start))
    during_fall_segment = jnp.logical_and(jnp.greater(t_rise, 0), jnp.logical_and(jnp.greater(t, t_fall_start), jnp.less_equal(t, t_end)))

    return jnp.where(before_pulse_start, 0,
                    jnp.where(during_rise_segment, jnp.sin(jnp.pi * (t - t_start) / (2 * t_rise)) ** 2 * cos_modulation(),
                            jnp.where(constant_amplitude_segment, cos_modulation(),
                                        jnp.where(during_fall_segment, jnp.sin(jnp.pi * (t_end - t) / (2 * t_rise)) ** 2 * cos_modulation(), 0))))

solver = dq.solver.Dopri8(
                    rtol= 1e-06,
                    atol= 1e-06,
                    safety_factor= 0.6,
                    min_factor= 0.1,
                    max_factor = 4.0,
                    max_steps = int(1e4*1000),
                )


# -------------------------------
# Define your parameters and objects
# -------------------------------
EJ = 3
EJoverEC = 6
EJoverEL = 25
EC = EJ / EJoverEC
EL = EJ / EJoverEL

qbt = gfIFQ(EJ=EJ, EC=EC, EL=EL, flux=0, truncated_dim=20)

driven_op=qutip.Qobj(qbt.fluxonium.n_operator(energy_esys=True))

e_ops = [
    qutip.basis(qbt.truncated_dim, i) * qutip.basis(qbt.truncated_dim, i).dag()
    for i in range(10)
]

element = np.abs(
    qbt.fluxonium.matrixelement_table("n_operator", evals_count=3)[1, 2]
)
freq = (qbt.fluxonium.eigenvals()[2] - qbt.fluxonium.eigenvals()[1]) * 2 * np.pi
init_wd = qbt.fluxonium.eigenvals()[2] - qbt.fluxonium.eigenvals()[1]

# -------------------------------
# Objective function
# -------------------------------
def objective(t_tot, amp, w_d,ramp):
    tlist = jnp.linspace(0, t_tot * (1+ramp), 100)

    initial_states = [
        qutip.basis(qbt.truncated_dim, 1),
        qutip.basis(qbt.truncated_dim, 2),
    ]

    def _H(t,args):
        _H =  qbt.diag_hamiltonian.full()
        _H += driven_op.full() * square_pulse_with_rise_fall_jnp(t, args)
        return _H 
    f = functools.partial(_H, args = {
                                    "w_d": w_d,    # No extra 2pi factor
                                    "amp": amp,    # No extra 2pi factor
                                    "t_square": t_tot * (1-ramp),
                                    "t_rise": t_tot * ramp,
                                })
    H =  dq.timecallable(f)

    results = dq.sesolve(
                    H = H,
                    psi0 = initial_states,
                    tsave = tlist,
                    exp_ops = e_ops,
                    solver = solver,
                    options=dq.Options(progress_meter = None),
                    )
    one_minus_pop2 = abs((1 - results.expects[0][2][-1]).real)  # from state |1> to |2>
    one_minus_pop1 = abs((1 - results.expects[1][1][-1]).real)  # from state |2> to |1>

    return one_minus_pop2 + one_minus_pop1



t_tot_list = np.linspace(50, 250, 21)
for t_tot in t_tot_list:
    def dq_objective(x):
        amp, w_d,ramp = x
        return objective(t_tot=t_tot, amp=amp, w_d=w_d,ramp=ramp)
    
    amp_guess = 50/t_tot * 22

    func = jax.value_and_grad(dq_objective)
    params = jnp.array([amp_guess, init_wd, 0.15]) 

    optimizer = optax.nadam(learning_rate=jnp.array([1e-3,
                                                    1e-4,
                                                    1e-3])) 
    opt_state = optimizer.init( params )

    num_steps = 1000
    for step in range(num_steps):
        print(f"iter: {step}, params: {params}")
        val, grads = func(params)
        print(f"\t val={val} grads: {grads}")
        updates, opt_state = optimizer.update(grads, opt_state)
        params = optax.apply_updates(params, updates)

    print(f'Optimized params: {params}')
    
    # Extract best values
    best_amp = params[0]
    best_w_d = params[1]
    best_ramp = params[2]
    best_cost = val

    # Optionally, store results in a pickle
    results_dict = {
        "best_cost": best_cost,
        "best_amp": best_amp,
        "best_w_d": best_w_d,
        "best_ramp": best_ramp,
    }

    with open(f"dq_optimized_results_{t_tot}.pkl", "wb") as f:
        pickle.dump(results_dict, f)
# Out:
# iter: 0, params: [2.2000000e+01 3.2520439e-03 1.5000001e-01]
# 	 val=1.5756362676620483 grads: [-3.4779453e+01  1.0640644e+05  3.6932852e+02]
# iter: 1, params: [2.2001474e+01 3.1046765e-03 1.4852633e-01]
# 	 val=0.2995262145996094 grads: [ 2.2857506e+01 -6.8315148e+04 -2.2225786e+02]
# iter: 2, params: [2.2001162e+01 3.1346960e-03 1.4879014e-01]
# 	 val=0.6525201797485352 grads: [ 2.8799770e+01 -8.4015391e+04 -2.9533163e+02]
# iter: 3, params: [2.2000608e+01 3.1877793e-03 1.4932163e-01]
# 	 val=1.8474371433258057 grads: [-2.2804089e+01  6.8423078e+04  2.3793832e+02]
# iter: 4, params: [2.2000877e+01 3.1599079e-03 1.4903361e-01]
# 	 val=1.8394994735717773 grads: [ 2.3678612e+01 -7.0381844e+04 -2.4140982e+02]
# iter: 5, params: [2.2000519e+01 3.1946765e-03 1.4937371e-01]
# 	 val=1.7973053455352783 grads: [ 3.5664040e+01 -1.0850958e+05 -3.6749664e+02]
# iter: 6, params: [2.1999928e+01 3.2535784e-03 1.4995202e-01]
# 	 val=1.714721918106079 grads: [-3.0513477e+01  9.3489609e+04  3.2542279e+02]
# iter: 7, params: [2.2000031e+01 3.2421246e-03 1.4982624e-01]
# 	 val=0.29082947969436646 grads: [-1.3558273e+01  4.2536617e+04  1.4161459e+02]
# iter: 8, params: [2.2000103e+01 3.2335864e-03 1.4973837e-01]
# 	 val=1.1680209636688232 grads: [ 4.8509987e+01 -1.4919009e+05 -5.1393024e+02]
# iter: 9, params: [2.1999613e+01 3.2824620e-03 1.5022416e-01]
# 	 val=1.0221067667007446 grads: [-5.0571243e+01  1.5770153e+05  5.4274567e+02]
# iter: 10, params: [2.1999866e+01 3.2557577e-03 1.4995393e-01]
# 	 val=1.8921111822128296 grads: [-2.0946749e+01  6.4490938e+04  2.2391702e+02]
# iter: 11, params: [2.2000059e+01 3.2355331e-03 1.4974739e-01]
# 	 val=0.8569485545158386 grads: [ 5.1397530e+01 -1.5887075e+05 -5.4151270e+02]
# iter: 12, params: [2.1999748e+01 3.2662945e-03 1.5004916e-01]
# 	 val=1.1271085739135742 grads: [ 4.6722763e+01 -1.4417669e+05 -4.9655145e+02]
# iter: 13, params: [2.1999331e+01 3.3077754e-03 1.5046120e-01]
# 	 val=0.29577136039733887 grads: [-3.5283065e+00  1.1952217e+04  3.6556686e+01]
# iter: 14, params: [2.1999138e+01 3.3264281e-03 1.5064786e-01]
# 	 val=1.9345935583114624 grads: [ 1.8082809e+01 -5.7286848e+04 -1.9608740e+02]
# iter: 15, params: [2.1998825e+01 3.3578090e-03 1.5095989e-01]
# 	 val=1.9824159145355225 grads: [ 2.6952395e+00 -8.5283320e+03 -2.8967037e+01]
# iter: 16, params: [2.1998583e+01 3.3818916e-03 1.5119910e-01]
# 	 val=1.1409841775894165 grads: [-4.0779587e+01  1.2990028e+05  4.5233490e+02]
# iter: 17, params: [2.1998663e+01 3.3726688e-03 1.5110169e-01]
# 	 val=0.3393194079399109 grads: [ 7.4874897e+00 -2.3043078e+04 -8.5040161e+01]
# iter: 18, params: [2.1998549e+01 3.3835489e-03 1.5121131e-01]
# 	 val=1.3645379543304443 grads: [-4.0883690e+01  1.3045022e+05  4.5586685e+02]
# iter: 19, params: [2.1998747e+01 3.3621746e-03 1.5099233e-01]
# 	 val=1.7272331714630127 grads: [ 3.2743401e+01 -1.0425245e+05 -3.6381201e+02]
# iter: 20, params: [2.1998577e+01 3.3789275e-03 1.5115993e-01]
# 	 val=0.7542451024055481 grads: [-3.6663651e+01  1.1729355e+05  4.0133551e+02]
# iter: 21, params: [2.1998768e+01 3.3586735e-03 1.5095793e-01]
# 	 val=1.9665553569793701 grads: [ 8.7274952e+00 -2.7630146e+04 -9.5818260e+01]
# iter: 22, params: [2.1998768e+01 3.3579406e-03 1.5095063e-01]
# 	 val=1.981266975402832 grads: [ 3.5136347e+00 -1.1119472e+04 -3.8011265e+01]
# iter: 23, params: [2.1998774e+01 3.3568346e-03 1.5093921e-01]
# 	 val=1.979095458984375 grads: [-4.7907796e+00  1.5187744e+04  5.3536575e+01]
# iter: 24, params: [2.1998821e+01 3.3513852e-03 1.5088373e-01]
# 	 val=1.4902422428131104 grads: [-4.7521538e+01  1.5159619e+05  5.2032410e+02]
# iter: 25, params: [2.1999157e+01 3.3165468e-03 1.5053597e-01]
# 	 val=1.2594621181488037 grads: [-4.05845604e+01  1.26818875e+05  4.38834442e+02]
# iter: 26, params: [2.1999567e+01 3.2746291e-03 1.5011576e-01]
# 	 val=0.47407257556915283 grads: [ 5.2007351e+00 -1.6840393e+04 -6.2174000e+01]
# iter: 27, params: [2.1999783e+01 3.2523887e-03 1.4989544e-01]
# 	 val=1.5812747478485107 grads: [-3.4581848e+01  1.0579066e+05  3.6740448e+02]
# iter: 28, params: [2.2000212e+01 3.2092223e-03 1.4946292e-01]
# 	 val=0.517849862575531 grads: [-4.6058145e+00  1.2971939e+04  4.2794380e+01]
# iter: 29, params: [2.2000526e+01 3.1776191e-03 1.4914805e-01]
# 	 val=0.504686176776886 grads: [-4.3118546e+01  1.3124706e+05  4.3699139e+02]
# iter: 30, params: [2.2001062e+01 3.1242501e-03 1.4862286e-01]
# 	 val=1.9811630249023438 grads: [ 5.7558637e+00 -1.7025887e+04 -5.7891724e+01]
# iter: 31, params: [2.2001383e+01 3.0919733e-03 1.4830330e-01]
# 	 val=1.810408592224121 grads: [ 2.615280e+01 -7.597844e+04 -2.592441e+02]
# iter: 32, params: [2.2001522e+01 3.0768716e-03 1.4815408e-01]
# 	 val=0.7587167620658875 grads: [-2.1470943e+01  6.0622672e+04  2.1646347e+02]
# iter: 33, params: [2.2001865e+01 3.0431228e-03 1.4781418e-01]
# 	 val=0.856044352054596 grads: [-6.0924011e+01  1.7653194e+05  5.8215887e+02]
# iter: 34, params: [2.2002472e+01 2.9844055e-03 1.4723948e-01]
# 	 val=1.9751622676849365 grads: [-6.5226164e+00  1.8369586e+04  6.3026047e+01]
# iter: 35, params: [2.2002886e+01 2.9441454e-03 1.4684178e-01]
# 	 val=1.598325490951538 grads: [-5.0351021e+01  1.4006900e+05  4.6926685e+02]
# iter: 36, params: [2.2003536e+01 2.8824902e-03 1.4623505e-01]
# 	 val=1.6830967664718628 grads: [ 2.8870167e+01 -7.7367461e+04 -2.6544348e+02]
# iter: 37, params: [2.2003801e+01 2.8554406e-03 1.4597100e-01]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 117
#     115 for step in range(num_steps):
#     116     print(f"iter: {step}, params: {params}")
# --> 117     val, grads = func(params)
#     118     print(f"\t val={val} grads: {grads}")
#     119     updates, opt_state = optimizer.update(grads, opt_state)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/api.py:709, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     707 _check_scalar(ans)
#     708 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 709 g = vjp_py(lax_internal._one(ans))
#     710 g = g[0] if isinstance(argnums, int) else g
#     711 if not has_aux:
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/tree_util.py:477, in _HashableCallableShim.__call__(self, *args, **kw)
#     476 def __call__(self, *args, **kw):
# --> 477   return self.fun(*args, **kw)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/api.py:2121, in _vjp_pullback_wrapper(name, out_primal_avals, io_tree, fun, *py_args_)
#    2114   if (not core.typecompat(ct_aval, ct_aval_expected) and
#    2115       not _temporary_dtype_exception(ct_aval, ct_aval_expected)):
#    2116     raise ValueError(
#    2117         "unexpected JAX type (e.g. shape/dtype) for argument to vjp function: "
#    2118         f"got {ct_aval.str_short()}, but expected {ct_aval_expected.str_short()} "
#    2119         f"because the corresponding output of the function {name} had JAX type "
#    2120         f"{aval.str_short()}")
# -> 2121 ans = fun(*args)
#    2122 return tree_unflatten(out_tree, ans)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/tree_util.py:477, in _HashableCallableShim.__call__(self, *args, **kw)
#     476 def __call__(self, *args, **kw):
# --> 477   return self.fun(*args, **kw)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:149, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     147 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     148 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 149 arg_cts = backward_pass(jaxpr, True, consts, dummy_args, cts)
#     150 return map(instantiate_zeros, arg_cts)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:249, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     246   cts_out = get_primitive_transpose(eqn.primitive)(
#     247       params, call_jaxpr, invals, cts_in, cts_in_avals)
#     248 elif eqn.primitive in reducing_transposes:
# --> 249   cts_out = reducing_transposes[eqn.primitive](
#     250       cts_in, *invals, **eqn.params)
#     251 else:
#     252   cts_out = get_primitive_transpose(eqn.primitive)(
#     253       cts_in, *invals, **eqn.params)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/pjit.py:2280, in _pjit_transpose(cts_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *primals_in)
#    2273 transpose_in_layouts = (
#    2274   *prune_type(ad.UndefinedPrimal, in_layouts, primals_in),
#    2275   *prune_type(ad.Zero, out_layouts, cts_in)
#    2276 )
#    2277 global_cts_in_avals = tuple(core.raise_to_shaped(core.get_aval(ct))
#    2278                             for ct in primals_and_nz_cts_in)
# -> 2280 transpose_jaxpr, attrs_tracked = _pjit_transpose_trace(
#    2281     body, global_cts_in_avals)
#    2282 cts_out_treedef = cts_out_treedef_thunk()
#    2283 transpose_out_shardings = prune_type(
#    2284     ad.Zero,
#    2285     in_shardings,
#    2286     tree_unflatten(cts_out_treedef, [object()] * cts_out_treedef.num_leaves))
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/linear_util.py:352, in cache.<locals>.memoized_fun(fun, *args)
#     350   fun.populate_stores(stores)
#     351 else:
# --> 352   ans = call(fun, *args)
#     353   if explain and config.explain_cache_misses.value:
#     354     explain(fun.f, cache is new_cache, cache, key)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/pjit.py:2252, in _pjit_transpose_trace(fun, in_avals)
#    2250 @lu.cache
#    2251 def _pjit_transpose_trace(fun, in_avals):
# -> 2252   transpose_jaxpr, _, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    2253       fun, in_avals)
#    2254   transpose_jaxpr = core.ClosedJaxpr(transpose_jaxpr, consts)
#    2255   return transpose_jaxpr, attrs_tracked
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2358, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2356 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:
#    2357   main.jaxpr_stack = ()  # type: ignore
# -> 2358   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2359     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2360   del main, fun
#    2361 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2381, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2379 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2380 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2381 ans = fun.call_wrapped(*in_tracers_)
#    2382 out_tracers = map(trace.full_raise, ans)
#    2383 jaxpr, consts, attrs_tracked = frame.to_jaxpr(trace, out_tracers)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:263, in closed_backward_pass(jaxpr, transform_stack, primals_in, cotangents_in)
#     261 def closed_backward_pass(jaxpr: core.ClosedJaxpr, transform_stack,
#     262                          primals_in, cotangents_in):
# --> 263   return backward_pass(jaxpr.jaxpr, transform_stack, jaxpr.consts,
#     264                        primals_in, cotangents_in)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:249, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     246   cts_out = get_primitive_transpose(eqn.primitive)(
#     247       params, call_jaxpr, invals, cts_in, cts_in_avals)
#     248 elif eqn.primitive in reducing_transposes:
# --> 249   cts_out = reducing_transposes[eqn.primitive](
#     250       cts_in, *invals, **eqn.params)
#     251 else:
#     252   cts_out = get_primitive_transpose(eqn.primitive)(
#     253       cts_in, *invals, **eqn.params)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/pjit.py:2280, in _pjit_transpose(cts_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *primals_in)
#    2273 transpose_in_layouts = (
#    2274   *prune_type(ad.UndefinedPrimal, in_layouts, primals_in),
#    2275   *prune_type(ad.Zero, out_layouts, cts_in)
#    2276 )
#    2277 global_cts_in_avals = tuple(core.raise_to_shaped(core.get_aval(ct))
#    2278                             for ct in primals_and_nz_cts_in)
# -> 2280 transpose_jaxpr, attrs_tracked = _pjit_transpose_trace(
#    2281     body, global_cts_in_avals)
#    2282 cts_out_treedef = cts_out_treedef_thunk()
#    2283 transpose_out_shardings = prune_type(
#    2284     ad.Zero,
#    2285     in_shardings,
#    2286     tree_unflatten(cts_out_treedef, [object()] * cts_out_treedef.num_leaves))
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/linear_util.py:352, in cache.<locals>.memoized_fun(fun, *args)
#     350   fun.populate_stores(stores)
#     351 else:
# --> 352   ans = call(fun, *args)
#     353   if explain and config.explain_cache_misses.value:
#     354     explain(fun.f, cache is new_cache, cache, key)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/pjit.py:2252, in _pjit_transpose_trace(fun, in_avals)
#    2250 @lu.cache
#    2251 def _pjit_transpose_trace(fun, in_avals):
# -> 2252   transpose_jaxpr, _, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    2253       fun, in_avals)
#    2254   transpose_jaxpr = core.ClosedJaxpr(transpose_jaxpr, consts)
#    2255   return transpose_jaxpr, attrs_tracked
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2358, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2356 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:
#    2357   main.jaxpr_stack = ()  # type: ignore
# -> 2358   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2359     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2360   del main, fun
#    2361 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2381, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2379 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2380 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2381 ans = fun.call_wrapped(*in_tracers_)
#    2382 out_tracers = map(trace.full_raise, ans)
#    2383 jaxpr, consts, attrs_tracked = frame.to_jaxpr(trace, out_tracers)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:263, in closed_backward_pass(jaxpr, transform_stack, primals_in, cotangents_in)
#     261 def closed_backward_pass(jaxpr: core.ClosedJaxpr, transform_stack,
#     262                          primals_in, cotangents_in):
# --> 263   return backward_pass(jaxpr.jaxpr, transform_stack, jaxpr.consts,
#     264                        primals_in, cotangents_in)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:252, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     249   cts_out = reducing_transposes[eqn.primitive](
#     250       cts_in, *invals, **eqn.params)
#     251 else:
# --> 252   cts_out = get_primitive_transpose(eqn.primitive)(
#     253       cts_in, *invals, **eqn.params)
#     254 cts_out = [Zero(v.aval) for v in eqn.invars] if cts_out is Zero else cts_out
#     255 # FIXME: Some invars correspond to primals!
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/ad.py:751, in _custom_lin_transpose(cts_out, num_res, bwd, out_avals, symbolic_zeros, *invals)
#     749 else:
#     750   cts_out = map(instantiate_zeros, cts_out)
# --> 751 cts_in = bwd(*res, *cts_out)
#     752 cts_in = map(replace_rule_output_symbolic_zeros, cts_in)
#     753 return [None] * num_res + list(cts_in)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:948, in batch_custom_vjp_bwd.<locals>.new_bwd(*args)
#     944 bwd_ = _batch_outer(bwd_, axis_name, axis_size, in_dims_, main_type,
#     945                     spmd_axis_name)
#     946 bwd_ = _match_axes_and_sum(bwd_, axis_size, axis_name, out_dims_thunk,
#     947                            out_dim_dests)
# --> 948 return bwd_.call_wrapped(*args)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/custom_derivatives.py:832, in CustomVJPCallPrimitive.bind.<locals>.<lambda>(*args)
#     829 fwd, env_trace_todo2 = process_env_traces_fwd(
#     830   fwd, top_trace and top_trace.level, out_trees)
#     831 tracers = map(top_trace.full_raise, args)
# --> 832 bwd_ = lambda *args: bwd(*args)
#     833 outs = top_trace.process_custom_vjp_call(self, fun, fwd, bwd_, tracers,
#     834                                          out_trees=out_trees,
#     835                                          symbolic_zeros=symbolic_zeros)
#     836 fst, env_trace_todo = lu.merge_linear_aux(env_trace_todo1, env_trace_todo2)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/equinox/_ad.py:1075, in filter_custom_vjp._defvjp.<locals>.fn_bwd_wrapped(nonarray_vjp_arg, nonarray_args_kwargs, residuals, grad_out)
#    1073 grad_diff_array_out, _, _ = grad_out
#    1074 grad_diff_array_out = jtu.tree_map(_zero_to_none, grad_diff_array_out)
# -> 1075 out = self.fn_bwd(
#    1076     residuals, grad_diff_array_out, perturbed, vjp_arg, *args, **kwargs
#    1077 )
#    1078 if jtu.tree_structure(out, is_leaf=_is_none) != jtu.tree_structure(
#    1079     diff_array_vjp_arg, is_leaf=_is_none
#    1080 ):
#    1081     raise RuntimeError(
#    1082         "custom_vjp gradients must have the same structure as "
#    1083         "`equinox.filter(vjp_arg, equinox.is_inexact_array)`, where "
#    1084         "`vjp_arg` is the first argument used in the forward pass."
#    1085     )
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/equinox/internal/_loop/checkpointed.py:1173, in _checkpointed_while_loop_bwd(***failed resolving arguments***)
#    1138 # Note that the saved checkpoints hold both (a) values computed on the forward
#    1139 # pass, and (b) checkpoints recomputed on the backward pass. (We don't need to
#    1140 # distinguish them.)
#    (...)
#    1170 # Not reverse mode autodifferentiable, but it is forward-mode autodifferentiable!
#    1171 # That means we can do Hessians, at least.
#    1172 while_loop = jax.named_call(lax.while_loop, name="checkpointed-bwd")
# -> 1173 final_carry = while_loop(_cond_fun, _body_fun, init_carry)
#    1174 *_, grad_init_val, grad_body_fun, _, _ = final_carry
#    1175 out = grad_init_val, grad_body_fun
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1350, in while_loop(cond_fun, body_fun, init_val)
#    1347 if disallowed_effects:
#    1348   raise NotImplementedError(
#    1349       f'Effects not supported in `while`: {disallowed_effects}')
# -> 1350 outs = while_p.bind(*cond_consts, *body_consts, *init_vals,
#    1351                     cond_nconsts=len(cond_consts), cond_jaxpr=cond_jaxpr,
#    1352                     body_nconsts=len(body_consts), body_jaxpr=body_jaxpr)
#    1353 return tree_unflatten(body_tree, outs)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:2782, in AxisPrimitive.bind(self, *args, **params)
#    2778 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2779                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2780 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2781              else axis_main.with_cur_sublevel())
# -> 2782 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:443, in Primitive.bind_with_trace(self, trace, args, params)
#     441 def bind_with_trace(self, trace, args, params):
#     442   with pop_level(trace.level):
# --> 443     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     444   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:442, in BatchTrace.process_primitive(self, primitive, tracers, params)
#     440   frame = self.get_frame(vals_in, dims_in)
#     441   batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 442   val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     443 src = source_info_util.current()
#     444 if primitive.multiple_results:
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/lax/control_flow/loops.py:1403, in _while_loop_batching_rule(spmd_axis_name, axis_size, axis_name, main_type, args, dims, cond_nconsts, cond_jaxpr, body_nconsts, body_jaxpr)
#    1398 # Fixpoint computation of which carry are batched: either
#    1399 # batched from init, or the carry out is batched. Each iteration promotes
#    1400 # at least one carry to batched. We need at most len(carry) iterations to
#    1401 # reach a fixpoint.
#    1402 for _ in range(1 + len(carry_bat)):
# -> 1403   _, carry_bat_out = batching.batch_jaxpr(
#    1404       body_jaxpr, axis_size, bconst_bat + carry_bat, instantiate=carry_bat,
#    1405       axis_name=axis_name, spmd_axis_name=spmd_axis_name, main_type=main_type)
#    1406   if carry_bat == carry_bat_out:
#    1407     break
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:816, in batch_jaxpr(closed_jaxpr, axis_size, in_batched, instantiate, axis_name, spmd_axis_name, main_type)
#     813 def batch_jaxpr(closed_jaxpr, axis_size, in_batched, instantiate, axis_name,
#     814                 spmd_axis_name, main_type):
#     815   inst = tuple(instantiate) if isinstance(instantiate, list) else instantiate
# --> 816   return _batch_jaxpr(closed_jaxpr, axis_size, tuple(in_batched), inst,
#     817                       axis_name, spmd_axis_name, main_type)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:828, in _batch_jaxpr(closed_jaxpr, axis_size, in_batched, instantiate, axis_name, spmd_axis_name, main_type)
#     826 in_axes = [0 if b else not_mapped for b in in_batched]
#     827 out_axes_dest = [0 if inst else zero_if_mapped for inst in instantiate]
# --> 828 return batch_jaxpr_axes(closed_jaxpr, axis_size, in_axes, out_axes_dest,
#     829                         axis_name, spmd_axis_name, main_type)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:833, in batch_jaxpr_axes(closed_jaxpr, axis_size, in_axes, out_axes_dest, axis_name, spmd_axis_name, main_type)
#     831 def batch_jaxpr_axes(closed_jaxpr, axis_size, in_axes, out_axes_dest, axis_name,
#     832                      spmd_axis_name, main_type):
# --> 833   return _batch_jaxpr_axes(closed_jaxpr, axis_size, tuple(in_axes),
#     834                            tuple(out_axes_dest), axis_name, spmd_axis_name,
#     835                            main_type)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:847, in _batch_jaxpr_axes(closed_jaxpr, axis_size, in_axes, out_axes_dest, axis_name, spmd_axis_name, main_type)
#     843 f = _batch_jaxpr_outer(f, axis_name, spmd_axis_name, axis_size, in_axes,
#     844                        main_type)
#     845 avals_in = [core.unmapped_aval(axis_size, axis_name, b, aval) if b is not not_mapped
#     846             else aval for aval, b in unsafe_zip(closed_jaxpr.in_avals, in_axes)]
# --> 847 jaxpr_out, _, consts, () = pe.trace_to_jaxpr_dynamic(f, avals_in)
#     848 return core.ClosedJaxpr(jaxpr_out, consts), out_batched()
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2358, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2356 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:
#    2357   main.jaxpr_stack = ()  # type: ignore
# -> 2358   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2359     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2360   del main, fun
#    2361 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2381, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2379 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2380 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2381 ans = fun.call_wrapped(*in_tracers_)
#    2382 out_tracers = map(trace.full_raise, ans)
#    2383 jaxpr, consts, attrs_tracked = frame.to_jaxpr(trace, out_tracers)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:260, in jaxpr_as_fun(closed_jaxpr, *args)
#     258 @curry
#     259 def jaxpr_as_fun(closed_jaxpr: ClosedJaxpr, *args):
# --> 260   return eval_jaxpr(closed_jaxpr.jaxpr, closed_jaxpr.consts, *args)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:509, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     506 traceback = eqn.source_info.traceback if propagate_source_info else None
#     507 with source_info_util.user_context(
#     508     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 509   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     510 if eqn.primitive.multiple_results:
#     511   map(write, eqn.outvars, ans)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/lax/control_flow/conditionals.py:803, in cond_bind(branches, *args)
#     801   for jaxpr in branches:
#     802     core.check_jaxpr(jaxpr.jaxpr)
# --> 803 return core.AxisPrimitive.bind(cond_p, *args, branches=branches)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:2782, in AxisPrimitive.bind(self, *args, **params)
#    2778 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2779                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2780 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2781              else axis_main.with_cur_sublevel())
# -> 2782 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:443, in Primitive.bind_with_trace(self, trace, args, params)
#     441 def bind_with_trace(self, trace, args, params):
#     442   with pop_level(trace.level):
# --> 443     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     444   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:442, in BatchTrace.process_primitive(self, primitive, tracers, params)
#     440   frame = self.get_frame(vals_in, dims_in)
#     441   batched_primitive = self.get_primitive_batcher(primitive, frame)
# --> 442   val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#     443 src = source_info_util.current()
#     444 if primitive.multiple_results:
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/lax/control_flow/conditionals.py:408, in _cond_batching_rule(spmd_axis_name, axis_size, axis_name, main_type, args, dims, branches)
#     403 branches_out_bat = [
#     404     batching.batch_jaxpr(jaxpr, axis_size, ops_bat, False, axis_name,
#     405                          spmd_axis_name, main_type)[1]
#     406     for jaxpr in branches]
#     407 out_bat = [any(bat) for bat in zip(*branches_out_bat)]
# --> 408 branches_batched = tuple(
#     409     batching.batch_jaxpr(jaxpr, axis_size, ops_bat, out_bat, axis_name,
#     410                          spmd_axis_name, main_type)[0]
#     411     for jaxpr in branches)
#     413 out_dims = [0 if b else batching.not_mapped for b in out_bat]
#     414 out = cond_p.bind(index, *ops, branches=branches_batched)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/lax/control_flow/conditionals.py:409, in <genexpr>(.0)
#     403 branches_out_bat = [
#     404     batching.batch_jaxpr(jaxpr, axis_size, ops_bat, False, axis_name,
#     405                          spmd_axis_name, main_type)[1]
#     406     for jaxpr in branches]
#     407 out_bat = [any(bat) for bat in zip(*branches_out_bat)]
#     408 branches_batched = tuple(
# --> 409     batching.batch_jaxpr(jaxpr, axis_size, ops_bat, out_bat, axis_name,
#     410                          spmd_axis_name, main_type)[0]
#     411     for jaxpr in branches)
#     413 out_dims = [0 if b else batching.not_mapped for b in out_bat]
#     414 out = cond_p.bind(index, *ops, branches=branches_batched)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:816, in batch_jaxpr(closed_jaxpr, axis_size, in_batched, instantiate, axis_name, spmd_axis_name, main_type)
#     813 def batch_jaxpr(closed_jaxpr, axis_size, in_batched, instantiate, axis_name,
#     814                 spmd_axis_name, main_type):
#     815   inst = tuple(instantiate) if isinstance(instantiate, list) else instantiate
# --> 816   return _batch_jaxpr(closed_jaxpr, axis_size, tuple(in_batched), inst,
#     817                       axis_name, spmd_axis_name, main_type)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:828, in _batch_jaxpr(closed_jaxpr, axis_size, in_batched, instantiate, axis_name, spmd_axis_name, main_type)
#     826 in_axes = [0 if b else not_mapped for b in in_batched]
#     827 out_axes_dest = [0 if inst else zero_if_mapped for inst in instantiate]
# --> 828 return batch_jaxpr_axes(closed_jaxpr, axis_size, in_axes, out_axes_dest,
#     829                         axis_name, spmd_axis_name, main_type)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:833, in batch_jaxpr_axes(closed_jaxpr, axis_size, in_axes, out_axes_dest, axis_name, spmd_axis_name, main_type)
#     831 def batch_jaxpr_axes(closed_jaxpr, axis_size, in_axes, out_axes_dest, axis_name,
#     832                      spmd_axis_name, main_type):
# --> 833   return _batch_jaxpr_axes(closed_jaxpr, axis_size, tuple(in_axes),
#     834                            tuple(out_axes_dest), axis_name, spmd_axis_name,
#     835                            main_type)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/batching.py:847, in _batch_jaxpr_axes(closed_jaxpr, axis_size, in_axes, out_axes_dest, axis_name, spmd_axis_name, main_type)
#     843 f = _batch_jaxpr_outer(f, axis_name, spmd_axis_name, axis_size, in_axes,
#     844                        main_type)
#     845 avals_in = [core.unmapped_aval(axis_size, axis_name, b, aval) if b is not not_mapped
#     846             else aval for aval, b in unsafe_zip(closed_jaxpr.in_avals, in_axes)]
# --> 847 jaxpr_out, _, consts, () = pe.trace_to_jaxpr_dynamic(f, avals_in)
#     848 return core.ClosedJaxpr(jaxpr_out, consts), out_batched()
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2358, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2356 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:
#    2357   main.jaxpr_stack = ()  # type: ignore
# -> 2358   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2359     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2360   del main, fun
#    2361 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/interpreters/partial_eval.py:2381, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2379 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2380 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2381 ans = fun.call_wrapped(*in_tracers_)
#    2382 out_tracers = map(trace.full_raise, ans)
#    2383 jaxpr, consts, attrs_tracked = frame.to_jaxpr(trace, out_tracers)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:260, in jaxpr_as_fun(closed_jaxpr, *args)
#     258 @curry
#     259 def jaxpr_as_fun(closed_jaxpr: ClosedJaxpr, *args):
# --> 260   return eval_jaxpr(closed_jaxpr.jaxpr, closed_jaxpr.consts, *args)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:509, in eval_jaxpr(jaxpr, consts, propagate_source_info, *args)
#     506 traceback = eqn.source_info.traceback if propagate_source_info else None
#     507 with source_info_util.user_context(
#     508     traceback, name_stack=name_stack), eqn.ctx.manager:
# --> 509   ans = eqn.primitive.bind(*subfuns, *map(read, eqn.invars), **bind_params)
#     510 if eqn.primitive.multiple_results:
#     511   map(write, eqn.outvars, ans)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:439, in Primitive.bind(self, *args, **params)
#     436 def bind(self, *args, **params):
#     437   assert (not config.enable_checks.value or
#     438           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 439   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/miniconda3/envs/dynamiqs/lib/python3.10/site-packages/jax/_src/core.py:441, in Primitive.bind_with_trace(self, trace, args, params)
#     437   assert (not config.enable_checks.value or
#     438           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
#     439   return self.bind_with_trace(find_top_trace(args), args, params)
# --> 441 def bind_with_trace(self, trace, args, params):
#     442   with pop_level(trace.level):
#     443     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#
# KeyboardInterrupt:

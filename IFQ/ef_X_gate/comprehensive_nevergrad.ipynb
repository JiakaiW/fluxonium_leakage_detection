# %%
import numpy as np
import qutip
import pickle
import nevergrad as ng
from CoupledQuantumSystems.drive import DriveTerm, square_pulse_with_rise_fall
from CoupledQuantumSystems.IFQ import gfIFQ
from CoupledQuantumSystems.evo import ODEsolve_and_post_process
from concurrent.futures import ProcessPoolExecutor
# -------------------------------
# Define your parameters and objects
# -------------------------------
EJ = 3
EJoverEC = 6
EJoverEL = 25
EC = EJ / EJoverEC
EL = EJ / EJoverEL

qbt = gfIFQ(EJ=EJ, EC=EC, EL=EL, flux=0, truncated_dim=20)
e_ops = [
    qutip.basis(qbt.truncated_dim, i) * qutip.basis(qbt.truncated_dim, i).dag()
    for i in range(10)
]

element = np.abs(
    qbt.fluxonium.matrixelement_table("n_operator", evals_count=3)[1, 2]
)
freq = (qbt.fluxonium.eigenvals()[2] - qbt.fluxonium.eigenvals()[1]) * 2 * np.pi


def objective(t_tot, amp, w_d,ramp):
    tlist = np.linspace(0, t_tot * (1+ramp), 100)

    initial_states = [
        qutip.basis(qbt.truncated_dim, 1),
        qutip.basis(qbt.truncated_dim, 2),
    ]

    drive_terms = [
        DriveTerm(
            driven_op=qutip.Qobj(qbt.fluxonium.n_operator(energy_esys=True)),
            pulse_shape_func=square_pulse_with_rise_fall,
            pulse_id="pi",
            pulse_shape_args={
                "w_d": w_d,    # No extra 2pi factor
                "amp": amp,    # No extra 2pi factor
                "t_square": t_tot * (1-ramp),
                "t_rise": t_tot * ramp,
            },
        )
    ]

    # Solve the dynamics for each initial state
    results = []
    for init_state in initial_states:
        res = ODEsolve_and_post_process(
            y0=init_state,
            tlist=tlist,
            static_hamiltonian=qbt.diag_hamiltonian,
            drive_terms=drive_terms,
            e_ops=e_ops,
            print_progress=False,
        )
        results.append(res)

    # Calculate final populations
    # (We want to transfer |1> -> |2> and |2> -> |1>.)
    one_minus_pop2 = abs(1 - results[0].expect[2][-1])  # from state |1> to |2>
    one_minus_pop1 = abs(1 - results[1].expect[1][-1])  # from state |2> to |1>

    return one_minus_pop2 + one_minus_pop1

# ---------------------------------------------------------------------
# SET UP NEVERGRAD INSTRUMENTATION
# ---------------------------------------------------------------------
# We'll specify a search space for each of t_tot, amp, w_d.
# For example, let's guess t_tot is in [1, 300].
# We'll assume amp in [0, 0.1], w_d in [freq*0.9, freq*1.1] as an example.
# Adjust these bounds to your scenario.


t_tot_list = np.linspace(50, 250, 21)
for t_tot in t_tot_list:
    # init_amp = np.pi / element / t_tot / 3.1415 / 2
    init_wd = qbt.fluxonium.eigenvals()[2] - qbt.fluxonium.eigenvals()[1]
    amp_guess = 50/t_tot * 22
    parametrization = ng.p.Instrumentation(
        amp=ng.p.Scalar(init=amp_guess, lower=amp_guess/5, upper=amp_guess*5),        # or choose your own guess
        w_d=ng.p.Log(init=init_wd, lower=0.003, upper=0.02),
        ramp=ng.p.Scalar(init=0.15, lower=1e-10, upper=0.5),
    )
    # ---------------------------------------------------------------------
    # CHOOSE THE OPTIMIZER
    # ---------------------------------------------------------------------
    # Some popular choices: "CMA", "TwoPointsDE", "OnePlusOne", "PSO", "NGOpt", etc.
    # We'll pick CMA as an example. We'll also set a budget (# of function evaluations)
    # and a concurrency level (num_workers) for parallelizing the objective calls.
    budget = 1000
    num_workers = 20 
    optimizer = ng.optimizers.CMA(parametrization=parametrization,
                                budget=budget,
                                num_workers=num_workers)
    # ---------------------------------------------------------------------
    # RUN THE OPTIMIZATION
    # (Nevergrad automatically parallelizes if num_workers > 1.)
    # ---------------------------------------------------------------------
    def nevergrad_objective( amp, w_d,ramp):
        return objective(t_tot=t_tot, amp=amp, w_d=w_d,ramp=ramp)
    with ProcessPoolExecutor(max_workers=num_workers) as executor:
        recommendation = optimizer.minimize(nevergrad_objective,batch_mode=True,verbosity=2,executor=executor)

    # Extract best values
    best_amp = recommendation.kwargs["amp"]
    best_w_d = recommendation.kwargs["w_d"]
    best_ramp = recommendation.kwargs["ramp"]
    best_cost = recommendation.value

    print(f"Best cost found: {best_cost}")
    print(f"Best amp: {best_amp}, best w_d: {best_w_d}, best ramp: {best_ramp}")

    # Optionally, store results in a pickle
    results_dict = {
        "best_cost": best_cost,
        "best_amp": best_amp,
        "best_w_d": best_w_d,
        "best_ramp": best_ramp,
        "recommendation": recommendation,  # the full nevergrad result object
    }

    with open(f"nevergrad_optimized_results_{t_tot}.pkl", "wb") as f:
        pickle.dump(results_dict, f)
# Out:
# Updating fitness with value 0.0370713459142642
# Updating fitness with value 1.693385637031012
# Updating fitness with value 0.24494663266314975
# Updating fitness with value 0.1632527556741581
# Updating fitness with value 0.06937567213107732
# Updating fitness with value 0.029364594057765703
# Updating fitness with value 0.10248247382628017
# Updating fitness with value 0.10971089361271369
# Updating fitness with value 0.28512122549294516
# Updating fitness with value 0.19593938716241577
# Updating fitness with value 1.951726192139153
# Updating fitness with value 1.157128909725747
# Updating fitness with value 1.9333770466187656
# Updating fitness with value 1.2967487054717626
# Updating fitness with value 1.8614014361309394
# Updating fitness with value 1.2145729413933948
# Updating fitness with value 0.21270837673683085
# Updating fitness with value 1.5997858428773504
# Updating fitness with value 1.1259507985670094
# Updating fitness with value 1.278372798121982
# 860 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.028346498173570933, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.602562562292977, 'w_d': 0.003291880173953712, 'ramp': 0.2211257542659125})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.08936904199773932
# Updating fitness with value 1.1937117107194346
# Updating fitness with value 1.886364986746234
# Updating fitness with value 1.543950599155138
# Updating fitness with value 0.7676823269890012
# Updating fitness with value 1.2181826473173447
# Updating fitness with value 1.8895010489458162
# Updating fitness with value 1.9470931447189739
# Updating fitness with value 1.636271739347919
# Updating fitness with value 0.03159517961303615
# Updating fitness with value 1.59306986928518
# Updating fitness with value 1.9854859015708681
# Updating fitness with value 0.541126919850977
# Updating fitness with value 1.8103020733738877
# Updating fitness with value 0.013340590511951689
# Updating fitness with value 0.07646097492385007
# Updating fitness with value 0.09335378263235072
# Updating fitness with value 1.5657572422226336
# Updating fitness with value 1.5520460447644648
# Updating fitness with value 1.8163161514396808
# 840 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6839866892234878
# 820 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 1.425382773802454
# Updating fitness with value 1.8935773797618982
# Updating fitness with value 1.299661526341851
# Updating fitness with value 1.7079468650449412
# Updating fitness with value 1.6356101244215018
# Updating fitness with value 1.0634381728699187
# Updating fitness with value 1.8743477355159313
# Updating fitness with value 0.5331400371201546
# Updating fitness with value 0.7697973589645608
# Updating fitness with value 0.1373450869179741
# Updating fitness with value 0.0841024532656216
# Updating fitness with value 1.8596125679697377
# Updating fitness with value 0.8324161969376527
# Updating fitness with value 1.8035517216771644
# Updating fitness with value 1.8244697846594562
# Updating fitness with value 1.2280975245058103
# Updating fitness with value 0.2509211762156437
# Updating fitness with value 0.03992992511133164
# Updating fitness with value 1.9416633824916658
# 820 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.438347516719926
# Updating fitness with value 0.8510356000601392
# Updating fitness with value 0.7020794991479877
# Updating fitness with value 1.8834644364783246
# Updating fitness with value 1.1805621811308333
# Updating fitness with value 0.977544930937587
# Updating fitness with value 1.6953006062287432
# 800 remaining budget and 13 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 0.4754060660459716
# Updating fitness with value 1.0271135572328576
# Updating fitness with value 0.918334558068397
# Updating fitness with value 0.3385426368348514
# Updating fitness with value 1.993400032496612
# Updating fitness with value 1.9486173537879903
# Updating fitness with value 1.8491839015676348
# Updating fitness with value 0.04469798951011994
# Updating fitness with value 1.63537518783457
# Updating fitness with value 0.09857802225543111
# Updating fitness with value 1.9648548825716947
# Updating fitness with value 0.9398997121058718
# Updating fitness with value 0.667262865243456
# 800 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.7395454468810629
# 780 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 0.7183113242632951
# Updating fitness with value 0.0890182530858109
# Updating fitness with value 1.875663265630066
# Updating fitness with value 1.207291112875346
# Updating fitness with value 1.2987675737554678
# Updating fitness with value 0.5176415777165826
# Updating fitness with value 0.7482857865152113
# Updating fitness with value 1.6295612029752897
# Updating fitness with value 0.9952048236157669
# Updating fitness with value 1.071984271571883
# Updating fitness with value 0.19138516118787918
# Updating fitness with value 1.9496450151101627
# Updating fitness with value 0.0538673855521935
# Updating fitness with value 0.2498327501552824
# 780 remaining budget and 5 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 1.8748554953071044
# Updating fitness with value 0.6035354452331742
# Updating fitness with value 0.22424341212824905
# Updating fitness with value 0.7573859773605447
# Updating fitness with value 1.264362860356031
# 780 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.4901791198125276
# Updating fitness with value 1.0017023342105817
# Updating fitness with value 1.7529099468105516
# Updating fitness with value 1.7855730176351077
# Updating fitness with value 1.0055020887824664
# Updating fitness with value 0.2197392657441538
# Updating fitness with value 0.5975204527506403
# Updating fitness with value 0.9541327018171302
# Updating fitness with value 1.4422966900856944
# Updating fitness with value 0.4575011745946582
# Updating fitness with value 0.9642722854402482
# Updating fitness with value 1.8300028856107422
# Updating fitness with value 0.6758940988818306
# Updating fitness with value 0.9102836536019887
# 760 remaining budget and 6 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 1.1052519334463133
# 760 remaining budget and 5 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 1.2988093851838145
# Updating fitness with value 0.603252884429622
# Updating fitness with value 0.6544255615471863
# Updating fitness with value 1.9856216612654816
# Updating fitness with value 0.9768756302920689
# 760 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.1350684964512099
# Updating fitness with value 0.6942100895559711
# Updating fitness with value 0.9105057428035963
# Updating fitness with value 0.3491834983156049
# Updating fitness with value 0.7819747171248185
# Updating fitness with value 1.769344634545266
# 740 remaining budget and 14 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 0.14427233180446786
# Updating fitness with value 1.0453058890086222
# Updating fitness with value 0.6951824079166523
# Updating fitness with value 0.3270565946102597
# Updating fitness with value 1.1665069715695089
# Updating fitness with value 0.09453674841589377
# Updating fitness with value 0.4716321566829059
# Updating fitness with value 1.8662216503669369
# Updating fitness with value 1.250946703414894
# Updating fitness with value 1.9524888406186756
# Updating fitness with value 0.8217463108496159
# Updating fitness with value 0.6709667836724408
# Updating fitness with value 0.03361842684897398
# Updating fitness with value 1.6273455345892613
# 740 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.795693632255481
# Updating fitness with value 1.900129064959895
# Updating fitness with value 0.7934165345253966
# Updating fitness with value 0.28439786623956975
# 720 remaining budget and 16 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 1.5688270640984985
# Updating fitness with value 1.8011594699127933
# Updating fitness with value 1.241308870014036
# Updating fitness with value 1.74558541907082
# Updating fitness with value 1.697643460342777
# Updating fitness with value 0.08478690023326085
# Updating fitness with value 1.8577114199509055
# Updating fitness with value 1.4760634286665986
# Updating fitness with value 1.8260699634955306
# Updating fitness with value 1.8053648031827052
# Updating fitness with value 0.3917739363172186
# Updating fitness with value 1.698600848288669
# Updating fitness with value 1.2357286047268592
# Updating fitness with value 1.8217838878510326
# Updating fitness with value 0.39293816645175983
# Updating fitness with value 1.5190336686635293
# 720 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6990336639066765
# Updating fitness with value 1.2818869486565143
# Updating fitness with value 1.8845431021486696
# Updating fitness with value 1.7706937073370113
# Updating fitness with value 0.10964042489287795
# Updating fitness with value 1.91857249264639
# Updating fitness with value 0.6889280410642257
# Updating fitness with value 1.2219773915791081
# 700 remaining budget and 12 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 1.3518152588859917
# Updating fitness with value 1.1566173007156433
# Updating fitness with value 0.5362608649209166
# Updating fitness with value 0.34994995338606893
# Updating fitness with value 1.5253775802437466
# Updating fitness with value 0.2641993329552861
# Updating fitness with value 1.2262891665689901
# Updating fitness with value 1.4435466691672063
# Updating fitness with value 0.08093544967950195
# Updating fitness with value 0.02696421317762976
# Updating fitness with value 1.4929022198693138
# Updating fitness with value 1.7226329962182314
# 700 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.7468566683221823
# Updating fitness with value 0.1208098776109282
# Updating fitness with value 1.1087881670404887
# Updating fitness with value 1.2326346737902734
# Updating fitness with value 1.870984438805047
# Updating fitness with value 1.8526247937859908
# Updating fitness with value 1.0777356604950454
# Updating fitness with value 0.17675579923113616
# Updating fitness with value 1.5948581624067935
# Updating fitness with value 0.08212922593165495
# Updating fitness with value 1.64548030592668
# Updating fitness with value 0.16756693362518282
# Updating fitness with value 1.0324032409162403
# Updating fitness with value 1.1405918582638201
# Updating fitness with value 1.4285759383554923
# Updating fitness with value 0.1453918982939394
# Updating fitness with value 0.018729303955816734
# Updating fitness with value 1.8037252816601765
# Updating fitness with value 0.7872027459637262
# 680 remaining budget and 1 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 1.4418211211459602
# 680 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.4821328591363097
# Updating fitness with value 1.8821953688124755
# Updating fitness with value 1.9004132008179275
# Updating fitness with value 0.44911815496765617
# Updating fitness with value 0.8117014604955338
# Updating fitness with value 0.9201880206424424
# Updating fitness with value 0.6978724570430327
# Updating fitness with value 0.6995413122640662
# Updating fitness with value 0.05049096731151237
# Updating fitness with value 1.9827649098383735
# Updating fitness with value 0.13686542891345355
# Updating fitness with value 0.018939590980484033
# Updating fitness with value 1.0614617558869686
# Updating fitness with value 1.884490927468079
# Updating fitness with value 0.9782963288132275
# Updating fitness with value 1.3219801552003863
# Updating fitness with value 1.220909038433149
# Updating fitness with value 0.6217069256549312
# 660 remaining budget and 2 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 0.030937002984371298
# Updating fitness with value 1.9120921469861867
# 660 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.8439533850341715
# Updating fitness with value 0.6957580098734211
# Updating fitness with value 1.7687881936148682
# Updating fitness with value 1.8767521420931086
# Updating fitness with value 1.6477605208575439
# Updating fitness with value 1.61351408650004
# Updating fitness with value 1.0104286929219937
# Updating fitness with value 0.8756492276175365
# Updating fitness with value 0.7017517107714027
# 640 remaining budget and 11 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 1.071880300083781
# 640 remaining budget and 10 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Updating fitness with value 1.8504311732796248
# Updating fitness with value 1.5284768760077272
# Updating fitness with value 0.0971806143582814
# Updating fitness with value 1.9453507057974486
# Updating fitness with value 1.7337500672196104
# Updating fitness with value 1.0196351958329477
# Updating fitness with value 1.3016206064737053
# Updating fitness with value 1.8957349444790457
# Updating fitness with value 1.9038019416027248
# Updating fitness with value 1.9533977103792366
# 640 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.013340590511951689, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.37022699744472, 'w_d': 0.004055523198633103, 'ramp': 0.27242465022259216})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.16141846353908407
# Updating fitness with value 0.07726436154541039
# Updating fitness with value 1.7647168657188144
# Updating fitness with value 0.3856796869923431
# Updating fitness with value 1.0083252323343035
# Updating fitness with value 0.06573089353623796
# Updating fitness with value 0.07722318010709084
# Updating fitness with value 1.0036084398653582
# Updating fitness with value 1.6614513772754873
# Updating fitness with value 0.00799153856288426
# Updating fitness with value 1.3301908819737145
# Updating fitness with value 0.0345252303178426
# Updating fitness with value 0.15677780007936337
# Updating fitness with value 0.22772879989354078
# 620 remaining budget and 6 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 0.7769927641113326
# Updating fitness with value 1.7959185459259892
# Updating fitness with value 1.5561726114864034
# Updating fitness with value 0.28458571556057843
# Updating fitness with value 1.7708405232982138
# Updating fitness with value 1.9255404771935005
# 620 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.4794489315353566
# Updating fitness with value 1.7513668288597883
# Updating fitness with value 0.8068355606270372
# Updating fitness with value 1.4477303501966576
# Updating fitness with value 1.4911255058868949
# Updating fitness with value 0.025342295530415004
# Updating fitness with value 1.9727371887516467
# Updating fitness with value 0.43315828213870666
# Updating fitness with value 0.026701043959908577
# Updating fitness with value 0.03992392588102733
# Updating fitness with value 1.8199341304697865
# Updating fitness with value 0.742669334862853
# Updating fitness with value 0.44988630558687104
# Updating fitness with value 1.7536812697069446
# 600 remaining budget and 6 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 1.038067285624222
# Updating fitness with value 1.9806449381106788
# Updating fitness with value 0.6933670698259786
# Updating fitness with value 1.6206580599891465
# Updating fitness with value 0.09808008700718862
# Updating fitness with value 0.19760254262128696
# 600 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.849462672167916
# Updating fitness with value 0.30984374065398057
# Updating fitness with value 0.6086102637364338
# Updating fitness with value 1.4997988249122818
# Updating fitness with value 0.193584025484549
# Updating fitness with value 0.536384415379975
# Updating fitness with value 0.20817310604686068
# Updating fitness with value 0.02744550065034168
# Updating fitness with value 1.860506669401318
# Updating fitness with value 0.9965336962239785
# Updating fitness with value 1.5623157568602017
# Updating fitness with value 1.2514362145362128
# Updating fitness with value 1.834436043811134
# Updating fitness with value 0.28194594285652064
# Updating fitness with value 0.3968406676372316
# 580 remaining budget and 5 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 0.017922088269648362
# 580 remaining budget and 4 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 0.23686799268050773
# Updating fitness with value 0.8981784372235205
# Updating fitness with value 1.3367925333094142
# Updating fitness with value 0.22753416649948677
# 580 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.13011558931456857
# 560 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 1.2848985821978878
# Updating fitness with value 1.8024369994506966
# Updating fitness with value 1.820876360912001
# Updating fitness with value 1.6956744370123815
# Updating fitness with value 0.2924217382646398
# Updating fitness with value 1.1828531460238259
# Updating fitness with value 1.8049047863801377
# Updating fitness with value 0.9475503078323209
# Updating fitness with value 0.37278276425021273
# Updating fitness with value 1.0298167986241356
# Updating fitness with value 0.49647568896783734
# Updating fitness with value 0.16350331077530567
# Updating fitness with value 0.5661337916935261
# Updating fitness with value 1.5824930384487936
# Updating fitness with value 0.03705111562462471
# Updating fitness with value 1.5819756961056821
# Updating fitness with value 0.14899225274449468
# Updating fitness with value 0.2755808786268792
# Updating fitness with value 1.2808086999034876
# 560 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.688903889185931
# 540 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 1.3919121253741165
# Updating fitness with value 1.1596921466565369
# Updating fitness with value 0.07624333196811517
# Updating fitness with value 1.3783842309894525
# Updating fitness with value 1.791257648247898
# Updating fitness with value 1.4687483969091
# Updating fitness with value 0.04887957346880212
# Updating fitness with value 1.23563648182526
# Updating fitness with value 0.022363202201601706
# Updating fitness with value 0.5335990002591794
# Updating fitness with value 0.9203650107462815
# Updating fitness with value 0.8564971726992169
# Updating fitness with value 0.8536380995854053
# Updating fitness with value 1.0326839127678809
# Updating fitness with value 1.5841222563358963
# Updating fitness with value 0.011760795280067127
# Updating fitness with value 0.4072654570772152
# Updating fitness with value 0.42118252340578555
# Updating fitness with value 0.8299793483465361
# 540 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.884658554558402
# Updating fitness with value 0.9225878652062786
# Updating fitness with value 1.331471347311753
# Updating fitness with value 0.36380049632762146
# Updating fitness with value 0.16039606871515666
# Updating fitness with value 0.3716666169062045
# Updating fitness with value 0.040163959359046486
# Updating fitness with value 1.2287432043612894
# Updating fitness with value 0.5515199277351754
# Updating fitness with value 0.9225355643384089
# Updating fitness with value 1.1376887526359196
# Updating fitness with value 1.0211519938324924
# Updating fitness with value 0.19555381592595367
# Updating fitness with value 1.8991717090939613
# Updating fitness with value 1.0044552600644412
# Updating fitness with value 1.7029374329132123
# Updating fitness with value 0.8767280166855871
# Updating fitness with value 1.8875279190689045
# Updating fitness with value 1.029858492640123
# Updating fitness with value 1.524460649291881
# 520 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.27025419704179976
# Updating fitness with value 0.09226432311921007
# Updating fitness with value 0.04667716488671336
# Updating fitness with value 0.34235152073050756
# Updating fitness with value 1.642784234711228
# Updating fitness with value 1.398843359329226
# Updating fitness with value 0.7956035275972619
# Updating fitness with value 0.9512282221819887
# Updating fitness with value 0.14896959223115758
# 500 remaining budget and 11 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 1.0250948749252737
# Updating fitness with value 0.5388764849928549
# Updating fitness with value 1.9316020370431435
# Updating fitness with value 0.4317451332056459
# Updating fitness with value 0.8125163176981908
# Updating fitness with value 1.1659772915662723
# Updating fitness with value 1.2206243995563013
# Updating fitness with value 0.39096048303391717
# Updating fitness with value 1.4694057405600083
# Updating fitness with value 1.8256098612921028
# Updating fitness with value 1.5994680312393128
# 500 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.5209891148419246
# Updating fitness with value 1.159078153904697
# Updating fitness with value 0.6247213781532993
# Updating fitness with value 1.3827441208995954
# 480 remaining budget and 16 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 1.0147934481192287
# Updating fitness with value 1.574483553084236
# Updating fitness with value 0.024488301884237007
# Updating fitness with value 1.15215005713782
# Updating fitness with value 1.9599673239411017
# Updating fitness with value 1.837259500593251
# Updating fitness with value 0.20375175882488838
# Updating fitness with value 0.5272374499765252
# Updating fitness with value 0.2269815684496581
# Updating fitness with value 1.5440342505682785
# Updating fitness with value 0.82685504330986
# Updating fitness with value 0.7796218512537921
# Updating fitness with value 1.9160428104683256
# Updating fitness with value 0.05294576487756575
# Updating fitness with value 0.031732903816239943
# Updating fitness with value 1.9072884362197287
# 480 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.0787827531399874
# 460 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 0.07850818456376085
# Updating fitness with value 1.3629421791556746
# Updating fitness with value 1.1340654834193387
# Updating fitness with value 1.8678768967151542
# Updating fitness with value 0.15397095893894075
# Updating fitness with value 1.6162929953266565
# Updating fitness with value 0.17716507560608863
# Updating fitness with value 0.13247643733663084
# Updating fitness with value 0.5509072531076773
# Updating fitness with value 1.8368827601779252
# Updating fitness with value 1.484492064524213
# Updating fitness with value 1.1553621670366079
# Updating fitness with value 0.7026894868347994
# Updating fitness with value 1.8270110625538734
# Updating fitness with value 1.5785967033747275
# Updating fitness with value 0.6149865737306056
# Updating fitness with value 0.38510938174957665
# Updating fitness with value 1.5565060057636964
# Updating fitness with value 0.5815176414568132
# 460 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.614139668210298
# Updating fitness with value 1.3831184807147212
# Updating fitness with value 1.5343204887526607
# Updating fitness with value 0.03492763243025865
# Updating fitness with value 0.20365739495458324
# Updating fitness with value 0.25209378210049516
# Updating fitness with value 1.5298623769103492
# Updating fitness with value 0.6295507621452726
# Updating fitness with value 0.9413885897286742
# Updating fitness with value 0.597459775964817
# Updating fitness with value 1.720943512972167
# Updating fitness with value 1.4750373966336061
# Updating fitness with value 1.3207181729942652
# Updating fitness with value 0.17025934214572536
# Updating fitness with value 0.07302025360009512
# 440 remaining budget and 5 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 0.19864025510812588
# 440 remaining budget and 4 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Updating fitness with value 1.188375241638714
# Updating fitness with value 0.9344457803942714
# Updating fitness with value 1.4667438158741528
# Updating fitness with value 1.4297415115031904
# 440 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.00799153856288426, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 23.891967217752807, 'w_d': 0.004352315573709141, 'ramp': 0.2637710682105266})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.06224374554648615
# Updating fitness with value 0.013864966634272724
# Updating fitness with value 0.04028751227352656
# Updating fitness with value 1.7705078011556104
# Updating fitness with value 1.4881276318562051
# Updating fitness with value 1.277075117283224
# Updating fitness with value 0.0024478434395760473
# Updating fitness with value 1.4004146400482242
# Updating fitness with value 0.7779475990461331
# Updating fitness with value 0.5821124227089717
# Updating fitness with value 1.5819817229109117
# Updating fitness with value 1.2424189510027275
# Updating fitness with value 1.5620652760515434
# Updating fitness with value 0.24905279275145054
# 420 remaining budget and 6 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0024478434395760473, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.462196646166575, 'w_d': 0.004384449697752483, 'ramp': 0.24255193219265903})>
# Updating fitness with value 1.3289896329823228
# Updating fitness with value 0.8897630803618479
# Updating fitness with value 0.8838390846469599
# Updating fitness with value 0.011455246947409847
# Updating fitness with value 1.9304425909947338
# Updating fitness with value 0.4296938546275978
# 420 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0024478434395760473, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.462196646166575, 'w_d': 0.004384449697752483, 'ramp': 0.24255193219265903})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.8591634362397276
# Updating fitness with value 0.5919003161810795
# Updating fitness with value 1.2627895853788549
# Updating fitness with value 0.015577441315122509
# Updating fitness with value 0.9159167411997918
# Updating fitness with value 1.7775200068708474
# Updating fitness with value 1.8736792235063873
# Updating fitness with value 1.4521064615041688
# Updating fitness with value 1.4458127506753562
# Updating fitness with value 0.019361868740843224
# Updating fitness with value 0.1279850020643739
# Updating fitness with value 0.10171387730405401
# Updating fitness with value 1.5929684321672772
# Updating fitness with value 0.8294869886770745
# Updating fitness with value 1.3302443751397819
# 400 remaining budget and 5 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0024478434395760473, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.462196646166575, 'w_d': 0.004384449697752483, 'ramp': 0.24255193219265903})>
# Updating fitness with value 1.7544810837617892
# Updating fitness with value 0.8545733810226214
# Updating fitness with value 1.0983194163681602
# Updating fitness with value 1.8549913827736406
# Updating fitness with value 0.48395592421813005
# 400 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0024478434395760473, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.462196646166575, 'w_d': 0.004384449697752483, 'ramp': 0.24255193219265903})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.9107888958213417
# Updating fitness with value 0.0057296050861375125
# Updating fitness with value 0.8237164249357869
# Updating fitness with value 1.2154431644038584
# Updating fitness with value 0.1007165927026451
# Updating fitness with value 0.16423082756349616
# Updating fitness with value 1.1059231498018733
# Updating fitness with value 0.5550287855421095
# Updating fitness with value 0.0910333353815953
# Updating fitness with value 0.5279285068510108
# Updating fitness with value 1.417974719566196
# Updating fitness with value 1.525009603961415
# Updating fitness with value 0.5736602034079934
# Updating fitness with value 0.838338804210391
# Updating fitness with value 0.004743811429014699
# Updating fitness with value 1.6462585595352788
# Updating fitness with value 0.6272544493422195
# Updating fitness with value 1.3211900968370291
# Updating fitness with value 0.1355804768643748
# Updating fitness with value 1.708613123948414
# 380 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0024478434395760473, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.666666666666667,91.66666666666669,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 22.462196646166575, 'w_d': 0.004384449697752483, 'ramp': 0.24255193219265903})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.01707763404475593
# Updating fitness with value 1.3891589541978542
# Updating fitness with value 1.2856876847187595
# Updating fitness with value 0.2066352172965782
# Updating fitness with value 1.9410406089515178
# 360 remaining budget and 15 running jobs
# ...
# Updating fitness with value 0.44483459641152623
# Updating fitness with value 0.22393206496735474
# Updating fitness with value 1.5442641104932684
# 820 remaining budget and 17 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Updating fitness with value 0.34021633633719994
# Updating fitness with value 0.15711630695663903
# Updating fitness with value 0.1270305318933268
# Updating fitness with value 1.4239404581971007
# Updating fitness with value 0.28499584424823066
# Updating fitness with value 0.10829063165000219
# Updating fitness with value 1.815892184335743
# Updating fitness with value 0.4891504769433108
# Updating fitness with value 0.8000678019308527
# Updating fitness with value 1.3390210787650112
# Updating fitness with value 1.8071701255261177
# Updating fitness with value 0.11428209403537004
# Updating fitness with value 0.5257634303481689
# Updating fitness with value 0.6080593360567342
# Updating fitness with value 0.6942381078334507
# Updating fitness with value 1.298021004923147
# Updating fitness with value 1.4267112931958965
# 820 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.0170549454271347
# Updating fitness with value 1.659577307071184
# Updating fitness with value 1.169176172445576
# Updating fitness with value 1.6439939283872316
# Updating fitness with value 0.5331162914833871
# Updating fitness with value 0.1178284464804723
# Updating fitness with value 0.39676300975115875
# Updating fitness with value 0.2004345923576053
# Updating fitness with value 1.8845597515569386
# Updating fitness with value 1.4167080388614788
# Updating fitness with value 1.5594074737122803
# Updating fitness with value 1.2470743111814069
# Updating fitness with value 0.36897099194355043
# Updating fitness with value 1.6322998165972598
# Updating fitness with value 0.5163898691464441
# Updating fitness with value 1.5298670710386693
# Updating fitness with value 0.22491706421442004
# Updating fitness with value 0.7509526351290121
# 800 remaining budget and 2 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Updating fitness with value 1.8584628695129488
# Updating fitness with value 1.235248564719174
# 800 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.7744880102264707
# Updating fitness with value 0.10843266848018285
# Updating fitness with value 1.1252475931127341
# Updating fitness with value 0.15239288440534082
# Updating fitness with value 1.460184867340793
# Updating fitness with value 1.1134182964381616
# Updating fitness with value 1.0894088043445922
# Updating fitness with value 1.3542484241768764
# Updating fitness with value 1.2893292844162647
# Updating fitness with value 0.22365771997153272
# Updating fitness with value 0.13820487982851426
# Updating fitness with value 1.90562725903545
# Updating fitness with value 1.5645466645106207
# Updating fitness with value 0.1579492623923573
# Updating fitness with value 0.5173761903339463
# 780 remaining budget and 5 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Updating fitness with value 0.2958027677104197
# Updating fitness with value 0.4010231166589835
# Updating fitness with value 0.13727133620892928
# Updating fitness with value 1.2810318734878574
# Updating fitness with value 1.657288210645627
# 780 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.6046359955029734
# Updating fitness with value 1.4566888069072
# Updating fitness with value 0.9847441650856876
# Updating fitness with value 1.0548747998593004
# Updating fitness with value 1.8860461746091954
# Updating fitness with value 1.7998960122917913
# Updating fitness with value 0.1603812507065182
# Updating fitness with value 1.850500986123536
# Updating fitness with value 0.5089593261151232
# Updating fitness with value 0.11810356886661644
# Updating fitness with value 1.2116868862808967
# Updating fitness with value 0.11640121867388686
# Updating fitness with value 0.10331708257564254
# Updating fitness with value 0.4069262739718328
# Updating fitness with value 1.0751336562919716
# Updating fitness with value 0.697374876302794
# Updating fitness with value 1.481333840085216
# Updating fitness with value 0.6770247882955834
# Updating fitness with value 0.7550778450514788
# Updating fitness with value 0.8911544765825442
# 760 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.3591554290346033
# Updating fitness with value 0.5077704773519489
# Updating fitness with value 0.5755105634398996
# Updating fitness with value 1.0703986970311274
# Updating fitness with value 0.5525488458318233
# Updating fitness with value 0.8729310350499994
# Updating fitness with value 0.12335732531135557
# Updating fitness with value 1.6287547020283561
# Updating fitness with value 0.10063079916273654
# Updating fitness with value 1.5407226950138162
# Updating fitness with value 0.04934885795606159
# Updating fitness with value 1.1762004579060525
# Updating fitness with value 1.4568580748701758
# Updating fitness with value 1.202134090630318
# Updating fitness with value 0.7889412786296272
# Updating fitness with value 0.1488394521246008
# Updating fitness with value 1.0038433590441844
# Updating fitness with value 0.3432882475344101
# Updating fitness with value 1.1085557123944942
# Updating fitness with value 1.648545507719807
# 740 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.1467359655646271
# 720 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Updating fitness with value 0.5631258861033502
# Updating fitness with value 0.8032459432239665
# Updating fitness with value 0.41863011380398374
# Updating fitness with value 0.5105448266565478
# Updating fitness with value 1.3940876315182753
# Updating fitness with value 0.8510920917332654
# Updating fitness with value 1.407127076624447
# Updating fitness with value 1.7780196691284207
# Updating fitness with value 0.17062913607396712
# Updating fitness with value 1.3709760076803648
# Updating fitness with value 0.6496610392133586
# Updating fitness with value 1.2244623259095424
# Updating fitness with value 1.6497729045918494
# Updating fitness with value 0.7497069093362313
# Updating fitness with value 0.8484789369788286
# Updating fitness with value 0.230795360875937
# Updating fitness with value 1.8797504056154488
# Updating fitness with value 1.8333445112794395
# Updating fitness with value 0.10049753948776963
# 720 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.5844802541921735
# Updating fitness with value 1.4498905993094764
# Updating fitness with value 0.4095826861102406
# Updating fitness with value 1.966498237303619
# Updating fitness with value 1.0797470950166435
# Updating fitness with value 0.16716260293645369
# Updating fitness with value 1.4797881016740377
# Updating fitness with value 0.36343909523292406
# Updating fitness with value 1.4063713230638557
# 700 remaining budget and 11 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Updating fitness with value 0.13677427720757318
# Updating fitness with value 0.17894294091985685
# Updating fitness with value 0.0629963621883759
# Updating fitness with value 1.1767045294019858
# Updating fitness with value 1.4956588297004223
# Updating fitness with value 0.132298999394297
# Updating fitness with value 1.6722116693130433
# Updating fitness with value 1.28763314912345
# Updating fitness with value 1.639593111480769
# Updating fitness with value 0.6956420487114531
# Updating fitness with value 1.045980092664466
# 700 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.11826611324880143
# 680 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Updating fitness with value 0.2579968142730874
# Updating fitness with value 0.4397304818890402
# Updating fitness with value 0.7148356818231678
# Updating fitness with value 0.26580617172185295
# Updating fitness with value 0.2006815996482364
# Updating fitness with value 0.12830976934068827
# Updating fitness with value 1.2095107802249543
# Updating fitness with value 1.554006916827424
# Updating fitness with value 0.9312496094970275
# Updating fitness with value 0.6418257686513367
# Updating fitness with value 1.4625074129878042
# Updating fitness with value 0.17127885774562435
# Updating fitness with value 1.9221818788768275
# Updating fitness with value 1.497464702572795
# Updating fitness with value 1.2236099178332345
# Updating fitness with value 1.3739787473822525
# Updating fitness with value 1.4789875199599924
# Updating fitness with value 1.1255572128495293
# Updating fitness with value 1.0036977864814274
# 680 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.06597309688992281
# Updating fitness with value 0.04045797854395605
# Updating fitness with value 0.8272044127880946
# 660 remaining budget and 17 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Updating fitness with value 0.7965353810747263
# Updating fitness with value 0.8426428260226757
# Updating fitness with value 1.553055589170659
# Updating fitness with value 1.2921328088697677
# Updating fitness with value 0.028399726145983073
# Updating fitness with value 1.80898599907846
# Updating fitness with value 1.4070601995287257
# Updating fitness with value 0.36865337805364184
# Updating fitness with value 0.3008349406188434
# Updating fitness with value 0.2183529192577489
# Updating fitness with value 1.8302033629486765
# Updating fitness with value 0.5759006646773598
# Updating fitness with value 0.5955257774524629
# Updating fitness with value 1.1499299374382215
# Updating fitness with value 0.8642380734204188
# Updating fitness with value 1.3779462043608512
# Updating fitness with value 1.687914617299334
# 660 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.01667030366512534, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(3.1428571428571432,78.57142857142858,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 17.669319790211485, 'w_d': 0.003989379505982875, 'ramp': 0.19994238113205284})>
# Launching 20 jobs with new suggestions

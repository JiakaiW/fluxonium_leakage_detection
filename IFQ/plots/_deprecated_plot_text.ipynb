# %%
import matplotlib.pyplot as plt
plt.text(0.1,0.5,f'Limit decay from\nintermediate\nstate via\nadiabaticity',color= '#d5373d',size = 9)

plt.text(0.3,0.2,rf'''
Detect leakage to $|1\rangle$
via $\chi_0=\chi_2\ne\chi_1$
with $\omega_r\approx \omega_{{0,10}}$''',color= '#4999c3',size = 9)

plt.text(0.3,0.7,rf'''
Detect $m=\pm2$
fluxon via
fluorescence''',color= '#4999c3',size = 9)


plt.savefig('text_aaaa.pdf')

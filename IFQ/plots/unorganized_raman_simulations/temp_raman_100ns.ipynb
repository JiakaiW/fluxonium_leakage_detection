# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import scqubits
from functools import partial
import qutip
import concurrent
from loky import get_reusable_executor
import numpy as np
import qutip
import scqubits
from typing import List, Union,Any

from CoupledQuantumSystems.qobj_manip import *
from CoupledQuantumSystems.drive import *
from CoupledQuantumSystems.evo import ODEsolve_and_post_process
from CoupledQuantumSystems.noise import *
from CoupledQuantumSystems.qobj_manip import *
from CoupledQuantumSystems.IFQ import gfIFQ

# %%
from scipy.optimize import minimize

EJ = 4
EC = EJ/2.7
EL = EJ/45

qbt = gfIFQ(EJ = EJ,EC =EC,EL = EL,truncated_dim=4)

temp_in_mK = 20
loss_tangent_ref = 5e-6
one_over_f_flux_noise_amplitude = 1e-6

c_ops=qbt.get_T1_c_ops(temp_in_mK,
                        loss_tangent_ref,
                        one_over_f_flux_noise_amplitude)
e_ops = [qutip.ket2dm(qutip.basis(qbt.truncated_dim, i)) for i in range(4)]

# %% [markdown]
# # First optimize without decay

# %%
from IPython.display import clear_output

t_duration = 100
tlist = np.linspace(0,t_duration,t_duration)

def shift_diff(x):
    detuning = 0.1
    amp1_scaling_factor = x[0]
    amp2_scaling_factor = x[1]
    results  = qbt.run_qutip_mesolve_parrallel(
        initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
        tlist = tlist,
        drive_terms = qbt.get_Raman_drive_terms(
            i = 0,
            j = 3,
            k = 2,
            detuning=detuning,
            t_duration=t_duration,
            shape='sin^2',
            amp_scaling_factor = 1,
            amp1_scaling_factor = amp1_scaling_factor,
            amp2_scaling_factor = amp2_scaling_factor
        ),
        c_ops = c_ops,
        e_ops = e_ops
    )
    clear_output()
    print(x)
    for i, exp in enumerate(results[0].expect):
        plt.plot(tlist,exp,label= f"{i}")
    plt.legend()
    plt.show()
    
    one_minus_pop2 = 1-results[0].expect[2][-1]
    one_minus_pop0 = 1-results[1].expect[0][-1]
    print((one_minus_pop2, one_minus_pop0))
    return one_minus_pop2 + one_minus_pop0

initial_guess = [1.5, 1.5 ]

result = minimize(shift_diff, initial_guess, method='Nelder-Mead')
# Out:
# [1.65061367 1.77867065]
# (0.0004898997313159681, 0.0007742622033251045)
#  Total run time:   0.34s*] Elapsed 0.34s / Remaining 00:00:00:00
#  Total run time:   0.50s*] Elapsed 0.50s / Remaining 00:00:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 41
#      37     return one_minus_pop2 + one_minus_pop0
#      39 initial_guess = [1.5, 1.5 ]
# ---> 41 result = minimize(shift_diff, initial_guess, method='Nelder-Mead')
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698 callback = _wrap_callback(callback, meth)
#     700 if meth == 'nelder-mead':
# --> 701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
#     704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:948, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     946 if bounds is not None:
#     947     xr = np.clip(xr, lower_bound, upper_bound)
# --> 948 fxr = func(xr)
#     949 doshrink = 0
#     951 if fxr < fsim[0]:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:640, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     638 ncalls[0] += 1
#     639 # A copy of x is sent to the user function (gh13740)
# --> 640 fx = function(np.copy(x), *(wrapper_args + args))
#     641 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     642 # backwards-compatibility, also allow np.array([1.3]),
#     643 # np.array([[1.3]]) etc.
#     644 if not np.isscalar(fx):
#
# Cell In[7], line 10, in shift_diff(x)
#       8 amp1_scaling_factor = x[0]
#       9 amp2_scaling_factor = x[1]
# ---> 10 results  = qbt.run_qutip_mesolve_parrallel(
#      11     initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
#      12     tlist = tlist,
#      13     drive_terms = qbt.get_Raman_drive_terms(
#      14         i = 0,
#      15         j = 3,
#      16         k = 2,
#      17         detuning=detuning,
#      18         t_duration=t_duration,
#      19         shape='sin^2',
#      20         amp_scaling_factor = 1,
#      21         amp1_scaling_factor = amp1_scaling_factor,
#      22         amp2_scaling_factor = amp2_scaling_factor
#      23     ),
#      24     c_ops = c_ops,
#      25     e_ops = e_ops
#      26 )
#      27 clear_output()
#      28 print(x)
#
# Cell In[2], line 140, in gfIFQ.run_qutip_mesolve_parrallel(self, initial_states, tlist, drive_terms, c_ops, e_ops, post_processing)
#     128 with get_reusable_executor(max_workers=None, context='loky') as executor:
#     129     futures = {executor.submit(ODEsolve_and_post_process,
#     130                                y0=initial_states[i],
#     131                                tlist=tlist,
#    (...)
#     137                                post_processing_args=post_processing_args,
#     138                                ): i for i in range(len(initial_states))}
# --> 140     for future in concurrent.futures.as_completed(futures):
#     141         original_index = futures[future]
#     142         results[original_index] = future.result()
#
# File ~/miniconda3/envs/test/lib/python3.10/concurrent/futures/_base.py:245, in as_completed(fs, timeout)
#     240     if wait_timeout < 0:
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#     248     finished = waiter.finished_futures
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
from IPython.display import clear_output

t_duration = 100
tlist = np.linspace(0,t_duration,t_duration)
def shift_diff(x):
    detuning = 0.1
    amp1_scaling_factor = x[0]
    amp2_scaling_factor = x[1]
    results  = qbt.run_qutip_mesolve_parrallel(
        initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
        tlist = tlist,
        drive_terms = qbt.get_Raman_drive_terms(
            i = 0,
            j = 3,
            k = 2,
            detuning=detuning,
            t_duration=t_duration,
            shape='sin^2',
            amp_scaling_factor = 1,
            amp1_scaling_factor = amp1_scaling_factor,
            amp2_scaling_factor = amp2_scaling_factor
        ),
        c_ops = c_ops,
        e_ops = e_ops
    )
    clear_output()
    print(x)
    for i, exp in enumerate(results[0].expect):
        plt.plot(tlist,exp,label= f"{i}")
    plt.legend()
    plt.show()
    
    one_minus_pop2 = 1-results[0].expect[2][-1]
    one_minus_pop0 = 1-results[1].expect[0][-1]
    print((one_minus_pop2, one_minus_pop0))
    return one_minus_pop2 + one_minus_pop0

initial_guess = [1.65042718, 1.77833104]

result = minimize(shift_diff, initial_guess, method='Nelder-Mead')
# Out:
# [1.65074742 1.77830049]
# (0.000488999469483109, 0.0007733571241664849)

# %%
x = [1.6506964,  1.77826822]
detuning = 0.1
amp1_scaling_factor = x[0]
amp2_scaling_factor = x[1]
results  = qbt.run_qutip_mesolve_parrallel(
    initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
    tlist = tlist,
    drive_terms = qbt.get_Raman_drive_terms(
        i = 0,
        j = 3,
        k = 2,
        detuning=detuning,
        t_duration=t_duration,
        shape='sin^2',
        amp_scaling_factor = 1,
        amp1_scaling_factor = amp1_scaling_factor,
        amp2_scaling_factor = amp2_scaling_factor
    ),
    c_ops = c_ops,
    e_ops = e_ops
)
clear_output()
print(x)
for i, exp in enumerate(results[0].expect):
    plt.plot(tlist,exp,label= f"{i}")
plt.legend()
plt.yscale('log')
plt.show()
# Out:
# [1.6506964, 1.77826822]

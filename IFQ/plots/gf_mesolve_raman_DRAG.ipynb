# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import qutip
import numpy as np
import qutip
import scqubits
from scipy.optimize import minimize
from IPython.display import clear_output

from CoupledQuantumSystems.qobj_manip import *
from CoupledQuantumSystems.drive import *
from CoupledQuantumSystems.evo import ODEsolve_and_post_process
from CoupledQuantumSystems.noise import *
from CoupledQuantumSystems.qobj_manip import *
from CoupledQuantumSystems.IFQ import gfIFQ

# %%
EJ = 4
EC = EJ/2.7
EL = EJ/45

qbt = gfIFQ(EJ = EJ,EC =EC,EL = EL,truncated_dim=13)

t_duration = 50
tlist = np.linspace(0,t_duration,t_duration)
e_ops = [qutip.ket2dm(qutip.basis(qbt.truncated_dim, i)) for i in range(10)]

# %%
def objective(x):
    # amp1_scaling_factor = 2.1866024
    # amp2_scaling_factor = 2.14973954
    # amp1_correction_scaling_factor = x[0]
    # amp2_correction_scaling_factor = x[1]
    # detuning1 =x[2]
    # detuning2 =x[3]

    amp1_scaling_factor = x[0]
    amp2_scaling_factor = x[1]
    amp1_correction_scaling_factor = x[2]
    amp2_correction_scaling_factor = x[3]
    detuning1 =0.5
    detuning2 =0.5

    results  = qbt.run_qutip_mesolve_parrallel(
        initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
        tlist = tlist,
        drive_terms = qbt.get_Raman_DRAG_drive_terms(
            i = 0,
            j = 3,
            k = 2,
            detuning1=detuning1,
            detuning2 = detuning2,
            t_duration=t_duration,
            shape='sin^2',
            amp_scaling_factor = 1,
            amp1_scaling_factor = amp1_scaling_factor,
            amp2_scaling_factor = amp2_scaling_factor,
            amp1_correction_scaling_factor = amp1_correction_scaling_factor,
            amp2_correction_scaling_factor = amp2_correction_scaling_factor,
        ),
        # c_ops = c_ops,
        e_ops = e_ops
    )
    clear_output()
    print(x)
    fig, axes = plt.subplots(1,2,figsize = (10,5))
    for i, exp in enumerate(results[0].expect):
        axes[0].plot(tlist,exp,label= f"{i}")
    for i, exp in enumerate(results[1].expect):
        axes[1].plot(tlist,exp,label= f"{i}")
    axes[0].legend()
    axes[0].set_yscale('log')
    axes[0].set_ylim(1e-8,1e1)
    axes[1].legend()
    axes[1].set_yscale('log')
    axes[1].set_ylim(1e-8,1e1)
    plt.show()
    
    result0_pop_57 = np.max(np.abs(results[0].expect[5] + results[0].expect[7]))
    result1_pop_57 = np.max(np.abs(results[1].expect[5] + results[1].expect[7]))

    one_minus_pop2 = np.abs( 1- (results[0].expect[2][-1]))
    one_minus_pop0 = np.abs(1- (results[1].expect[0][-1]))

    print((result0_pop_57, result1_pop_57, one_minus_pop2, one_minus_pop0))
    return 0.5* (result0_pop_57 + result1_pop_57) + one_minus_pop2 + one_minus_pop0

initial_guess =[2.7,2.7 ,0.1,0.1]


result = minimize(objective, initial_guess, method='Nelder-Mead')
# Out:
# [2.8352579  2.83236774 0.0936445  0.09987682]
# (0.014349908197431621, 0.012604715664849586, 0.00032400222917117194, 0.00033288322200031306)
#  Total run time:   0.31s*] Elapsed 0.31s / Remaining 00:00:00:00 [*********56%*          ] Elapsed 0.17s / Remaining 00:00:00:00
#  Total run time:   0.31s*] Elapsed 0.31s / Remaining 00:00:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 63
#      58     return 0.5* (result0_pop_57 + result1_pop_57) + one_minus_pop2 + one_minus_pop0
#      60 initial_guess =[2.7,2.7 ,0.1,0.1]
# ---> 63 result = minimize(objective, initial_guess, method='Nelder-Mead')
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698 callback = _wrap_callback(callback, meth)
#     700 if meth == 'nelder-mead':
# --> 701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
#     704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:985, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     983 if bounds is not None:
#     984     xcc = np.clip(xcc, lower_bound, upper_bound)
# --> 985 fxcc = func(xcc)
#     987 if fxcc < fsim[-1]:
#     988     sim[-1] = xcc
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:640, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     638 ncalls[0] += 1
#     639 # A copy of x is sent to the user function (gh13740)
# --> 640 fx = function(np.copy(x), *(wrapper_args + args))
#     641 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     642 # backwards-compatibility, also allow np.array([1.3]),
#     643 # np.array([[1.3]]) etc.
#     644 if not np.isscalar(fx):
#
# Cell In[7], line 16, in objective(x)
#      13 detuning1 =0.5
#      14 detuning2 =0.5
# ---> 16 results  = qbt.run_qutip_mesolve_parrallel(
#      17     initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
#      18     tlist = tlist,
#      19     drive_terms = qbt.get_Raman_DRAG_drive_terms(
#      20         i = 0,
#      21         j = 3,
#      22         k = 2,
#      23         detuning1=detuning1,
#      24         detuning2 = detuning2,
#      25         t_duration=t_duration,
#      26         shape='sin^2',
#      27         amp_scaling_factor = 1,
#      28         amp1_scaling_factor = amp1_scaling_factor,
#      29         amp2_scaling_factor = amp2_scaling_factor,
#      30         amp1_correction_scaling_factor = amp1_correction_scaling_factor,
#      31         amp2_correction_scaling_factor = amp2_correction_scaling_factor,
#      32     ),
#      33     # c_ops = c_ops,
#      34     e_ops = e_ops
#      35 )
#      36 clear_output()
#      37 print(x)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/CoupledQuantumSystems/IFQ.py:394, in gfIFQ.run_qutip_mesolve_parrallel(self, initial_states, tlist, drive_terms, c_ops, e_ops, post_processing)
#     382 with get_reusable_executor(max_workers=None, context='loky') as executor:
#     383     futures = {executor.submit(ODEsolve_and_post_process,
#     384                                y0=initial_states[i],
#     385                                tlist=tlist,
#    (...)
#     391                                post_processing_args=post_processing_args,
#     392                                ): i for i in range(len(initial_states))}
# --> 394     for future in concurrent.futures.as_completed(futures):
#     395         original_index = futures[future]
#     396         results[original_index] = future.result()
#
# File ~/miniconda3/envs/test/lib/python3.10/concurrent/futures/_base.py:245, in as_completed(fs, timeout)
#     240     if wait_timeout < 0:
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#     248     finished = waiter.finished_futures
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
def objective(x):
    # amp1_scaling_factor = 2.1866024
    # amp2_scaling_factor = 2.14973954
    # amp1_correction_scaling_factor = x[0]
    # amp2_correction_scaling_factor = x[1]
    # detuning1 =x[2]
    # detuning2 =x[3]

    amp1_scaling_factor = x[0]
    amp2_scaling_factor = x[1]
    amp1_correction_scaling_factor = x[2]
    amp2_correction_scaling_factor = x[3]
    detuning1 =0.2
    detuning2 =0.2

    results  = qbt.run_qutip_mesolve_parrallel(
        initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
        tlist = tlist,
        drive_terms = qbt.get_Raman_DRAG_drive_terms(
            i = 0,
            j = 3,
            k = 2,
            detuning1=detuning1,
            detuning2 = detuning2,
            t_duration=t_duration,
            shape='sin^2',
            amp_scaling_factor = 1,
            amp1_scaling_factor = amp1_scaling_factor,
            amp2_scaling_factor = amp2_scaling_factor,
            amp1_correction_scaling_factor = amp1_correction_scaling_factor,
            amp2_correction_scaling_factor = amp2_correction_scaling_factor,
        ),
        # c_ops = c_ops,
        e_ops = e_ops
    )
    clear_output()
    print(x)
    fig, axes = plt.subplots(1,2,figsize = (10,5))
    for i, exp in enumerate(results[0].expect):
        axes[0].plot(tlist,exp,label= f"{i}")
    for i, exp in enumerate(results[1].expect):
        axes[1].plot(tlist,exp,label= f"{i}")
    axes[0].legend()
    axes[0].set_yscale('log')
    axes[0].set_ylim(1e-8,1e1)
    axes[1].legend()
    axes[1].set_yscale('log')
    axes[1].set_ylim(1e-8,1e1)
    plt.show()
    
    result0_pop_57 = np.max(np.abs(results[0].expect[5] + results[0].expect[7]))
    result1_pop_57 = np.max(np.abs(results[1].expect[5] + results[1].expect[7]))

    one_minus_pop2 = np.abs( 1- (results[0].expect[2][-1]))
    one_minus_pop0 = np.abs(1- (results[1].expect[0][-1]))

    print((result0_pop_57, result1_pop_57, one_minus_pop2, one_minus_pop0))
    return 0.5* (result0_pop_57 + result1_pop_57) + one_minus_pop2 + one_minus_pop0

initial_guess =[1.7,1.7 ,0.1,0.1]


result = minimize(objective, initial_guess, method='Nelder-Mead')
# Out:
# [1.815396   1.75262409 0.0881651  0.10242305]
# (0.008714451975275832, 0.00750102648293401, 0.0003600990624503808, 0.00038356818488227695)
#  Total run time:   0.29s*] Elapsed 0.29s / Remaining 00:00:00:00
#  Total run time:   0.30s*] Elapsed 0.30s / Remaining 00:00:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 63
#      58     return 0.5* (result0_pop_57 + result1_pop_57) + one_minus_pop2 + one_minus_pop0
#      60 initial_guess =[1.7,1.7 ,0.1,0.1]
# ---> 63 result = minimize(objective, initial_guess, method='Nelder-Mead')
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698 callback = _wrap_callback(callback, meth)
#     700 if meth == 'nelder-mead':
# --> 701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
#     704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:985, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     983 if bounds is not None:
#     984     xcc = np.clip(xcc, lower_bound, upper_bound)
# --> 985 fxcc = func(xcc)
#     987 if fxcc < fsim[-1]:
#     988     sim[-1] = xcc
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:640, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     638 ncalls[0] += 1
#     639 # A copy of x is sent to the user function (gh13740)
# --> 640 fx = function(np.copy(x), *(wrapper_args + args))
#     641 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     642 # backwards-compatibility, also allow np.array([1.3]),
#     643 # np.array([[1.3]]) etc.
#     644 if not np.isscalar(fx):
#
# Cell In[8], line 16, in objective(x)
#      13 detuning1 =0.2
#      14 detuning2 =0.2
# ---> 16 results  = qbt.run_qutip_mesolve_parrallel(
#      17     initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
#      18     tlist = tlist,
#      19     drive_terms = qbt.get_Raman_DRAG_drive_terms(
#      20         i = 0,
#      21         j = 3,
#      22         k = 2,
#      23         detuning1=detuning1,
#      24         detuning2 = detuning2,
#      25         t_duration=t_duration,
#      26         shape='sin^2',
#      27         amp_scaling_factor = 1,
#      28         amp1_scaling_factor = amp1_scaling_factor,
#      29         amp2_scaling_factor = amp2_scaling_factor,
#      30         amp1_correction_scaling_factor = amp1_correction_scaling_factor,
#      31         amp2_correction_scaling_factor = amp2_correction_scaling_factor,
#      32     ),
#      33     # c_ops = c_ops,
#      34     e_ops = e_ops
#      35 )
#      36 clear_output()
#      37 print(x)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/CoupledQuantumSystems/IFQ.py:394, in gfIFQ.run_qutip_mesolve_parrallel(self, initial_states, tlist, drive_terms, c_ops, e_ops, post_processing)
#     382 with get_reusable_executor(max_workers=None, context='loky') as executor:
#     383     futures = {executor.submit(ODEsolve_and_post_process,
#     384                                y0=initial_states[i],
#     385                                tlist=tlist,
#    (...)
#     391                                post_processing_args=post_processing_args,
#     392                                ): i for i in range(len(initial_states))}
# --> 394     for future in concurrent.futures.as_completed(futures):
#     395         original_index = futures[future]
#     396         results[original_index] = future.result()
#
# File ~/miniconda3/envs/test/lib/python3.10/concurrent/futures/_base.py:245, in as_completed(fs, timeout)
#     240     if wait_timeout < 0:
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#     248     finished = waiter.finished_futures
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
def objective(x):
    # amp1_scaling_factor = 2.1866024
    # amp2_scaling_factor = 2.14973954
    # amp1_correction_scaling_factor = x[0]
    # amp2_correction_scaling_factor = x[1]
    # detuning1 =x[2]
    # detuning2 =x[3]

    amp1_scaling_factor = x[0]
    amp2_scaling_factor = x[1]
    amp1_correction_scaling_factor = x[2]
    amp2_correction_scaling_factor = x[3]
    detuning1 =0.1
    detuning2 =0.1

    results  = qbt.run_qutip_mesolve_parrallel(
        initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
        tlist = tlist,
        drive_terms = qbt.get_Raman_DRAG_drive_terms(
            i = 0,
            j = 3,
            k = 2,
            detuning1=detuning1,
            detuning2 = detuning2,
            t_duration=t_duration,
            shape='sin^2',
            amp_scaling_factor = 1,
            amp1_scaling_factor = amp1_scaling_factor,
            amp2_scaling_factor = amp2_scaling_factor,
            amp1_correction_scaling_factor = amp1_correction_scaling_factor,
            amp2_correction_scaling_factor = amp2_correction_scaling_factor,
        ),
        # c_ops = c_ops,
        e_ops = e_ops
    )
    clear_output()
    print(x)
    fig, axes = plt.subplots(1,2,figsize = (10,5))
    for i, exp in enumerate(results[0].expect):
        axes[0].plot(tlist,exp,label= f"{i}")
    for i, exp in enumerate(results[1].expect):
        axes[1].plot(tlist,exp,label= f"{i}")
    axes[0].legend()
    axes[0].set_yscale('log')
    axes[0].set_ylim(1e-8,1e1)
    axes[1].legend()
    axes[1].set_yscale('log')
    axes[1].set_ylim(1e-8,1e1)
    plt.show()
    
    result0_pop_57 = np.max(np.abs(results[0].expect[5] + results[0].expect[7]))
    result1_pop_57 = np.max(np.abs(results[1].expect[5] + results[1].expect[7]))

    one_minus_pop2 = np.abs( 1- (results[0].expect[2][-1]))
    one_minus_pop0 = np.abs(1- (results[1].expect[0][-1]))

    print((result0_pop_57, result1_pop_57, one_minus_pop2, one_minus_pop0))
    return 0.5* (result0_pop_57 + result1_pop_57) + one_minus_pop2 + one_minus_pop0

initial_guess =[1.1,1.1 ,0.1,0.1]


result = minimize(objective, initial_guess, method='Nelder-Mead')
# Out:
# [1.30489638 1.30253745 0.07079778 0.09271019]
# (0.010727949478423848, 0.007502305321593388, 0.018117175898672233, 0.018871088205958397)
#  Total run time:   0.32s*] Elapsed 0.32s / Remaining 00:00:00:00 [*********40%           ] Elapsed 0.11s / Remaining 00:00:00:00
#  Total run time:   0.33s*] Elapsed 0.33s / Remaining 00:00:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 63
#      58     return 0.5* (result0_pop_57 + result1_pop_57) + one_minus_pop2 + one_minus_pop0
#      60 initial_guess =[1.1,1.1 ,0.1,0.1]
# ---> 63 result = minimize(objective, initial_guess, method='Nelder-Mead')
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_minimize.py:701, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     698 callback = _wrap_callback(callback, meth)
#     700 if meth == 'nelder-mead':
# --> 701     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     702                                **options)
#     703 elif meth == 'powell':
#     704     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:948, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     946 if bounds is not None:
#     947     xr = np.clip(xr, lower_bound, upper_bound)
# --> 948 fxr = func(xr)
#     949 doshrink = 0
#     951 if fxr < fsim[0]:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/optimize/_optimize.py:640, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     638 ncalls[0] += 1
#     639 # A copy of x is sent to the user function (gh13740)
# --> 640 fx = function(np.copy(x), *(wrapper_args + args))
#     641 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     642 # backwards-compatibility, also allow np.array([1.3]),
#     643 # np.array([[1.3]]) etc.
#     644 if not np.isscalar(fx):
#
# Cell In[10], line 16, in objective(x)
#      13 detuning1 =0.1
#      14 detuning2 =0.1
# ---> 16 results  = qbt.run_qutip_mesolve_parrallel(
#      17     initial_states = [qutip.basis(qbt.truncated_dim, 0),qutip.basis(qbt.truncated_dim, 2)],
#      18     tlist = tlist,
#      19     drive_terms = qbt.get_Raman_DRAG_drive_terms(
#      20         i = 0,
#      21         j = 3,
#      22         k = 2,
#      23         detuning1=detuning1,
#      24         detuning2 = detuning2,
#      25         t_duration=t_duration,
#      26         shape='sin^2',
#      27         amp_scaling_factor = 1,
#      28         amp1_scaling_factor = amp1_scaling_factor,
#      29         amp2_scaling_factor = amp2_scaling_factor,
#      30         amp1_correction_scaling_factor = amp1_correction_scaling_factor,
#      31         amp2_correction_scaling_factor = amp2_correction_scaling_factor,
#      32     ),
#      33     # c_ops = c_ops,
#      34     e_ops = e_ops
#      35 )
#      36 clear_output()
#      37 print(x)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/CoupledQuantumSystems/IFQ.py:394, in gfIFQ.run_qutip_mesolve_parrallel(self, initial_states, tlist, drive_terms, c_ops, e_ops, post_processing)
#     382 with get_reusable_executor(max_workers=None, context='loky') as executor:
#     383     futures = {executor.submit(ODEsolve_and_post_process,
#     384                                y0=initial_states[i],
#     385                                tlist=tlist,
#    (...)
#     391                                post_processing_args=post_processing_args,
#     392                                ): i for i in range(len(initial_states))}
# --> 394     for future in concurrent.futures.as_completed(futures):
#     395         original_index = futures[future]
#     396         results[original_index] = future.result()
#
# File ~/miniconda3/envs/test/lib/python3.10/concurrent/futures/_base.py:245, in as_completed(fs, timeout)
#     240     if wait_timeout < 0:
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#     248     finished = waiter.finished_futures
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/miniconda3/envs/test/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

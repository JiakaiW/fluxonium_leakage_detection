# %%
import numpy as np
import pickle

import qutip
from pymoo.core.problem import ElementwiseProblem,StarmapParallelization
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.algorithms.soo.nonconvex.cmaes import CMAES
from pymoo.termination import get_termination
from pymoo.optimize import minimize
from pymoo.algorithms.soo.nonconvex.ga import GA
from pymoo.algorithms.soo.nonconvex.nelder import NelderMead

import multiprocessing


# CoupledQuantumSystems (as from your code):
from CoupledQuantumSystems.drive import DriveTerm, square_pulse_with_rise_fall
from CoupledQuantumSystems.IFQ import gfIFQ
from CoupledQuantumSystems.evo import ODEsolve_and_post_process


# -------------------------------
# Define your parameters and objects
# -------------------------------
EJ = 3
EJoverEC = 6
EJoverEL = 25
EC = EJ / EJoverEC
EL = EJ / EJoverEL

qbt = gfIFQ(EJ=EJ, EC=EC, EL=EL, flux=0, truncated_dim=20)
e_ops = [
    qutip.basis(qbt.truncated_dim, i) * qutip.basis(qbt.truncated_dim, i).dag()
    for i in range(10)
]

element = np.abs(qbt.fluxonium.matrixelement_table("n_operator", evals_count=3)[1, 2])
freq = (qbt.fluxonium.eigenvals()[2] - qbt.fluxonium.eigenvals()[1]) * 2 * np.pi

# --------------------------------------------------------------
# DEFINE THE OBJECTIVE FUNCTION
# x = (t_tot, amp, w_d)
# We want to minimize sum of infidelities for |1>->|2> and |2>->|1>.
# --------------------------------------------------------------
def fluxonium_objective(t_tot, amp, w_d,ramp):
    tlist = np.linspace(0, t_tot * (1+ramp), 100)

    initial_states = [
        qutip.basis(qbt.truncated_dim, 1),
        qutip.basis(qbt.truncated_dim, 2),
    ]

    drive_terms = [
        DriveTerm(
            driven_op=qutip.Qobj(qbt.fluxonium.n_operator(energy_esys=True)),
            pulse_shape_func=square_pulse_with_rise_fall,
            pulse_id="pi",
            pulse_shape_args={
                "w_d": w_d,    # No extra 2pi factor
                "amp": amp,    # No extra 2pi factor
                "t_square": t_tot * (1-ramp),
                "t_rise": t_tot * ramp,
            },
        )
    ]

    # Solve the dynamics for each initial state
    results = []
    for init_state in initial_states:
        res = ODEsolve_and_post_process(
            y0=init_state,
            tlist=tlist,
            static_hamiltonian=qbt.diag_hamiltonian,
            drive_terms=drive_terms,
            e_ops=e_ops,
            print_progress=False,
        )
        results.append(res)

    # Calculate final populations
    # (We want to transfer |1> -> |2> and |2> -> |1>.)
    one_minus_pop2 = abs(1 - results[0].expect[2][-1])  # from state |1> to |2>
    one_minus_pop1 = abs(1 - results[1].expect[1][-1])  # from state |2> to |1>

    return one_minus_pop2 + one_minus_pop1


# --------------------------------------------------------------
# CREATE A PYMOO PROBLEM SUBCLASS
# --------------------------------------------------------------
class FluxoniumProblem(ElementwiseProblem):
    """
    We define a single-objective problem with:
      - n_var=3: (amp, w_d,ramp)
      - n_obj=1: we want to minimize a single objective
      - n_constr=1: we add a constraint G <= 0 => t_tot>0 => -t_tot < 0
      - x_lower and x_upper define bounding box
    """

    def __init__(self,t_tot):
        self.t_tot = t_tot
        # init_amp = np.pi / element / t_tot / 3.1415 / 2
        init_wd = qbt.fluxonium.eigenvals()[2] - qbt.fluxonium.eigenvals()[1]
        amp_guess = 50/t_tot * 22

        xl = np.array([amp_guess/5, 0.003, 1e-10])
        xu = np.array([amp_guess*5, 0.02, 0.5])

        # n_constr=1 means we'll define 1 constraint
        super().__init__(
            n_var=3,
            n_obj=1,
            n_constr=0,
            xl=xl,
            xu=xu,
            elementwise_evaluation=True  # we evaluate one solution at a time
        )

    def _evaluate(self, x, out, *args, **kwargs):
        """
        x is a single solution [amp, w_d,ramp] because we use elementwise_evaluation=True
        We'll compute:
          out["F"] = fluxonium_objective(x)
          out["G"] = the constraint violation (needs to be <= 0 to be feasible)
        """
        amp, w_d,ramp = x

        # The objective:
        f = fluxonium_objective(self.t_tot, amp, w_d,ramp)

        out["F"] = f
        out["G"] = -t_tot

n_proccess = 20

# define the problem by passing the starmap interface of the thread pool
t_tot_list = np.linspace(50, 250, 21)
for t_tot in t_tot_list:
    pool = multiprocessing.Pool(n_proccess)
    runner = StarmapParallelization(pool.starmap)
    problem = FluxoniumProblem(t_tot)
    res = minimize(problem, GA(), termination=("n_gen", 200), seed=1,verbose=True)
    pool.close()
    print("Best solution found: \nX = %s\nF = %s" % (res.X, res.F))

    results_dict = {
        't_tot': t_tot,
        'res': res
    }

    with open(f"pymoo_optimized_results_{t_tot}.pkl", "wb") as f:
        pickle.dump(results_dict, f)
# Out:
# capi_return is NULL
# Call-back cb_f_in_zvode__user__routines failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 142
#     140 runner = StarmapParallelization(pool.starmap)
#     141 problem = FluxoniumProblem(t_tot)
# --> 142 res = minimize(problem, GA(), termination=("n_gen", 200), seed=1,verbose=True)
#     143 pool.close()
#     144 print("Best solution found: \nX = %s\nF = %s" % (res.X, res.F))
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/optimize.py:67, in minimize(problem, algorithm, termination, copy_algorithm, copy_termination, **kwargs)
#      64     algorithm.setup(problem, **kwargs)
#      66 # actually execute the algorithm
# ---> 67 res = algorithm.run()
#      69 # store the deep copied algorithm in the result object
#      70 res.algorithm = algorithm
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/algorithm.py:138, in Algorithm.run(self)
#     136 def run(self):
#     137     while self.has_next():
# --> 138         self.next()
#     139     return self.result()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/algorithm.py:158, in Algorithm.next(self)
#     156 # call the advance with them after evaluation
#     157 if infills is not None:
# --> 158     self.evaluator.eval(self.problem, infills, algorithm=self)
#     159     self.advance(infills=infills)
#     161 # if the algorithm does not follow the infill-advance scheme just call advance
#     162 else:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/evaluator.py:69, in Evaluator.eval(self, problem, pop, skip_already_evaluated, evaluate_values_of, count_evals, **kwargs)
#      65 # evaluate the solutions (if there are any)
#      66 if len(I) > 0:
#      67
#      68     # do the actual evaluation - call the sub-function to set the corresponding values to the population
# ---> 69     self._eval(problem, pop[I], evaluate_values_of, **kwargs)
#      71 # update the function evaluation counter
#      72 if count_evals:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/evaluator.py:90, in Evaluator._eval(self, problem, pop, evaluate_values_of, **kwargs)
#      87 X = pop.get("X")
#      89 # call the problem to evaluate the solutions
# ---> 90 out = problem.evaluate(X, return_values_of=evaluate_values_of, return_as_dictionary=True, **kwargs)
#      92 # for each of the attributes set it to the problem
#      93 for key, val in out.items():
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/problem.py:257, in Problem.evaluate(self, X, return_values_of, return_as_dictionary, *args, **kwargs)
#     254     only_single_value = not (isinstance(X, list) or isinstance(X, np.ndarray))
#     256 # this is where the actual evaluation takes place
# --> 257 _out = self.do(X, return_values_of, *args, **kwargs)
#     259 out = {}
#     260 for k, v in _out.items():
#     261
#     262     # copy it to a numpy array (it might be one of jax at this point)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/problem.py:297, in Problem.do(self, X, return_values_of, *args, **kwargs)
#     295 # do the function evaluation
#     296 if self.elementwise:
# --> 297     self._evaluate_elementwise(X, out, *args, **kwargs)
#     298 else:
#     299     self._evaluate_vectorized(X, out, *args, **kwargs)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/problem.py:315, in Problem._evaluate_elementwise(self, X, out, *args, **kwargs)
#     312 f = self.elementwise_func(self, args, kwargs)
#     314 # execute the runner
# --> 315 elems = self.elementwise_runner(f, X)
#     317 # for each evaluation call
#     318 for elem in elems:
#     319
#     320     # for each key stored for this evaluation
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/problem.py:32, in LoopedElementwiseEvaluation.__call__(self, f, X)
#      31 def __call__(self, f, X):
# ---> 32     return [f(x) for x in X]
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/problem.py:32, in <listcomp>(.0)
#      31 def __call__(self, f, X):
# ---> 32     return [f(x) for x in X]
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/pymoo/core/problem.py:25, in ElementwiseEvaluationFunction.__call__(self, x)
#      23 def __call__(self, x):
#      24     out = dict()
# ---> 25     self.problem._evaluate(x, out, *self.args, **self.kwargs)
#      26     return out
#
# Cell In[1], line 129, in FluxoniumProblem._evaluate(self, x, out, *args, **kwargs)
#     126 amp, w_d,ramp = x
#     128 # The objective:
# --> 129 f = fluxonium_objective(self.t_tot, amp, w_d,ramp)
#     131 out["F"] = f
#     132 out["G"] = -t_tot
#
# Cell In[1], line 70, in fluxonium_objective(t_tot, amp, w_d, ramp)
#      68 results = []
#      69 for init_state in initial_states:
# ---> 70     res = ODEsolve_and_post_process(
#      71         y0=init_state,
#      72         tlist=tlist,
#      73         static_hamiltonian=qbt.diag_hamiltonian,
#      74         drive_terms=drive_terms,
#      75         e_ops=e_ops,
#      76         print_progress=False,
#      77     )
#      78     results.append(res)
#      80 # Calculate final populations
#      81 # (We want to transfer |1> -> |2> and |2> -> |1>.)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/CoupledQuantumSystems/evo.py:66, in ODEsolve_and_post_process(y0, tlist, static_hamiltonian, drive_terms, c_ops, e_ops, store_states, method, post_processing_funcs, post_processing_args, print_progress, file_name)
#      63             additional_args[key] = drive_term.pulse_shape_args_with_id[key]
#      65 if method == 'qutip.mesolve':
# ---> 66     result = qutip.mesolve(
#      67         rho0=y0,
#      68         H=H_with_drives,
#      69         tlist=tlist,
#      70         c_ops=c_ops,
#      71         e_ops = e_ops,
#      72         args=additional_args,
#      73         options=qutip.Options(store_states=store_states, nsteps=200000, num_cpus=1),
#      74         progress_bar = qutip.ui.progressbar.EnhancedTextProgressBar() if print_progress else None,
#      75     )
#      77 elif method == 'qutip.mcsolve':
#      78     result = qutip.mcsolve(psi0=y0,
#      79                         H= H_with_drives,
#      80                         tlist=tlist,
#    (...)
#      86                         progress_bar = qutip.ui.progressbar.EnhancedTextProgressBar() if print_progress else None,
#      87                         )
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/mesolve.py:217, in mesolve(H, rho0, tlist, c_ops, e_ops, args, options, progress_bar, _safe_mode)
#     205 use_mesolve = ((c_ops and len(c_ops) > 0)
#     206                or (not isket(rho0))
#     207                or (isinstance(H, Qobj) and issuper(H))
#    (...)
#     213                or (not isinstance(H, (Qobj, QobjEvo)) and callable(H) and
#     214                         options.rhs_with_state))
#     216 if not use_mesolve:
# --> 217     return sesolve(H, rho0, tlist, e_ops=e_ops, args=args, options=options,
#     218                    progress_bar=progress_bar, _safe_mode=_safe_mode)
#     220 if isket(rho0):
#     221     rho0 = ket2dm(rho0)
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/sesolve.py:136, in sesolve(H, psi0, tlist, e_ops, args, options, progress_bar, _safe_mode)
#     133     v = psi0.full().ravel('F')
#     134     func(0., v, *ode_args) + v
# --> 136 res = _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, options,
#     137                          progress_bar, dims=psi0.dims)
#     138 if e_ops_dict:
#     139     res.expect = {e: res.expect[n]
#     140                   for n, e in enumerate(e_ops_dict.keys())}
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/sesolve.py:381, in _generic_ode_solve(func, ode_args, psi0, tlist, e_ops, opt, progress_bar, dims)
#     377             output.expect[m][t_idx] = cy_expect_psi(e_ops_data[m], cdata,
#     378                                                     e_ops[m].isherm)
#     380     if t_idx < n_tsteps - 1:
# --> 381         r.integrate(r.t + dt[t_idx])
#     383 progress_bar.finished()
#     385 if opt.store_final_state:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/integrate/_ode.py:431, in ode.integrate(self, t, step, relax)
#     428     mth = self._integrator.run
#     430 try:
# --> 431     self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     432                           self._y, self.t, t,
#     433                           self.f_params, self.jac_params)
#     434 except SystemError as e:
#     435     # f2py issue with tuple returns, see ticket 1187.
#     436     raise ValueError(
#     437         'Function to integrate must not return a tuple.'
#     438     ) from e
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/scipy/integrate/_ode.py:1008, in vode.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1004     jac = _vode_banded_jac_wrapper(jac, self.ml, jac_params)
#    1006 args = ((f, jac, y0, t0, t1) + tuple(self.call_args) +
#    1007         (f_params, jac_params))
# -> 1008 y1, t, istate = self.runner(*args)
#    1009 self.istate = istate
#    1010 if istate < 0:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/cy/cqobjevo.pyx:212, in qutip.cy.cqobjevo.CQobjEvo.mul_vec()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/cy/cqobjevo.pyx:679, in qutip.cy.cqobjevo.CQobjEvoTd._mul_vec()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/cy/cqobjevo.pyx:293, in qutip.cy.cqobjevo.CQobjEvo._factor_dyn()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/cy/cqobjevo.pyx:278, in qutip.cy.cqobjevo.CQobjEvo._factor()
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/qutip/qobjevo.py:1829, in _UnitedFuncCaller.__call__(self, t, args)
#    1827 out = []
#    1828 for func in self.funclist:
# -> 1829     out.append(func(t, now_args))
#    1830 return out
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/CoupledQuantumSystems/drive.py:43, in DriveTerm.wrapper(self, t, args)
#      40 try:
#      41     if self.pulse_id is not None:
#      42         # Remove the id from the args that contain id, and then call the original function
# ---> 43         unmodified_args = {key[:-len(self.pulse_id)]: value for key, value in args.items() if key.endswith(self.pulse_id)}
#      44         return self.pulse_shape_func(t, unmodified_args)
#      45     else:
#
# File ~/miniconda3/envs/test/lib/python3.10/site-packages/CoupledQuantumSystems/drive.py:43, in <dictcomp>(.0)
#      40 try:
#      41     if self.pulse_id is not None:
#      42         # Remove the id from the args that contain id, and then call the original function
# ---> 43         unmodified_args = {key[:-len(self.pulse_id)]: value for key, value in args.items() if key.endswith(self.pulse_id)}
#      44         return self.pulse_shape_func(t, unmodified_args)
#      45     else:
#
# KeyboardInterrupt:

# %%
import numpy as np
import qutip
import pickle
import nevergrad as ng
from CoupledQuantumSystems.drive import DriveTerm, square_pulse_with_rise_fall
from CoupledQuantumSystems.IFQ import gfIFQ
from CoupledQuantumSystems.evo import ODEsolve_and_post_process
from concurrent.futures import ProcessPoolExecutor
# -------------------------------
# Define your parameters and objects
# -------------------------------
EJ = 3
EJoverEC = 6
EJoverEL = 25
EC = EJ / EJoverEC
EL = EJ / EJoverEL

qbt = gfIFQ(EJ=EJ, EC=EC, EL=EL, flux=0, truncated_dim=20)
e_ops = [
    qutip.basis(qbt.truncated_dim, i) * qutip.basis(qbt.truncated_dim, i).dag()
    for i in range(10)
]

element = np.abs(
    qbt.fluxonium.matrixelement_table("n_operator", evals_count=3)[1, 2]
)
freq = (qbt.fluxonium.eigenvals()[2] - qbt.fluxonium.eigenvals()[1]) * 2 * np.pi


def objective(t_tot, amp, w_d,ramp):
    tlist = np.linspace(0, t_tot * (1+ramp), 100)

    initial_states = [
        qutip.basis(qbt.truncated_dim, 1),
        qutip.basis(qbt.truncated_dim, 2),
    ]

    drive_terms = [
        DriveTerm(
            driven_op=qutip.Qobj(qbt.fluxonium.n_operator(energy_esys=True)),
            pulse_shape_func=square_pulse_with_rise_fall,
            pulse_id="pi",
            pulse_shape_args={
                "w_d": w_d,    # No extra 2pi factor
                "amp": amp,    # No extra 2pi factor
                "t_square": t_tot * (1-ramp),
                "t_rise": t_tot * ramp,
            },
        )
    ]

    # Solve the dynamics for each initial state
    results = []
    for init_state in initial_states:
        res = ODEsolve_and_post_process(
            y0=init_state,
            tlist=tlist,
            static_hamiltonian=qbt.diag_hamiltonian,
            drive_terms=drive_terms,
            e_ops=e_ops,
            print_progress=False,
        )
        results.append(res)

    # Calculate final populations
    # (We want to transfer |1> -> |2> and |2> -> |1>.)
    one_minus_pop2 = abs(1 - results[0].expect[2][-1])  # from state |1> to |2>
    one_minus_pop1 = abs(1 - results[1].expect[1][-1])  # from state |2> to |1>

    return one_minus_pop2 + one_minus_pop1

# ---------------------------------------------------------------------
# SET UP NEVERGRAD INSTRUMENTATION
# ---------------------------------------------------------------------
# We'll specify a search space for each of t_tot, amp, w_d.
# For example, let's guess t_tot is in [1, 300].
# We'll assume amp in [0, 0.1], w_d in [freq*0.9, freq*1.1] as an example.
# Adjust these bounds to your scenario.


# t_tot_list = np.linspace(50, 250, 21)
# Start from 160
t_tot_list = [220,230,240,250]
for t_tot in t_tot_list:
    # init_amp = np.pi / element / t_tot / 3.1415 / 2
    init_wd = qbt.fluxonium.eigenvals()[2] - qbt.fluxonium.eigenvals()[1]
    amp_guess = 50/t_tot * 22
    parametrization = ng.p.Instrumentation(
        amp=ng.p.Scalar(init=amp_guess, lower=amp_guess/5, upper=amp_guess*5),        # or choose your own guess
        w_d=ng.p.Log(init=init_wd, lower=0.003, upper=0.02),
        ramp=ng.p.Scalar(init=0.15, lower=1e-10, upper=0.5),
    )
    # ---------------------------------------------------------------------
    # CHOOSE THE OPTIMIZER
    # ---------------------------------------------------------------------
    # Some popular choices: "CMA", "TwoPointsDE", "OnePlusOne", "PSO", "NGOpt", etc.
    # We'll pick CMA as an example. We'll also set a budget (# of function evaluations)
    # and a concurrency level (num_workers) for parallelizing the objective calls.
    budget = 1000
    num_workers = 20
    optimizer = ng.optimizers.CMA(parametrization=parametrization,
                                budget=budget,
                                num_workers=num_workers)
    # ---------------------------------------------------------------------
    # RUN THE OPTIMIZATION
    # (Nevergrad automatically parallelizes if num_workers > 1.)
    # ---------------------------------------------------------------------
    def nevergrad_objective( amp, w_d,ramp):
        return objective(t_tot=t_tot, amp=amp, w_d=w_d,ramp=ramp)
    with ProcessPoolExecutor(max_workers=num_workers) as executor:
        recommendation = optimizer.minimize(nevergrad_objective,batch_mode=True,verbosity=2,executor=executor)

    # Extract best values
    best_amp = recommendation.kwargs["amp"]
    best_w_d = recommendation.kwargs["w_d"]
    best_ramp = recommendation.kwargs["ramp"]

    print(f"Best amp: {best_amp}, best w_d: {best_w_d}, best ramp: {best_ramp}")

    # Optionally, store results in a pickle
    results_dict = {
        "best_amp": best_amp,
        "best_w_d": best_w_d,
        "best_ramp": best_ramp,
        "recommendation": recommendation,  # the full nevergrad result object
    }

    with open(f"nevergrad_optimized_results_{t_tot}.pkl", "wb") as f:
        pickle.dump(results_dict, f)
# Out:
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.9416518918439287
# Updating fitness with value 1.4786642195021698
# 980 remaining budget and 18 running jobs
# Current pessimistic best is: MultiValue<mean: 1.4786642195021698, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 1.6347958842747707, 'w_d': 0.0034613333453793953, 'ramp': 0.11163668947489254})>
# UserWarning: Ignoring since timer was stopped before starting.
#  /home/kai/miniconda3/envs/test/lib/python3.10/site-packages/nevergrad/common/tools.py: 107
# Updating fitness with value 1.7261812259007154
# Updating fitness with value 1.5531362919626055
# Updating fitness with value 1.7781865590522767
# Updating fitness with value 1.8337670874664371
# Updating fitness with value 1.9436282435436651
# Updating fitness with value 1.5651068911538362
# Updating fitness with value 1.7237091158394284
# Updating fitness with value 1.7650792711961043
# Updating fitness with value 1.8597700552584298
# Updating fitness with value 1.7726967040539265
# Updating fitness with value 1.5407066317198361
# Updating fitness with value 1.518763776681115
# Updating fitness with value 1.783739205516626
# Updating fitness with value 1.794131843982214
# Updating fitness with value 1.843794779819537
# Updating fitness with value 1.5697116951558054
# Updating fitness with value 1.7232824185294162
# Updating fitness with value 1.9484332996508793
# 980 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 1.4786642195021698, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 1.6347958842747707, 'w_d': 0.0034613333453793953, 'ramp': 0.11163668947489254})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.3920038049529728
# Updating fitness with value 1.730567714636801
# Updating fitness with value 1.915364666773843
# Updating fitness with value 1.8328762426116714
# Updating fitness with value 1.8692942407760382
# Updating fitness with value 1.9851141403356758
# Updating fitness with value 1.906863636158783
# 960 remaining budget and 13 running jobs
# Current pessimistic best is: MultiValue<mean: 1.3920038049529728, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 3.964346076947824, 'w_d': 0.003134791491629286, 'ramp': 0.1721520948490608})>
# Updating fitness with value 1.2719411194352226
# Updating fitness with value 1.6272737703489626
# Updating fitness with value 1.8424651197317343
# Updating fitness with value 1.5924981560453602
# Updating fitness with value 1.6813625906683032
# Updating fitness with value 1.8008226564466203
# Updating fitness with value 1.9362731524884813
# Updating fitness with value 1.9003069537891502
# Updating fitness with value 1.9536950527641412
# Updating fitness with value 1.9801513001139799
# Updating fitness with value 1.9035949486331905
# Updating fitness with value 1.8611142358561348
# Updating fitness with value 1.1652269287038757
# 960 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 1.1652269287038757, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.9903301115595, 'w_d': 0.003475544119000524, 'ramp': 0.12024079530470418})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.6728042719465144
# Updating fitness with value 1.8568179086085306
# Updating fitness with value 1.4502643324158282
# Updating fitness with value 1.7786659734941515
# Updating fitness with value 1.7942632866541781
# Updating fitness with value 1.471663582301527
# Updating fitness with value 1.8315344376024347
# Updating fitness with value 1.5453844001047807
# Updating fitness with value 1.8899377605840932
# Updating fitness with value 1.9613461998072172
# Updating fitness with value 1.9145776856554584
# Updating fitness with value 1.4232113030898654
# Updating fitness with value 1.4837009273031418
# Updating fitness with value 1.9581310674085284
# 940 remaining budget and 6 running jobs
# Current pessimistic best is: MultiValue<mean: 1.1652269287038757, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.9903301115595, 'w_d': 0.003475544119000524, 'ramp': 0.12024079530470418})>
# Updating fitness with value 1.8825786078172542
# Updating fitness with value 1.9690644824507215
# Updating fitness with value 1.907457173658258
# Updating fitness with value 1.9881856924387131
# Updating fitness with value 1.9548852237012997
# Updating fitness with value 1.9340164092842622
# 940 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 1.1652269287038757, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.9903301115595, 'w_d': 0.003475544119000524, 'ramp': 0.12024079530470418})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.7826184458766345
# Updating fitness with value 1.918308865211614
# Updating fitness with value 1.327809188552425
# 920 remaining budget and 17 running jobs
# Current pessimistic best is: MultiValue<mean: 1.1652269287038757, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.9903301115595, 'w_d': 0.003475544119000524, 'ramp': 0.12024079530470418})>
# Updating fitness with value 1.579137939463025
# Updating fitness with value 1.267064716627849
# Updating fitness with value 1.1309137606409156
# Updating fitness with value 1.4505053927442972
# Updating fitness with value 1.6681739102594944
# Updating fitness with value 1.9062651181391184
# Updating fitness with value 1.8929313845007116
# Updating fitness with value 1.9243286113794587
# Updating fitness with value 0.7349687110258257
# Updating fitness with value 1.6780613839534455
# Updating fitness with value 1.5530505331875188
# Updating fitness with value 1.112207041551413
# Updating fitness with value 1.8224667448238492
# Updating fitness with value 1.6106294751976766
# Updating fitness with value 1.978523466961072
# Updating fitness with value 1.7388136941620989
# 920 remaining budget and 1 running jobs
# Current pessimistic best is: MultiValue<mean: 0.7349687110258257, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 10.74609738088651, 'w_d': 0.0030649659208863596, 'ramp': 0.0752029296989964})>
# Updating fitness with value 1.6883124933378229
# 920 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.7349687110258257, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 10.74609738088651, 'w_d': 0.0030649659208863596, 'ramp': 0.0752029296989964})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.9155775757780629
# 900 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.7349687110258257, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 10.74609738088651, 'w_d': 0.0030649659208863596, 'ramp': 0.0752029296989964})>
# Updating fitness with value 1.8422048154414303
# Updating fitness with value 1.4918573506120971
# Updating fitness with value 1.989559159495439
# Updating fitness with value 1.923832737127395
# Updating fitness with value 1.4561009126987703
# 900 remaining budget and 14 running jobs
# Current pessimistic best is: MultiValue<mean: 0.7349687110258257, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 10.74609738088651, 'w_d': 0.0030649659208863596, 'ramp': 0.0752029296989964})>
# Updating fitness with value 0.6796913872932131
# Updating fitness with value 1.8796937075772635
# Updating fitness with value 1.6948577430498073
# Updating fitness with value 1.9318119237122122
# Updating fitness with value 1.7476075032738136
# Updating fitness with value 1.5239630291246304
# Updating fitness with value 1.910659670801429
# Updating fitness with value 1.6031107827008224
# Updating fitness with value 1.4717775752860733
# Updating fitness with value 1.8707541113229407
# Updating fitness with value 1.8632416600289938
# Updating fitness with value 1.2764037288400067
# 900 remaining budget and 2 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6796913872932131, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.409305716599317, 'w_d': 0.004219267130488168, 'ramp': 0.13819855676155965})>
# Updating fitness with value 1.3720559004123927
# Updating fitness with value 1.7704214946419459
# 900 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6796913872932131, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.409305716599317, 'w_d': 0.004219267130488168, 'ramp': 0.13819855676155965})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.8235613215555566
# Updating fitness with value 1.605104263834891
# Updating fitness with value 1.9366220019545408
# Updating fitness with value 1.9713791030027066
# Updating fitness with value 1.7748139196361923
# Updating fitness with value 1.7632908847078963
# 880 remaining budget and 14 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6796913872932131, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.409305716599317, 'w_d': 0.004219267130488168, 'ramp': 0.13819855676155965})>
# Updating fitness with value 1.6936923255730691
# Updating fitness with value 1.2945922977365398
# Updating fitness with value 1.3784280651078054
# Updating fitness with value 1.7683096337575583
# Updating fitness with value 1.5915118724263908
# Updating fitness with value 1.1385446360121743
# Updating fitness with value 1.1653415666111169
# Updating fitness with value 1.9392656327047062
# Updating fitness with value 0.5231736286846747
# Updating fitness with value 0.8896527132366808
# Updating fitness with value 0.728605613100511
# Updating fitness with value 0.9617144054935515
# Updating fitness with value 1.6011575025233542
# 880 remaining budget and 1 running jobs
# Current pessimistic best is: MultiValue<mean: 0.5231736286846747, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.045336321978397, 'w_d': 0.003496691722682273, 'ramp': 0.038383716342035225})>
# Updating fitness with value 1.2446401091618151
# 880 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.5231736286846747, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.045336321978397, 'w_d': 0.003496691722682273, 'ramp': 0.038383716342035225})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.94145649045466
# 860 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.5231736286846747, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 8.045336321978397, 'w_d': 0.003496691722682273, 'ramp': 0.038383716342035225})>
# Updating fitness with value 1.519468558053957
# Updating fitness with value 0.7657243121759238
# Updating fitness with value 1.8141425202132675
# Updating fitness with value 0.09469054743157113
# Updating fitness with value 1.8881279911347482
# Updating fitness with value 0.9220685472103978
# Updating fitness with value 1.957434331429152
# 860 remaining budget and 12 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.9276985927181718
# Updating fitness with value 1.8676247946954274
# Updating fitness with value 1.6825091774732175
# Updating fitness with value 1.7974927949723711
# Updating fitness with value 1.867677231415209
# Updating fitness with value 1.4648788867633167
# Updating fitness with value 1.9074395085967115
# Updating fitness with value 1.5750656085787833
# Updating fitness with value 1.728769640427048
# Updating fitness with value 1.7001182221191804
# 860 remaining budget and 2 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.6257000761177012
# Updating fitness with value 1.1170206026474983
# 860 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.9479127510771141
# Updating fitness with value 1.4092934606414422
# Updating fitness with value 1.9801897477059507
# Updating fitness with value 1.6267046441496396
# Updating fitness with value 0.7114252251280951
# Updating fitness with value 1.7692990340508752
# 840 remaining budget and 14 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.0341234480794328
# 840 remaining budget and 13 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.6842994572069696
# Updating fitness with value 1.2526333358996913
# Updating fitness with value 1.621814856054894
# Updating fitness with value 1.9909196020710156
# Updating fitness with value 1.3953998937531926
# Updating fitness with value 1.3950407111981602
# 840 remaining budget and 7 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.6742041975943605
# Updating fitness with value 1.9128774697414248
# Updating fitness with value 1.6076889172907103
# Updating fitness with value 1.724437436328578
# Updating fitness with value 0.7294807237737925
# Updating fitness with value 1.9144501130897797
# Updating fitness with value 0.7057822951007374
# 840 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.3635170003817212
# Updating fitness with value 1.9853633245137519
# Updating fitness with value 1.7901553788589502
# 820 remaining budget and 17 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.8287020280458144
# Updating fitness with value 1.8107980364829543
# Updating fitness with value 1.7440805985730297
# Updating fitness with value 1.7251336607437544
# Updating fitness with value 1.9379589211974544
# Updating fitness with value 0.1516660684923593
# 820 remaining budget and 11 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.346701625536669
# Updating fitness with value 1.4257415593029383
# Updating fitness with value 0.8982224057625603
# Updating fitness with value 1.592325036039961
# Updating fitness with value 0.3905053972053898
# Updating fitness with value 0.558017432788668
# Updating fitness with value 0.7807931181084575
# Updating fitness with value 1.3709666541188301
# Updating fitness with value 0.7256178278908713
# Updating fitness with value 1.0940826102370587
# 820 remaining budget and 1 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.645804745618693
# 820 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.9597175890308272
# Updating fitness with value 1.8810884290400116
# Updating fitness with value 0.38778023171789466
# 800 remaining budget and 17 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.1815593433196994
# Updating fitness with value 1.6348203329771434
# Updating fitness with value 1.661279893838245
# Updating fitness with value 1.1411345821693664
# Updating fitness with value 1.941648612596612
# Updating fitness with value 1.901491299046846
# Updating fitness with value 1.7819895141305624
# Updating fitness with value 1.8636570488460387
# 800 remaining budget and 9 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.4838861363358542
# 800 remaining budget and 8 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.9604883056220102
# 800 remaining budget and 7 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.6998711440222327
# Updating fitness with value 0.7003392435067846
# Updating fitness with value 1.8618593532616707
# Updating fitness with value 1.2471266044432832
# 800 remaining budget and 3 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 0.650878968363666
# Updating fitness with value 0.5979616910676329
# Updating fitness with value 0.37698246419632564
# 800 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.4768587177864436
# Updating fitness with value 1.4607414575923823
# Updating fitness with value 1.2040111031657288
# 780 remaining budget and 17 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.4487764522351596
# Updating fitness with value 1.9226531292808247
# Updating fitness with value 1.4541834599991899
# Updating fitness with value 0.8853276129999684
# Updating fitness with value 0.13287207145897129
# Updating fitness with value 0.8814066163998595
# Updating fitness with value 1.594901740887814
# Updating fitness with value 1.727563280714581
# Updating fitness with value 1.7637979695942465
# Updating fitness with value 1.0576003452212142
# Updating fitness with value 0.9117012578614605
# Updating fitness with value 1.4193413725907713
# Updating fitness with value 1.5822026615028661
# Updating fitness with value 1.3350820770936447
# 780 remaining budget and 3 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.7252713027582833
# Updating fitness with value 0.307187999609849
# Updating fitness with value 1.059710840347986
# 780 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.999257250996023
# Updating fitness with value 1.9357878183328567
# 760 remaining budget and 18 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.7626367770197504
# Updating fitness with value 1.0325703605578676
# Updating fitness with value 1.6472523549133726
# 760 remaining budget and 15 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 0.49626697085494487
# Updating fitness with value 1.5513522974284915
# Updating fitness with value 0.15050719776538568
# Updating fitness with value 1.6789469392833363
# Updating fitness with value 1.7630830022974164
# Updating fitness with value 1.9422537716830106
# Updating fitness with value 1.440943601606973
# Updating fitness with value 1.6719281959356058
# 760 remaining budget and 7 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.9909408153718942
# Updating fitness with value 0.35658139662253663
# Updating fitness with value 0.7167720646679122
# Updating fitness with value 0.9989175766764687
# Updating fitness with value 1.6830645008548406
# Updating fitness with value 0.8870293497088138
# Updating fitness with value 0.3206691643435635
# 760 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.8388383890773783
# Updating fitness with value 1.8279411352836843
# Updating fitness with value 1.0228424495254482
# 740 remaining budget and 17 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 0.8562916093589316
# Updating fitness with value 0.9333858488857162
# Updating fitness with value 0.37543646136980624
# Updating fitness with value 1.1190422284132837
# Updating fitness with value 0.9696377463680643
# Updating fitness with value 1.4068220940226293
# Updating fitness with value 0.5931399139375934
# Updating fitness with value 1.9528548686877627
# Updating fitness with value 1.511078107836387
# Updating fitness with value 1.1511031225607897
# Updating fitness with value 1.4551507182608996
# Updating fitness with value 0.5080150516403695
# Updating fitness with value 1.0237533423553224
# Updating fitness with value 1.7867591055642582
# Updating fitness with value 0.9501742136079134
# 740 remaining budget and 2 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.7592817184837375
# Updating fitness with value 1.53160328840134
# 740 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.3346849109759955
# 720 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 0.9164119308968187
# Updating fitness with value 1.994267719702456
# Updating fitness with value 0.44691341246854854
# Updating fitness with value 1.6292131151620766
# Updating fitness with value 0.6708628782729913
# 720 remaining budget and 14 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.9904776698551694
# Updating fitness with value 1.7002851065248468
# Updating fitness with value 0.29567056941396497
# Updating fitness with value 1.650188651478488
# Updating fitness with value 0.4193380431158926
# Updating fitness with value 1.1976721051535215
# Updating fitness with value 1.6796564583614695
# Updating fitness with value 1.2598392131121865
# 720 remaining budget and 6 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 0.7930704886710687
# 720 remaining budget and 5 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.4403121895174253
# Updating fitness with value 1.6817569590755808
# Updating fitness with value 0.9909528269524567
# Updating fitness with value 1.9186564170525262
# 720 remaining budget and 1 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 1.88389910401605
# 720 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.5383065036929167
# 700 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.09469054743157113, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.137358786867386, 'w_d': 0.003902280558043861, 'ramp': 0.06424137972625237})>
# Updating fitness with value 0.07367065733802236
# Updating fitness with value 1.1104557622306503
# Updating fitness with value 1.4990672394160254
# Updating fitness with value 1.9800019460242189
# Updating fitness with value 0.2738475470455677
# 700 remaining budget and 14 running jobs
# Current pessimistic best is: MultiValue<mean: 0.07367065733802236, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 14.272564758788608, 'w_d': 0.004316665050242232, 'ramp': 0.06288927909918626})>
# Updating fitness with value 1.2030693372123675
# Updating fitness with value 0.18056092096062348
# Updating fitness with value 1.8558602205422559
# Updating fitness with value 1.4452974509131593
# Updating fitness with value 0.7715542902468704
# Updating fitness with value 1.4943391324315463
# Updating fitness with value 1.8356152431452406
# Updating fitness with value 0.4536856881161093
# Updating fitness with value 1.3962231851009994
# Updating fitness with value 1.171642033638384
# Updating fitness with value 0.6332139324261812
# Updating fitness with value 1.4858366454524323
# Updating fitness with value 1.8177749889397168
# Updating fitness with value 0.7461621091034962
# 700 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.07367065733802236, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 14.272564758788608, 'w_d': 0.004316665050242232, 'ramp': 0.06288927909918626})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.5015077808347483
# Updating fitness with value 0.24552286407947832
# Updating fitness with value 0.8825183367348848
# Updating fitness with value 1.5276072241820748
# Updating fitness with value 1.6508714144281447
# 680 remaining budget and 15 running jobs
# Current pessimistic best is: MultiValue<mean: 0.07367065733802236, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 14.272564758788608, 'w_d': 0.004316665050242232, 'ramp': 0.06288927909918626})>
# Updating fitness with value 1.9056784231683412
# Updating fitness with value 1.3607919540880475
# Updating fitness with value 1.2367164013895546
# Updating fitness with value 0.11961771157601309
# Updating fitness with value 1.2554427070293253
# Updating fitness with value 0.6064586453408766
# Updating fitness with value 1.069657848865341
# Updating fitness with value 1.5089563274850906
# 680 remaining budget and 7 running jobs
# Current pessimistic best is: MultiValue<mean: 0.07367065733802236, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 14.272564758788608, 'w_d': 0.004316665050242232, 'ramp': 0.06288927909918626})>
# Updating fitness with value 1.3231122496857406
# Updating fitness with value 1.9467252567897604
# Updating fitness with value 0.9312752121405009
# Updating fitness with value 0.604053683063061
# Updating fitness with value 1.0768365824435968
# Updating fitness with value 0.8264505722264374
# Updating fitness with value 0.18298655365248773
# 680 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.07367065733802236, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 14.272564758788608, 'w_d': 0.004316665050242232, 'ramp': 0.06288927909918626})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.2609151178526756
# 660 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.07367065733802236, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 14.272564758788608, 'w_d': 0.004316665050242232, 'ramp': 0.06288927909918626})>
# Updating fitness with value 0.05564198276972265
# Updating fitness with value 1.00276722584764
# Updating fitness with value 1.3876892858233907
# Updating fitness with value 1.9326720282553342
# Updating fitness with value 1.3866800301831275
# 660 remaining budget and 14 running jobs
# Current pessimistic best is: MultiValue<mean: 0.05564198276972265, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 16.779326856661612, 'w_d': 0.003978554278246267, 'ramp': 0.06341836527660961})>
# Updating fitness with value 1.6091739564536451
# Updating fitness with value 1.0538903624048734
# Updating fitness with value 0.8269484242550589
# Updating fitness with value 1.5697193986664946
# Updating fitness with value 0.22579140240883155
# Updating fitness with value 1.9857685393836246
# Updating fitness with value 0.1985540405536247
# Updating fitness with value 0.8318061888446859
# Updating fitness with value 0.9998201274901979
# Updating fitness with value 1.277903127321123
# Updating fitness with value 1.3966481047593686
# 660 remaining budget and 3 running jobs
# Current pessimistic best is: MultiValue<mean: 0.05564198276972265, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 16.779326856661612, 'w_d': 0.003978554278246267, 'ramp': 0.06341836527660961})>
# Updating fitness with value 1.167212000315197
# Updating fitness with value 0.27683474117237616
# Updating fitness with value 0.2863537147008587
# 660 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.05564198276972265, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 16.779326856661612, 'w_d': 0.003978554278246267, 'ramp': 0.06341836527660961})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.9646969019982845
# 640 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.05564198276972265, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 16.779326856661612, 'w_d': 0.003978554278246267, 'ramp': 0.06341836527660961})>
# Updating fitness with value 1.6407598168199478
# 640 remaining budget and 18 running jobs
# Current pessimistic best is: MultiValue<mean: 0.05564198276972265, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 16.779326856661612, 'w_d': 0.003978554278246267, 'ramp': 0.06341836527660961})>
# Updating fitness with value 0.06861992066844413
# Updating fitness with value 1.793224134663392
# Updating fitness with value 1.21166989298394
# Updating fitness with value 1.2444763265522274
# Updating fitness with value 1.731091605232349
# Updating fitness with value 0.4993758671701829
# Updating fitness with value 1.9981305506767955
# Updating fitness with value 0.9566990326659228
# Updating fitness with value 1.5353715406031103
# 640 remaining budget and 9 running jobs
# Current pessimistic best is: MultiValue<mean: 0.05564198276972265, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 16.779326856661612, 'w_d': 0.003978554278246267, 'ramp': 0.06341836527660961})>
# Updating fitness with value 1.7214472256768785
# Updating fitness with value 0.2554733577250523
# Updating fitness with value 0.13157090624618129
# Updating fitness with value 1.5441563154772178
# Updating fitness with value 1.8411834951760873
# Updating fitness with value 1.9444500144387926
# Updating fitness with value 1.4409978579901126
# Updating fitness with value 0.6694570126057381
# 640 remaining budget and 1 running jobs
# Current pessimistic best is: MultiValue<mean: 0.05564198276972265, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 16.779326856661612, 'w_d': 0.003978554278246267, 'ramp': 0.06341836527660961})>
# Updating fitness with value 0.4358335880880062
# 640 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.05564198276972265, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 16.779326856661612, 'w_d': 0.003978554278246267, 'ramp': 0.06341836527660961})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.4420767038615923
# Updating fitness with value 0.7559744810032208
# Updating fitness with value 0.5170591422351632
# Updating fitness with value 0.020174963209946162
# Updating fitness with value 1.6892121450180955
# 620 remaining budget and 15 running jobs
# Current pessimistic best is: MultiValue<mean: 0.020174963209946162, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.39791303712563, 'w_d': 0.004363109793472696, 'ramp': 0.08739011717947566})>
# Updating fitness with value 1.0998431931178463
# 620 remaining budget and 14 running jobs
# Current pessimistic best is: MultiValue<mean: 0.020174963209946162, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.39791303712563, 'w_d': 0.004363109793472696, 'ramp': 0.08739011717947566})>
# Updating fitness with value 0.6107981292668796
# Updating fitness with value 1.1596907014514672
# Updating fitness with value 1.563381369121667
# Updating fitness with value 0.4381698840396011
# Updating fitness with value 0.9950732908857822
# Updating fitness with value 1.71012207283122
# 620 remaining budget and 8 running jobs
# Current pessimistic best is: MultiValue<mean: 0.020174963209946162, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.39791303712563, 'w_d': 0.004363109793472696, 'ramp': 0.08739011717947566})>
# Updating fitness with value 0.7080062470488804
# Updating fitness with value 0.8507099361312724
# Updating fitness with value 0.48003421892417864
# Updating fitness with value 1.6317262103432948
# Updating fitness with value 1.298251660932539
# Updating fitness with value 1.737467454021664
# Updating fitness with value 0.17281609518725327
# Updating fitness with value 0.34250251475466276
# 620 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.020174963209946162, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.39791303712563, 'w_d': 0.004363109793472696, 'ramp': 0.08739011717947566})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 1.4097351408541456
# 600 remaining budget and 19 running jobs
# Current pessimistic best is: MultiValue<mean: 0.020174963209946162, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(1,25,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 12.39791303712563, 'w_d': 0.004363109793472696, 'ramp': 0.08739011717947566})>
# Updating fitness with value 1.0158509650004663
# ...
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6172237654765069
# Updating fitness with value 0.6172240965602925
# Updating fitness with value 0.6172238407898326
# Updating fitness with value 0.6172238981415143
# Updating fitness with value 0.6172238386881923
# Updating fitness with value 0.6172244480400096
# Updating fitness with value 0.61722379436736
# Updating fitness with value 0.6172241990967464
# Updating fitness with value 0.6172238175458704
# 140 remaining budget and 11 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172235150917458, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.1246606070136815, 'w_d': 0.004953075056355395, 'ramp': 0.11681850817544535})>
# Updating fitness with value 0.6172245142159289
# Updating fitness with value 0.6172236542346362
# Updating fitness with value 0.6172245936298689
# Updating fitness with value 0.6172237564836003
# Updating fitness with value 0.6172240750828372
# Updating fitness with value 0.6172251186837227
# Updating fitness with value 0.6172236712518434
# Updating fitness with value 0.6172238387152634
# Updating fitness with value 0.6172242784122981
# Updating fitness with value 0.6172237182797293
# Updating fitness with value 0.6172237663935064
# 140 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172235150917458, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.1246606070136815, 'w_d': 0.004953075056355395, 'ramp': 0.11681850817544535})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6172237965584555
# Updating fitness with value 0.6172238079644377
# Updating fitness with value 0.6172238898335894
# Updating fitness with value 0.6172241599813685
# Updating fitness with value 0.6172237508924682
# Updating fitness with value 0.6172239704956737
# Updating fitness with value 0.6172242228643501
# 120 remaining budget and 13 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172235150917458, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.1246606070136815, 'w_d': 0.004953075056355395, 'ramp': 0.11681850817544535})>
# Updating fitness with value 0.6172246266929587
# Updating fitness with value 0.6172238857082333
# Updating fitness with value 0.6172240130692662
# Updating fitness with value 0.6172236715363547
# Updating fitness with value 0.617224326173294
# Updating fitness with value 0.6172240446692879
# Updating fitness with value 0.617224022515464
# Updating fitness with value 0.6172240195521149
# Updating fitness with value 0.6172239824680472
# Updating fitness with value 0.6172236207347848
# Updating fitness with value 0.6172240546851682
# Updating fitness with value 0.6172266108465356
# Updating fitness with value 0.6172237963837854
# 120 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172235150917458, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.1246606070136815, 'w_d': 0.004953075056355395, 'ramp': 0.11681850817544535})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6172236906776796
# Updating fitness with value 0.6172240791450399
# 100 remaining budget and 18 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172235150917458, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.1246606070136815, 'w_d': 0.004953075056355395, 'ramp': 0.11681850817544535})>
# Updating fitness with value 0.617223946901089
# Updating fitness with value 0.6172237837402565
# Updating fitness with value 0.6172234662019507
# Updating fitness with value 0.61722407671635
# Updating fitness with value 0.6172236101873949
# Updating fitness with value 0.6172237945688425
# Updating fitness with value 0.6172236043114891
# Updating fitness with value 0.6172240048399491
# Updating fitness with value 0.6172241984254739
# Updating fitness with value 0.6172242340222629
# Updating fitness with value 0.617223543125516
# Updating fitness with value 0.6172237646268715
# Updating fitness with value 0.6172236692505129
# Updating fitness with value 0.6172235721121834
# Updating fitness with value 0.6172235307059593
# Updating fitness with value 0.6172237155846975
# Updating fitness with value 0.6172238608709704
# Updating fitness with value 0.6172237560079693
# 100 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234662019507, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.124601770144736, 'w_d': 0.004953156060317686, 'ramp': 0.11679648262616417})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6172241467728208
# Updating fitness with value 0.6172237689681818
# 80 remaining budget and 18 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234662019507, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.124601770144736, 'w_d': 0.004953156060317686, 'ramp': 0.11679648262616417})>
# Updating fitness with value 0.6172241219008794
# Updating fitness with value 0.6172235542816135
# Updating fitness with value 0.6172238547789093
# Updating fitness with value 0.6172237477476287
# Updating fitness with value 0.6172239569822964
# Updating fitness with value 0.6172236629330583
# Updating fitness with value 0.6172234653006202
# Updating fitness with value 0.6172237207354001
# Updating fitness with value 0.6172234542054724
# Updating fitness with value 0.6172235553355636
# Updating fitness with value 0.6172235504220683
# Updating fitness with value 0.6172238479798599
# Updating fitness with value 0.6172237063295007
# Updating fitness with value 0.6172236500514751
# Updating fitness with value 0.6172235699645418
# Updating fitness with value 0.6172235433365617
# Updating fitness with value 0.617223866966148
# Updating fitness with value 0.6172236941956604
# 80 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234542054724, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.12462530080473, 'w_d': 0.004953135818355599, 'ramp': 0.11679392822854624})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6172239067969917
# Updating fitness with value 0.6172237373955577
# Updating fitness with value 0.6172236036689733
# Updating fitness with value 0.6172236008528561
# Updating fitness with value 0.6172235174621
# Updating fitness with value 0.6172236254447703
# Updating fitness with value 0.6172236272154685
# Updating fitness with value 0.6172240306364881
# Updating fitness with value 0.6172236768417603
# Updating fitness with value 0.6172235377626437
# Updating fitness with value 0.6172236341989357
# Updating fitness with value 0.6172235508939741
# 60 remaining budget and 8 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234542054724, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.12462530080473, 'w_d': 0.004953135818355599, 'ramp': 0.11679392822854624})>
# Updating fitness with value 0.6172235982236955
# Updating fitness with value 0.6172236141785579
# Updating fitness with value 0.6172235519123119
# Updating fitness with value 0.6172238657794092
# Updating fitness with value 0.61722369080287
# Updating fitness with value 0.617223895555039
# Updating fitness with value 0.6172235397687272
# Updating fitness with value 0.6172235706276563
# 60 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234542054724, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.12462530080473, 'w_d': 0.004953135818355599, 'ramp': 0.11679392822854624})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6172236059457533
# Updating fitness with value 0.617223577635127
# Updating fitness with value 0.6172234801145356
# Updating fitness with value 0.6172234709675705
# Updating fitness with value 0.6172236062324303
# Updating fitness with value 0.6172235351156559
# Updating fitness with value 0.6172235837103561
# 40 remaining budget and 13 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234542054724, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.12462530080473, 'w_d': 0.004953135818355599, 'ramp': 0.11679392822854624})>
# Updating fitness with value 0.6172237754953707
# 40 remaining budget and 12 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234542054724, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.12462530080473, 'w_d': 0.004953135818355599, 'ramp': 0.11679392822854624})>
# Updating fitness with value 0.6172237662252484
# Updating fitness with value 0.6172235961356682
# Updating fitness with value 0.6172235224444766
# Updating fitness with value 0.6172238197447035
# Updating fitness with value 0.6172235065399495
# Updating fitness with value 0.6172236703262872
# Updating fitness with value 0.6172235671161226
# Updating fitness with value 0.6172236525194614
# Updating fitness with value 0.6172236113693388
# Updating fitness with value 0.6172235736323878
# Updating fitness with value 0.6172236584439408
# Updating fitness with value 0.6172236199618162
# 40 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234542054724, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.12462530080473, 'w_d': 0.004953135818355599, 'ramp': 0.11679392822854624})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6172235367524058
# Updating fitness with value 0.6172235092423339
# Updating fitness with value 0.617223738090481
# Updating fitness with value 0.6172238011654886
# Updating fitness with value 0.6172235453668938
# Updating fitness with value 0.6172235440415301
# Updating fitness with value 0.617223501604067
# Updating fitness with value 0.6172235464634616
# Updating fitness with value 0.6172235947756545
# Updating fitness with value 0.6172235294690004
# Updating fitness with value 0.6172235379078084
# Updating fitness with value 0.6172235215336908
# Updating fitness with value 0.6172235246905712
# Updating fitness with value 0.617223522600755
# Updating fitness with value 0.6172236213483596
# 20 remaining budget and 5 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234542054724, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.12462530080473, 'w_d': 0.004953135818355599, 'ramp': 0.11679392822854624})>
# Updating fitness with value 0.6172236451858558
# Updating fitness with value 0.6172235359544401
# 20 remaining budget and 3 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234542054724, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.12462530080473, 'w_d': 0.004953135818355599, 'ramp': 0.11679392822854624})>
# Updating fitness with value 0.6172235435739877
# Updating fitness with value 0.617223540822848
# Updating fitness with value 0.6172237140156942
# 20 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234542054724, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.12462530080473, 'w_d': 0.004953135818355599, 'ramp': 0.11679392822854624})>
# Launching 20 jobs with new suggestions
# Updating fitness with value 0.6172235387685168
# Updating fitness with value 0.617223587201902
# Updating fitness with value 0.6172234484897188
# Updating fitness with value 0.617223534248825
# Updating fitness with value 0.6172235270342489
# Updating fitness with value 0.617223454342478
# Updating fitness with value 0.6172234762357657
# Updating fitness with value 0.6172234733479458
# Updating fitness with value 0.6172234534223033
# Updating fitness with value 0.6172236146353101
# Updating fitness with value 0.6172234172852941
# Updating fitness with value 0.6172236128486092
# Updating fitness with value 0.6172235249320767
# Updating fitness with value 0.617223566294061
# 0 remaining budget and 6 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234172852941, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.124627515893816, 'w_d': 0.0049531510711089705, 'ramp': 0.11679667204331352})>
# Updating fitness with value 0.6172235029262853
# Updating fitness with value 0.6172236436991927
# Updating fitness with value 0.6172235536787677
# Updating fitness with value 0.6172235064501826
# Updating fitness with value 0.6172235384429567
# Updating fitness with value 0.6172234703458406
# 0 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.6172234172852941, count: 1, parameter: Instrumentation(Tuple(),Dict(amp=Scalar{Cl(0.8800000000000001,22,b)}[sigma=Scalar{exp=2.03}],ramp=Scalar{Cl(1e-10,0.5,b)}[sigma=Scalar{exp=2.03}],w_d=Log{Cl(-18.372511079725303,-12.372511079725303,b),exp=1.37})):((), {'amp': 4.124627515893816, 'w_d': 0.0049531510711089705, 'ramp': 0.11679667204331352})>
# Best cost found: ((), {'amp': 4.124613950124525, 'w_d': 0.004953125824114393, 'ramp': 0.11679628940032613})
# Best amp: 4.124613950124525, best w_d: 0.004953125824114393, best ramp: 0.11679628940032613
